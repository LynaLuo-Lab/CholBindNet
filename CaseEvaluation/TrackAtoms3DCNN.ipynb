# %%
import numpy as np
import MDAnalysis as mda
from rdkit import Chem
from collections import defaultdict
from scipy.spatial import cKDTree
from heapq import heappush, heappop
import pandas as pd
from scipy.spatial.transform import Rotation as R

np.set_printoptions(linewidth=500)

grid = np.load("../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp1/Test/Positive/6PS5-filtered_grid_3.npy")
file = "../3DCNN/filtered-pdbs-distinct-5A/positive/6PS5-filtered.pdb"
#df = pd.read_csv('grad_cam_scores_sorted_6PS5_3.csv')

# %%
def create_grid(size=20, resolution=1):
    num_cells = int(size * resolution)
    grid = np.zeros((num_cells, num_cells, num_cells, 37))  # 23 features per grid point
    return grid

def pdb_to_dataframe(pdb_file):
    """
    Load a PDB file using MDAnalysis and convert key atom information to a pandas DataFrame.
    """
    u = mda.Universe(pdb_file)
    
    # Extract atom-related data: atom name, residue name, residue ID, and chain ID
    atom_data = {
        'Atom Name': u.atoms.names,
        'Residue Name': u.atoms.resnames,
        'Residue ID': u.atoms.resids,
        'Chain ID': u.atoms.segids,
        'X': u.atoms.positions[:, 0],
        'Y': u.atoms.positions[:, 1],
        'Z': u.atoms.positions[:, 2],
    }
    
    # Create a pandas DataFrame from the atom data
    df = pd.DataFrame(atom_data)
    
    return df

# Function to apply 3D rotation to atomic coordinates
def rotate_dataframe(df, rotation_matrix, origin='centroid', inplace=False):
    """
    Rotate coordinates in a PDB DataFrame.

    Parameters
    ----------
    df : pd.DataFrame
        Must have columns 'X','Y','Z' (float Å).
    rotation_matrix : (3,3) ndarray
        Proper rotation matrix.
    origin : {'centroid','mean', array-like of shape (3,), None}
        Point about which to rotate. 'centroid' (same as 'mean') subtracts the
        mean of coordinates before rotating, then adds it back. If an array is
        given, rotate about that fixed point. If None, rotate about (0,0,0).
    inplace : bool
        If True, updates df in place and returns df. Otherwise returns a copy.

    Returns
    -------
    pd.DataFrame
    """
    if not {'X','Y','Z'}.issubset(df.columns):
        raise ValueError("DataFrame must contain columns: 'X','Y','Z'.")

    # Choose working frame
    out = df if inplace else df.copy()

    # Extract coordinates (N,3)
    coords = out[['X','Y','Z']].to_numpy(dtype=float)

    # Determine rotation origin
    if origin in ('centroid', 'mean'):
        pivot = coords.mean(axis=0, keepdims=True)  # (1,3)
    elif origin is None:
        pivot = np.zeros((1,3), dtype=float)
    else:
        pivot = np.asarray(origin, dtype=float).reshape(1,3)

    # Rotate about pivot: (coords - pivot) @ R^T + pivot
    rotated = (coords - pivot) @ rotation_matrix.T + pivot

    # Write back
    out[['X','Y','Z']] = rotated
    return out

# Generate a random rotation matrix
def generate_random_rotation_matrix():
    # Generate a random 3D rotation using Euler angles
    rotation = R.from_euler('xyz', np.random.uniform(0, 360, size=3), degrees=True)
    return rotation.as_matrix()

BIGGEST_SET = [
    # Carbon (C) subtypes
    'C', 'CA', 'CB', 'CD', 'CD1', 'CD2', 'CE', 'CE1', 'CE2', 'CE3',
    'CG', 'CG1', 'CG2', 'CH2', 'CZ', 'CZ2', 'CZ3',

    # Oxygen (O) subtypes
    'O', 'OH', 'OD1', 'OD2', 'OE1', 'OE2', 'OG', 'OG1',

    # Nitrogen (N) subtypes
    'N', 'NE', 'NE1', 'NE2', 'ND1', 'ND2', 'NZ', 'NH1', 'NH2',

    # Sulfur (S) subtypes
    'SD', 'SG'
]
BIGGEST_SET.append('UNKNOWN')  # index for unknown atom names
ATOM_INDEX = {atom: i for i, atom in enumerate(BIGGEST_SET)}
ATOM_ONEHOT_DIM = len(BIGGEST_SET)  # 37 with the list above

def atom_one_hot_from_name(atom_name: str) -> np.ndarray:
    vec = np.zeros(ATOM_ONEHOT_DIM, dtype=float)
    key = (atom_name or "").strip().upper()
    idx = ATOM_INDEX.get(key, ATOM_INDEX['UNKNOWN'])
    vec[idx] = 1.0
    if key not in ATOM_INDEX:
        print(atom_name, "went to unknown column")
    return vec

def find_nearest_empty(grid: np.ndarray, gc: np.ndarray, G: int, max_radius: int = None):
    """
    Find the nearest empty voxel to gc by expanding L∞ shells.
    Returns a tuple (x,y,z) or None if none found within max_radius.
    """
    x0, y0, z0 = map(int, gc)
    if max_radius is None:
        max_radius = G  # worst-case fallback

    # If target is already empty, use it
    if 0 <= x0 < G and 0 <= y0 < G and 0 <= z0 < G and not np.any(grid[x0, y0, z0]):
        return (x0, y0, z0)

    for r in range(1, max_radius + 1):
        xmin, xmax = max(0, x0 - r), min(G - 1, x0 + r)
        ymin, ymax = max(0, y0 - r), min(G - 1, y0 + r)
        zmin, zmax = max(0, z0 - r), min(G - 1, z0 + r)

        best_cell = None
        best_d2 = np.inf

        # Scan only the shell (any coord on the boundary of the cube)
        for x in range(xmin, xmax + 1):
            for y in range(ymin, ymax + 1):
                for z in range(zmin, zmax + 1):
                    if not (x in (xmin, xmax) or y in (ymin, ymax) or z in (zmin, zmax)):
                        continue
                    if not np.any(grid[x, y, z]):
                        d2 = (x - x0) ** 2 + (y - y0) ** 2 + (z - z0) ** 2
                        if d2 < best_d2:
                            best_d2 = d2
                            best_cell = (x, y, z)

        if best_cell is not None:
            return best_cell

    return None

def one_hot_to_subtype(vec: np.ndarray) -> tuple[str, int]:
    """
    Convert a 37-d one-hot vector to (subtype_str, index).
    If multiple/non-binary entries exist, uses argmax. If all zeros, returns ('UNKNOWN', ATOM_INDEX['UNKNOWN']).
    """
    vec = np.asarray(vec).ravel()
    if vec.size != ATOM_ONEHOT_DIM:
        raise ValueError(f"Expected one-hot length {ATOM_ONEHOT_DIM}, got {vec.size}")
    idx = int(np.argmax(vec))
    # handle all-zero explicitly
    if vec[idx] <= 0:
        idx = ATOM_INDEX['UNKNOWN']
    return BIGGEST_SET[idx], idx

# Map atoms to the grid based on their 3D coordinates
def map_atoms_to_grid(df, grid, grid_center, grid_size=20, resolution=1):
    # Compute bounds for min max normalization
    coords = df[['X','Y','Z']].to_numpy(dtype=float)
    min_coords = np.min(coords, axis=0)
    shifted = coords - min_coords

    grid_to_atom_map = {}
    
    for idx, row in df.iterrows():
        spos = shifted[idx]
        gc = np.rint(spos).astype(int)

        # Try rint cell first
        target = None
        if 0 <= gc[0] < grid_size and 0 <= gc[1] < grid_size and 0 <= gc[2] < grid_size and not np.any(grid[tuple(gc)]):
            target = tuple(gc)
        else:
            # Find nearest empty voxel
            target = find_nearest_empty(grid, gc, grid_size, max_radius=2)

        if target is None:
            raise Exception(f"Atom at df index {idx} could not be placed (no empty voxel found).")
        
        atom_feat = atom_one_hot_from_name(row['Atom Name'])

        grid[target] = atom_feat

        subtype_str, subtype_idx = one_hot_to_subtype(atom_feat)

        grid_to_atom_map[target] = {
            "atom_id": int(idx) + 1,      # or use original PDB serial if you have it
            "atom_subtype": subtype_str,   # e.g., 'CA', 'OD2', 'NZ', 'UNKNOWN', ...
            "subtype_index": subtype_idx   # optional, handy for debugging
        }

    return grid, grid_to_atom_map

# Main function to generate multiple rotated grids
def generate_non_rotated_grid(grid_center, filtered_pdb_path, grid_size=30, resolution=1):
    pdb_df = pdb_to_dataframe(filtered_pdb_path)

    # Create a new grid
    grid = create_grid(size=grid_size, resolution=resolution)
    
    # Generate a random rotation matrix
    rotation_matrix = generate_random_rotation_matrix()
    
    # Rotate the molecule
    rotated_pdb_df = rotate_dataframe(pdb_df, rotation_matrix)
    
    # Map rotated atoms to the grid
    grid = map_atoms_to_grid(rotated_pdb_df, grid, grid_center, grid_size, resolution)
    
    return grid

# %%
def _index_to_subtype(idx: int) -> str:
    if 0 <= idx < len(BIGGEST_SET):
        return BIGGEST_SET[idx]
    return 'UNKNOWN'

def print_features(features: np.ndarray):
    """
    Expect a 37-dim one-hot vector over atom subtypes (BIGGEST_SET order).
    Prints only the chosen atom subtype.
    """
    features = np.asarray(features).ravel()
    if features.size != ATOM_ONEHOT_DIM:
        raise ValueError(f"Expected feature length {ATOM_ONEHOT_DIM}, got {features.size}")

    hot_idxs = np.where(features > 0.5)[0]

    if len(hot_idxs) == 0:
        subtype = 'UNKNOWN'
    elif len(hot_idxs) == 1:
        subtype = _index_to_subtype(int(hot_idxs[0]))
    else:
        # Multiple hots, pick argmax but warn
        subtype = _index_to_subtype(int(np.argmax(features)))
        print("Warning: multiple hot indices detected; used argmax.")

    print(f"Atom subtype: {subtype}\n")

def get_atom_subtype(features: np.ndarray):
    features = np.asarray(features).ravel()
    if features.size != ATOM_ONEHOT_DIM:
        raise ValueError(f"Expected feature length {ATOM_ONEHOT_DIM}, got {features.size}")

    hot_idxs = np.where(features > 0.5)[0]
    if len(hot_idxs) == 0:
        subtype = 'UNKNOWN'
    else:
        subtype = _index_to_subtype(int(np.argmax(features)))

    return subtype

# %%
grid_center = np.array([0, 0, 0])  # Grid center at origin

non_rotated_grid, mapped_grid = generate_non_rotated_grid(grid_center, file)

print(f"Grid shape: {non_rotated_grid.shape}")  # Should be (x, y, z, features)

# Compute sum of absolute feature values at each (x, y, z)
non_zero_mask = np.sum(np.abs(non_rotated_grid), axis=3) != 0  # Shape: (x, y, z)

# Find coordinates where at least one feature is non-zero
non_zero_coords = np.argwhere(non_zero_mask)

print(f"Total non-zero grid points: {non_zero_coords.shape[0]}\n")

number_of_atom_type_matches = 0

for coord in non_zero_coords:
    x, y, z = coord
    features = non_rotated_grid[x, y, z, :]
    grid_atom_type = get_atom_subtype(features)

    atom_info = mapped_grid.get((x, y, z))
    if not atom_info:
        print(f"WARNING: Grid coordinate ({x},{y},{z}) has no mapped atom!")
        continue

    # Compare atom type
    atom_type_match = (atom_info["atom_subtype"] == grid_atom_type)

    if atom_type_match:
        number_of_atom_type_matches += 1

    print(f"Grid ({x},{y},{z}) --> Atom ID {atom_info['atom_id']}, Type {atom_info['atom_subtype']}")
    print(f"   Grid Feature Atom Type: {grid_atom_type}, Match: {atom_type_match}")

# Final summary
total_points = len(non_zero_coords)
print(f"\nSummary:")
print(f"Correct Atom Type Matches: {number_of_atom_type_matches}/{total_points}")
# Out:
# Grid shape: (30, 30, 30, 37)
# Total non-zero grid points: 56
#
# Grid (0,14,5) --> Atom ID 29, Type CD2
#    Grid Feature Atom Type: CD2, Match: True
# Grid (1,19,8) --> Atom ID 28, Type CG2
#    Grid Feature Atom Type: CG2, Match: True
# Grid (3,8,4) --> Atom ID 47, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (3,11,6) --> Atom ID 53, Type CE3
#    Grid Feature Atom Type: CE3, Match: True
# Grid (4,9,5) --> Atom ID 48, Type CG
#    Grid Feature Atom Type: CG, Match: True
# Grid (4,10,6) --> Atom ID 50, Type CD2
#    Grid Feature Atom Type: CD2, Match: True
# Grid (4,12,7) --> Atom ID 55, Type CZ3
#    Grid Feature Atom Type: CZ3, Match: True
# Grid (5,5,2) --> Atom ID 44, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (5,5,5) --> Atom ID 40, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (5,8,6) --> Atom ID 49, Type CD1
#    Grid Feature Atom Type: CD1, Match: True
# Grid (5,8,7) --> Atom ID 51, Type NE1
#    Grid Feature Atom Type: NE1, Match: True
# Grid (5,10,7) --> Atom ID 52, Type CE2
#    Grid Feature Atom Type: CE2, Match: True
# Grid (5,11,8) --> Atom ID 54, Type CZ2
#    Grid Feature Atom Type: CZ2, Match: True
# Grid (5,12,8) --> Atom ID 56, Type CH2
#    Grid Feature Atom Type: CH2, Match: True
# Grid (5,18,8) --> Atom ID 26, Type CG1
#    Grid Feature Atom Type: CG1, Match: True
# Grid (6,17,9) --> Atom ID 25, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (7,5,0) --> Atom ID 45, Type CG
#    Grid Feature Atom Type: CG, Match: True
# Grid (7,7,9) --> Atom ID 22, Type OG
#    Grid Feature Atom Type: OG, Match: True
# Grid (7,10,10) --> Atom ID 20, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (7,17,8) --> Atom ID 27, Type CG2
#    Grid Feature Atom Type: CG2, Match: True
# Grid (8,2,2) --> Atom ID 32, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (8,4,6) --> Atom ID 41, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (8,5,1) --> Atom ID 46, Type CD1
#    Grid Feature Atom Type: CD1, Match: True
# Grid (8,5,6) --> Atom ID 42, Type CG2
#    Grid Feature Atom Type: CG2, Match: True
# Grid (8,7,9) --> Atom ID 21, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (8,9,11) --> Atom ID 19, Type C
#    Grid Feature Atom Type: C, Match: True
# Grid (9,1,2) --> Atom ID 31, Type C
#    Grid Feature Atom Type: C, Match: True
# Grid (9,8,10) --> Atom ID 18, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (9,12,9) --> Atom ID 23, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (10,1,3) --> Atom ID 30, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (10,3,7) --> Atom ID 43, Type CD1
#    Grid Feature Atom Type: CD1, Match: True
# Grid (10,8,10) --> Atom ID 17, Type N
#    Grid Feature Atom Type: N, Match: True
# Grid (11,1,2) --> Atom ID 33, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (11,8,10) --> Atom ID 13, Type C
#    Grid Feature Atom Type: C, Match: True
# Grid (11,10,10) --> Atom ID 14, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (11,12,8) --> Atom ID 24, Type SG
#    Grid Feature Atom Type: SG, Match: True
# Grid (12,4,10) --> Atom ID 2, Type C
#    Grid Feature Atom Type: C, Match: True
# Grid (12,5,9) --> Atom ID 3, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (13,2,2) --> Atom ID 34, Type CG
#    Grid Feature Atom Type: CG, Match: True
# Grid (13,2,8) --> Atom ID 4, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (13,3,9) --> Atom ID 1, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (13,8,11) --> Atom ID 12, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (14,2,1) --> Atom ID 35, Type CD
#    Grid Feature Atom Type: CD, Match: True
# Grid (14,7,10) --> Atom ID 15, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (14,8,9) --> Atom ID 16, Type CG2
#    Grid Feature Atom Type: CG2, Match: True
# Grid (15,1,7) --> Atom ID 7, Type CD2
#    Grid Feature Atom Type: CD2, Match: True
# Grid (15,2,2) --> Atom ID 36, Type NE
#    Grid Feature Atom Type: NE, Match: True
# Grid (15,2,8) --> Atom ID 5, Type CG
#    Grid Feature Atom Type: CG, Match: True
# Grid (16,0,2) --> Atom ID 38, Type NH1
#    Grid Feature Atom Type: NH1, Match: True
# Grid (16,1,2) --> Atom ID 37, Type CZ
#    Grid Feature Atom Type: CZ, Match: True
# Grid (16,1,6) --> Atom ID 9, Type CE2
#    Grid Feature Atom Type: CE2, Match: True
# Grid (16,3,8) --> Atom ID 6, Type CD1
#    Grid Feature Atom Type: CD1, Match: True
# Grid (17,2,2) --> Atom ID 39, Type NH2
#    Grid Feature Atom Type: NH2, Match: True
# Grid (17,2,6) --> Atom ID 10, Type CZ
#    Grid Feature Atom Type: CZ, Match: True
# Grid (17,3,7) --> Atom ID 8, Type CE1
#    Grid Feature Atom Type: CE1, Match: True
# Grid (18,1,5) --> Atom ID 11, Type OH
#    Grid Feature Atom Type: OH, Match: True
#
# Summary:
# Correct Atom Type Matches: 56/56

# %%
print(f"Grid shape: {grid.shape}")  # Should be (x, y, z, features)

# Compute sum of absolute feature values at each (x, y, z)
non_zero_mask = np.sum(np.abs(grid), axis=3) != 0  # Shape: (x, y, z)

# Find coordinates where at least one feature is non-zero
non_zero_coords = np.argwhere(non_zero_mask)

print(f"Total non-zero grid points: {non_zero_coords.shape[0]}\n")

# Print coordinates
for coord in non_zero_coords:
    x, y, z = coord
    features = grid[x, y, z, :]
    
    # print(f"(x={x}, y={y}, z={z})")
    print_features(features)
# Out:
# Grid shape: (30, 30, 30, 37)
# Total non-zero grid points: 56
#
# Atom subtype: CG1
#
# Atom subtype: CB
#
# Atom subtype: CG2
#
# Atom subtype: CG2
#
# Atom subtype: SG
#
# Atom subtype: CB
#
# Atom subtype: CG2
#
# Atom subtype: O
#
# Atom subtype: CB
#
# Atom subtype: C
#
# Atom subtype: CA
#
# Atom subtype: CD2
#
# Atom subtype: CZ3
#
# Atom subtype: CH2
#
# Atom subtype: CZ2
#
# Atom subtype: O
#
# Atom subtype: C
#
# Atom subtype: N
#
# Atom subtype: CE1
#
# Atom subtype: CE3
#
# Atom subtype: CD2
#
# Atom subtype: CE2
#
# Atom subtype: CA
#
# Atom subtype: CD1
#
# Atom subtype: NH2
#
# Atom subtype: CZ
#
# Atom subtype: OH
#
# Atom subtype: CG
#
# Atom subtype: NE1
#
# Atom subtype: CB
#
# Atom subtype: O
#
# Atom subtype: C
#
# Atom subtype: CA
#
# Atom subtype: NE
#
# Atom subtype: CG
#
# Atom subtype: CZ
#
# Atom subtype: CB
#
# Atom subtype: CD1
#
# Atom subtype: OG
#
# Atom subtype: CD1
#
# Atom subtype: CG2
#
# Atom subtype: CG
#
# Atom subtype: CD
#
# Atom subtype: CB
#
# Atom subtype: NH1
#
# Atom subtype: CD2
#
# Atom subtype: CE2
#
# Atom subtype: CG
#
# Atom subtype: CD1
#
# Atom subtype: CB
#
# Atom subtype: CA
#
# Atom subtype: O
#
# Atom subtype: CB
#
# Atom subtype: O
#
# Atom subtype: CA
#
# Atom subtype: C

# %%
# Non-zero coordinates in rotated grid
non_zero_coords_rot = np.argwhere(np.sum(np.abs(grid), axis=3) != 0)

# Non-zero coordinates in non-rotated grid
non_zero_coords_non_rot = np.argwhere(np.sum(np.abs(non_rotated_grid), axis=3) != 0)

# Build feature lookup dictionaries
features_rot_dict = {tuple(coord): grid[tuple(coord)][...] for coord in non_zero_coords_rot}
features_non_rot_dict = {tuple(coord): non_rotated_grid[tuple(coord)][...] for coord in non_zero_coords_non_rot}

# Build KD-Trees for fast neighbor lookup
tree_rot = cKDTree(non_zero_coords_rot)
tree_non_rot = cKDTree(non_zero_coords_non_rot)

# Build feature to coords lookup for non-rotated grid
feature_to_coord_non_rot = defaultdict(list)
for coord in non_zero_coords_non_rot:
    feature_key = tuple(np.round(non_rotated_grid[tuple(coord)], 5))
    feature_to_coord_non_rot[feature_key].append(tuple(coord))

mapped_non_rot_coords = {}

# %%
match_candidates = []

for coord_rot in non_zero_coords_rot:
    feature_key = tuple(np.round(grid[tuple(coord_rot)], 5))
    candidate_coords = feature_to_coord_non_rot.get(feature_key, [])
    print("Potential Candidates:")
    print(coord_rot, ":", candidate_coords)

    dists_rot, idxs_rot = tree_rot.query(coord_rot, k=11)
    neighbors_rot = [tuple(non_zero_coords_rot[i]) for i in idxs_rot if not np.array_equal(non_zero_coords_rot[i], coord_rot)]
    dists_rot = [d for i, d in zip(idxs_rot, dists_rot) if not np.array_equal(non_zero_coords_rot[i], coord_rot)]

    for coord_non_rot in candidate_coords:
        dists_non_rot, idxs_non_rot = tree_non_rot.query(coord_non_rot, k=11)
        neighbors_non_rot = [tuple(non_zero_coords_non_rot[i]) for i in idxs_non_rot if not np.array_equal(non_zero_coords_non_rot[i], coord_non_rot)]
        dists_non_rot = [d for i, d in zip(idxs_non_rot, dists_non_rot) if not np.array_equal(non_zero_coords_non_rot[i], coord_non_rot)]

        # Compare neighbor features with distance weighting
        score = 0
        for n_rot, dist_rot in zip(neighbors_rot, dists_rot):
            f_rot = np.round(features_rot_dict[n_rot], 5)

            for n_non_rot, dist_non_rot in zip(neighbors_non_rot, dists_non_rot):
                f_non_rot = np.round(features_non_rot_dict[n_non_rot], 5)

                if np.allclose(f_rot, f_non_rot, atol=1e-5):
                    weight = 1.0 / (1.0 + (dist_rot + dist_non_rot) / 2.0)
                    score += weight
                    break

        if score >= 0.5:
            heappush(match_candidates, (-score, tuple(coord_rot), tuple(coord_non_rot)))

# Finalize unique best matches
mapped_non_rot_coords = {}
used_rot = set()
used_non_rot = set()
number_of_confident_matches = 0

while match_candidates:
    neg_score, coord_rot, coord_non_rot = heappop(match_candidates)
    score = -neg_score

    if coord_rot not in used_rot and coord_non_rot not in used_non_rot:
        print(f"Confident match: Rotated {coord_rot} <--> Non-rotated {coord_non_rot} with score {score:.2f}\n")
        mapped_non_rot_coords[coord_rot] = coord_non_rot
        used_rot.add(coord_rot)
        used_non_rot.add(coord_non_rot)
        number_of_confident_matches += 1

print("Number of Confident Matches are", number_of_confident_matches)
# Out:
# Potential Candidates:
# [0 4 9] : [(5, 18, 8)]
# Potential Candidates:
# [ 0  5 10] : [(3, 8, 4), (6, 17, 9), (8, 4, 6), (8, 7, 9), (9, 12, 9), (11, 1, 2), (13, 2, 8), (14, 7, 10)]
# Potential Candidates:
# [0 6 8] : [(1, 19, 8), (7, 17, 8), (8, 5, 6), (14, 8, 9)]
# Potential Candidates:
# [1 0 9] : [(1, 19, 8), (7, 17, 8), (8, 5, 6), (14, 8, 9)]
# Potential Candidates:
# [ 2 12  8] : [(11, 12, 8)]
# Potential Candidates:
# [ 3 11  9] : [(3, 8, 4), (6, 17, 9), (8, 4, 6), (8, 7, 9), (9, 12, 9), (11, 1, 2), (13, 2, 8), (14, 7, 10)]
# Potential Candidates:
# [ 3 17  8] : [(1, 19, 8), (7, 17, 8), (8, 5, 6), (14, 8, 9)]
# Potential Candidates:
# [ 4 14 10] : [(5, 5, 5), (7, 10, 10), (8, 2, 2), (11, 10, 10), (12, 5, 9)]
# Potential Candidates:
# [ 4 17  9] : [(3, 8, 4), (6, 17, 9), (8, 4, 6), (8, 7, 9), (9, 12, 9), (11, 1, 2), (13, 2, 8), (14, 7, 10)]
# Potential Candidates:
# [ 5 15 10] : [(8, 9, 11), (9, 1, 2), (11, 8, 10), (12, 4, 10)]
# Potential Candidates:
# [ 5 16 11] : [(5, 5, 2), (9, 8, 10), (10, 1, 3), (13, 3, 9), (13, 8, 11)]
# Potential Candidates:
# [6 2 6] : [(0, 14, 5), (4, 10, 6), (15, 1, 7)]
# Potential Candidates:
# [6 6 8] : [(4, 12, 7)]
# Potential Candidates:
# [6 7 8] : [(5, 12, 8)]
# Potential Candidates:
# [6 8 8] : [(5, 11, 8)]
# Potential Candidates:
# [ 6 11 11] : [(5, 5, 5), (7, 10, 10), (8, 2, 2), (11, 10, 10), (12, 5, 9)]
# Potential Candidates:
# [ 6 12 11] : [(8, 9, 11), (9, 1, 2), (11, 8, 10), (12, 4, 10)]
# Potential Candidates:
# [ 6 14 10] : [(10, 8, 10)]
# Potential Candidates:
# [ 6 22  6] : [(17, 3, 7)]
# Potential Candidates:
# [7 6 7] : [(3, 11, 6)]
# Potential Candidates:
# [7 7 7] : [(0, 14, 5), (4, 10, 6), (15, 1, 7)]
# Potential Candidates:
# [7 8 8] : [(5, 10, 7), (16, 1, 6)]
# Potential Candidates:
# [ 7 13 10] : [(5, 5, 2), (9, 8, 10), (10, 1, 3), (13, 3, 9), (13, 8, 11)]
# Potential Candidates:
# [ 7 21  7] : [(5, 8, 6), (8, 5, 1), (10, 3, 7), (16, 3, 8)]
# Potential Candidates:
# [ 7 23  2] : [(17, 2, 2)]
# Potential Candidates:
# [ 7 23  5] : [(16, 1, 2), (17, 2, 6)]
# Potential Candidates:
# [ 7 24  4] : [(18, 1, 5)]
# Potential Candidates:
# [8 8 6] : [(4, 9, 5), (7, 5, 0), (13, 2, 2), (15, 2, 8)]
# Potential Candidates:
# [8 9 7] : [(5, 8, 7)]
# Potential Candidates:
# [ 8 13  9] : [(3, 8, 4), (6, 17, 9), (8, 4, 6), (8, 7, 9), (9, 12, 9), (11, 1, 2), (13, 2, 8), (14, 7, 10)]
# Potential Candidates:
# [ 8 17  9] : [(5, 5, 5), (7, 10, 10), (8, 2, 2), (11, 10, 10), (12, 5, 9)]
# Potential Candidates:
# [ 8 18  9] : [(8, 9, 11), (9, 1, 2), (11, 8, 10), (12, 4, 10)]
# Potential Candidates:
# [ 8 19  9] : [(5, 5, 2), (9, 8, 10), (10, 1, 3), (13, 3, 9), (13, 8, 11)]
# Potential Candidates:
# [ 8 20  1] : [(15, 2, 2)]
# Potential Candidates:
# [ 8 21  7] : [(4, 9, 5), (7, 5, 0), (13, 2, 2), (15, 2, 8)]
# Potential Candidates:
# [ 8 22  1] : [(16, 1, 2), (17, 2, 6)]
# Potential Candidates:
# [9 7 5] : [(3, 8, 4), (6, 17, 9), (8, 4, 6), (8, 7, 9), (9, 12, 9), (11, 1, 2), (13, 2, 8), (14, 7, 10)]
# Potential Candidates:
# [9 9 6] : [(5, 8, 6), (8, 5, 1), (10, 3, 7), (16, 3, 8)]
# Potential Candidates:
# [ 9 12  9] : [(7, 7, 9)]
# Potential Candidates:
# [ 9 13  1] : [(5, 8, 6), (8, 5, 1), (10, 3, 7), (16, 3, 8)]
# Potential Candidates:
# [ 9 13  6] : [(1, 19, 8), (7, 17, 8), (8, 5, 6), (14, 8, 9)]
# Potential Candidates:
# [ 9 19  2] : [(4, 9, 5), (7, 5, 0), (13, 2, 2), (15, 2, 8)]
# Potential Candidates:
# [ 9 20  1] : [(14, 2, 1)]
# Potential Candidates:
# [ 9 20  8] : [(3, 8, 4), (6, 17, 9), (8, 4, 6), (8, 7, 9), (9, 12, 9), (11, 1, 2), (13, 2, 8), (14, 7, 10)]
# Potential Candidates:
# [ 9 22  1] : [(16, 0, 2)]
# Potential Candidates:
# [ 9 22  6] : [(0, 14, 5), (4, 10, 6), (15, 1, 7)]
# Potential Candidates:
# [ 9 23  5] : [(5, 10, 7), (16, 1, 6)]
# Potential Candidates:
# [10 12  0] : [(4, 9, 5), (7, 5, 0), (13, 2, 2), (15, 2, 8)]
# Potential Candidates:
# [10 16  7] : [(5, 8, 6), (8, 5, 1), (10, 3, 7), (16, 3, 8)]
# Potential Candidates:
# [10 18  1] : [(3, 8, 4), (6, 17, 9), (8, 4, 6), (8, 7, 9), (9, 12, 9), (11, 1, 2), (13, 2, 8), (14, 7, 10)]
# Potential Candidates:
# [11 11  2] : [(5, 5, 2), (9, 8, 10), (10, 1, 3), (13, 3, 9), (13, 8, 11)]
# Potential Candidates:
# [11 11  5] : [(5, 5, 5), (7, 10, 10), (8, 2, 2), (11, 10, 10), (12, 5, 9)]
# Potential Candidates:
# [11 14  6] : [(3, 8, 4), (6, 17, 9), (8, 4, 6), (8, 7, 9), (9, 12, 9), (11, 1, 2), (13, 2, 8), (14, 7, 10)]
# Potential Candidates:
# [11 15  2] : [(5, 5, 5), (7, 10, 10), (8, 2, 2), (11, 10, 10), (12, 5, 9)]
# Potential Candidates:
# [11 17  2] : [(5, 5, 2), (9, 8, 10), (10, 1, 3), (13, 3, 9), (13, 8, 11)]
# Potential Candidates:
# [12 16  2] : [(8, 9, 11), (9, 1, 2), (11, 8, 10), (12, 4, 10)]
# Confident match: Rotated (6, 14, 10) <--> Non-rotated (10, 8, 10) with score 3.25
#
# Confident match: Rotated (7, 8, 8) <--> Non-rotated (5, 10, 7) with score 3.16
#
# Confident match: Rotated (7, 7, 7) <--> Non-rotated (4, 10, 6) with score 3.06
#
# Confident match: Rotated (6, 8, 8) <--> Non-rotated (5, 11, 8) with score 3.02
#
# Confident match: Rotated (5, 15, 10) <--> Non-rotated (11, 8, 10) with score 2.94
#
# Confident match: Rotated (7, 6, 7) <--> Non-rotated (3, 11, 6) with score 2.93
#
# Confident match: Rotated (8, 8, 6) <--> Non-rotated (4, 9, 5) with score 2.93
#
# Confident match: Rotated (6, 7, 8) <--> Non-rotated (5, 12, 8) with score 2.92
#
# Confident match: Rotated (8, 21, 7) <--> Non-rotated (15, 2, 8) with score 2.86
#
# Confident match: Rotated (7, 13, 10) <--> Non-rotated (9, 8, 10) with score 2.75
#
# Confident match: Rotated (8, 22, 1) <--> Non-rotated (16, 1, 2) with score 2.73
#
# Confident match: Rotated (7, 21, 7) <--> Non-rotated (16, 3, 8) with score 2.72
#
# Confident match: Rotated (9, 23, 5) <--> Non-rotated (16, 1, 6) with score 2.71
#
# Confident match: Rotated (8, 17, 9) <--> Non-rotated (12, 5, 9) with score 2.67
#
# Confident match: Rotated (6, 6, 8) <--> Non-rotated (4, 12, 7) with score 2.67
#
# Confident match: Rotated (4, 14, 10) <--> Non-rotated (11, 10, 10) with score 2.64
#
# Confident match: Rotated (9, 22, 1) <--> Non-rotated (16, 0, 2) with score 2.63
#
# Confident match: Rotated (8, 18, 9) <--> Non-rotated (12, 4, 10) with score 2.62
#
# Confident match: Rotated (9, 20, 1) <--> Non-rotated (14, 2, 1) with score 2.61
#
# Confident match: Rotated (5, 16, 11) <--> Non-rotated (13, 8, 11) with score 2.61
#
# Confident match: Rotated (6, 22, 6) <--> Non-rotated (17, 3, 7) with score 2.61
#
# Confident match: Rotated (6, 12, 11) <--> Non-rotated (8, 9, 11) with score 2.59
#
# Confident match: Rotated (8, 20, 1) <--> Non-rotated (15, 2, 2) with score 2.56
#
# Confident match: Rotated (9, 12, 9) <--> Non-rotated (7, 7, 9) with score 2.56
#
# Confident match: Rotated (9, 20, 8) <--> Non-rotated (13, 2, 8) with score 2.56
#
# Confident match: Rotated (7, 23, 5) <--> Non-rotated (17, 2, 6) with score 2.56
#
# Confident match: Rotated (9, 19, 2) <--> Non-rotated (13, 2, 2) with score 2.53
#
# Confident match: Rotated (4, 17, 9) <--> Non-rotated (14, 7, 10) with score 2.52
#
# Confident match: Rotated (8, 19, 9) <--> Non-rotated (13, 3, 9) with score 2.50
#
# Confident match: Rotated (11, 17, 2) <--> Non-rotated (10, 1, 3) with score 2.50
#
# Confident match: Rotated (8, 13, 9) <--> Non-rotated (8, 7, 9) with score 2.50
#
# Confident match: Rotated (7, 23, 2) <--> Non-rotated (17, 2, 2) with score 2.50
#
# Confident match: Rotated (6, 11, 11) <--> Non-rotated (7, 10, 10) with score 2.49
#
# Confident match: Rotated (12, 16, 2) <--> Non-rotated (9, 1, 2) with score 2.48
#
# Confident match: Rotated (7, 24, 4) <--> Non-rotated (18, 1, 5) with score 2.45
#
# Confident match: Rotated (11, 15, 2) <--> Non-rotated (8, 2, 2) with score 2.40
#
# Confident match: Rotated (8, 9, 7) <--> Non-rotated (5, 8, 7) with score 2.39
#
# Confident match: Rotated (9, 13, 6) <--> Non-rotated (8, 5, 6) with score 2.37
#
# Confident match: Rotated (9, 9, 6) <--> Non-rotated (5, 8, 6) with score 2.35
#
# Confident match: Rotated (9, 22, 6) <--> Non-rotated (15, 1, 7) with score 2.34
#
# Confident match: Rotated (10, 18, 1) <--> Non-rotated (11, 1, 2) with score 2.25
#
# Confident match: Rotated (10, 16, 7) <--> Non-rotated (10, 3, 7) with score 2.19
#
# Confident match: Rotated (9, 13, 1) <--> Non-rotated (8, 5, 1) with score 2.17
#
# Confident match: Rotated (3, 11, 9) <--> Non-rotated (9, 12, 9) with score 2.12
#
# Confident match: Rotated (11, 11, 5) <--> Non-rotated (5, 5, 5) with score 2.11
#
# Confident match: Rotated (9, 7, 5) <--> Non-rotated (3, 8, 4) with score 2.11
#
# Confident match: Rotated (11, 11, 2) <--> Non-rotated (5, 5, 2) with score 2.06
#
# Confident match: Rotated (3, 17, 8) <--> Non-rotated (14, 8, 9) with score 2.05
#
# Confident match: Rotated (10, 12, 0) <--> Non-rotated (7, 5, 0) with score 2.04
#
# Confident match: Rotated (11, 14, 6) <--> Non-rotated (8, 4, 6) with score 2.03
#
# Confident match: Rotated (0, 4, 9) <--> Non-rotated (5, 18, 8) with score 1.87
#
# Confident match: Rotated (2, 12, 8) <--> Non-rotated (11, 12, 8) with score 1.84
#
# Confident match: Rotated (0, 5, 10) <--> Non-rotated (6, 17, 9) with score 1.65
#
# Confident match: Rotated (0, 6, 8) <--> Non-rotated (7, 17, 8) with score 1.58
#
# Confident match: Rotated (6, 2, 6) <--> Non-rotated (0, 14, 5) with score 1.47
#
# Confident match: Rotated (1, 0, 9) <--> Non-rotated (1, 19, 8) with score 1.26
#
# Number of Confident Matches are 56

# %%
print(mapped_non_rot_coords)

number_of_atom_type_matches = 0

valid_coords = []
for coord in non_zero_coords_rot:
    x, y, z = coord
    valid_coords.append((x, y, z))

data = []

# print(f"Number of valid gridpoints with score >= {threshold} and non-zero voxel: {len(valid_coords)}")
# print("\nGrad-CAM scores for valid coordinates:")
for coord in valid_coords:
    x, y, z = coord
    data.append({'x': x, 'y': y, 'z': z})

df = pd.DataFrame(data)

# Loop through rows
for index, row in df.iterrows():
    x = int(row['x'])
    y = int(row['y'])
    z = int(row['z'])

    grid_features = grid[x, y, z, :]
    grid_atom_type = get_atom_subtype(grid_features)

    mapped_coord = mapped_non_rot_coords.get((x, y, z))
    mapped_x, mapped_y, mapped_z = mapped_coord    
    atom_info = mapped_grid.get((mapped_x, mapped_y, mapped_z))

    # Compare atom type
    atom_type_match = (atom_info["atom_subtype"] == grid_atom_type)

    if atom_type_match:
        number_of_atom_type_matches += 1
    
    print(f"Grid ({x},{y},{z}) --> Atom ID {atom_info['atom_id']}, Type {atom_info['atom_subtype']}")
    print(f"   Grid Feature Atom Type: {grid_atom_type}, Match: {atom_type_match}")
    #print_features(grid_features)

# Final summary
total_points = len(non_zero_coords)
print(f"\nSummary:")
print(f"Correct Atom Type Matches: {number_of_atom_type_matches}/{total_points}")
# Out:
# {(6, 14, 10): (10, 8, 10), (7, 8, 8): (5, 10, 7), (7, 7, 7): (4, 10, 6), (6, 8, 8): (5, 11, 8), (5, 15, 10): (11, 8, 10), (7, 6, 7): (3, 11, 6), (8, 8, 6): (4, 9, 5), (6, 7, 8): (5, 12, 8), (8, 21, 7): (15, 2, 8), (7, 13, 10): (9, 8, 10), (8, 22, 1): (16, 1, 2), (7, 21, 7): (16, 3, 8), (9, 23, 5): (16, 1, 6), (8, 17, 9): (12, 5, 9), (6, 6, 8): (4, 12, 7), (4, 14, 10): (11, 10, 10), (9, 22, 1): (16, 0, 2), (8, 18, 9): (12, 4, 10), (9, 20, 1): (14, 2, 1), (5, 16, 11): (13, 8, 11), (6, 22, 6): (17, 3, 7), (6, 12, 11): (8, 9, 11), (8, 20, 1): (15, 2, 2), (9, 12, 9): (7, 7, 9), (9, 20, 8): (13, 2, 8), (7, 23, 5): (17, 2, 6), (9, 19, 2): (13, 2, 2), (4, 17, 9): (14, 7, 10), (8, 19, 9): (13, 3, 9), (11, 17, 2): (10, 1, 3), (8, 13, 9): (8, 7, 9), (7, 23, 2): (17, 2, 2), (6, 11, 11): (7, 10, 10), (12, 16, 2): (9, 1, 2), (7, 24, 4): (18, 1, 5), (11, 15, 2): (8, 2, 2), (8, 9, 7): (5, 8, 7), (9, 13, 6): (8, 5, 6), (9, 9, 6): (5, 8, 6), (9, 22, 6): (15, 1, 7), (10, 18, 1): (11, 1, 2), (10, 16, 7): (10, 3, 7), (9, 13, 1): (8, 5, 1), (3, 11, 9): (9, 12, 9), (11, 11, 5): (5, 5, 5), (9, 7, 5): (3, 8, 4), (11, 11, 2): (5, 5, 2), (3, 17, 8): (14, 8, 9), (10, 12, 0): (7, 5, 0), (11, 14, 6): (8, 4, 6), (0, 4, 9): (5, 18, 8), (2, 12, 8): (11, 12, 8), (0, 5, 10): (6, 17, 9), (0, 6, 8): (7, 17, 8), (6, 2, 6): (0, 14, 5), (1, 0, 9): (1, 19, 8)}
# Grid (0,4,9) --> Atom ID 26, Type CG1
#    Grid Feature Atom Type: CG1, Match: True
# Grid (0,5,10) --> Atom ID 25, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (0,6,8) --> Atom ID 27, Type CG2
#    Grid Feature Atom Type: CG2, Match: True
# Grid (1,0,9) --> Atom ID 28, Type CG2
#    Grid Feature Atom Type: CG2, Match: True
# Grid (2,12,8) --> Atom ID 24, Type SG
#    Grid Feature Atom Type: SG, Match: True
# Grid (3,11,9) --> Atom ID 23, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (3,17,8) --> Atom ID 16, Type CG2
#    Grid Feature Atom Type: CG2, Match: True
# Grid (4,14,10) --> Atom ID 14, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (4,17,9) --> Atom ID 15, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (5,15,10) --> Atom ID 13, Type C
#    Grid Feature Atom Type: C, Match: True
# Grid (5,16,11) --> Atom ID 12, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (6,2,6) --> Atom ID 29, Type CD2
#    Grid Feature Atom Type: CD2, Match: True
# Grid (6,6,8) --> Atom ID 55, Type CZ3
#    Grid Feature Atom Type: CZ3, Match: True
# Grid (6,7,8) --> Atom ID 56, Type CH2
#    Grid Feature Atom Type: CH2, Match: True
# Grid (6,8,8) --> Atom ID 54, Type CZ2
#    Grid Feature Atom Type: CZ2, Match: True
# Grid (6,11,11) --> Atom ID 20, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (6,12,11) --> Atom ID 19, Type C
#    Grid Feature Atom Type: C, Match: True
# Grid (6,14,10) --> Atom ID 17, Type N
#    Grid Feature Atom Type: N, Match: True
# Grid (6,22,6) --> Atom ID 8, Type CE1
#    Grid Feature Atom Type: CE1, Match: True
# Grid (7,6,7) --> Atom ID 53, Type CE3
#    Grid Feature Atom Type: CE3, Match: True
# Grid (7,7,7) --> Atom ID 50, Type CD2
#    Grid Feature Atom Type: CD2, Match: True
# Grid (7,8,8) --> Atom ID 52, Type CE2
#    Grid Feature Atom Type: CE2, Match: True
# Grid (7,13,10) --> Atom ID 18, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (7,21,7) --> Atom ID 6, Type CD1
#    Grid Feature Atom Type: CD1, Match: True
# Grid (7,23,2) --> Atom ID 39, Type NH2
#    Grid Feature Atom Type: NH2, Match: True
# Grid (7,23,5) --> Atom ID 10, Type CZ
#    Grid Feature Atom Type: CZ, Match: True
# Grid (7,24,4) --> Atom ID 11, Type OH
#    Grid Feature Atom Type: OH, Match: True
# Grid (8,8,6) --> Atom ID 48, Type CG
#    Grid Feature Atom Type: CG, Match: True
# Grid (8,9,7) --> Atom ID 51, Type NE1
#    Grid Feature Atom Type: NE1, Match: True
# Grid (8,13,9) --> Atom ID 21, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (8,17,9) --> Atom ID 3, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (8,18,9) --> Atom ID 2, Type C
#    Grid Feature Atom Type: C, Match: True
# Grid (8,19,9) --> Atom ID 1, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (8,20,1) --> Atom ID 36, Type NE
#    Grid Feature Atom Type: NE, Match: True
# Grid (8,21,7) --> Atom ID 5, Type CG
#    Grid Feature Atom Type: CG, Match: True
# Grid (8,22,1) --> Atom ID 37, Type CZ
#    Grid Feature Atom Type: CZ, Match: True
# Grid (9,7,5) --> Atom ID 47, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (9,9,6) --> Atom ID 49, Type CD1
#    Grid Feature Atom Type: CD1, Match: True
# Grid (9,12,9) --> Atom ID 22, Type OG
#    Grid Feature Atom Type: OG, Match: True
# Grid (9,13,1) --> Atom ID 46, Type CD1
#    Grid Feature Atom Type: CD1, Match: True
# Grid (9,13,6) --> Atom ID 42, Type CG2
#    Grid Feature Atom Type: CG2, Match: True
# Grid (9,19,2) --> Atom ID 34, Type CG
#    Grid Feature Atom Type: CG, Match: True
# Grid (9,20,1) --> Atom ID 35, Type CD
#    Grid Feature Atom Type: CD, Match: True
# Grid (9,20,8) --> Atom ID 4, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (9,22,1) --> Atom ID 38, Type NH1
#    Grid Feature Atom Type: NH1, Match: True
# Grid (9,22,6) --> Atom ID 7, Type CD2
#    Grid Feature Atom Type: CD2, Match: True
# Grid (9,23,5) --> Atom ID 9, Type CE2
#    Grid Feature Atom Type: CE2, Match: True
# Grid (10,12,0) --> Atom ID 45, Type CG
#    Grid Feature Atom Type: CG, Match: True
# Grid (10,16,7) --> Atom ID 43, Type CD1
#    Grid Feature Atom Type: CD1, Match: True
# Grid (10,18,1) --> Atom ID 33, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (11,11,2) --> Atom ID 44, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (11,11,5) --> Atom ID 40, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (11,14,6) --> Atom ID 41, Type CB
#    Grid Feature Atom Type: CB, Match: True
# Grid (11,15,2) --> Atom ID 32, Type O
#    Grid Feature Atom Type: O, Match: True
# Grid (11,17,2) --> Atom ID 30, Type CA
#    Grid Feature Atom Type: CA, Match: True
# Grid (12,16,2) --> Atom ID 31, Type C
#    Grid Feature Atom Type: C, Match: True
#
# Summary:
# Correct Atom Type Matches: 56/56
