# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("spy_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")
# Out:
# Smallest average_score: 0.000005
# Largest average_score: 0.999576
# Median average_score: 0.998457
# Mean average_score: 0.929763
# Mean average_score (number_atoms between 40 and 80): 0.930314
# Mean average_score (number_atoms between 55 and 65): 0.865046

# %%
# Load the CSV
df = pd.read_csv("test_positive_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_positive_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.000007
# Largest average_score: 0.999567
# Median average_score: 0.998649
# Mean average_score: 0.932593
# Mean average_score (number_atoms between 40 and 80): 0.917034
# Mean average_score (number_atoms between 55 and 65): 0.827424
# label
# LikelyPositive    653
# LikelyNegative    117
# Name: count, dtype: int64

# %%
# Load the CSV
df = pd.read_csv("test_unlabeled_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_unlabeled_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.000000
# Largest average_score: 0.999532
# Median average_score: 0.001294
# Mean average_score: 0.140743
# Mean average_score (number_atoms between 40 and 80): 0.172819
# Mean average_score (number_atoms between 55 and 65): 0.215974
# label
# LikelyNegative    2439
# LikelyPositive     234
# TrueNegative        97
# Name: count, dtype: int64

# %%
# Load the CSV
df = pd.read_csv("test_positive_unlabeled_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_positive_unlabeled_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.000036
# Largest average_score: 0.999553
# Median average_score: 0.974498
# Mean average_score: 0.772665
# Mean average_score (number_atoms between 40 and 80): 0.626559
# Mean average_score (number_atoms between 55 and 65): 0.468682
# label
# LikelyPositive    1103
# LikelyNegative     742
# Name: count, dtype: int64
