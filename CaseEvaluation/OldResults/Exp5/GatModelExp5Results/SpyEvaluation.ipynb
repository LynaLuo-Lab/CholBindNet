# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("spy_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")
# Out:
# Smallest average_score: 0.029162
# Largest average_score: 0.996428
# Median average_score: 0.830277
# Mean average_score: 0.752860
# Mean average_score (number_atoms between 40 and 80): 0.728859
# Mean average_score (number_atoms between 55 and 65): 0.650361

# %%
# Load the CSV
df = pd.read_csv("test_positive_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_positive_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.094683
# Largest average_score: 0.992381
# Median average_score: 0.850824
# Mean average_score: 0.763845
# Mean average_score (number_atoms between 40 and 80): 0.710632
# Mean average_score (number_atoms between 55 and 65): 0.587038
# label
# LikelyPositive    102
# LikelyNegative     52
# Name: count, dtype: int64

# %%
# Load the CSV
df = pd.read_csv("test_unlabeled_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_unlabeled_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.001831
# Largest average_score: 0.977644
# Median average_score: 0.111686
# Mean average_score: 0.208151
# Mean average_score (number_atoms between 40 and 80): 0.266738
# Mean average_score (number_atoms between 55 and 65): 0.300701
# label
# LikelyNegative    432
# TrueNegative      100
# LikelyPositive     22
# Name: count, dtype: int64

# %%
# Load the CSV
df = pd.read_csv("test_positive_unlabeled_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_positive_unlabeled_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.004828
# Largest average_score: 0.990349
# Median average_score: 0.485283
# Mean average_score: 0.523179
# Mean average_score (number_atoms between 40 and 80): 0.386395
# Mean average_score (number_atoms between 55 and 65): 0.312499
# label
# LikelyNegative    256
# LikelyPositive    108
# TrueNegative        5
# Name: count, dtype: int64
