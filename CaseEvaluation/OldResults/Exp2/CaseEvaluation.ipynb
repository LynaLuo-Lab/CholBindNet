# %%
import pandas as pd
import os

# Load CSV files
cnn3d_pos_df = pd.read_csv("3DCNNExp2Results/test_positive_labels.csv")
gnn_pos_df = pd.read_csv("GNNExp2Results/test_positive_labels.csv")
gat_pos_df = pd.read_csv("GatModelExp2Results/test_positive_labels.csv")

# Function to extract protein ID from filename
def extract_protein_id(path):
    base = os.path.basename(path)
    return base.split("-")[0]  # e.g., "1LRI" from "1LRI-filtered_graphs.npy"

# Add protein_id column
for df in [cnn3d_pos_df, gnn_pos_df, gat_pos_df]:
    df['protein_id'] = df['filename'].apply(extract_protein_id)

# Filter for average_score >= 0.9
cnn3d_filtered = cnn3d_pos_df[cnn3d_pos_df['average_score'] >= 0.9]
gnn_filtered = gnn_pos_df[gnn_pos_df['average_score'] >= 0.9]
gat_filtered = gat_pos_df[gat_pos_df['average_score'] >= 0.9]

# Get sets of protein_ids
cnn_ids = set(cnn3d_filtered['protein_id'])
gnn_ids = set(gnn_filtered['protein_id'])
gat_ids = set(gat_filtered['protein_id'])

# Find overlapping protein IDs
overlapping_ids = cnn_ids & gnn_ids & gat_ids

print(len(overlapping_ids), "is number of overlapping id's")

# Print results
print("Overlapping protein IDs with average_score >= 0.9 in all models:\n")
for protein_id in sorted(overlapping_ids):
    cnn_score = cnn3d_filtered[cnn3d_filtered['protein_id'] == protein_id]['average_score'].values
    gnn_score = gnn_filtered[gnn_filtered['protein_id'] == protein_id]['average_score'].values[0]
    gat_score = gat_filtered[gat_filtered['protein_id'] == protein_id]['average_score'].values[0]
    
    print(f"{protein_id}: 3DCNN = {cnn_score}, GNN = {gnn_score:.4f}, GAT = {gat_score:.4f}")
# Out:
# 46 is number of overlapping id's
# Overlapping protein IDs with average_score >= 0.9 in all models:
#
# 4NTJ: 3DCNN = [0.99941908 0.99906795 0.99915658 0.99952325 0.99920032], GNN = 0.9763, GAT = 0.9633
# 5AVW: 3DCNN = [0.99946285 0.99911366 0.99920046 0.99930396 0.99914812], GNN = 0.9732, GAT = 0.9477
# 5AW3: 3DCNN = [0.9984702  0.99875179 0.9990147  0.99877882 0.99760758], GNN = 0.9386, GAT = 0.9539
# 5AW4: 3DCNN = [0.99911389 0.99929561 0.9991718  0.99939699 0.99940962], GNN = 0.9808, GAT = 0.9317
# 5AW6: 3DCNN = [0.99933066 0.99908119 0.99596537 0.99933517 0.99889346], GNN = 0.9808, GAT = 0.9317
# 5AW9: 3DCNN = [0.99868326 0.99780826 0.99923388 0.99949437 0.99920695], GNN = 0.9608, GAT = 0.9268
# 5D5A: 3DCNN = [0.99140487 0.97337379 0.99348945], GNN = 0.9037, GAT = 0.9138
# 6KUW: 3DCNN = [0.99920165 0.99932168 0.99676026 0.98948717 0.99903796], GNN = 0.9580, GAT = 0.9728
# 6LW5: 3DCNN = [0.99002034 0.99824993 0.99905298 0.99885944 0.99706016], GNN = 0.9533, GAT = 0.9687
# 6OMM: 3DCNN = [0.99835228 0.99919074 0.99934598 0.99943287 0.99914364], GNN = 0.9587, GAT = 0.9046
# 6PB1: 3DCNN = [0.99938539 0.99884079 0.9994866  0.99926032 0.99928893], GNN = 0.9314, GAT = 0.9479
# 6PS5: 3DCNN = [0.99881096], GNN = 0.9406, GAT = 0.9822
# 6RZ7: 3DCNN = [0.99960315 0.99939853 0.99956243 0.99940269 0.9994957 ], GNN = 0.9480, GAT = 0.9394
# 6RZ9: 3DCNN = [0.99887074 0.98923509 0.99070408 0.95551332 0.99807267], GNN = 0.9591, GAT = 0.9563
# 6T4I: 3DCNN = [0.9941381  0.9823299  0.97584468 0.99592026 0.96385594], GNN = 0.9043, GAT = 0.9160
# 6T9N: 3DCNN = [0.99954041 0.99955185 0.99955467 0.99956014 0.99959091], GNN = 0.9604, GAT = 0.9099
# 6VI4: 3DCNN = [0.99471211 0.99843863 0.99772939 0.998408   0.995382  ], GNN = 0.9812, GAT = 0.9002
# 7CKY: 3DCNN = [0.99448707 0.99847849 0.99885004 0.99920877 0.99890509], GNN = 0.9690, GAT = 0.9354
# 7D76: 3DCNN = [0.99951927 0.99952026 0.99957472 0.99947537 0.99952176], GNN = 0.9499, GAT = 0.9838
# 7E14: 3DCNN = [0.999648   0.99956639 0.99963053 0.99964803 0.99960754], GNN = 0.9541, GAT = 0.9575
# 7F16: 3DCNN = [0.99949048 0.99943457 0.99940527 0.99934564 0.99940132], GNN = 0.9779, GAT = 0.9456
# 7F6H: 3DCNN = [0.99961516 0.9996193  0.99963801 0.99938291 0.99945731], GNN = 0.9758, GAT = 0.9454
# 7LJC: 3DCNN = [0.99936892 0.99950821 0.99944717 0.99954432 0.99947546], GNN = 0.9753, GAT = 0.9297
# %%
import pandas as pd
import os

# Load CSV files
cnn3d_pos_df = pd.read_csv("3DCNNExp2Results/test_positive_labels.csv")
gnn_pos_df = pd.read_csv("GNNExp2Results/test_positive_labels.csv")
gat_pos_df = pd.read_csv("GatModelExp2Results/test_positive_labels.csv")

# Function to extract protein ID from filename
def extract_protein_id(path):
    base = os.path.basename(path)
    return base.split("-")[0]  # e.g., "1LRI" from "1LRI-filtered_graphs.npy"

# Add protein_id column
for df in [cnn3d_pos_df, gnn_pos_df, gat_pos_df]:
    df['protein_id'] = df['filename'].apply(extract_protein_id)

# Filter for average_score >= 0.9
cnn3d_filtered = cnn3d_pos_df[cnn3d_pos_df['average_score'] < 0.5]
gnn_filtered = gnn_pos_df[gnn_pos_df['average_score'] > 0.5]
gat_filtered = gat_pos_df[gat_pos_df['average_score'] > 0.5]

# Get sets of protein_ids
cnn_ids = set(cnn3d_filtered['protein_id'])
gnn_ids = set(gnn_filtered['protein_id'])
gat_ids = set(gat_filtered['protein_id'])

# Find overlapping protein IDs
overlapping_ids = cnn_ids & gnn_ids & gat_ids
print(len(overlapping_ids), "is number of overlapping id's")

# Print results
print("Overlapping protein IDs for Case 3:\n")
for protein_id in sorted(overlapping_ids):
    cnn_score = cnn3d_filtered[cnn3d_filtered['protein_id'] == protein_id]['average_score'].values
    gnn_score = gnn_filtered[gnn_filtered['protein_id'] == protein_id]['average_score'].values[0]
    gat_score = gat_filtered[gat_filtered['protein_id'] == protein_id]['average_score'].values[0]
    
    print(f"{protein_id}: 3DCNN = {cnn_score}, GNN = {gnn_score:.4f}, GAT = {gat_score:.4f}")
# Out:
# 5 is number of overlapping id's
# Overlapping protein IDs for Case 3:
#
# 4RES: 3DCNN = [0.40012862 0.24709232], GNN = 0.9574, GAT = 0.7434
# 6PS5: 3DCNN = [0.4220356], GNN = 0.9406, GAT = 0.9822
# 7V0S: 3DCNN = [0.43744851], GNN = 0.6945, GAT = 0.5615
# 8SI7: 3DCNN = [0.12334539 0.09238788 0.47181217 0.01135748 0.03960447], GNN = 0.9055, GAT = 0.5959
# 8SRE: 3DCNN = [0.27696445 0.32920926 0.47478855], GNN = 0.9595, GAT = 0.5814

# %%
import pandas as pd
import os

# Load CSV files
cnn3d_pos_df = pd.read_csv("3DCNNExp2Results/test_positive_labels.csv")
gnn_pos_df = pd.read_csv("GNNExp2Results/test_positive_labels.csv")
gat_pos_df = pd.read_csv("GatModelExp2Results/test_positive_labels.csv")

# Function to extract protein ID from filename
def extract_protein_id(path):
    base = os.path.basename(path)
    return base.split("-")[0]  # e.g., "1LRI" from "1LRI-filtered_graphs.npy"

# Add protein_id column
for df in [cnn3d_pos_df, gnn_pos_df, gat_pos_df]:
    df['protein_id'] = df['filename'].apply(extract_protein_id)

# Filter for average_score >= 0.9
cnn3d_filtered = cnn3d_pos_df[cnn3d_pos_df['average_score'] <= 0.5]
gnn_filtered = gnn_pos_df[gnn_pos_df['average_score'] <= 0.5]
gat_filtered = gat_pos_df[gat_pos_df['average_score'] <= 0.5]

# Get sets of protein_ids
cnn_ids = set(cnn3d_filtered['protein_id'])
gnn_ids = set(gnn_filtered['protein_id'])
gat_ids = set(gat_filtered['protein_id'])

# Find overlapping protein IDs
overlapping_ids = cnn_ids & gnn_ids & gat_ids
print(len(overlapping_ids), "is number of overlapping id's")

# Print results
print("Overlapping protein IDs for Case 4:\n")
for protein_id in sorted(overlapping_ids):
    cnn_score = cnn3d_filtered[cnn3d_filtered['protein_id'] == protein_id]['average_score'].values
    gnn_score = gnn_filtered[gnn_filtered['protein_id'] == protein_id]['average_score'].values[0]
    gat_score = gat_filtered[gat_filtered['protein_id'] == protein_id]['average_score'].values[0]
    
    print(f"{protein_id}: 3DCNN = {cnn_score}, GNN = {gnn_score:.4f}, GAT = {gat_score:.4f}")
# Out:
# 5 is number of overlapping id's
# Overlapping protein IDs for Case 4:
#
# 5UPH: 3DCNN = [4.61431047e-06 1.03763551e-05 7.81422881e-06 5.69042565e-06
#  5.64997277e-06], GNN = 0.0000, GAT = 0.0347
# 7Q1U: 3DCNN = [3.58374537e-05 3.73110888e-04 1.35700035e-04 1.84410757e-04
#  1.10618973e-04], GNN = 0.0298, GAT = 0.1163
# 7UZQ: 3DCNN = [1.23472261e-04 1.57159908e-05 1.71039367e-05 5.03744484e-05
#  3.10720808e-04], GNN = 0.0004, GAT = 0.0508
# 7ZXN: 3DCNN = [0.00144391 0.00020759 0.0373526  0.00448287 0.02495503], GNN = 0.1010, GAT = 0.3209
# 8T56: 3DCNN = [0.00096982 0.01555044 0.00411445 0.00511432 0.00390535], GNN = 0.3325, GAT = 0.3162
