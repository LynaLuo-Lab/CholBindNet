# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("spy_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")
# Out:
# Smallest average_score: 0.000462
# Largest average_score: 0.999770
# Median average_score: 0.999174
# Mean average_score: 0.934532
# Mean average_score (number_atoms between 40 and 80): 0.898187
# Mean average_score (number_atoms between 55 and 65): 0.762627

# %%
# Load the CSV
df = pd.read_csv("test_positive_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_positive_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.000010
# Largest average_score: 0.999762
# Median average_score: 0.998987
# Mean average_score: 0.881174
# Mean average_score (number_atoms between 40 and 80): 0.858475
# Mean average_score (number_atoms between 55 and 65): 0.654623
# label
# LikelyPositive    612
# LikelyNegative    148
# TrueNegative       10
# Name: count, dtype: int64

# %%
# Load the CSV
df = pd.read_csv("test_unlabeled_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_unlabeled_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.000000
# Largest average_score: 0.999752
# Median average_score: 0.000923
# Mean average_score: 0.118962
# Mean average_score (number_atoms between 40 and 80): 0.159393
# Mean average_score (number_atoms between 55 and 65): 0.224379
# label
# LikelyNegative    1367
# TrueNegative      1229
# LikelyPositive     174
# Name: count, dtype: int64

# %%
# Load the CSV
df = pd.read_csv("test_positive_unlabeled_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_positive_unlabeled_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.000021
# Largest average_score: 0.999750
# Median average_score: 0.985245
# Mean average_score: 0.785614
# Mean average_score (number_atoms between 40 and 80): 0.647118
# Mean average_score (number_atoms between 55 and 65): 0.472404
# label
# LikelyPositive    1140
# LikelyNegative     681
# TrueNegative        24
# Name: count, dtype: int64
