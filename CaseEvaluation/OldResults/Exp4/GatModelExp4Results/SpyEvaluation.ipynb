# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("spy_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")
# Out:
# Smallest average_score: 0.037821
# Largest average_score: 0.996202
# Median average_score: 0.818991
# Mean average_score: 0.738340
# Mean average_score (number_atoms between 40 and 80): 0.710644
# Mean average_score (number_atoms between 55 and 65): 0.653828

# %%
# Load the CSV
df = pd.read_csv("test_positive_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_positive_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.151541
# Largest average_score: 0.998523
# Median average_score: 0.848383
# Mean average_score: 0.778725
# Mean average_score (number_atoms between 40 and 80): 0.730464
# Mean average_score (number_atoms between 55 and 65): 0.599663
# label
# LikelyPositive    107
# LikelyNegative     46
# TruePositive        1
# Name: count, dtype: int64

# %%
# Load the CSV
df = pd.read_csv("test_unlabeled_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_unlabeled_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.005749
# Largest average_score: 0.982322
# Median average_score: 0.114838
# Mean average_score: 0.200201
# Mean average_score (number_atoms between 40 and 80): 0.251565
# Mean average_score (number_atoms between 55 and 65): 0.279994
# label
# LikelyNegative    416
# TrueNegative      119
# LikelyPositive     19
# Name: count, dtype: int64

# %%
# Load the CSV
df = pd.read_csv("test_positive_unlabeled_capture_rates.csv")

feature = 'average_score'

# Calculate statistics
min_score = df[feature].min()
max_score = df[feature].max()
median_score = df[feature].median()
mean_score = df[feature].mean()

# Print the results
print(f"Smallest average_score: {min_score:.6f}")
print(f"Largest average_score: {max_score:.6f}")
print(f"Median average_score: {median_score:.6f}")
print(f"Mean average_score: {mean_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 40) & (df["number_atoms"] <= 80)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 40 and 80): {mean_filtered_score:.6f}")

filtered_df = df[(df["number_atoms"] >= 55) & (df["number_atoms"] <= 65)]

# Compute mean of average_score in filtered rows
mean_filtered_score = filtered_df["average_score"].mean()

# Print result
print(f"Mean average_score (number_atoms between 55 and 65): {mean_filtered_score:.6f}")

df = pd.read_csv("test_positive_unlabeled_labels.csv")

value_counts = df['label'].value_counts()
print(value_counts)
# Out:
# Smallest average_score: 0.003950
# Largest average_score: 0.992881
# Median average_score: 0.507258
# Mean average_score: 0.534050
# Mean average_score (number_atoms between 40 and 80): 0.396292
# Mean average_score (number_atoms between 55 and 65): 0.330290
# label
# LikelyNegative    248
# LikelyPositive    114
# TrueNegative        7
# Name: count, dtype: int64
