# %%
import torch
import torch.nn as nn
import glob
import csv
import numpy as np
import os

# 3D CNN Model
class CNN3D(nn.Module):
    def __init__(self):
        super(CNN3D, self).__init__()
        
        self.conv0 = nn.Conv3d(in_channels=37, out_channels=64, kernel_size=1, stride=1, padding=0) # play around with output channels
        self.conv1 = nn.Conv3d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv3d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)

        #self.dropout_conv = nn.Dropout3d(p=0.05)
        
        # After two pooling layers, spatial dimensions reduce from 40x40x40 -> 5x5x5
        self.fc1 = nn.Linear(128 * 3 * 3 * 3, 256)  # Try increasing over 256
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 2)  # Assuming 1 output for docking status/position

        #self.dropout_fc = nn.Dropout(p=0.15)
        
    def forward(self, x):
        # Forward pass through Conv layers
        x = self.pool(torch.relu(self.conv0(x)))  # Conv0 -> ReLU -> Pooling
        #x = self.dropout_conv(x)
        x = self.pool(torch.relu(self.conv1(x)))  # Conv1 -> ReLU -> Pooling
        x = self.pool2(torch.relu(self.conv2(x)))  # Conv2 -> ReLU -> Pooling

        # Flatten the input for fully connected layers
        x = x.view(-1, 128 * 3 * 3 * 3)
        
        # Forward pass through fully connected layers
        x = torch.relu(self.fc1(x)) #use tanh activation
        #x = self.dropout_fc(x)
        x = torch.relu(self.fc2(x))
        x = torch.nn.functional.softmax(self.fc3(x), dim=1)  # Final layer (output layer)
        #x = torch.clamp(x, min=1e-7, max=1 - 1e-7)  # Clamp outputs to avoid extreme values
        
        return x
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

models_exp1 = []
models_exp2 = []
models_exp3 = []
models_exp4 = []
models_exp5 = []

k = 50

for i in range (1, (k + 1)):
    model_exp1 = CNN3D().to(device)

    model_exp2 = CNN3D().to(device)

    model_exp3 = CNN3D().to(device)

    model_exp4 = CNN3D().to(device)

    model_exp5 = CNN3D().to(device)

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp1/Models/model_bin_{i}.pth" 
    model_exp1.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp2/Models/model_bin_{i}.pth" 
    model_exp2.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp3/Models/model_bin_{i}.pth" 
    model_exp3.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp4/Models/model_bin_{i}.pth" 
    model_exp4.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp5/Models/model_bin_{i}.pth" 
    model_exp5.load_state_dict(torch.load(model_path, map_location=device))

    model_exp1.eval()
    model_exp2.eval()
    model_exp3.eval()
    model_exp4.eval()
    model_exp5.eval()

    models_exp1.append(model_exp1)
    models_exp2.append(model_exp2)
    models_exp3.append(model_exp3)
    models_exp4.append(model_exp4)
    models_exp5.append(model_exp5)
# Out:
# /tmp/ipykernel_3573731/2050218513.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp1.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_3573731/2050218513.py:72: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp2.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_3573731/2050218513.py:75: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp3.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_3573731/2050218513.py:78: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp4.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_3573731/2050218513.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp5.load_state_dict(torch.load(model_path, map_location=device))

# %%
def evaluate_file(model, file_path, threshold=0.5):
    grid = np.load(file_path)

    non_padded_rows = np.sum(np.any(grid != 0, axis=(3)))
    
    grid_tensor = torch.tensor(grid, dtype=torch.float32).permute(3, 0, 1, 2).unsqueeze(0)
    grid_tensor = grid_tensor.to(device)
    
    model.eval()
    with torch.no_grad():
        output = model(grid_tensor)

    prob = output[0, 1].item()

    predicted_class = int(prob >= threshold)

    return predicted_class, prob, non_padded_rows

# %%
def evaluate_directory(dir, csv_output, models):
    predictions = []
    capture_rate = 0
    overlapping_capture_rate = 0
    overlapping_index = 0

    files = glob.glob(f"{dir}/*.npy")

    model_positive_counts = [0] * len(models)
    model_negative_counts = [0] * len(models)

    #print(f"{'Filename':<120} {'IndividualCaptureRate':<25} NumberOfAtoms")

    os.makedirs(os.path.dirname(csv_output), exist_ok=True)

    with open(csv_output, "w", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["filename", "average_score", "score_std", "number_atoms"]) 

        for file in sorted(files):    
            model_probs = []
            for model_index, model in enumerate(models):
                predicted_class, prob, non_padded_rows = evaluate_file(model, file)
                model_probs.append(prob)

                if predicted_class == 1:
                    model_positive_counts[model_index] += 1
                else:
                    model_negative_counts[model_index] += 1

            prediction_mean = np.mean(model_probs)
            prediction_std = np.std(model_probs)

            capture_rate += prediction_mean
            #if non_padded_rows <= 65 and non_padded_rows >= 55:
            #print(f"{file:<120} {prediction:<25} {non_padded_rows}")
            overlapping_capture_rate += prediction_mean
            overlapping_index += 1
            writer.writerow([file, prediction_mean, prediction_std, non_padded_rows])

    capture_rate /= len(files)
    overlapping_capture_rate /= overlapping_index

    print("\nModel Predictions Summary:")
    for i, (pos, neg) in enumerate(zip(model_positive_counts, model_negative_counts), start=1):
        print(f"Model {i}: Positives = {pos}, Negatives = {neg}")

    print("Overlapping Capture Rate is", overlapping_capture_rate)

    return capture_rate

# %%
spies_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp1/Spies"  
csv_output_exp1 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp1/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp1, csv_output_exp1, models_exp1)

spies_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp2/Spies"  
csv_output_exp2 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp2/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp2, csv_output_exp2, models_exp2)

spies_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp3/Spies"  
csv_output_exp3 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp3/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp3, csv_output_exp3, models_exp3)

spies_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp4/Spies"  
csv_output_exp4 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp4/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp4, csv_output_exp4, models_exp4)

spies_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp5/Spies"  
csv_output_exp5 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp5/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 712, Negatives = 58
# Model 2: Positives = 711, Negatives = 59
# Model 3: Positives = 701, Negatives = 69
# Model 4: Positives = 720, Negatives = 50
# Model 5: Positives = 715, Negatives = 55
# Model 6: Positives = 710, Negatives = 60
# Model 7: Positives = 706, Negatives = 64
# Model 8: Positives = 708, Negatives = 62
# Model 9: Positives = 703, Negatives = 67
# Model 10: Positives = 711, Negatives = 59
# Model 11: Positives = 717, Negatives = 53
# Model 12: Positives = 709, Negatives = 61
# Model 13: Positives = 715, Negatives = 55
# Model 14: Positives = 713, Negatives = 57
# Model 15: Positives = 720, Negatives = 50
# Model 16: Positives = 724, Negatives = 46
# Model 17: Positives = 696, Negatives = 74
# Model 18: Positives = 724, Negatives = 46
# Model 19: Positives = 712, Negatives = 58
# Model 20: Positives = 713, Negatives = 57
# Model 21: Positives = 710, Negatives = 60
# Model 22: Positives = 701, Negatives = 69
# Model 23: Positives = 717, Negatives = 53
# Model 24: Positives = 705, Negatives = 65
# Model 25: Positives = 710, Negatives = 60
# Model 26: Positives = 714, Negatives = 56
# Model 27: Positives = 710, Negatives = 60
# Model 28: Positives = 708, Negatives = 62
# Model 29: Positives = 708, Negatives = 62
# Model 30: Positives = 699, Negatives = 71
# Model 31: Positives = 712, Negatives = 58
# Model 32: Positives = 713, Negatives = 57
# Model 33: Positives = 718, Negatives = 52
# Model 34: Positives = 711, Negatives = 59
# Model 35: Positives = 715, Negatives = 55
# Model 36: Positives = 711, Negatives = 59
# Model 37: Positives = 717, Negatives = 53
# Model 38: Positives = 710, Negatives = 60
# Model 39: Positives = 713, Negatives = 57
# Model 40: Positives = 715, Negatives = 55
# Model 41: Positives = 707, Negatives = 63
# Model 42: Positives = 715, Negatives = 55
# Model 43: Positives = 718, Negatives = 52
# Model 44: Positives = 708, Negatives = 62
# Model 45: Positives = 708, Negatives = 62
# Model 46: Positives = 711, Negatives = 59
# Model 47: Positives = 711, Negatives = 59
# Model 48: Positives = 710, Negatives = 60
# Model 49: Positives = 711, Negatives = 59
# Model 50: Positives = 716, Negatives = 54
# Overlapping Capture Rate is 0.9091956585508784
#
# Model Predictions Summary:
# Model 1: Positives = 712, Negatives = 58
# Model 2: Positives = 721, Negatives = 49
# Model 3: Positives = 721, Negatives = 49
# Model 4: Positives = 713, Negatives = 57
# Model 5: Positives = 715, Negatives = 55
# Model 6: Positives = 720, Negatives = 50
# Model 7: Positives = 731, Negatives = 39
# Model 8: Positives = 725, Negatives = 45
# Model 9: Positives = 711, Negatives = 59
# Model 10: Positives = 716, Negatives = 54
# Model 11: Positives = 716, Negatives = 54
# Model 12: Positives = 718, Negatives = 52
# Model 13: Positives = 719, Negatives = 51
# Model 14: Positives = 725, Negatives = 45
# Model 15: Positives = 725, Negatives = 45
# Model 16: Positives = 710, Negatives = 60
# Model 17: Positives = 715, Negatives = 55
# Model 18: Positives = 724, Negatives = 46
# Model 19: Positives = 728, Negatives = 42
# Model 20: Positives = 717, Negatives = 53
# Model 21: Positives = 721, Negatives = 49
# Model 22: Positives = 702, Negatives = 68
# Model 23: Positives = 709, Negatives = 61
# Model 24: Positives = 725, Negatives = 45
# Model 25: Positives = 726, Negatives = 44
# Model 26: Positives = 718, Negatives = 52
# Model 27: Positives = 721, Negatives = 49
# Model 28: Positives = 718, Negatives = 52
# Model 29: Positives = 730, Negatives = 40
# Model 30: Positives = 722, Negatives = 48
# Model 31: Positives = 711, Negatives = 59
# Model 32: Positives = 728, Negatives = 42
# Model 33: Positives = 725, Negatives = 45
# Model 34: Positives = 723, Negatives = 47
# Model 35: Positives = 719, Negatives = 51
# Model 36: Positives = 721, Negatives = 49
# Model 37: Positives = 717, Negatives = 53
# Model 38: Positives = 715, Negatives = 55
# Model 39: Positives = 716, Negatives = 54
# Model 40: Positives = 709, Negatives = 61
# Model 41: Positives = 717, Negatives = 53
# Model 42: Positives = 718, Negatives = 52
# Model 43: Positives = 720, Negatives = 50
# Model 44: Positives = 701, Negatives = 69
# Model 45: Positives = 703, Negatives = 67
# Model 46: Positives = 712, Negatives = 58
# Model 47: Positives = 721, Negatives = 49
# Model 48: Positives = 710, Negatives = 60
# Model 49: Positives = 722, Negatives = 48
# Model 50: Positives = 721, Negatives = 49
# Overlapping Capture Rate is 0.9112918496207899
#
# Model Predictions Summary:
# Model 1: Positives = 727, Negatives = 43
# Model 2: Positives = 727, Negatives = 43
# Model 3: Positives = 724, Negatives = 46
# Model 4: Positives = 725, Negatives = 45
# Model 5: Positives = 726, Negatives = 44
# Model 6: Positives = 735, Negatives = 35
# Model 7: Positives = 722, Negatives = 48
# Model 8: Positives = 727, Negatives = 43
# Model 9: Positives = 722, Negatives = 48
# Model 10: Positives = 726, Negatives = 44
# Model 11: Positives = 722, Negatives = 48
# Model 12: Positives = 721, Negatives = 49
# Model 13: Positives = 720, Negatives = 50
# Model 14: Positives = 725, Negatives = 45
# Model 15: Positives = 728, Negatives = 42
# Model 16: Positives = 727, Negatives = 43
# Model 17: Positives = 714, Negatives = 56
# Model 18: Positives = 723, Negatives = 47
# Model 19: Positives = 726, Negatives = 44
# Model 20: Positives = 728, Negatives = 42
# Model 21: Positives = 724, Negatives = 46
# Model 22: Positives = 720, Negatives = 50
# Model 23: Positives = 720, Negatives = 50
# Model 24: Positives = 723, Negatives = 47
# Model 25: Positives = 727, Negatives = 43
# Model 26: Positives = 725, Negatives = 45
# Model 27: Positives = 727, Negatives = 43
# Model 28: Positives = 721, Negatives = 49
# Model 29: Positives = 719, Negatives = 51
# Model 30: Positives = 715, Negatives = 55
# Model 31: Positives = 724, Negatives = 46
# Model 32: Positives = 726, Negatives = 44
# Model 33: Positives = 726, Negatives = 44
# Model 34: Positives = 721, Negatives = 49
# Model 35: Positives = 725, Negatives = 45
# Model 36: Positives = 726, Negatives = 44
# Model 37: Positives = 729, Negatives = 41
# Model 38: Positives = 723, Negatives = 47
# Model 39: Positives = 725, Negatives = 45
# Model 40: Positives = 728, Negatives = 42
# Model 41: Positives = 721, Negatives = 49
# Model 42: Positives = 720, Negatives = 50
# Model 43: Positives = 726, Negatives = 44
# Model 44: Positives = 726, Negatives = 44
# Model 45: Positives = 725, Negatives = 45
# Model 46: Positives = 719, Negatives = 51
# Model 47: Positives = 729, Negatives = 41
# Model 48: Positives = 717, Negatives = 53
# Model 49: Positives = 716, Negatives = 54
# Model 50: Positives = 721, Negatives = 49
# Overlapping Capture Rate is 0.9283116416442354
#
# Model Predictions Summary:
# Model 1: Positives = 694, Negatives = 76
# Model 2: Positives = 677, Negatives = 93
# Model 3: Positives = 704, Negatives = 66
# Model 4: Positives = 704, Negatives = 66
# Model 5: Positives = 684, Negatives = 86
# Model 6: Positives = 705, Negatives = 65
# Model 7: Positives = 688, Negatives = 82
# Model 8: Positives = 697, Negatives = 73
# Model 9: Positives = 684, Negatives = 86
# Model 10: Positives = 699, Negatives = 71
# Model 11: Positives = 672, Negatives = 98
# Model 12: Positives = 705, Negatives = 65
# Model 13: Positives = 708, Negatives = 62
# Model 14: Positives = 702, Negatives = 68
# Model 15: Positives = 702, Negatives = 68
# Model 16: Positives = 706, Negatives = 64
# Model 17: Positives = 688, Negatives = 82
# Model 18: Positives = 702, Negatives = 68
# Model 19: Positives = 694, Negatives = 76
# Model 20: Positives = 671, Negatives = 99
# Model 21: Positives = 699, Negatives = 71
# Model 22: Positives = 701, Negatives = 69
# Model 23: Positives = 691, Negatives = 79
# Model 24: Positives = 707, Negatives = 63
# Model 25: Positives = 703, Negatives = 67
# Model 26: Positives = 708, Negatives = 62
# Model 27: Positives = 704, Negatives = 66
# Model 28: Positives = 698, Negatives = 72
# Model 29: Positives = 703, Negatives = 67
# Model 30: Positives = 707, Negatives = 63
# Model 31: Positives = 704, Negatives = 66
# Model 32: Positives = 700, Negatives = 70
# Model 33: Positives = 712, Negatives = 58
# Model 34: Positives = 699, Negatives = 71
# Model 35: Positives = 685, Negatives = 85
# Model 36: Positives = 688, Negatives = 82
# Model 37: Positives = 686, Negatives = 84
# Model 38: Positives = 705, Negatives = 65
# Model 39: Positives = 700, Negatives = 70
# Model 40: Positives = 713, Negatives = 57
# Model 41: Positives = 711, Negatives = 59
# Model 42: Positives = 708, Negatives = 62
# Model 43: Positives = 687, Negatives = 83
# Model 44: Positives = 698, Negatives = 72
# Model 45: Positives = 701, Negatives = 69
# Model 46: Positives = 707, Negatives = 63
# Model 47: Positives = 707, Negatives = 63
# Model 48: Positives = 706, Negatives = 64
# Model 49: Positives = 696, Negatives = 74
# Model 50: Positives = 691, Negatives = 79
# Overlapping Capture Rate is 0.8941962295984089
#
# Model Predictions Summary:
# Model 1: Positives = 720, Negatives = 50
# Model 2: Positives = 716, Negatives = 54
# Model 3: Positives = 716, Negatives = 54
# Model 4: Positives = 722, Negatives = 48
# Model 5: Positives = 720, Negatives = 50
# Model 6: Positives = 719, Negatives = 51
# Model 7: Positives = 724, Negatives = 46
# Model 8: Positives = 715, Negatives = 55
# Model 9: Positives = 721, Negatives = 49
# Model 10: Positives = 722, Negatives = 48
# Model 11: Positives = 720, Negatives = 50
# Model 12: Positives = 723, Negatives = 47
# Model 13: Positives = 717, Negatives = 53
# Model 14: Positives = 719, Negatives = 51
# Model 15: Positives = 719, Negatives = 51
# Model 16: Positives = 721, Negatives = 49
# Model 17: Positives = 712, Negatives = 58
# Model 18: Positives = 717, Negatives = 53
# Model 19: Positives = 722, Negatives = 48
# Model 20: Positives = 716, Negatives = 54
# Model 21: Positives = 722, Negatives = 48
# Model 22: Positives = 719, Negatives = 51
# Model 23: Positives = 716, Negatives = 54
# Model 24: Positives = 713, Negatives = 57
# Model 25: Positives = 722, Negatives = 48
# Model 26: Positives = 721, Negatives = 49
# Model 27: Positives = 719, Negatives = 51
# Model 28: Positives = 722, Negatives = 48
# Model 29: Positives = 719, Negatives = 51
# Model 30: Positives = 721, Negatives = 49
# Model 31: Positives = 720, Negatives = 50
# Model 32: Positives = 719, Negatives = 51
# Model 33: Positives = 716, Negatives = 54
# Model 34: Positives = 720, Negatives = 50
# Model 35: Positives = 715, Negatives = 55
# Model 36: Positives = 725, Negatives = 45
# Model 37: Positives = 721, Negatives = 49
# Model 38: Positives = 721, Negatives = 49
# Model 39: Positives = 719, Negatives = 51
# Model 40: Positives = 722, Negatives = 48
# Model 41: Positives = 716, Negatives = 54
# Model 42: Positives = 715, Negatives = 55
# Model 43: Positives = 720, Negatives = 50
# Model 44: Positives = 724, Negatives = 46
# Model 45: Positives = 722, Negatives = 48
# Model 46: Positives = 713, Negatives = 57
# Model 47: Positives = 723, Negatives = 47
# Model 48: Positives = 720, Negatives = 50
# Model 49: Positives = 719, Negatives = 51
# Model 50: Positives = 723, Negatives = 47
# Overlapping Capture Rate is 0.9223063588816017

# %%
import pandas as pd

def get_spy_info(csv):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    # Extract the 'average_score' column
    scores = df["average_score"]

    # Compute statistics
    mean_score = scores.mean()
    percentile_50 = scores.quantile(0.5)
    percentile_25 = scores.quantile(0.25)
    percentile_75 = scores.quantile(0.75)
    min_score = scores.min()
    max_score = scores.max()

    # Print results
    print(f"Mean: {mean_score:.6f}")
    print(f"50th Percentile (Median): {percentile_50:.6f}")
    print(f"Bottom 25 Percentile: {percentile_25:.6f}")
    print(f"Top 25 Percentile: {percentile_75:.6f}")
    print(f"Min: {min_score:.6f}")
    print(f"Max: {max_score:.6f}\n")

    return mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score

print("Experiment 1 Spy Results:")
mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1 = get_spy_info(csv_output_exp1)

print("Experiment 2 Spy Results:")
mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2 = get_spy_info(csv_output_exp2)

print("Experiment 3 Spy Results:")
mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3 = get_spy_info(csv_output_exp3)

print("Experiment 4 Spy Results:")
mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4 = get_spy_info(csv_output_exp4)

print("Experiment 5 Spy Results:")
mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5 = get_spy_info(csv_output_exp5)
# Out:
# Experiment 1 Spy Results:
# Mean: 0.909196
# 50th Percentile (Median): 0.998402
# Bottom 25 Percentile: 0.971694
# Top 25 Percentile: 0.999265
# Min: 0.000393
# Max: 0.999589
#
# Experiment 2 Spy Results:
# Mean: 0.911292
# 50th Percentile (Median): 0.997469
# Bottom 25 Percentile: 0.947971
# Top 25 Percentile: 0.999269
# Min: 0.014354
# Max: 0.999578
#
# Experiment 3 Spy Results:
# Mean: 0.928312
# 50th Percentile (Median): 0.998486
# Bottom 25 Percentile: 0.983632
# Top 25 Percentile: 0.999377
# Min: 0.001310
# Max: 0.999662
#
# Experiment 4 Spy Results:
# Mean: 0.894196
# 50th Percentile (Median): 0.997700
# Bottom 25 Percentile: 0.958346
# Top 25 Percentile: 0.999255
# Min: 0.000063
# Max: 0.999621
#
# Experiment 5 Spy Results:
# Mean: 0.922306
# 50th Percentile (Median): 0.997718
# Bottom 25 Percentile: 0.982572
# Top 25 Percentile: 0.998905
# Min: 0.000010
# Max: 0.999436

# %%
test_positives_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp1/Test/Positive"  
csv_output_exp1 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp1/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp1, csv_output_exp1, models_exp1)

test_positives_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp2/Test/Positive"  
csv_output_exp2 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp2/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp2, csv_output_exp2, models_exp2)

test_positives_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp3/Test/Positive"  
csv_output_exp3 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp3/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp3, csv_output_exp3, models_exp3)

test_positives_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp4/Test/Positive"  
csv_output_exp4 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp4/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp4, csv_output_exp4, models_exp4)

test_positives_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp5/Test/Positive"  
csv_output_exp5 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp5/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 723, Negatives = 47
# Model 2: Positives = 718, Negatives = 52
# Model 3: Positives = 719, Negatives = 51
# Model 4: Positives = 727, Negatives = 43
# Model 5: Positives = 720, Negatives = 50
# Model 6: Positives = 727, Negatives = 43
# Model 7: Positives = 714, Negatives = 56
# Model 8: Positives = 716, Negatives = 54
# Model 9: Positives = 718, Negatives = 52
# Model 10: Positives = 718, Negatives = 52
# Model 11: Positives = 727, Negatives = 43
# Model 12: Positives = 718, Negatives = 52
# Model 13: Positives = 725, Negatives = 45
# Model 14: Positives = 724, Negatives = 46
# Model 15: Positives = 723, Negatives = 47
# Model 16: Positives = 724, Negatives = 46
# Model 17: Positives = 723, Negatives = 47
# Model 18: Positives = 722, Negatives = 48
# Model 19: Positives = 719, Negatives = 51
# Model 20: Positives = 723, Negatives = 47
# Model 21: Positives = 724, Negatives = 46
# Model 22: Positives = 715, Negatives = 55
# Model 23: Positives = 724, Negatives = 46
# Model 24: Positives = 724, Negatives = 46
# Model 25: Positives = 716, Negatives = 54
# Model 26: Positives = 727, Negatives = 43
# Model 27: Positives = 719, Negatives = 51
# Model 28: Positives = 722, Negatives = 48
# Model 29: Positives = 723, Negatives = 47
# Model 30: Positives = 721, Negatives = 49
# Model 31: Positives = 722, Negatives = 48
# Model 32: Positives = 719, Negatives = 51
# Model 33: Positives = 718, Negatives = 52
# Model 34: Positives = 721, Negatives = 49
# Model 35: Positives = 720, Negatives = 50
# Model 36: Positives = 716, Negatives = 54
# Model 37: Positives = 728, Negatives = 42
# Model 38: Positives = 723, Negatives = 47
# Model 39: Positives = 723, Negatives = 47
# Model 40: Positives = 721, Negatives = 49
# Model 41: Positives = 720, Negatives = 50
# Model 42: Positives = 721, Negatives = 49
# Model 43: Positives = 721, Negatives = 49
# Model 44: Positives = 720, Negatives = 50
# Model 45: Positives = 727, Negatives = 43
# Model 46: Positives = 719, Negatives = 51
# Model 47: Positives = 715, Negatives = 55
# Model 48: Positives = 719, Negatives = 51
# Model 49: Positives = 719, Negatives = 51
# Model 50: Positives = 726, Negatives = 44
# Overlapping Capture Rate is 0.9253298034627696
#
# Model Predictions Summary:
# Model 1: Positives = 719, Negatives = 51
# Model 2: Positives = 725, Negatives = 45
# Model 3: Positives = 719, Negatives = 51
# Model 4: Positives = 718, Negatives = 52
# Model 5: Positives = 723, Negatives = 47
# Model 6: Positives = 725, Negatives = 45
# Model 7: Positives = 731, Negatives = 39
# Model 8: Positives = 729, Negatives = 41
# Model 9: Positives = 709, Negatives = 61
# Model 10: Positives = 726, Negatives = 44
# Model 11: Positives = 721, Negatives = 49
# Model 12: Positives = 715, Negatives = 55
# Model 13: Positives = 723, Negatives = 47
# Model 14: Positives = 718, Negatives = 52
# Model 15: Positives = 727, Negatives = 43
# Model 16: Positives = 712, Negatives = 58
# Model 17: Positives = 720, Negatives = 50
# Model 18: Positives = 730, Negatives = 40
# Model 19: Positives = 727, Negatives = 43
# Model 20: Positives = 719, Negatives = 51
# Model 21: Positives = 718, Negatives = 52
# Model 22: Positives = 710, Negatives = 60
# Model 23: Positives = 713, Negatives = 57
# Model 24: Positives = 728, Negatives = 42
# Model 25: Positives = 723, Negatives = 47
# Model 26: Positives = 724, Negatives = 46
# Model 27: Positives = 727, Negatives = 43
# Model 28: Positives = 718, Negatives = 52
# Model 29: Positives = 725, Negatives = 45
# Model 30: Positives = 724, Negatives = 46
# Model 31: Positives = 708, Negatives = 62
# Model 32: Positives = 720, Negatives = 50
# Model 33: Positives = 726, Negatives = 44
# Model 34: Positives = 722, Negatives = 48
# Model 35: Positives = 727, Negatives = 43
# Model 36: Positives = 719, Negatives = 51
# Model 37: Positives = 721, Negatives = 49
# Model 38: Positives = 718, Negatives = 52
# Model 39: Positives = 717, Negatives = 53
# Model 40: Positives = 717, Negatives = 53
# Model 41: Positives = 718, Negatives = 52
# Model 42: Positives = 721, Negatives = 49
# Model 43: Positives = 725, Negatives = 45
# Model 44: Positives = 711, Negatives = 59
# Model 45: Positives = 713, Negatives = 57
# Model 46: Positives = 713, Negatives = 57
# Model 47: Positives = 719, Negatives = 51
# Model 48: Positives = 717, Negatives = 53
# Model 49: Positives = 716, Negatives = 54
# Model 50: Positives = 726, Negatives = 44
# Overlapping Capture Rate is 0.9236037766198245
#
# Model Predictions Summary:
# Model 1: Positives = 686, Negatives = 84
# Model 2: Positives = 683, Negatives = 87
# Model 3: Positives = 694, Negatives = 76
# Model 4: Positives = 692, Negatives = 78
# Model 5: Positives = 696, Negatives = 74
# Model 6: Positives = 692, Negatives = 78
# Model 7: Positives = 693, Negatives = 77
# Model 8: Positives = 699, Negatives = 71
# Model 9: Positives = 698, Negatives = 72
# Model 10: Positives = 696, Negatives = 74
# Model 11: Positives = 686, Negatives = 84
# Model 12: Positives = 698, Negatives = 72
# Model 13: Positives = 699, Negatives = 71
# Model 14: Positives = 695, Negatives = 75
# Model 15: Positives = 698, Negatives = 72
# Model 16: Positives = 696, Negatives = 74
# Model 17: Positives = 692, Negatives = 78
# Model 18: Positives = 686, Negatives = 84
# Model 19: Positives = 705, Negatives = 65
# Model 20: Positives = 692, Negatives = 78
# Model 21: Positives = 688, Negatives = 82
# Model 22: Positives = 702, Negatives = 68
# Model 23: Positives = 681, Negatives = 89
# Model 24: Positives = 690, Negatives = 80
# Model 25: Positives = 696, Negatives = 74
# Model 26: Positives = 691, Negatives = 79
# Model 27: Positives = 699, Negatives = 71
# Model 28: Positives = 689, Negatives = 81
# Model 29: Positives = 694, Negatives = 76
# Model 30: Positives = 687, Negatives = 83
# Model 31: Positives = 694, Negatives = 76
# Model 32: Positives = 701, Negatives = 69
# Model 33: Positives = 693, Negatives = 77
# Model 34: Positives = 690, Negatives = 80
# Model 35: Positives = 690, Negatives = 80
# Model 36: Positives = 695, Negatives = 75
# Model 37: Positives = 690, Negatives = 80
# Model 38: Positives = 696, Negatives = 74
# Model 39: Positives = 698, Negatives = 72
# Model 40: Positives = 697, Negatives = 73
# Model 41: Positives = 691, Negatives = 79
# Model 42: Positives = 688, Negatives = 82
# Model 43: Positives = 699, Negatives = 71
# Model 44: Positives = 697, Negatives = 73
# Model 45: Positives = 696, Negatives = 74
# Model 46: Positives = 688, Negatives = 82
# Model 47: Positives = 705, Negatives = 65
# Model 48: Positives = 701, Negatives = 69
# Model 49: Positives = 695, Negatives = 75
# Model 50: Positives = 679, Negatives = 91
# Overlapping Capture Rate is 0.8899959675020359
#
# Model Predictions Summary:
# Model 1: Positives = 722, Negatives = 48
# Model 2: Positives = 705, Negatives = 65
# Model 3: Positives = 727, Negatives = 43
# Model 4: Positives = 719, Negatives = 51
# Model 5: Positives = 714, Negatives = 56
# Model 6: Positives = 716, Negatives = 54
# Model 7: Positives = 723, Negatives = 47
# Model 8: Positives = 713, Negatives = 57
# Model 9: Positives = 719, Negatives = 51
# Model 10: Positives = 719, Negatives = 51
# Model 11: Positives = 712, Negatives = 58
# Model 12: Positives = 718, Negatives = 52
# Model 13: Positives = 710, Negatives = 60
# Model 14: Positives = 720, Negatives = 50
# Model 15: Positives = 716, Negatives = 54
# Model 16: Positives = 714, Negatives = 56
# Model 17: Positives = 721, Negatives = 49
# Model 18: Positives = 720, Negatives = 50
# Model 19: Positives = 719, Negatives = 51
# Model 20: Positives = 710, Negatives = 60
# Model 21: Positives = 728, Negatives = 42
# Model 22: Positives = 723, Negatives = 47
# Model 23: Positives = 721, Negatives = 49
# Model 24: Positives = 717, Negatives = 53
# Model 25: Positives = 716, Negatives = 54
# Model 26: Positives = 727, Negatives = 43
# Model 27: Positives = 718, Negatives = 52
# Model 28: Positives = 724, Negatives = 46
# Model 29: Positives = 732, Negatives = 38
# Model 30: Positives = 718, Negatives = 52
# Model 31: Positives = 716, Negatives = 54
# Model 32: Positives = 722, Negatives = 48
# Model 33: Positives = 710, Negatives = 60
# Model 34: Positives = 716, Negatives = 54
# Model 35: Positives = 719, Negatives = 51
# Model 36: Positives = 718, Negatives = 52
# Model 37: Positives = 718, Negatives = 52
# Model 38: Positives = 714, Negatives = 56
# Model 39: Positives = 714, Negatives = 56
# Model 40: Positives = 721, Negatives = 49
# Model 41: Positives = 723, Negatives = 47
# Model 42: Positives = 720, Negatives = 50
# Model 43: Positives = 723, Negatives = 47
# Model 44: Positives = 722, Negatives = 48
# Model 45: Positives = 723, Negatives = 47
# Model 46: Positives = 724, Negatives = 46
# Model 47: Positives = 718, Negatives = 52
# Model 48: Positives = 717, Negatives = 53
# Model 49: Positives = 728, Negatives = 42
# Model 50: Positives = 716, Negatives = 54
# Overlapping Capture Rate is 0.922397576815433
#
# Model Predictions Summary:
# Model 1: Positives = 727, Negatives = 43
# Model 2: Positives = 729, Negatives = 41
# Model 3: Positives = 729, Negatives = 41
# Model 4: Positives = 731, Negatives = 39
# Model 5: Positives = 730, Negatives = 40
# Model 6: Positives = 723, Negatives = 47
# Model 7: Positives = 733, Negatives = 37
# Model 8: Positives = 728, Negatives = 42
# Model 9: Positives = 728, Negatives = 42
# Model 10: Positives = 730, Negatives = 40
# Model 11: Positives = 727, Negatives = 43
# Model 12: Positives = 731, Negatives = 39
# Model 13: Positives = 727, Negatives = 43
# Model 14: Positives = 728, Negatives = 42
# Model 15: Positives = 724, Negatives = 46
# Model 16: Positives = 728, Negatives = 42
# Model 17: Positives = 722, Negatives = 48
# Model 18: Positives = 726, Negatives = 44
# Model 19: Positives = 722, Negatives = 48
# Model 20: Positives = 728, Negatives = 42
# Model 21: Positives = 722, Negatives = 48
# Model 22: Positives = 729, Negatives = 41
# Model 23: Positives = 730, Negatives = 40
# Model 24: Positives = 723, Negatives = 47
# Model 25: Positives = 727, Negatives = 43
# Model 26: Positives = 727, Negatives = 43
# Model 27: Positives = 724, Negatives = 46
# Model 28: Positives = 732, Negatives = 38
# Model 29: Positives = 730, Negatives = 40
# Model 30: Positives = 730, Negatives = 40
# Model 31: Positives = 727, Negatives = 43
# Model 32: Positives = 723, Negatives = 47
# Model 33: Positives = 724, Negatives = 46
# Model 34: Positives = 723, Negatives = 47
# Model 35: Positives = 730, Negatives = 40
# Model 36: Positives = 736, Negatives = 34
# Model 37: Positives = 725, Negatives = 45
# Model 38: Positives = 730, Negatives = 40
# Model 39: Positives = 726, Negatives = 44
# Model 40: Positives = 725, Negatives = 45
# Model 41: Positives = 724, Negatives = 46
# Model 42: Positives = 729, Negatives = 41
# Model 43: Positives = 727, Negatives = 43
# Model 44: Positives = 725, Negatives = 45
# Model 45: Positives = 728, Negatives = 42
# Model 46: Positives = 727, Negatives = 43
# Model 47: Positives = 729, Negatives = 41
# Model 48: Positives = 731, Negatives = 39
# Model 49: Positives = 718, Negatives = 52
# Model 50: Positives = 732, Negatives = 38
# Overlapping Capture Rate is 0.9317580843515325

# %%
def apply_labeling_from_spies(csv, mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    # Extract protein ID from filename
    df['protein_id'] = df['filename'].apply(lambda x: os.path.basename(x)[:7])
    print(len(df['protein_id']), "is length of protein id's")

    # Group by protein for mean and max versions
    df1_grouped_mean = df.groupby('protein_id').agg({
        'average_score': 'mean',
        'number_atoms': 'first'
    }).reset_index()

    def get_min_max_label(score):
        if score < min_score:
            return "StrongNegative"
        elif min_score <= score < mean_score:
            return "PseudoNegative"
        elif mean_score <= score < max_score:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df1_grouped_mean["min_max_label"] = df1_grouped_mean["average_score"].apply(get_min_max_label)

    def get_percentile_label(score):
        if score < percentile_25:
            return "StrongNegative"
        elif percentile_25 <= score < percentile_50:
            return "PseudoNegative"
        elif percentile_50 <= score < percentile_75:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df1_grouped_mean["percentile_label"] = df1_grouped_mean["average_score"].apply(get_percentile_label)
    df1_grouped_mean["threshold_label"] = df1_grouped_mean["average_score"].apply(lambda x: "Negative" if x < 0.5 else "Positive")

    min_max_results = []
    min_max_results.append((df1_grouped_mean["average_score"] < min_score).sum()) # min_max_strong_negative_count
    min_max_results.append(((df1_grouped_mean["average_score"] > min_score) & (df1_grouped_mean["average_score"] < mean_score)).sum()) # min_max_pseudo_negative_count
    min_max_results.append(((df1_grouped_mean["average_score"] > mean_score) & (df1_grouped_mean["average_score"] < max_score)).sum()) # min_max_pseudo_positive_count
    min_max_results.append((df1_grouped_mean["average_score"] > max_score).sum()) # min_max_strong_positive_count

    percentile_results = []
    percentile_results.append((df1_grouped_mean["average_score"] < percentile_25).sum()) # percentile_strong_negative_count
    percentile_results.append(((df1_grouped_mean["average_score"] > percentile_25) & (df1_grouped_mean["average_score"] < percentile_50)).sum()) # percentile_pseudo_negative_count
    percentile_results.append(((df1_grouped_mean["average_score"] > percentile_50) & (df1_grouped_mean["average_score"] < percentile_75)).sum()) # percentile_pseudo_positive_count
    percentile_results.append((df1_grouped_mean["average_score"] > percentile_75).sum()) # percentile_strong_positive_count

    threshold_results = []
    threshold_results.append((df1_grouped_mean["average_score"] < 0.5).sum()) # threshold_negative_count
    threshold_results.append((df1_grouped_mean["average_score"] > 0.5).sum()) # threshold_positive_count

    # Table 1: Min/Max and Percentile
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    minmax_percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Min_Max (Using Mean)": min_max_results,
        "Percentile (75-50-25)": percentile_results
    })

    # Table 2: Threshold 0.5
    labels_2 = ["Negative", "Positive"]
    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold (0.5)": threshold_results
    })

    print(minmax_percentile_df,"\n", threshold_df)

    output_csv = csv.replace(".csv", "_labeled.csv")
    df1_grouped_mean.to_csv(output_csv, index=False)
    print(f"Updated CSV written to: {output_csv}")

    return min_max_results, percentile_results, threshold_results

def show_evaluation_results(min_max_all, percentile_all, threshold_all):
    # Compute mean and std for each label
    min_max_mean = np.mean(min_max_all, axis=0)
    min_max_std = np.std(min_max_all, axis=0)

    percentile_mean = np.mean(percentile_all, axis=0)
    percentile_std = np.std(percentile_all, axis=0)

    threshold_mean = np.mean(threshold_all, axis=0)
    threshold_std = np.std(threshold_all, axis=0)

    # Create DataFrames to display
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    labels_2 = ["Negative", "Positive"]

    min_max_df = pd.DataFrame({
        "Label": labels_4,
        "Min-Max Mean": min_max_mean,
        "Min-Max Std": min_max_std
    })

    percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Percentile Mean": percentile_mean,
        "Percentile Std": percentile_std
    })

    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold Mean": threshold_mean,
        "Threshold Std": threshold_std
    })

    # Display
    print("=== Min-Max Results ===")
    print(min_max_df)
    print("\n=== Percentile Results ===")
    print(percentile_df)
    print("\n=== Threshold Results ===")
    print(threshold_df)

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     35
# 1  PseudoNegative                    20                     41
# 2  PseudoPositive                   133                     44
# 3  StrongPositive                     0                     34
#        Label  Threshold (0.5)
# 0  Negative                9
# 1  Positive              145
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp1/NewResults/TestPositiveCaptureRates_labeled.csv
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     4                     26
# 1  PseudoNegative                    16                     44
# 2  PseudoPositive                   134                     45
# 3  StrongPositive                     0                     39
#        Label  Threshold (0.5)
# 0  Negative               10
# 1  Positive              144
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp2/NewResults/TestPositiveCaptureRates_labeled.csv
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     47
# 1  PseudoNegative                    33                     30
# 2  PseudoPositive                   120                     43
# 3  StrongPositive                     0                     34
#        Label  Threshold (0.5)
# 0  Negative               16
# 1  Positive              138
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp3/NewResults/TestPositiveCaptureRates_labeled.csv
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     37
# 1  PseudoNegative                    23                     33
# 2  PseudoPositive                   131                     38
# 3  StrongPositive                     0                     46
#        Label  Threshold (0.5)
# 0  Negative               10
# 1  Positive              144
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp4/NewResults/TestPositiveCaptureRates_labeled.csv
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     40
# 1  PseudoNegative                    26                     37
# 2  PseudoPositive                   128                     36
# 3  StrongPositive                     0                     41
#        Label  Threshold (0.5)
# 0  Negative                7
# 1  Positive              147
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp5/NewResults/TestPositiveCaptureRates_labeled.csv
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           1.2     1.469694
# 1  PseudoNegative          23.6     5.748043
# 2  PseudoPositive         129.2     5.035871
# 3  StrongPositive           0.0     0.000000
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative             37.0        6.841053
# 1  PseudoNegative             37.0        5.099020
# 2  PseudoPositive             41.2        3.544009
# 3  StrongPositive             38.8        4.534314
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative            10.4       3.006659
# 1  Positive           143.6       3.006659

# %%
test_unlabeled_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp1/Test/CombinedUnlabeled"  
csv_output_exp1 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp1/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp1, csv_output_exp1, models_exp1)

test_unlabeled_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp2/Test/CombinedUnlabeled"  
csv_output_exp2 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp2/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp2, csv_output_exp2, models_exp2)

test_unlabeled_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp3/Test/CombinedUnlabeled"  
csv_output_exp3 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp3/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp3, csv_output_exp3, models_exp3)

test_unlabeled_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp4/Test/CombinedUnlabeled"  
csv_output_exp4 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp4/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp4, csv_output_exp4, models_exp4)

test_unlabeled_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-st_exp5/Test/CombinedUnlabeled"  
csv_output_exp5 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp5/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 1811, Negatives = 2799
# Model 2: Positives = 1791, Negatives = 2819
# Model 3: Positives = 1846, Negatives = 2764
# Model 4: Positives = 1707, Negatives = 2903
# Model 5: Positives = 1906, Negatives = 2704
# Model 6: Positives = 1679, Negatives = 2931
# Model 7: Positives = 1830, Negatives = 2780
# Model 8: Positives = 1660, Negatives = 2950
# Model 9: Positives = 1754, Negatives = 2856
# Model 10: Positives = 1727, Negatives = 2883
# Model 11: Positives = 1755, Negatives = 2855
# Model 12: Positives = 1811, Negatives = 2799
# Model 13: Positives = 1720, Negatives = 2890
# Model 14: Positives = 1666, Negatives = 2944
# Model 15: Positives = 1855, Negatives = 2755
# Model 16: Positives = 1767, Negatives = 2843
# Model 17: Positives = 1819, Negatives = 2791
# Model 18: Positives = 1766, Negatives = 2844
# Model 19: Positives = 1766, Negatives = 2844
# Model 20: Positives = 1717, Negatives = 2893
# Model 21: Positives = 1796, Negatives = 2814
# Model 22: Positives = 1768, Negatives = 2842
# Model 23: Positives = 1693, Negatives = 2917
# Model 24: Positives = 1655, Negatives = 2955
# Model 25: Positives = 1705, Negatives = 2905
# Model 26: Positives = 1751, Negatives = 2859
# Model 27: Positives = 1806, Negatives = 2804
# Model 28: Positives = 1827, Negatives = 2783
# Model 29: Positives = 1743, Negatives = 2867
# Model 30: Positives = 1846, Negatives = 2764
# Model 31: Positives = 1747, Negatives = 2863
# Model 32: Positives = 1786, Negatives = 2824
# Model 33: Positives = 1793, Negatives = 2817
# Model 34: Positives = 1780, Negatives = 2830
# Model 35: Positives = 1872, Negatives = 2738
# Model 36: Positives = 1630, Negatives = 2980
# Model 37: Positives = 1796, Negatives = 2814
# Model 38: Positives = 1805, Negatives = 2805
# Model 39: Positives = 1811, Negatives = 2799
# Model 40: Positives = 1695, Negatives = 2915
# Model 41: Positives = 1787, Negatives = 2823
# Model 42: Positives = 1730, Negatives = 2880
# Model 43: Positives = 1738, Negatives = 2872
# Model 44: Positives = 1740, Negatives = 2870
# Model 45: Positives = 1738, Negatives = 2872
# Model 46: Positives = 1870, Negatives = 2740
# Model 47: Positives = 1833, Negatives = 2777
# Model 48: Positives = 1865, Negatives = 2745
# Model 49: Positives = 1720, Negatives = 2890
# Model 50: Positives = 1761, Negatives = 2849
# Overlapping Capture Rate is 0.38338315882184426
#
# Model Predictions Summary:
# Model 1: Positives = 1944, Negatives = 2671
# Model 2: Positives = 1675, Negatives = 2940
# Model 3: Positives = 1802, Negatives = 2813
# Model 4: Positives = 1837, Negatives = 2778
# Model 5: Positives = 1745, Negatives = 2870
# Model 6: Positives = 1676, Negatives = 2939
# Model 7: Positives = 1716, Negatives = 2899
# Model 8: Positives = 1701, Negatives = 2914
# Model 9: Positives = 1756, Negatives = 2859
# Model 10: Positives = 1765, Negatives = 2850
# Model 11: Positives = 1739, Negatives = 2876
# Model 12: Positives = 1783, Negatives = 2832
# Model 13: Positives = 1867, Negatives = 2748
# Model 14: Positives = 1783, Negatives = 2832
# Model 15: Positives = 1686, Negatives = 2929
# Model 16: Positives = 1869, Negatives = 2746
# Model 17: Positives = 1744, Negatives = 2871
# Model 18: Positives = 1780, Negatives = 2835
# Model 19: Positives = 1743, Negatives = 2872
# Model 20: Positives = 1757, Negatives = 2858
# Model 21: Positives = 1831, Negatives = 2784
# Model 22: Positives = 1886, Negatives = 2729
# Model 23: Positives = 1760, Negatives = 2855
# Model 24: Positives = 1816, Negatives = 2799
# Model 25: Positives = 1836, Negatives = 2779
# Model 26: Positives = 1781, Negatives = 2834
# Model 27: Positives = 1663, Negatives = 2952
# Model 28: Positives = 1880, Negatives = 2735
# Model 29: Positives = 1807, Negatives = 2808
# Model 30: Positives = 1774, Negatives = 2841
# Model 31: Positives = 1769, Negatives = 2846
# Model 32: Positives = 1825, Negatives = 2790
# Model 33: Positives = 1762, Negatives = 2853
# Model 34: Positives = 1846, Negatives = 2769
# Model 35: Positives = 1689, Negatives = 2926
# Model 36: Positives = 1940, Negatives = 2675
# Model 37: Positives = 1792, Negatives = 2823
# Model 38: Positives = 1861, Negatives = 2754
# Model 39: Positives = 1797, Negatives = 2818
# Model 40: Positives = 1772, Negatives = 2843
# Model 41: Positives = 1742, Negatives = 2873
# Model 42: Positives = 1785, Negatives = 2830
# Model 43: Positives = 1774, Negatives = 2841
# Model 44: Positives = 1843, Negatives = 2772
# Model 45: Positives = 1762, Negatives = 2853
# Model 46: Positives = 1750, Negatives = 2865
# Model 47: Positives = 1827, Negatives = 2788
# Model 48: Positives = 1855, Negatives = 2760
# Model 49: Positives = 1749, Negatives = 2866
# Model 50: Positives = 1702, Negatives = 2913
# Overlapping Capture Rate is 0.38790740193016254
#
# Model Predictions Summary:
# Model 1: Positives = 1805, Negatives = 2810
# Model 2: Positives = 1825, Negatives = 2790
# Model 3: Positives = 1778, Negatives = 2837
# Model 4: Positives = 1671, Negatives = 2944
# Model 5: Positives = 1648, Negatives = 2967
# Model 6: Positives = 1709, Negatives = 2906
# Model 7: Positives = 1642, Negatives = 2973
# Model 8: Positives = 1670, Negatives = 2945
# Model 9: Positives = 1718, Negatives = 2897
# Model 10: Positives = 1693, Negatives = 2922
# Model 11: Positives = 1771, Negatives = 2844
# Model 12: Positives = 1687, Negatives = 2928
# Model 13: Positives = 1745, Negatives = 2870
# Model 14: Positives = 1691, Negatives = 2924
# Model 15: Positives = 1736, Negatives = 2879
# Model 16: Positives = 1668, Negatives = 2947
# Model 17: Positives = 1826, Negatives = 2789
# Model 18: Positives = 1850, Negatives = 2765
# Model 19: Positives = 1668, Negatives = 2947
# Model 20: Positives = 1811, Negatives = 2804
# Model 21: Positives = 1803, Negatives = 2812
# Model 22: Positives = 1670, Negatives = 2945
# Model 23: Positives = 1749, Negatives = 2866
# Model 24: Positives = 1865, Negatives = 2750
# Model 25: Positives = 1652, Negatives = 2963
# Model 26: Positives = 1630, Negatives = 2985
# Model 27: Positives = 1782, Negatives = 2833
# Model 28: Positives = 1758, Negatives = 2857
# Model 29: Positives = 1749, Negatives = 2866
# Model 30: Positives = 1807, Negatives = 2808
# Model 31: Positives = 1780, Negatives = 2835
# Model 32: Positives = 1668, Negatives = 2947
# Model 33: Positives = 1732, Negatives = 2883
# Model 34: Positives = 1917, Negatives = 2698
# Model 35: Positives = 1736, Negatives = 2879
# Model 36: Positives = 1647, Negatives = 2968
# Model 37: Positives = 1720, Negatives = 2895
# Model 38: Positives = 1797, Negatives = 2818
# Model 39: Positives = 1679, Negatives = 2936
# Model 40: Positives = 1670, Negatives = 2945
# Model 41: Positives = 1839, Negatives = 2776
# Model 42: Positives = 1743, Negatives = 2872
# Model 43: Positives = 1820, Negatives = 2795
# Model 44: Positives = 1785, Negatives = 2830
# Model 45: Positives = 1703, Negatives = 2912
# Model 46: Positives = 1821, Negatives = 2794
# Model 47: Positives = 1717, Negatives = 2898
# Model 48: Positives = 1698, Negatives = 2917
# Model 49: Positives = 1748, Negatives = 2867
# Model 50: Positives = 1761, Negatives = 2854
# Overlapping Capture Rate is 0.3795976550075492
#
# Model Predictions Summary:
# Model 1: Positives = 1627, Negatives = 2983
# Model 2: Positives = 1460, Negatives = 3150
# Model 3: Positives = 1625, Negatives = 2985
# Model 4: Positives = 1648, Negatives = 2962
# Model 5: Positives = 1554, Negatives = 3056
# Model 6: Positives = 1751, Negatives = 2859
# Model 7: Positives = 1568, Negatives = 3042
# Model 8: Positives = 1507, Negatives = 3103
# Model 9: Positives = 1498, Negatives = 3112
# Model 10: Positives = 1689, Negatives = 2921
# Model 11: Positives = 1443, Negatives = 3167
# Model 12: Positives = 1711, Negatives = 2899
# Model 13: Positives = 1735, Negatives = 2875
# Model 14: Positives = 1643, Negatives = 2967
# Model 15: Positives = 1696, Negatives = 2914
# Model 16: Positives = 1726, Negatives = 2884
# Model 17: Positives = 1612, Negatives = 2998
# Model 18: Positives = 1737, Negatives = 2873
# Model 19: Positives = 1617, Negatives = 2993
# Model 20: Positives = 1450, Negatives = 3160
# Model 21: Positives = 1567, Negatives = 3043
# Model 22: Positives = 1615, Negatives = 2995
# Model 23: Positives = 1597, Negatives = 3013
# Model 24: Positives = 1734, Negatives = 2876
# Model 25: Positives = 1649, Negatives = 2961
# Model 26: Positives = 1564, Negatives = 3046
# Model 27: Positives = 1702, Negatives = 2908
# Model 28: Positives = 1599, Negatives = 3011
# Model 29: Positives = 1639, Negatives = 2971
# Model 30: Positives = 1771, Negatives = 2839
# Model 31: Positives = 1780, Negatives = 2830
# Model 32: Positives = 1629, Negatives = 2981
# Model 33: Positives = 1843, Negatives = 2767
# Model 34: Positives = 1620, Negatives = 2990
# Model 35: Positives = 1557, Negatives = 3053
# Model 36: Positives = 1537, Negatives = 3073
# Model 37: Positives = 1485, Negatives = 3125
# Model 38: Positives = 1757, Negatives = 2853
# Model 39: Positives = 1680, Negatives = 2930
# Model 40: Positives = 1806, Negatives = 2804
# Model 41: Positives = 1707, Negatives = 2903
# Model 42: Positives = 1794, Negatives = 2816
# Model 43: Positives = 1604, Negatives = 3006
# Model 44: Positives = 1570, Negatives = 3040
# Model 45: Positives = 1585, Negatives = 3025
# Model 46: Positives = 1647, Negatives = 2963
# Model 47: Positives = 1605, Negatives = 3005
# Model 48: Positives = 1795, Negatives = 2815
# Model 49: Positives = 1641, Negatives = 2969
# Model 50: Positives = 1439, Negatives = 3171
# Overlapping Capture Rate is 0.3571385009941981
#
# Model Predictions Summary:
# Model 1: Positives = 1746, Negatives = 2869
# Model 2: Positives = 1897, Negatives = 2718
# Model 3: Positives = 1675, Negatives = 2940
# Model 4: Positives = 1763, Negatives = 2852
# Model 5: Positives = 1825, Negatives = 2790
# Model 6: Positives = 1808, Negatives = 2807
# Model 7: Positives = 1886, Negatives = 2729
# Model 8: Positives = 1903, Negatives = 2712
# Model 9: Positives = 1798, Negatives = 2817
# Model 10: Positives = 1825, Negatives = 2790
# Model 11: Positives = 1784, Negatives = 2831
# Model 12: Positives = 1849, Negatives = 2766
# Model 13: Positives = 1895, Negatives = 2720
# Model 14: Positives = 1754, Negatives = 2861
# Model 15: Positives = 1740, Negatives = 2875
# Model 16: Positives = 1745, Negatives = 2870
# Model 17: Positives = 1888, Negatives = 2727
# Model 18: Positives = 1716, Negatives = 2899
# Model 19: Positives = 1871, Negatives = 2744
# Model 20: Positives = 1882, Negatives = 2733
# Model 21: Positives = 1722, Negatives = 2893
# Model 22: Positives = 1759, Negatives = 2856
# Model 23: Positives = 1759, Negatives = 2856
# Model 24: Positives = 1666, Negatives = 2949
# Model 25: Positives = 1767, Negatives = 2848
# Model 26: Positives = 1837, Negatives = 2778
# Model 27: Positives = 1838, Negatives = 2777
# Model 28: Positives = 1800, Negatives = 2815
# Model 29: Positives = 1924, Negatives = 2691
# Model 30: Positives = 1890, Negatives = 2725
# Model 31: Positives = 1664, Negatives = 2951
# Model 32: Positives = 1794, Negatives = 2821
# Model 33: Positives = 1665, Negatives = 2950
# Model 34: Positives = 1882, Negatives = 2733
# Model 35: Positives = 1856, Negatives = 2759
# Model 36: Positives = 1858, Negatives = 2757
# Model 37: Positives = 1759, Negatives = 2856
# Model 38: Positives = 1857, Negatives = 2758
# Model 39: Positives = 1782, Negatives = 2833
# Model 40: Positives = 1883, Negatives = 2732
# Model 41: Positives = 1815, Negatives = 2800
# Model 42: Positives = 1810, Negatives = 2805
# Model 43: Positives = 1768, Negatives = 2847
# Model 44: Positives = 1872, Negatives = 2743
# Model 45: Positives = 1866, Negatives = 2749
# Model 46: Positives = 1788, Negatives = 2827
# Model 47: Positives = 1851, Negatives = 2764
# Model 48: Positives = 1783, Negatives = 2832
# Model 49: Positives = 1727, Negatives = 2888
# Model 50: Positives = 1705, Negatives = 2910
# Overlapping Capture Rate is 0.39235261719517817

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4z = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
# 4610 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   168                    721
# 1  PseudoNegative                   513                     95
# 2  PseudoPositive                   241                     57
# 3  StrongPositive                     0                     49
#        Label  Threshold (0.5)
# 0  Negative              562
# 1  Positive              360
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp1/NewResults/TestUnlabeledCaptureRates_labeled.csv
# 4615 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   347                    704
# 1  PseudoNegative                   334                     97
# 2  PseudoPositive                   242                     69
# 3  StrongPositive                     0                     53
#        Label  Threshold (0.5)
# 0  Negative              565
# 1  Positive              358
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp2/NewResults/TestUnlabeledCaptureRates_labeled.csv
# 4615 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   242                    737
# 1  PseudoNegative                   450                     76
# 2  PseudoPositive                   231                     60
# 3  StrongPositive                     0                     50
#        Label  Threshold (0.5)
# 0  Negative              576
# 1  Positive              347
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp3/NewResults/TestUnlabeledCaptureRates_labeled.csv
# 4610 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   113                    724
# 1  PseudoNegative                   585                     86
# 2  PseudoPositive                   224                     51
# 3  StrongPositive                     0                     61
#        Label  Threshold (0.5)
# 0  Negative              594
# 1  Positive              328
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp4/NewResults/TestUnlabeledCaptureRates_labeled.csv
# 4615 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                    21                    740
# 1  PseudoNegative                   660                     68
# 2  PseudoPositive                   242                     47
# 3  StrongPositive                     0                     68
#        Label  Threshold (0.5)
# 0  Negative              559
# 1  Positive              364
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp5/NewResults/TestUnlabeledCaptureRates_labeled.csv
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative         178.2   111.023241
# 1  PseudoNegative         508.4   111.979641
# 2  PseudoPositive         236.0     7.293833
# 3  StrongPositive           0.0     0.000000
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative            725.2       12.859238
# 1  PseudoNegative             84.4       11.074295
# 2  PseudoPositive             56.8        7.600000
# 3  StrongPositive             56.2        7.249828
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative           454.4     222.274245
# 1  Positive           314.6      85.485905

# %%
test_ivan_exp1 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-st/positive"  
csv_output_exp1 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp1/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp1, csv_output_exp1, models_exp1)

test_ivan_exp2 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-st/positive"  
csv_output_exp2 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp2/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp2, csv_output_exp2, models_exp2)

test_ivan_exp3 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-st/positive"  
csv_output_exp3 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp3/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp3, csv_output_exp3, models_exp3)

test_ivan_exp4 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-st/positive"  
csv_output_exp4 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp4/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp4, csv_output_exp4, models_exp4)

test_ivan_exp5 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-st/positive"  
csv_output_exp5 = "../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp5/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 52, Negatives = 5
# Model 2: Positives = 52, Negatives = 5
# Model 3: Positives = 50, Negatives = 7
# Model 4: Positives = 54, Negatives = 3
# Model 5: Positives = 52, Negatives = 5
# Model 6: Positives = 49, Negatives = 8
# Model 7: Positives = 50, Negatives = 7
# Model 8: Positives = 49, Negatives = 8
# Model 9: Positives = 49, Negatives = 8
# Model 10: Positives = 49, Negatives = 8
# Model 11: Positives = 52, Negatives = 5
# Model 12: Positives = 52, Negatives = 5
# Model 13: Positives = 48, Negatives = 9
# Model 14: Positives = 53, Negatives = 4
# Model 15: Positives = 50, Negatives = 7
# Model 16: Positives = 51, Negatives = 6
# Model 17: Positives = 52, Negatives = 5
# Model 18: Positives = 52, Negatives = 5
# Model 19: Positives = 52, Negatives = 5
# Model 20: Positives = 52, Negatives = 5
# Model 21: Positives = 47, Negatives = 10
# Model 22: Positives = 50, Negatives = 7
# Model 23: Positives = 52, Negatives = 5
# Model 24: Positives = 51, Negatives = 6
# Model 25: Positives = 49, Negatives = 8
# Model 26: Positives = 52, Negatives = 5
# Model 27: Positives = 49, Negatives = 8
# Model 28: Positives = 53, Negatives = 4
# Model 29: Positives = 50, Negatives = 7
# Model 30: Positives = 53, Negatives = 4
# Model 31: Positives = 52, Negatives = 5
# Model 32: Positives = 52, Negatives = 5
# Model 33: Positives = 52, Negatives = 5
# Model 34: Positives = 51, Negatives = 6
# Model 35: Positives = 51, Negatives = 6
# Model 36: Positives = 50, Negatives = 7
# Model 37: Positives = 49, Negatives = 8
# Model 38: Positives = 53, Negatives = 4
# Model 39: Positives = 52, Negatives = 5
# Model 40: Positives = 50, Negatives = 7
# Model 41: Positives = 53, Negatives = 4
# Model 42: Positives = 48, Negatives = 9
# Model 43: Positives = 53, Negatives = 4
# Model 44: Positives = 53, Negatives = 4
# Model 45: Positives = 48, Negatives = 9
# Model 46: Positives = 52, Negatives = 5
# Model 47: Positives = 50, Negatives = 7
# Model 48: Positives = 49, Negatives = 8
# Model 49: Positives = 50, Negatives = 7
# Model 50: Positives = 52, Negatives = 5
# Overlapping Capture Rate is 0.8802606832806381
# Model Predictions Summary:
# Model 1: Positives = 51, Negatives = 6
# Model 2: Positives = 52, Negatives = 5
# Model 3: Positives = 54, Negatives = 3
# Model 4: Positives = 53, Negatives = 4
# Model 5: Positives = 53, Negatives = 4
# Model 6: Positives = 52, Negatives = 5
# Model 7: Positives = 52, Negatives = 5
# Model 8: Positives = 53, Negatives = 4
# Model 9: Positives = 52, Negatives = 5
# Model 10: Positives = 52, Negatives = 5
# Model 11: Positives = 54, Negatives = 3
# Model 12: Positives = 52, Negatives = 5
# Model 13: Positives = 53, Negatives = 4
# Model 14: Positives = 54, Negatives = 3
# Model 15: Positives = 51, Negatives = 6
# Model 16: Positives = 53, Negatives = 4
# Model 17: Positives = 53, Negatives = 4
# Model 18: Positives = 52, Negatives = 5
# Model 19: Positives = 53, Negatives = 4
# Model 20: Positives = 52, Negatives = 5
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 51, Negatives = 6
# Model 23: Positives = 53, Negatives = 4
# Model 24: Positives = 53, Negatives = 4
# Model 25: Positives = 53, Negatives = 4
# Model 26: Positives = 53, Negatives = 4
# Model 27: Positives = 51, Negatives = 6
# Model 28: Positives = 53, Negatives = 4
# Model 29: Positives = 53, Negatives = 4
# Model 30: Positives = 52, Negatives = 5
# Model 31: Positives = 52, Negatives = 5
# Model 32: Positives = 54, Negatives = 3
# Model 33: Positives = 51, Negatives = 6
# Model 34: Positives = 54, Negatives = 3
# Model 35: Positives = 53, Negatives = 4
# Model 36: Positives = 53, Negatives = 4
# Model 37: Positives = 54, Negatives = 3
# Model 38: Positives = 52, Negatives = 5
# Model 39: Positives = 53, Negatives = 4
# Model 40: Positives = 53, Negatives = 4
# Model 41: Positives = 52, Negatives = 5
# Model 42: Positives = 54, Negatives = 3
# Model 43: Positives = 52, Negatives = 5
# Model 44: Positives = 49, Negatives = 8
# Model 45: Positives = 52, Negatives = 5
# Model 46: Positives = 54, Negatives = 3
# Model 47: Positives = 54, Negatives = 3
# Model 48: Positives = 52, Negatives = 5
# Model 49: Positives = 53, Negatives = 4
# Model 50: Positives = 52, Negatives = 5
# Overlapping Capture Rate is 0.9004810296189822
#
# Model Predictions Summary:
# Model 1: Positives = 49, Negatives = 8
# Model 2: Positives = 51, Negatives = 6
# Model 3: Positives = 53, Negatives = 4
# Model 4: Positives = 49, Negatives = 8
# Model 5: Positives = 51, Negatives = 6
# Model 6: Positives = 52, Negatives = 5
# Model 7: Positives = 50, Negatives = 7
# Model 8: Positives = 48, Negatives = 9
# Model 9: Positives = 50, Negatives = 7
# Model 10: Positives = 50, Negatives = 7
# Model 11: Positives = 49, Negatives = 8
# Model 12: Positives = 47, Negatives = 10
# Model 13: Positives = 46, Negatives = 11
# Model 14: Positives = 49, Negatives = 8
# Model 15: Positives = 51, Negatives = 6
# Model 16: Positives = 49, Negatives = 8
# Model 17: Positives = 47, Negatives = 10
# Model 18: Positives = 47, Negatives = 10
# Model 19: Positives = 51, Negatives = 6
# Model 20: Positives = 48, Negatives = 9
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 53, Negatives = 4
# Model 23: Positives = 49, Negatives = 8
# Model 24: Positives = 50, Negatives = 7
# Model 25: Positives = 47, Negatives = 10
# Model 26: Positives = 51, Negatives = 6
# Model 27: Positives = 53, Negatives = 4
# Model 28: Positives = 46, Negatives = 11
# Model 29: Positives = 50, Negatives = 7
# Model 30: Positives = 52, Negatives = 5
# Model 31: Positives = 50, Negatives = 7
# Model 32: Positives = 49, Negatives = 8
# Model 33: Positives = 50, Negatives = 7
# Model 34: Positives = 47, Negatives = 10
# Model 35: Positives = 53, Negatives = 4
# Model 36: Positives = 48, Negatives = 9
# Model 37: Positives = 49, Negatives = 8
# Model 38: Positives = 52, Negatives = 5
# Model 39: Positives = 51, Negatives = 6
# Model 40: Positives = 52, Negatives = 5
# Model 41: Positives = 49, Negatives = 8
# Model 42: Positives = 50, Negatives = 7
# Model 43: Positives = 52, Negatives = 5
# Model 44: Positives = 54, Negatives = 3
# Model 45: Positives = 51, Negatives = 6
# Model 46: Positives = 48, Negatives = 9
# Model 47: Positives = 52, Negatives = 5
# Model 48: Positives = 47, Negatives = 10
# Model 49: Positives = 48, Negatives = 9
# Model 50: Positives = 48, Negatives = 9
# Overlapping Capture Rate is 0.868393994799041
#
# Model Predictions Summary:
# Model 1: Positives = 51, Negatives = 6
# Model 2: Positives = 48, Negatives = 9
# Model 3: Positives = 52, Negatives = 5
# Model 4: Positives = 52, Negatives = 5
# Model 5: Positives = 48, Negatives = 9
# Model 6: Positives = 49, Negatives = 8
# Model 7: Positives = 50, Negatives = 7
# Model 8: Positives = 52, Negatives = 5
# Model 9: Positives = 48, Negatives = 9
# Model 10: Positives = 53, Negatives = 4
# Model 11: Positives = 52, Negatives = 5
# Model 12: Positives = 48, Negatives = 9
# Model 13: Positives = 52, Negatives = 5
# Model 14: Positives = 50, Negatives = 7
# Model 15: Positives = 50, Negatives = 7
# Model 16: Positives = 52, Negatives = 5
# Model 17: Positives = 49, Negatives = 8
# Model 18: Positives = 50, Negatives = 7
# Model 19: Positives = 52, Negatives = 5
# Model 20: Positives = 49, Negatives = 8
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 49, Negatives = 8
# Model 23: Positives = 49, Negatives = 8
# Model 24: Positives = 53, Negatives = 4
# Model 25: Positives = 49, Negatives = 8
# Model 26: Positives = 54, Negatives = 3
# Model 27: Positives = 50, Negatives = 7
# Model 28: Positives = 53, Negatives = 4
# Model 29: Positives = 52, Negatives = 5
# Model 30: Positives = 50, Negatives = 7
# Model 31: Positives = 52, Negatives = 5
# Model 32: Positives = 53, Negatives = 4
# Model 33: Positives = 52, Negatives = 5
# Model 34: Positives = 51, Negatives = 6
# Model 35: Positives = 50, Negatives = 7
# Model 36: Positives = 52, Negatives = 5
# Model 37: Positives = 49, Negatives = 8
# Model 38: Positives = 52, Negatives = 5
# Model 39: Positives = 51, Negatives = 6
# Model 40: Positives = 53, Negatives = 4
# Model 41: Positives = 52, Negatives = 5
# Model 42: Positives = 49, Negatives = 8
# Model 43: Positives = 52, Negatives = 5
# Model 44: Positives = 50, Negatives = 7
# Model 45: Positives = 51, Negatives = 6
# Model 46: Positives = 53, Negatives = 4
# Model 47: Positives = 51, Negatives = 6
# Model 48: Positives = 51, Negatives = 6
# Model 49: Positives = 51, Negatives = 6
# Model 50: Positives = 50, Negatives = 7
# Overlapping Capture Rate is 0.8790415522008039
#
# Model Predictions Summary:
# Model 1: Positives = 51, Negatives = 6
# Model 2: Positives = 50, Negatives = 7
# Model 3: Positives = 52, Negatives = 5
# Model 4: Positives = 52, Negatives = 5
# Model 5: Positives = 49, Negatives = 8
# Model 6: Positives = 52, Negatives = 5
# Model 7: Positives = 54, Negatives = 3
# Model 8: Positives = 53, Negatives = 4
# Model 9: Positives = 53, Negatives = 4
# Model 10: Positives = 54, Negatives = 3
# Model 11: Positives = 52, Negatives = 5
# Model 12: Positives = 52, Negatives = 5
# Model 13: Positives = 51, Negatives = 6
# Model 14: Positives = 53, Negatives = 4
# Model 15: Positives = 53, Negatives = 4
# Model 16: Positives = 52, Negatives = 5
# Model 17: Positives = 52, Negatives = 5
# Model 18: Positives = 53, Negatives = 4
# Model 19: Positives = 49, Negatives = 8
# Model 20: Positives = 53, Negatives = 4
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 50, Negatives = 7
# Model 23: Positives = 52, Negatives = 5
# Model 24: Positives = 52, Negatives = 5
# Model 25: Positives = 53, Negatives = 4
# Model 26: Positives = 53, Negatives = 4
# Model 27: Positives = 53, Negatives = 4
# Model 28: Positives = 53, Negatives = 4
# Model 29: Positives = 51, Negatives = 6
# Model 30: Positives = 52, Negatives = 5
# Model 31: Positives = 51, Negatives = 6
# Model 32: Positives = 52, Negatives = 5
# Model 33: Positives = 52, Negatives = 5
# Model 34: Positives = 49, Negatives = 8
# Model 35: Positives = 50, Negatives = 7
# Model 36: Positives = 54, Negatives = 3
# Model 37: Positives = 52, Negatives = 5
# Model 38: Positives = 52, Negatives = 5
# Model 39: Positives = 53, Negatives = 4
# Model 40: Positives = 51, Negatives = 6
# Model 41: Positives = 51, Negatives = 6
# Model 42: Positives = 53, Negatives = 4
# Model 43: Positives = 54, Negatives = 3
# Model 44: Positives = 54, Negatives = 3
# Model 45: Positives = 53, Negatives = 4
# Model 46: Positives = 50, Negatives = 7
# Model 47: Positives = 52, Negatives = 5
# Model 48: Positives = 53, Negatives = 4
# Model 49: Positives = 51, Negatives = 6
# Model 50: Positives = 52, Negatives = 5
# Overlapping Capture Rate is 0.8878686361286076

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     15
# 1  PseudoNegative                    13                     14
# 2  PseudoPositive                    43                     13
# 3  StrongPositive                     0                     15
#        Label  Threshold (0.5)
# 0  Negative                5
# 1  Positive               52
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp1/NewResults/TestIvanCaptureRates_labeled.csv
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     13
# 1  PseudoNegative                    11                     10
# 2  PseudoPositive                    45                     17
# 3  StrongPositive                     0                     17
#        Label  Threshold (0.5)
# 0  Negative                4
# 1  Positive               53
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp2/NewResults/TestIvanCaptureRates_labeled.csv
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     16
# 1  PseudoNegative                    14                     11
# 2  PseudoPositive                    42                     14
# 3  StrongPositive                     0                     16
#        Label  Threshold (0.5)
# 0  Negative                7
# 1  Positive               50
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp3/NewResults/TestIvanCaptureRates_labeled.csv
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     15
# 1  PseudoNegative                    11                      9
# 2  PseudoPositive                    45                     12
# 3  StrongPositive                     0                     21
#        Label  Threshold (0.5)
# 0  Negative                5
# 1  Positive               52
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp4/NewResults/TestIvanCaptureRates_labeled.csv
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     17
# 1  PseudoNegative                    13                      9
# 2  PseudoPositive                    44                     11
# 3  StrongPositive                     0                     20
#        Label  Threshold (0.5)
# 0  Negative                4
# 1  Positive               53
# Updated CSV written to: ../../../Models/Cholesterol/3DCNN/3DCholesterolModels-st_exp5/NewResults/TestIvanCaptureRates_labeled.csv
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           0.8      0.40000
# 1  PseudoNegative          12.4      1.20000
# 2  PseudoPositive          43.8      1.16619
# 3  StrongPositive           0.0      0.00000
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative             15.2        1.326650
# 1  PseudoNegative             10.6        1.854724
# 2  PseudoPositive             13.4        2.059126
# 3  StrongPositive             17.8        2.315167
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative             5.0       1.095445
# 1  Positive            52.0       1.095445
