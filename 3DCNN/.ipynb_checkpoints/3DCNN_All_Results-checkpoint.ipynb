# %%
import torch
import torch.nn as nn
import glob
import csv
import numpy as np
import os

# 3D CNN Model
class CNN3D(nn.Module):
    def __init__(self):
        super(CNN3D, self).__init__()
        
        self.conv0 = nn.Conv3d(in_channels=23, out_channels=64, kernel_size=1, stride=1, padding=0) # play around with output channels
        self.conv1 = nn.Conv3d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv3d(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool3d(kernel_size=2, stride=2, padding=0)

        #self.dropout_conv = nn.Dropout3d(p=0.05)
        
        # After two pooling layers, spatial dimensions reduce from 40x40x40 -> 5x5x5
        self.fc1 = nn.Linear(128 * 3 * 3 * 3, 256)  # Try increasing over 256
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 2)  # Assuming 1 output for docking status/position

        #self.dropout_fc = nn.Dropout(p=0.15)
        
    def forward(self, x):
        # Forward pass through Conv layers
        x = self.pool(torch.relu(self.conv0(x)))  # Conv0 -> ReLU -> Pooling
        #x = self.dropout_conv(x)
        x = self.pool(torch.relu(self.conv1(x)))  # Conv1 -> ReLU -> Pooling
        x = self.pool2(torch.relu(self.conv2(x)))  # Conv2 -> ReLU -> Pooling

        # Flatten the input for fully connected layers
        x = x.view(-1, 128 * 3 * 3 * 3)
        
        # Forward pass through fully connected layers
        x = torch.relu(self.fc1(x)) #use tanh activation
        #x = self.dropout_fc(x)
        x = torch.relu(self.fc2(x))
        x = torch.nn.functional.softmax(self.fc3(x), dim=1)  # Final layer (output layer)
        #x = torch.clamp(x, min=1e-7, max=1 - 1e-7)  # Clamp outputs to avoid extreme values
        
        return x
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

models_exp1 = []
models_exp2 = []
models_exp3 = []
models_exp4 = []
models_exp5 = []

k = 50

for i in range (1, (k + 1)):
    model_exp1 = CNN3D().to(device)

    model_exp2 = CNN3D().to(device)

    model_exp3 = CNN3D().to(device)

    model_exp4 = CNN3D().to(device)

    model_exp5 = CNN3D().to(device)

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-5A_exp1/Models/model_bin_{i}.pth" 
    model_exp1.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-5A_exp2/Models/model_bin_{i}.pth" 
    model_exp2.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-5A_exp3/Models/model_bin_{i}.pth" 
    model_exp3.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-5A_exp4/Models/model_bin_{i}.pth" 
    model_exp4.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/3DCNN/3DCholesterolModels-5A_exp5/Models/model_bin_{i}.pth" 
    model_exp5.load_state_dict(torch.load(model_path, map_location=device))

    model_exp1.eval()
    model_exp2.eval()
    model_exp3.eval()
    model_exp4.eval()
    model_exp5.eval()

    models_exp1.append(model_exp1)
    models_exp2.append(model_exp2)
    models_exp3.append(model_exp3)
    models_exp4.append(model_exp4)
    models_exp5.append(model_exp5)
# Out:
# /tmp/ipykernel_2527237/460265724.py:69: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp1.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_2527237/460265724.py:72: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp2.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_2527237/460265724.py:75: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp3.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_2527237/460265724.py:78: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp4.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_2527237/460265724.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp5.load_state_dict(torch.load(model_path, map_location=device))

# %%
def evaluate_file(model, file_path, threshold=0.5):
    grid = np.load(file_path)

    non_padded_rows = np.sum(np.any(grid != 0, axis=(3)))
    
    grid_tensor = torch.tensor(grid, dtype=torch.float32).permute(3, 0, 1, 2).unsqueeze(0)
    grid_tensor = grid_tensor.to(device)
    
    model.eval()
    with torch.no_grad():
        output = model(grid_tensor)

    prob = output[0, 1].item()

    predicted_class = int(prob >= threshold)

    return predicted_class, prob, non_padded_rows

# %%
def evaluate_directory(dir, csv_output, models):
    predictions = []
    capture_rate = 0
    overlapping_capture_rate = 0
    overlapping_index = 0

    files = glob.glob(f"{dir}/*.npy")

    model_positive_counts = [0] * len(models)
    model_negative_counts = [0] * len(models)

    #print(f"{'Filename':<120} {'IndividualCaptureRate':<25} NumberOfAtoms")

    os.makedirs(os.path.dirname(csv_output), exist_ok=True)

    with open(csv_output, "w", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["filename", "average_score", "score_std", "number_atoms"]) 

        for file in sorted(files):    
            model_probs = []
            for model_index, model in enumerate(models):
                predicted_class, prob, non_padded_rows = evaluate_file(model, file)
                model_probs.append(prob)

                if predicted_class == 1:
                    model_positive_counts[model_index] += 1
                else:
                    model_negative_counts[model_index] += 1

            prediction_mean = np.mean(model_probs)
            prediction_std = np.std(model_probs)

            capture_rate += prediction_mean
            #if non_padded_rows <= 65 and non_padded_rows >= 55:
            #print(f"{file:<120} {prediction:<25} {non_padded_rows}")
            overlapping_capture_rate += prediction_mean
            overlapping_index += 1
            writer.writerow([file, prediction_mean, prediction_std, non_padded_rows])

    capture_rate /= len(files)
    overlapping_capture_rate /= overlapping_index

    print("\nModel Predictions Summary:")
    for i, (pos, neg) in enumerate(zip(model_positive_counts, model_negative_counts), start=1):
        print(f"Model {i}: Positives = {pos}, Negatives = {neg}")

    print("Overlapping Capture Rate is", overlapping_capture_rate)

    return capture_rate

# %%
spies_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp1/Spies"  
csv_output_exp1 = "GNN-5A_Exp1/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp1, csv_output_exp1, models_exp1)

spies_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp2/Spies"  
csv_output_exp2 = "GNN-5A_Exp2/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp2, csv_output_exp2, models_exp2)

spies_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp3/Spies"  
csv_output_exp3 = "GNN-5A_Exp3/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp3, csv_output_exp3, models_exp3)

spies_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp4/Spies"  
csv_output_exp4 = "GNN-5A_Exp4/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp4, csv_output_exp4, models_exp4)

spies_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp5/Spies"  
csv_output_exp5 = "GNN-5A_Exp5/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 712, Negatives = 58
# Model 2: Positives = 710, Negatives = 60
# Model 3: Positives = 716, Negatives = 54
# Model 4: Positives = 708, Negatives = 62
# Model 5: Positives = 717, Negatives = 53
# Model 6: Positives = 711, Negatives = 59
# Model 7: Positives = 704, Negatives = 66
# Model 8: Positives = 719, Negatives = 51
# Model 9: Positives = 707, Negatives = 63
# Model 10: Positives = 708, Negatives = 62
# Model 11: Positives = 709, Negatives = 61
# Model 12: Positives = 709, Negatives = 61
# Model 13: Positives = 715, Negatives = 55
# Model 14: Positives = 710, Negatives = 60
# Model 15: Positives = 712, Negatives = 58
# Model 16: Positives = 707, Negatives = 63
# Model 17: Positives = 714, Negatives = 56
# Model 18: Positives = 708, Negatives = 62
# Model 19: Positives = 722, Negatives = 48
# Model 20: Positives = 711, Negatives = 59
# Model 21: Positives = 712, Negatives = 58
# Model 31: Positives = 721, Negatives = 49
# Model 32: Positives = 720, Negatives = 50
# Model 33: Positives = 720, Negatives = 50
# Model 34: Positives = 724, Negatives = 46
# Model 35: Positives = 728, Negatives = 42
# Model 36: Positives = 729, Negatives = 41
# Model 37: Positives = 724, Negatives = 46
# Model 38: Positives = 731, Negatives = 39
# Model 39: Positives = 727, Negatives = 43
# Model 40: Positives = 720, Negatives = 50
# Model 41: Positives = 725, Negatives = 45
# Model 42: Positives = 726, Negatives = 44
# Model 43: Positives = 726, Negatives = 44
# Model 44: Positives = 730, Negatives = 40
# Model 45: Positives = 731, Negatives = 39
# Model 46: Positives = 731, Negatives = 39
# Model 47: Positives = 725, Negatives = 45
# Model 48: Positives = 725, Negatives = 45
# Model 49: Positives = 730, Negatives = 40
# Model 50: Positives = 719, Negatives = 51
# Overlapping Capture Rate is 0.9297626793920131

# %%
import pandas as pd

def get_spy_info(csv):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    # Extract the 'average_score' column
    scores = df["average_score"]

    # Compute statistics
    mean_score = scores.mean()
    percentile_50 = scores.quantile(0.5)
    percentile_25 = scores.quantile(0.25)
    percentile_75 = scores.quantile(0.75)
    min_score = scores.min()
    max_score = scores.max()

    # Print results
    print(f"Mean: {mean_score:.6f}")
    print(f"50th Percentile (Median): {percentile_50:.6f}")
    print(f"Bottom 25 Percentile: {percentile_25:.6f}")
    print(f"Top 25 Percentile: {percentile_75:.6f}")
    print(f"Min: {min_score:.6f}")
    print(f"Max: {max_score:.6f}\n")

    return mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score

print("Experiment 1 Spy Results:")
mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1 = get_spy_info(csv_output_exp1)

print("Experiment 2 Spy Results:")
mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2 = get_spy_info(csv_output_exp2)

print("Experiment 3 Spy Results:")
mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3 = get_spy_info(csv_output_exp3)

print("Experiment 4 Spy Results:")
mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4 = get_spy_info(csv_output_exp4)

print("Experiment 5 Spy Results:")
mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5 = get_spy_info(csv_output_exp5)
# Out:
# Experiment 1 Spy Results:
# Mean: 0.912832
# 50th Percentile (Median): 0.998791
# Bottom 25 Percentile: 0.984050
# Top 25 Percentile: 0.999355
# Min: 0.000151
# Max: 0.999649
#
# Experiment 2 Spy Results:
# Mean: 0.915664
# 50th Percentile (Median): 0.998331
# Bottom 25 Percentile: 0.965530
# Top 25 Percentile: 0.999445
# Min: 0.017560
# Max: 0.999718
#
# Experiment 3 Spy Results:
# Mean: 0.934532
# 50th Percentile (Median): 0.999174
# Bottom 25 Percentile: 0.994055
# Top 25 Percentile: 0.999560
# Min: 0.000462
# Max: 0.999770
#
# Experiment 4 Spy Results:
# Mean: 0.888939
# 50th Percentile (Median): 0.999292
# Bottom 25 Percentile: 0.987407
# Top 25 Percentile: 0.999626
# Min: 0.000003
# Max: 0.999799
#
# Experiment 5 Spy Results:
# Mean: 0.929763
# 50th Percentile (Median): 0.998457
# Bottom 25 Percentile: 0.989244
# Top 25 Percentile: 0.999217
# Min: 0.000005
# Max: 0.999576

# %%
test_positives_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp1/Test/Positive"  
csv_output_exp1 = "3DCholesterolModels-5A_exp1/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_ex
# Model 49: Positives = 722, Negatives = 48
# Model 50: Positives = 723, Negatives = 47
# Overlapping Capture Rate is 0.9351663422052161
#
# Model Predictions Summary:
# Model 1: Positives = 730, Negatives = 40
# Model 2: Positives = 735, Negatives = 35
# Model 3: Positives = 723, Negatives = 47
# Model 4: Positives = 723, Negatives = 47
# Model 5: Positives = 735, Negatives = 35
# Model 6: Positives = 722, Negatives = 48
# Model 7: Positives = 720, Negatives = 50
# Model 8: Positives = 731, Negatives = 39
# Model 9: Positives = 725, Negatives = 45
# Model 10: Positives = 723, Negatives = 47
# Model 11: Positives = 732, Negatives = 38
# Model 12: Positives = 723, Negatives = 47
# Model 13: Positives = 731, Negatives = 39
# Model 14: Positives = 723, Negatives = 47
# Model 15: Positives = 730, Negatives = 40
# Model 16: Positives = 734, Negatives = 36
# Model 17: Positives = 725, Negatives = 45
# Model 18: Positives = 731, Negatives = 39
# Model 19: Positives = 725, Negatives = 45
# Model 20: Positives = 725, Negatives = 45
# Model 21: Positives = 724, Negatives = 46
# Model 22: Positives = 737, Negatives = 33
# Model 23: Positives = 728, Negatives = 42
# Model 24: Positives = 723, Negatives = 47
# Model 25: Positives = 734, Negatives = 36
# Model 26: Positives = 718, Negatives = 52
# Model 27: Positives = 728, Negatives = 42
# Model 28: Positives = 728, Negatives = 42
# Model 29: Positives = 736, Negatives = 34
# Model 30: Positives = 737, Negatives = 33
# Model 31: Positives = 725, Negatives = 45
# Model 32: Positives = 726, Negatives = 44
# Model 33: Positives = 719, Negatives = 51
# Model 34: Positives = 733, Negatives = 37
# Model 35: Positives = 721, Negatives = 49
# Model 36: Positives = 731, Negatives = 39
# Model 37: Positives = 720, Negatives = 50
# Model 38: Positives = 734, Negatives = 36
# Model 39: Positives = 731, Negatives = 39
# Model 40: Positives = 718, Negatives = 52
# Model 41: Positives = 724, Negatives = 46
# Model 42: Positives = 727, Negatives = 43
# Model 43: Positives = 732, Negatives = 38
# Model 44: Positives = 734, Negatives = 36
# Model 45: Positives = 722, Negatives = 48
# Model 46: Positives = 725, Negatives = 45
# Model 47: Positives = 722, Negatives = 48
# Model 48: Positives = 730, Negatives = 40
# Model 49: Positives = 724, Negatives = 46
# Model 50: Positives = 732, Negatives = 38
# Overlapping Capture Rate is 0.9325929677775209

# %%
def apply_labeling_from_spies(csv, mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    # Extract protein ID from filename
    df['protein_id'] = df['filename'].apply(lambda x: os.path.basename(x)[:7])
    print(len(df['protein_id']), "is length of protein id's")

    # Group by protein for mean and max versions
    df1_grouped_mean = df.groupby('protein_id').agg({
        'average_score': 'mean',
        'number_atoms': 'first'
    }).reset_index()

    def get_min_max_label(score):
        if score < min_score:
            return "StrongNegative"
        elif min_score <= score < mean_score:
            return "PseudoNegative"
        elif mean_score <= score < max_score:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df1_grouped_mean["min_max_label"] = df1_grouped_mean["average_score"].apply(get_min_max_label)

    def get_percentile_label(score):
        if score < percentile_25:
            return "StrongNegative"
        elif percentile_25 <= score < percentile_50:
            return "PseudoNegative"
        elif percentile_50 <= score < percentile_75:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df1_grouped_mean["percentile_label"] = df1_grouped_mean["average_score"].apply(get_percentile_label)
    df1_grouped_mean["threshold_label"] = df1_grouped_mean["average_score"].apply(lambda x: "Negative" if x < 0.5 else "Positive")

    min_max_results = []
    min_max_results.append((df1_grouped_mean["average_score"] < min_score).sum()) # min_max_strong_negative_count
    min_max_results.append(((df1_grouped_mean["average_score"] > min_score) & (df1_grouped_mean["average_score"] < mean_score)).sum()) # min_max_pseudo_negative_count
    min_max_results.append(((df1_grouped_mean["average_score"] > mean_score) & (df1_grouped_mean["average_score"] < max_score)).sum()) # min_max_pseudo_positive_count
    min_max_results.append((df1_grouped_mean["average_score"] > max_score).sum()) # min_max_strong_positive_count

    percentile_results = []
    percentile_results.append((df1_grouped_mean["average_score"] < percentile_25).sum()) # percentile_strong_negative_count
    percentile_results.append(((df1_grouped_mean["average_score"] > percentile_25) & (df1_grouped_mean["average_score"] < percentile_50)).sum()) # percentile_pseudo_negative_count
    percentile_results.append(((df1_grouped_mean["average_score"] > percentile_50) & (df1_grouped_mean["average_score"] < percentile_75)).sum()) # percentile_pseudo_positive_count
    percentile_results.append((df1_grouped_mean["average_score"] > percentile_75).sum()) # percentile_strong_positive_count

    threshold_results = []
    threshold_results.append((df1_grouped_mean["average_score"] < 0.5).sum()) # threshold_negative_count
    threshold_results.append((df1_grouped_mean["average_score"] > 0.5).sum()) # threshold_positive_count

    # Table 1: Min/Max and Percentile
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    minmax_percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Min_Max (Using Mean)": min_max_results,
        "Percentile (75-50-25)": percentile_results
    })

    # Table 2: Threshold 0.5
    labels_2 = ["Negative", "Positive"]
    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold (0.5)": threshold_results
    })

    print(minmax_percentile_df,"\n", threshold_df)

    output_csv = csv.replace(".csv", "_labeled.csv")
    df1_grouped_mean.to_csv(output_csv, index=False)
    print(f"Updated CSV written to: {output_csv}")

    return min_max_results, percentile_results, threshold_results

def show_evaluation_results(min_max_all, percentile_all, threshold_all):
    # Compute mean and std for each label
    min_max_mean = np.mean(min_max_all, axis=0)
    min_max_std = np.std(min_max_all, axis=0)

    percentile_mean = np.mean(percentile_all, axis=0)
    percentile_std = np.std(percentile_all, axis=0)

    threshold_mean = np.mean(threshold_all, axis=0)
    threshold_std = np.std(threshold_all, axis=0)

    # Create DataFrames to display
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    labels_2 = ["Negative", "Positive"]

    min_max_df = pd.DataFrame({
        "Label": labels_4,
        "Min-Max Mean": min_max_mean,
        "Min-Max Std": min_max_std
    })

    percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Percentile Mean": percentile_mean,
        "Percentile Std": percentile_std
    })

    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold Mean": threshold_mean,
        "Threshold Std": threshold_std
    })

    # Display
    print("=== Min-Max Results ===")
    print(min_max_df)
    print("\n=== Percentile Results ===")
    print(percentile_df)
    print("\n=== Threshold Results ===")
    print(threshold_df)

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     39
# 1  PseudoNegative                    25                     47
# 2  PseudoPositive                   128                     33
# 3  StrongPositive                     0                     35
#        Label  Threshold (0.5)
# 0  Negative                7
# 1  Positive              147
# Updated CSV written to: 3DCholesterolModels-5A_exp1/NewResults/TestPositiveCaptureRates_labeled.csv
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     5                     32
# 1  PseudoNegative                    17                     47
# 2  PseudoPositive                   132                     41
# 3  StrongPositive                     0                     34
#        Label  Threshold (0.5)
# 0  Negative               10
# 1  Positive              144
# Updated CSV written to: 3DCholesterolModels-5A_exp2/NewResults/TestPositiveCaptureRates_labeled.csv
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     2                     59
# 1  PseudoNegative                    32                     32
# 2  PseudoPositive                   120                     34
# 3  StrongPositive                     0                     29
#        Label  Threshold (0.5)
# 0  Negative               19
# 1  Positive              135
# Updated CSV written to: 3DCholesterolModels-5A_exp3/NewResults/TestPositiveCaptureRates_labeled.csv
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     36
# 1  PseudoNegative                    19                     45
# 2  PseudoPositive                   135                     29
# 3  StrongPositive                     0                     44
#        Label  Threshold (0.5)
# 0  Negative                8
# 1  Positive              146
# Updated CSV written to: 3DCholesterolModels-5A_exp4/NewResults/TestPositiveCaptureRates_labeled.csv
# 770 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     43
# 1  PseudoNegative                    24                     37
# 2  PseudoPositive                   130                     39
# 3  StrongPositive                     0                     35
#        Label  Threshold (0.5)
# 0  Negative                8
# 1  Positive              146
# Updated CSV written to: 3DCholesterolModels-5A_exp5/NewResults/TestPositiveCaptureRates_labeled.csv
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           1.6     1.854724
# 1  PseudoNegative          23.4     5.238320
# 2  PseudoPositive         129.0     5.059644
# 3  StrongPositive           0.0     0.000000
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative             41.8        9.325235
# 1  PseudoNegative             41.6        6.053098
# 2  PseudoPositive             35.2        4.308132
# 3  StrongPositive             35.4        4.841487
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative            10.4       4.409082
# 1  Positive           143.6       4.409082

# %%
test_unlabeled_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp1/Test/CombinedUnlabeled"  
csv_output_exp1 = "3DCholesterolModels-5A_exp1/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp1, csv_output_exp1, models_exp1)

test_unlabeled_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp2/Test/CombinedUnlabeled"  
csv_output_exp2 = "3DCholesterolModels-5A_exp2/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp2, csv_output_exp2, models_exp2)

test_unlabeled_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp3/Test/CombinedUnlabeled"  
csv_output_exp3 = "3DCholesterolModels-5A_exp3/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp3, csv_output_exp3, models_exp3)

test_unlabeled_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp4/Test/CombinedUnlabeled"  
csv_output_exp4 = "3DCholesterolModels-5A_exp4/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp4, csv_output_exp4, models_exp4)

test_unlabeled_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-grid-5A_exp5/Test/CombinedUnlabeled"  
csv_output_exp5 = "3DCholesterolModels-5A_exp5/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives =
is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   205                    760
# 1  PseudoNegative                   474                     64
# 2  PseudoPositive                   244                     52
# 3  StrongPositive                     0                     47
#        Label  Threshold (0.5)
# 0  Negative              568
# 1  Positive              355
# Updated CSV written to: 3DCholesterolModels-5A_exp3/NewResults/TestUnlabeledCaptureRates_labeled.csv
# 4610 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                    39                    750
# 1  PseudoNegative                   631                     69
# 2  PseudoPositive                   252                     54
# 3  StrongPositive                     0                     49
#        Label  Threshold (0.5)
# 0  Negative              584
# 1  Positive              338
# Updated CSV written to: 3DCholesterolModels-5A_exp4/NewResults/TestUnlabeledCaptureRates_labeled.csv
# 4615 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                    15                    748
# 1  PseudoNegative                   661                     70
# 2  PseudoPositive                   247                     48
# 3  StrongPositive                     0                     57
#        Label  Threshold (0.5)
# 0  Negative              562
# 1  Positive              361
# Updated CSV written to: 3DCholesterolModels-5A_exp5/NewResults/TestUnlabeledCaptureRates_labeled.csv
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative         155.0   132.307218
# 1  PseudoNegative         521.2   127.819247
# 2  PseudoPositive         246.4     5.083306
# 3  StrongPositive           0.0     0.000000
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative            746.0        9.654015
# 1  PseudoNegative             75.0        9.295160
# 2  PseudoPositive             50.6        3.555278
# 3  StrongPositive             51.0        3.405877
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative           455.6     223.822787
# 1  Positive           313.4      83.762999

# %%
test_ivan_exp1 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-5A/positive"  
csv_output_exp1 = "3DCholesterolModels-5A_exp1/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp1, csv_output_exp1, models_exp1)

test_ivan_exp2 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-5A/positive"  
csv_output_exp2 = "3DCholesterolModels-5A_exp2/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp2, csv_output_exp2, models_exp2)

test_ivan_exp3 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-5A/positive"  
csv_output_exp3 = "3DCholesterolModels-5A_exp3/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp3, csv_output_exp3, models_exp3)

test_ivan_exp4 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-5A/positive"  
csv_output_exp4 = "3DCholesterolModels-5A_exp4/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp4, csv_output_exp4, models_exp4)

test_ivan_exp5 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-grid-5A/positive"  
csv_output_exp5 = "3DCholesterolModels-5A_exp5/NewResults/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 51, Negatives = 6
# Model 2: Positives = 52, Negatives = 5
# Model 3: Positives = 52, Negatives = 5
# Model 4: Positives = 52, Negatives = 5
# Model 5: Positives = 52, Negatives = 5
# Model 6: Positives = 52, Negatives = 5
# Model 7: Positives = 52, Negatives = 5
# Model 8: Positives = 52, Negatives = 5
# Model 9: Positives = 51, Negatives = 6
# Model 10: Positives = 52, Negatives = 5
# Model 11: Positives = 51, Negatives = 6
# Model 12: Positives = 52, Negatives = 5
# Model 13: Positives = 52, Negatives = 5
# Model 14: Positives = 52, Negatives = 5
# Model 15: Positives = 53, Negatives = 4
# Model 16: Positives = 52, Negatives = 5
# Model 17: Positives = 53, Negatives = 4
# Model 18: Positives = 52, Negatives = 5
# Model 19: Positives = 52, Negatives = 5
# Model 20: Positives = 53, Negatives = 4
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 51, Negatives = 6
# Model 23: Positives = 53, Negatives = 4
# Model 24: Positives = 53, Negatives = 4
# Model 25: Positives = 51, Negatives = 6
# Model 26: Positives = 52, Negatives = 5
# Model 27: Positives = 52, Negatives = 5
# Model 28: Positives = 52, Negatives = 5
# Model 29: Positives = 52, Negatives = 5
# Model 30: Positives = 52, Negatives = 5
# Model 31: Positives = 51, Negatives = 6
# Model 32: Positives = 52, Negatives = 5
# Model 33: Positives =
# Model 43: Positives = 52, Negatives = 5
# Model 44: Positives = 51, Negatives = 6
# Model 45: Positives = 50, Negatives = 7
# Model 46: Positives = 50, Negatives = 7
# Model 47: Positives = 52, Negatives = 5
# Model 48: Positives = 51, Negatives = 6
# Model 49: Positives = 51, Negatives = 6
# Model 50: Positives = 51, Negatives = 6
# Overlapping Capture Rate is 0.8832314282347876
#
# Model Predictions Summary:
# Model 1: Positives = 51, Negatives = 6
# Model 2: Positives = 51, Negatives = 6
# Model 3: Positives = 51, Negatives = 6
# Model 4: Positives = 51, Negatives = 6
# Model 5: Positives = 52, Negatives = 5
# Model 6: Positives = 52, Negatives = 5
# Model 7: Positives = 52, Negatives = 5
# Model 8: Positives = 50, Negatives = 7
# Model 9: Positives = 51, Negatives = 6
# Model 10: Positives = 50, Negatives = 7
# Model 11: Positives = 53, Negatives = 4
# Model 12: Positives = 52, Negatives = 5
# Model 13: Positives = 51, Negatives = 6
# Model 14: Positives = 52, Negatives = 5
# Model 15: Positives = 51, Negatives = 6
# Model 16: Positives = 52, Negatives = 5
# Model 17: Positives = 52, Negatives = 5
# Model 18: Positives = 53, Negatives = 4
# Model 19: Positives = 51, Negatives = 6
# Model 20: Positives = 52, Negatives = 5
# Model 21: Positives = 51, Negatives = 6
# Model 22: Positives = 52, Negatives = 5
# Model 23: Positives = 51, Negatives = 6
# Model 24: Positives = 52, Negatives = 5
# Model 25: Positives = 53, Negatives = 4
# Model 26: Positives = 52, Negatives = 5
# Model 27: Positives = 52, Negatives = 5
# Model 28: Positives = 51, Negatives = 6
# Model 29: Positives = 52, Negatives = 5
# Model 30: Positives = 52, Negatives = 5
# Model 31: Positives = 52, Negatives = 5
# Model 32: Positives = 51, Negatives = 6
# Model 33: Positives = 51, Negatives = 6
# Model 34: Positives = 50, Negatives = 7
# Model 35: Positives = 52, Negatives = 5
# Model 36: Positives = 53, Negatives = 4
# Model 37: Positives = 52, Negatives = 5
# Model 38: Positives = 52, Negatives = 5
# Model 39: Positives = 52, Negatives = 5
# Model 40: Positives = 52, Negatives = 5
# Model 41: Positives = 51, Negatives = 6
# Model 42: Positives = 52, Negatives = 5
# Model 43: Positives = 52, Negatives = 5
# Model 44: Positives = 52, Negatives = 5
# Model 45: Positives = 52, Negatives = 5
# Model 46: Positives = 51, Negatives = 6
# Model 47: Positives = 52, Negatives = 5
# Model 48: Positives = 51, Negatives = 6
# Model 49: Positives = 51, Negatives = 6
# Model 50: Positives = 52, Negatives = 5
# Overlapping Capture Rate is 0.8901785949829922

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     19
# 1  PseudoNegative                     9                     10
# 2  PseudoPositive                    47                     12
# 3  StrongPositive                     0                     16
#        Label  Threshold (0.5)
# 0  Negative                5
# 1  Positive               52
# Updated CSV written to: 3DCholesterolModels-5A_exp1/NewResults/TestIvanCaptureRates_labeled.csv
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     15
# 1  PseudoNegative                     9                     14
# 2  PseudoPositive                    47                     12
# 3  StrongPositive                     0                     16
#        Label  Threshold (0.5)
# 0  Negative                6
# 1  Positive               51
# Updated CSV written to: 3DCholesterolModels-5A_exp2/NewResults/TestIvanCaptureRates_labeled.csv
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     21
# 1  PseudoNegative                    12                     11
# 2  PseudoPositive                    44                     11
# 3  StrongPositive                     0                     14
#        Label  Threshold (0.5)
# 0  Negative                5
# 1  Positive               52
# Updated CSV written to: 3DCholesterolModels-5A_exp3/NewResults/TestIvanCaptureRates_labeled.csv
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     17
# 1  PseudoNegative                    10                     14
# 2  PseudoPositive                    47                      8
# 3  StrongPositive                     0                     18
#        Label  Threshold (0.5)
# 0  Negative                5
# 1  Positive               52
# Updated CSV written to: 3DCholesterolModels-5A_exp4/NewResults/TestIvanCaptureRates_labeled.csv
# 57 is length of protein id's
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     23
# 1  PseudoNegative                    12                      6
# 2  PseudoPositive                    45                     12
# 3  StrongPositive                     0                     16
#        Label  Threshold (0.5)
# 0  Negative                5
# 1  Positive               52
# Updated CSV written to: 3DCholesterolModels-5A_exp5/NewResults/TestIvanCaptureRates_labeled.csv
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           0.6     0.489898
# 1  PseudoNegative          10.4     1.356466
# 2  PseudoPositive          46.0     1.264911
# 3  StrongPositive           0.0     0.000000
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative             19.0        2.828427
# 1  PseudoNegative             11.0        2.966479
# 2  PseudoPositive             11.0        1.549193
# 3  StrongPositive             16.0        1.264911
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative             5.2            0.4
# 1  Positive            51.8            0.4
