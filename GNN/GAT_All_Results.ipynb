# %%
import torch
import torch.nn as nn
import numpy as np
from torch_geometric.data import Data
import glob
import os
import csv
from torch_geometric.nn import GATConv, global_mean_pool

# Define GAT model for batched data
class GAT(torch.nn.Module):
    def __init__(self, in_channels, out_channels, dropout_p=0.1):
        super().__init__()
        self.gat = GATConv(in_channels, out_channels, heads=1, concat=True, edge_dim=1)
        self.pool = global_mean_pool  # Can also use global_max_pool or global_add_pool
        self.dropout = nn.Dropout(p=dropout_p)
        self.norm = nn.BatchNorm1d(out_channels)
        self.linear = torch.nn.Linear(out_channels, 1)

    def forward(self, x, edge_index, edge_attr, batch):
        out, attn_weights = self.gat(x, edge_index, edge_attr, return_attention_weights=True)
        out = self.dropout(out)
        out = self.pool(out, batch)  # Pool over nodes in each graph
        out = self.norm(out)
        out = self.dropout(out) 
        out = self.linear(out)
        return out, attn_weights

def organize_graph_and_add_weight(file_path, label):
    data = np.load(file_path, allow_pickle=True).item()
    inverse_distance = data['inverse_distance']
    encoded_matrix = data['encoded_matrix']

    x = torch.tensor(encoded_matrix, dtype=torch.float32)
    adj = torch.tensor(inverse_distance, dtype=torch.float32)

    # Normalize adjacency (row-normalize)
    adj = adj / (adj.sum(dim=1, keepdim=True) + 1e-8)

    # Create edge_index and edge weights
    edge_index = (adj > 0).nonzero(as_tuple=False).t()
    edge_weight = adj[adj > 0]

    y = torch.tensor([label], dtype=torch.float32)
    
    return Data(x=x, edge_index=edge_index, edge_attr=edge_weight, y=y)
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

models_exp1 = []
models_exp2 = []
models_exp3 = []
models_exp4 = []
models_exp5 = []

k = 50

for i in range (1, (k + 1)):
    model_exp1 = GAT(in_channels=37, out_channels=32).to(device)

    model_exp2 = GAT(in_channels=37, out_channels=32).to(device)

    model_exp3 = GAT(in_channels=37, out_channels=32).to(device)

    model_exp4 = GAT(in_channels=37, out_channels=32).to(device)

    model_exp5 = GAT(in_channels=37, out_channels=32).to(device)

    model_path = f"../../../Models/Cholesterol/GAT/GATModels-5A_exp1v2/Models/model_bin_{i}.pth" 
    model_exp1.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/GAT/GATModels-5A_exp2v2/Models/model_bin_{i}.pth" 
    model_exp2.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/GAT/GATModels-5A_exp3v2/Models/model_bin_{i}.pth" 
    model_exp3.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/GAT/GATModels-5A_exp4v2/Models/model_bin_{i}.pth" 
    model_exp4.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/GAT/GATModels-5A_exp5v2/Models/model_bin_{i}.pth" 
    model_exp5.load_state_dict(torch.load(model_path, map_location=device))

    model_exp1.eval()
    model_exp2.eval()
    model_exp3.eval()
    model_exp4.eval()
    model_exp5.eval()

    models_exp1.append(model_exp1)
    models_exp2.append(model_exp2)
    models_exp3.append(model_exp3)
    models_exp4.append(model_exp4)
    models_exp5.append(model_exp5)
# Out:
# /tmp/ipykernel_530723/2587797401.py:70: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp1.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_530723/2587797401.py:73: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp2.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_530723/2587797401.py:76: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp3.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_530723/2587797401.py:79: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp4.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_530723/2587797401.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp5.load_state_dict(torch.load(model_path, map_location=device))

# %%
def get_capture_rate(dir, csv_output, models):
    predictions = []
    capture_rate = 0
    overlapping_capture_rate = 0
    overlapping_index = 0

    files = glob.glob(f"{dir}/*.npy")

    model_positive_counts = [0] * len(models)
    model_negative_counts = [0] * len(models)

    os.makedirs(os.path.dirname(csv_output), exist_ok=True)

    with open(csv_output, "w", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["filename", "average_score", "score_std", "number_atoms"]) 

        for file in sorted(files):    
            model_probs = []
            for model_index, model in enumerate(models):
                graph = organize_graph_and_add_weight(file, label=0).to(device)
                non_padded_rows = graph.x.size(0)
                with torch.no_grad():
                    out, _ = model(graph.x, graph.edge_index, graph.edge_attr, batch=torch.zeros(graph.x.size(0), dtype=torch.long).to(device))
                    prob = torch.sigmoid(out).item()
                    model_probs.append(prob)

                    if prob >= 0.5:
                        model_positive_counts[model_index] += 1
                    else:
                        model_negative_counts[model_index] += 1

            prediction_mean = np.mean(model_probs)
            prediction_std = np.std(model_probs)

            predictions.append((file, prediction_mean))
            capture_rate += prediction_mean
            #print(f"{file:<120} {prediction:<25} {non_padded_rows}")
            overlapping_capture_rate += prediction_mean
            overlapping_index += 1
            writer.writerow([file, prediction_mean, prediction_std, non_padded_rows])

    capture_rate /= len(files)
    overlapping_capture_rate /= overlapping_index

    print("\nModel Predictions Summary:")
    for i, (pos, neg) in enumerate(zip(model_positive_counts, model_negative_counts), start=1):
        print(f"Model {i}: Positives = {pos}, Negatives = {neg}")

    #print("Overlapping Capture Rate is", overlapping_capture_rate)

    return capture_rate

# %%
spies_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp1/Spies"  
csv_output_exp1 = "GATModels-5A_exp1v2/NewResults/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp1, csv_output_exp1, models_exp1)

spies_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp2/Spies"  
csv_output_exp2 = "GATModels-5A_exp2v2/NewResults/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp2, csv_output_exp2, models_exp2)

spies_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp3/Spies"  
csv_output_exp3 = "GATModels-5A_exp3v2/NewResults/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp3, csv_output_exp3, models_exp3)

spies_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp4/Spies"  
csv_output_exp4 = "GATModels-5A_exp4v2/NewResults/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp4, csv_output_exp4, models_exp4)

spies_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp5/Spies"  
csv_output_exp5 = "GATModels-5A_exp5v2/NewResults/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 124, Negatives = 30
# Model 2: Positives = 135, Negatives = 19
# Model 3: Positives = 130, Negatives = 24
# Model 4: Positives = 134, Negatives = 20
# Model 5: Positives = 127, Negatives = 27
# Model 6: Positives = 129, Negatives = 25
# Model 7: Positives = 133, Negatives = 21
# Model 8: Positives = 133, Negatives = 21
# Model 9: Positives = 139, Negatives = 15
# Model 10: Positives = 132, Negatives = 22
# Model 11: Positives = 126, Negatives = 28
# Model 12: Positives = 138, Negatives = 16
# Model 13: Positives = 132, Negatives = 22
# Model 14: Positives = 129, Negatives = 25
# Model 15: Positives = 131, Negatives = 23
# Model 16: Positives = 137, Negatives = 17
# Model 17: Positives = 129, Negatives = 25
# Model 18: Positives = 133, Negatives = 21
# Model 19: Positives = 124, Negatives = 30
# Model 20: Positives = 130, Negatives = 24
# Model 21: Positives = 132, Negatives = 22
# Model 22: Positives = 129, Negatives = 25
# Model 23: Positives = 121, Negatives = 33
# Model 24: Positives = 133, Negatives = 21
# Model 25: Positives = 130, Negatives = 24
# Model 26: Positives = 131, Negatives = 23
# Model 27: Positives = 131, Negatives = 23
# Model 28: Positives = 131, Negatives = 23
# Model 29: Positives = 119, Negatives = 35
# Model 30: Positives = 127, Negatives = 27
# Model 31: Positives = 127, Negatives = 27
# Model 32: Positives = 135, Negatives = 19
# Model 33: Positives = 134, Negatives = 20
# Model 34: Positives = 125, Negatives = 29
# Model 35: Positives = 129, Negatives = 25
# Model 36: Positives = 130, Negatives = 24
# Model 37: Positives = 131, Negatives = 23
# Model 38: Positives = 130, Negatives = 24
# Model 39: Positives = 135, Negatives = 19
# Model 40: Positives = 138, Negatives = 16
# Model 41: Positives = 124, Negatives = 30
# Model 42: Positives = 136, Negatives = 18
# Model 43: Positives = 131, Negatives = 23
# Model 44: Positives = 136, Negatives = 18
# Model 45: Positives = 131, Negatives = 23
# Model 46: Positives = 133, Negatives = 21
# Model 47: Positives = 127, Negatives = 27
# Model 48: Positives = 135, Negatives = 19
# Model 49: Positives = 127, Negatives = 27
# Model 50: Positives = 123, Negatives = 31
#
# Model Predictions Summary:
# Model 1: Positives = 113, Negatives = 41
# Model 2: Positives = 127, Negatives = 27
# Model 3: Positives = 131, Negatives = 23
# Model 4: Positives = 133, Negatives = 21
# Model 5: Positives = 125, Negatives = 29
# Model 6: Positives = 117, Negatives = 37
# Model 7: Positives = 131, Negatives = 23
# Model 8: Positives = 128, Negatives = 26
# Model 9: Positives = 131, Negatives = 23
# Model 10: Positives = 127, Negatives = 27
# Model 11: Positives = 131, Negatives = 23
# Model 12: Positives = 117, Negatives = 37
# Model 13: Positives = 126, Negatives = 28
# Model 14: Positives = 123, Negatives = 31
# Model 15: Positives = 133, Negatives = 21
# Model 16: Positives = 131, Negatives = 23
# Model 17: Positives = 112, Negatives = 42
# Model 18: Positives = 129, Negatives = 25
# Model 19: Positives = 124, Negatives = 30
# Model 20: Positives = 126, Negatives = 28
# Model 21: Positives = 122, Negatives = 32
# Model 22: Positives = 127, Negatives = 27
# Model 23: Positives = 127, Negatives = 27
# Model 24: Positives = 112, Negatives = 42
# Model 25: Positives = 126, Negatives = 28
# Model 26: Positives = 116, Negatives = 38
# Model 27: Positives = 114, Negatives = 40
# Model 28: Positives = 117, Negatives = 37
# Model 29: Positives = 136, Negatives = 18
# Model 30: Positives = 121, Negatives = 33
# Model 31: Positives = 123, Negatives = 31
# Model 32: Positives = 122, Negatives = 32
# Model 33: Positives = 122, Negatives = 32
# Model 34: Positives = 129, Negatives = 25
# Model 35: Positives = 116, Negatives = 38
# Model 36: Positives = 130, Negatives = 24
# Model 37: Positives = 113, Negatives = 41
# Model 38: Positives = 129, Negatives = 25
# Model 39: Positives = 119, Negatives = 35
# Model 40: Positives = 129, Negatives = 25
# Model 41: Positives = 115, Negatives = 39
# Model 42: Positives = 128, Negatives = 26
# Model 43: Positives = 116, Negatives = 38
# Model 44: Positives = 123, Negatives = 31
# Model 45: Positives = 121, Negatives = 33
# Model 46: Positives = 120, Negatives = 34
# Model 47: Positives = 136, Negatives = 18
# Model 48: Positives = 127, Negatives = 27
# Model 49: Positives = 133, Negatives = 21
# Model 50: Positives = 132, Negatives = 22
#
# Model Predictions Summary:
# Model 1: Positives = 132, Negatives = 22
# Model 2: Positives = 132, Negatives = 22
# Model 3: Positives = 142, Negatives = 12
# Model 4: Positives = 136, Negatives = 18
# Model 5: Positives = 137, Negatives = 17
# Model 6: Positives = 142, Negatives = 12
# Model 7: Positives = 138, Negatives = 16
# Model 8: Positives = 129, Negatives = 25
# Model 9: Positives = 137, Negatives = 17
# Model 10: Positives = 137, Negatives = 17
# Model 11: Positives = 138, Negatives = 16
# Model 12: Positives = 134, Negatives = 20
# Model 13: Positives = 138, Negatives = 16
# Model 14: Positives = 141, Negatives = 13
# Model 15: Positives = 131, Negatives = 23
# Model 16: Positives = 138, Negatives = 16
# Model 17: Positives = 132, Negatives = 22
# Model 18: Positives = 137, Negatives = 17
# Model 19: Positives = 141, Negatives = 13
# Model 20: Positives = 138, Negatives = 16
# Model 21: Positives = 131, Negatives = 23
# Model 22: Positives = 129, Negatives = 25
# Model 23: Positives = 131, Negatives = 23
# Model 24: Positives = 123, Negatives = 31
# Model 25: Positives = 137, Negatives = 17
# Model 26: Positives = 126, Negatives = 28
# Model 27: Positives = 135, Negatives = 19
# Model 28: Positives = 135, Negatives = 19
# Model 29: Positives = 138, Negatives = 16
# Model 30: Positives = 146, Negatives = 8
# Model 31: Positives = 131, Negatives = 23
# Model 32: Positives = 140, Negatives = 14
# Model 33: Positives = 129, Negatives = 25
# Model 34: Positives = 139, Negatives = 15
# Model 35: Positives = 135, Negatives = 19
# Model 36: Positives = 132, Negatives = 22
# Model 37: Positives = 134, Negatives = 20
# Model 38: Positives = 136, Negatives = 18
# Model 39: Positives = 138, Negatives = 16
# Model 40: Positives = 144, Negatives = 10
# Model 41: Positives = 137, Negatives = 17
# Model 42: Positives = 135, Negatives = 19
# Model 43: Positives = 134, Negatives = 20
# Model 44: Positives = 140, Negatives = 14
# Model 45: Positives = 139, Negatives = 15
# Model 46: Positives = 140, Negatives = 14
# Model 47: Positives = 130, Negatives = 24
# Model 48: Positives = 135, Negatives = 19
# Model 49: Positives = 137, Negatives = 17
# Model 50: Positives = 133, Negatives = 21
#
# Model Predictions Summary:
# Model 1: Positives = 121, Negatives = 33
# Model 2: Positives = 124, Negatives = 30
# Model 3: Positives = 109, Negatives = 45
# Model 4: Positives = 133, Negatives = 21
# Model 5: Positives = 120, Negatives = 34
# Model 6: Positives = 129, Negatives = 25
# Model 7: Positives = 134, Negatives = 20
# Model 8: Positives = 127, Negatives = 27
# Model 9: Positives = 134, Negatives = 20
# Model 10: Positives = 136, Negatives = 18
# Model 11: Positives = 124, Negatives = 30
# Model 12: Positives = 124, Negatives = 30
# Model 13: Positives = 128, Negatives = 26
# Model 14: Positives = 122, Negatives = 32
# Model 15: Positives = 128, Negatives = 26
# Model 16: Positives = 115, Negatives = 39
# Model 17: Positives = 123, Negatives = 31
# Model 18: Positives = 120, Negatives = 34
# Model 19: Positives = 125, Negatives = 29
# Model 20: Positives = 130, Negatives = 24
# Model 21: Positives = 125, Negatives = 29
# Model 22: Positives = 124, Negatives = 30
# Model 23: Positives = 113, Negatives = 41
# Model 24: Positives = 122, Negatives = 32
# Model 25: Positives = 122, Negatives = 32
# Model 26: Positives = 120, Negatives = 34
# Model 27: Positives = 125, Negatives = 29
# Model 28: Positives = 125, Negatives = 29
# Model 29: Positives = 128, Negatives = 26
# Model 30: Positives = 119, Negatives = 35
# Model 31: Positives = 130, Negatives = 24
# Model 32: Positives = 128, Negatives = 26
# Model 33: Positives = 130, Negatives = 24
# Model 34: Positives = 128, Negatives = 26
# Model 35: Positives = 128, Negatives = 26
# Model 36: Positives = 126, Negatives = 28
# Model 37: Positives = 117, Negatives = 37
# Model 38: Positives = 123, Negatives = 31
# Model 39: Positives = 136, Negatives = 18
# Model 40: Positives = 136, Negatives = 18
# Model 41: Positives = 123, Negatives = 31
# Model 42: Positives = 125, Negatives = 29
# Model 43: Positives = 135, Negatives = 19
# Model 44: Positives = 135, Negatives = 19
# Model 45: Positives = 130, Negatives = 24
# Model 46: Positives = 125, Negatives = 29
# Model 47: Positives = 124, Negatives = 30
# Model 48: Positives = 115, Negatives = 39
# Model 49: Positives = 121, Negatives = 33
# Model 50: Positives = 126, Negatives = 28
#
# Model Predictions Summary:
# Model 1: Positives = 136, Negatives = 18
# Model 2: Positives = 132, Negatives = 22
# Model 3: Positives = 130, Negatives = 24
# Model 4: Positives = 132, Negatives = 22
# Model 5: Positives = 123, Negatives = 31
# Model 6: Positives = 112, Negatives = 42
# Model 7: Positives = 130, Negatives = 24
# Model 8: Positives = 137, Negatives = 17
# Model 9: Positives = 129, Negatives = 25
# Model 10: Positives = 125, Negatives = 29
# Model 11: Positives = 124, Negatives = 30
# Model 12: Positives = 128, Negatives = 26
# Model 13: Positives = 116, Negatives = 38
# Model 14: Positives = 120, Negatives = 34
# Model 15: Positives = 129, Negatives = 25
# Model 16: Positives = 138, Negatives = 16
# Model 17: Positives = 136, Negatives = 18
# Model 18: Positives = 131, Negatives = 23
# Model 19: Positives = 132, Negatives = 22
# Model 20: Positives = 134, Negatives = 20
# Model 21: Positives = 122, Negatives = 32
# Model 22: Positives = 135, Negatives = 19
# Model 23: Positives = 135, Negatives = 19
# Model 24: Positives = 125, Negatives = 29
# Model 25: Positives = 130, Negatives = 24
# Model 26: Positives = 130, Negatives = 24
# Model 27: Positives = 132, Negatives = 22
# Model 28: Positives = 132, Negatives = 22
# Model 29: Positives = 120, Negatives = 34
# Model 30: Positives = 144, Negatives = 10
# Model 31: Positives = 124, Negatives = 30
# Model 32: Positives = 122, Negatives = 32
# Model 33: Positives = 136, Negatives = 18
# Model 34: Positives = 138, Negatives = 16
# Model 35: Positives = 135, Negatives = 19
# Model 36: Positives = 119, Negatives = 35
# Model 37: Positives = 129, Negatives = 25
# Model 38: Positives = 135, Negatives = 19
# Model 39: Positives = 127, Negatives = 27
# Model 40: Positives = 121, Negatives = 33
# Model 41: Positives = 128, Negatives = 26
# Model 42: Positives = 123, Negatives = 31
# Model 43: Positives = 136, Negatives = 18
# Model 44: Positives = 128, Negatives = 26
# Model 45: Positives = 128, Negatives = 26
# Model 46: Positives = 128, Negatives = 26
# Model 47: Positives = 138, Negatives = 16
# Model 48: Positives = 135, Negatives = 19
# Model 49: Positives = 139, Negatives = 15
# Model 50: Positives = 123, Negatives = 31

# %%
import pandas as pd

def get_spy_info(csv):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    # Extract the 'average_score' column
    scores = df["average_score"]

    # Compute statistics
    mean_score = scores.mean()
    percentile_50 = scores.quantile(0.5)
    percentile_25 = scores.quantile(0.25)
    percentile_75 = scores.quantile(0.75)
    min_score = scores.min()
    max_score = scores.max()

    # Print results
    print(f"Mean: {mean_score:.6f}")
    print(f"50th Percentile (Median): {percentile_50:.6f}")
    print(f"Bottom 25 Percentile: {percentile_25:.6f}")
    print(f"Top 25 Percentile: {percentile_75:.6f}")
    print(f"Min: {min_score:.6f}")
    print(f"Max: {max_score:.6f}\n")

    return mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score

print("Experiment 1 Spy Results:")
mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1 = get_spy_info(csv_output_exp1)

print("Experiment 2 Spy Results:")
mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2 = get_spy_info(csv_output_exp2)

print("Experiment 3 Spy Results:")
mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3 = get_spy_info(csv_output_exp3)

print("Experiment 4 Spy Results:")
mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4 = get_spy_info(csv_output_exp4)

print("Experiment 5 Spy Results:")
mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5 = get_spy_info(csv_output_exp5)
# Out:
# Experiment 1 Spy Results:
# Mean: 0.748171
# 50th Percentile (Median): 0.808170
# Bottom 25 Percentile: 0.649602
# Top 25 Percentile: 0.893732
# Min: 0.088230
# Max: 0.995296
#
# Experiment 2 Spy Results:
# Mean: 0.743725
# 50th Percentile (Median): 0.840388
# Bottom 25 Percentile: 0.588170
# Top 25 Percentile: 0.919473
# Min: 0.082657
# Max: 0.986154
#
# Experiment 3 Spy Results:
# Mean: 0.775384
# 50th Percentile (Median): 0.841336
# Bottom 25 Percentile: 0.703769
# Top 25 Percentile: 0.905124
# Min: 0.107967
# Max: 0.987543
#
# Experiment 4 Spy Results:
# Mean: 0.723468
# 50th Percentile (Median): 0.798318
# Bottom 25 Percentile: 0.614784
# Top 25 Percentile: 0.894516
# Min: 0.033989
# Max: 0.989565
#
# Experiment 5 Spy Results:
# Mean: 0.765624
# 50th Percentile (Median): 0.853644
# Bottom 25 Percentile: 0.643862
# Top 25 Percentile: 0.930683
# Min: 0.015046
# Max: 0.998265

# %%
test_positives_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp1/Test/Positive"  
csv_output_exp1 = "GATModels-5A_exp1v2/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp1, csv_output_exp1, models_exp1)

test_positives_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp2/Test/Positive"  
csv_output_exp2 = "GATModels-5A_exp2v2/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp2, csv_output_exp2, models_exp2)

test_positives_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp3/Test/Positive"  
csv_output_exp3 = "GATModels-5A_exp3v2/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp3, csv_output_exp3, models_exp3)

test_positives_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp4/Test/Positive"  
csv_output_exp4 = "GATModels-5A_exp4v2/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp4, csv_output_exp4, models_exp4)

test_positives_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp5/Test/Positive"  
csv_output_exp5 = "GATModels-5A_exp5v2/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 121, Negatives = 33
# Model 2: Positives = 136, Negatives = 18
# Model 3: Positives = 133, Negatives = 21
# Model 4: Positives = 141, Negatives = 13
# Model 5: Positives = 132, Negatives = 22
# Model 6: Positives = 134, Negatives = 20
# Model 7: Positives = 138, Negatives = 16
# Model 8: Positives = 136, Negatives = 18
# Model 9: Positives = 141, Negatives = 13
# Model 10: Positives = 131, Negatives = 23
# Model 11: Positives = 132, Negatives = 22
# Model 12: Positives = 140, Negatives = 14
# Model 13: Positives = 143, Negatives = 11
# Model 14: Positives = 133, Negatives = 21
# Model 15: Positives = 135, Negatives = 19
# Model 16: Positives = 133, Negatives = 21
# Model 17: Positives = 138, Negatives = 16
# Model 18: Positives = 137, Negatives = 17
# Model 19: Positives = 121, Negatives = 33
# Model 20: Positives = 137, Negatives = 17
# Model 21: Positives = 134, Negatives = 20
# Model 22: Positives = 132, Negatives = 22
# Model 23: Positives = 121, Negatives = 33
# Model 24: Positives = 138, Negatives = 16
# Model 25: Positives = 133, Negatives = 21
# Model 26: Positives = 134, Negatives = 20
# Model 27: Positives = 133, Negatives = 21
# Model 28: Positives = 132, Negatives = 22
# Model 29: Positives = 116, Negatives = 38
# Model 30: Positives = 133, Negatives = 21
# Model 31: Positives = 134, Negatives = 20
# Model 32: Positives = 137, Negatives = 17
# Model 33: Positives = 133, Negatives = 21
# Model 34: Positives = 131, Negatives = 23
# Model 35: Positives = 135, Negatives = 19
# Model 36: Positives = 133, Negatives = 21
# Model 37: Positives = 136, Negatives = 18
# Model 38: Positives = 130, Negatives = 24
# Model 39: Positives = 135, Negatives = 19
# Model 40: Positives = 136, Negatives = 18
# Model 41: Positives = 127, Negatives = 27
# Model 42: Positives = 138, Negatives = 16
# Model 43: Positives = 135, Negatives = 19
# Model 44: Positives = 141, Negatives = 13
# Model 45: Positives = 130, Negatives = 24
# Model 46: Positives = 133, Negatives = 21
# Model 47: Positives = 130, Negatives = 24
# Model 48: Positives = 134, Negatives = 20
# Model 49: Positives = 133, Negatives = 21
# Model 50: Positives = 131, Negatives = 23
#
# Model Predictions Summary:
# Model 1: Positives = 126, Negatives = 28
# Model 2: Positives = 135, Negatives = 19
# Model 3: Positives = 140, Negatives = 14
# Model 4: Positives = 138, Negatives = 16
# Model 5: Positives = 135, Negatives = 19
# Model 6: Positives = 128, Negatives = 26
# Model 7: Positives = 136, Negatives = 18
# Model 8: Positives = 136, Negatives = 18
# Model 9: Positives = 139, Negatives = 15
# Model 10: Positives = 135, Negatives = 19
# Model 11: Positives = 140, Negatives = 14
# Model 12: Positives = 125, Negatives = 29
# Model 13: Positives = 137, Negatives = 17
# Model 14: Positives = 133, Negatives = 21
# Model 15: Positives = 137, Negatives = 17
# Model 16: Positives = 140, Negatives = 14
# Model 17: Positives = 117, Negatives = 37
# Model 18: Positives = 133, Negatives = 21
# Model 19: Positives = 129, Negatives = 25
# Model 20: Positives = 130, Negatives = 24
# Model 21: Positives = 127, Negatives = 27
# Model 22: Positives = 136, Negatives = 18
# Model 23: Positives = 136, Negatives = 18
# Model 24: Positives = 125, Negatives = 29
# Model 25: Positives = 133, Negatives = 21
# Model 26: Positives = 129, Negatives = 25
# Model 27: Positives = 129, Negatives = 25
# Model 28: Positives = 127, Negatives = 27
# Model 29: Positives = 140, Negatives = 14
# Model 30: Positives = 129, Negatives = 25
# Model 31: Positives = 133, Negatives = 21
# Model 32: Positives = 134, Negatives = 20
# Model 33: Positives = 132, Negatives = 22
# Model 34: Positives = 132, Negatives = 22
# Model 35: Positives = 125, Negatives = 29
# Model 36: Positives = 136, Negatives = 18
# Model 37: Positives = 131, Negatives = 23
# Model 38: Positives = 135, Negatives = 19
# Model 39: Positives = 130, Negatives = 24
# Model 40: Positives = 138, Negatives = 16
# Model 41: Positives = 123, Negatives = 31
# Model 42: Positives = 132, Negatives = 22
# Model 43: Positives = 128, Negatives = 26
# Model 44: Positives = 137, Negatives = 17
# Model 45: Positives = 134, Negatives = 20
# Model 46: Positives = 127, Negatives = 27
# Model 47: Positives = 140, Negatives = 14
# Model 48: Positives = 135, Negatives = 19
# Model 49: Positives = 136, Negatives = 18
# Model 50: Positives = 136, Negatives = 18
#
# Model Predictions Summary:
# Model 1: Positives = 119, Negatives = 35
# Model 2: Positives = 123, Negatives = 31
# Model 3: Positives = 134, Negatives = 20
# Model 4: Positives = 129, Negatives = 25
# Model 5: Positives = 137, Negatives = 17
# Model 6: Positives = 133, Negatives = 21
# Model 7: Positives = 128, Negatives = 26
# Model 8: Positives = 123, Negatives = 31
# Model 9: Positives = 128, Negatives = 26
# Model 10: Positives = 124, Negatives = 30
# Model 11: Positives = 126, Negatives = 28
# Model 12: Positives = 126, Negatives = 28
# Model 13: Positives = 133, Negatives = 21
# Model 14: Positives = 132, Negatives = 22
# Model 15: Positives = 125, Negatives = 29
# Model 16: Positives = 134, Negatives = 20
# Model 17: Positives = 116, Negatives = 38
# Model 18: Positives = 127, Negatives = 27
# Model 19: Positives = 134, Negatives = 20
# Model 20: Positives = 130, Negatives = 24
# Model 21: Positives = 117, Negatives = 37
# Model 22: Positives = 120, Negatives = 34
# Model 23: Positives = 122, Negatives = 32
# Model 24: Positives = 122, Negatives = 32
# Model 25: Positives = 124, Negatives = 30
# Model 26: Positives = 113, Negatives = 41
# Model 27: Positives = 126, Negatives = 28
# Model 28: Positives = 133, Negatives = 21
# Model 29: Positives = 130, Negatives = 24
# Model 30: Positives = 137, Negatives = 17
# Model 31: Positives = 118, Negatives = 36
# Model 32: Positives = 126, Negatives = 28
# Model 33: Positives = 120, Negatives = 34
# Model 34: Positives = 131, Negatives = 23
# Model 35: Positives = 128, Negatives = 26
# Model 36: Positives = 121, Negatives = 33
# Model 37: Positives = 130, Negatives = 24
# Model 38: Positives = 121, Negatives = 33
# Model 39: Positives = 130, Negatives = 24
# Model 40: Positives = 128, Negatives = 26
# Model 41: Positives = 134, Negatives = 20
# Model 42: Positives = 121, Negatives = 33
# Model 43: Positives = 129, Negatives = 25
# Model 44: Positives = 133, Negatives = 21
# Model 45: Positives = 131, Negatives = 23
# Model 46: Positives = 130, Negatives = 24
# Model 47: Positives = 121, Negatives = 33
# Model 48: Positives = 128, Negatives = 26
# Model 49: Positives = 124, Negatives = 30
# Model 50: Positives = 119, Negatives = 35
#
# Model Predictions Summary:
# Model 1: Positives = 137, Negatives = 17
# Model 2: Positives = 131, Negatives = 23
# Model 3: Positives = 133, Negatives = 21
# Model 4: Positives = 141, Negatives = 13
# Model 5: Positives = 133, Negatives = 21
# Model 6: Positives = 131, Negatives = 23
# Model 7: Positives = 135, Negatives = 19
# Model 8: Positives = 137, Negatives = 17
# Model 9: Positives = 135, Negatives = 19
# Model 10: Positives = 140, Negatives = 14
# Model 11: Positives = 131, Negatives = 23
# Model 12: Positives = 135, Negatives = 19
# Model 13: Positives = 139, Negatives = 15
# Model 14: Positives = 131, Negatives = 23
# Model 15: Positives = 140, Negatives = 14
# Model 16: Positives = 132, Negatives = 22
# Model 17: Positives = 131, Negatives = 23
# Model 18: Positives = 130, Negatives = 24
# Model 19: Positives = 137, Negatives = 17
# Model 20: Positives = 136, Negatives = 18
# Model 21: Positives = 142, Negatives = 12
# Model 22: Positives = 135, Negatives = 19
# Model 23: Positives = 116, Negatives = 38
# Model 24: Positives = 131, Negatives = 23
# Model 25: Positives = 138, Negatives = 16
# Model 26: Positives = 132, Negatives = 22
# Model 27: Positives = 134, Negatives = 20
# Model 28: Positives = 136, Negatives = 18
# Model 29: Positives = 136, Negatives = 18
# Model 30: Positives = 123, Negatives = 31
# Model 31: Positives = 135, Negatives = 19
# Model 32: Positives = 132, Negatives = 22
# Model 33: Positives = 135, Negatives = 19
# Model 34: Positives = 132, Negatives = 22
# Model 35: Positives = 131, Negatives = 23
# Model 36: Positives = 135, Negatives = 19
# Model 37: Positives = 132, Negatives = 22
# Model 38: Positives = 132, Negatives = 22
# Model 39: Positives = 142, Negatives = 12
# Model 40: Positives = 141, Negatives = 13
# Model 41: Positives = 136, Negatives = 18
# Model 42: Positives = 136, Negatives = 18
# Model 43: Positives = 140, Negatives = 14
# Model 44: Positives = 142, Negatives = 12
# Model 45: Positives = 138, Negatives = 16
# Model 46: Positives = 130, Negatives = 24
# Model 47: Positives = 128, Negatives = 26
# Model 48: Positives = 121, Negatives = 33
# Model 49: Positives = 136, Negatives = 18
# Model 50: Positives = 134, Negatives = 20
#
# Model Predictions Summary:
# Model 1: Positives = 127, Negatives = 27
# Model 2: Positives = 133, Negatives = 21
# Model 3: Positives = 135, Negatives = 19
# Model 4: Positives = 130, Negatives = 24
# Model 5: Positives = 125, Negatives = 29
# Model 6: Positives = 119, Negatives = 35
# Model 7: Positives = 129, Negatives = 25
# Model 8: Positives = 132, Negatives = 22
# Model 9: Positives = 134, Negatives = 20
# Model 10: Positives = 132, Negatives = 22
# Model 11: Positives = 126, Negatives = 28
# Model 12: Positives = 128, Negatives = 26
# Model 13: Positives = 126, Negatives = 28
# Model 14: Positives = 119, Negatives = 35
# Model 15: Positives = 126, Negatives = 28
# Model 16: Positives = 138, Negatives = 16
# Model 17: Positives = 143, Negatives = 11
# Model 18: Positives = 133, Negatives = 21
# Model 19: Positives = 127, Negatives = 27
# Model 20: Positives = 134, Negatives = 20
# Model 21: Positives = 126, Negatives = 28
# Model 22: Positives = 133, Negatives = 21
# Model 23: Positives = 140, Negatives = 14
# Model 24: Positives = 127, Negatives = 27
# Model 25: Positives = 129, Negatives = 25
# Model 26: Positives = 130, Negatives = 24
# Model 27: Positives = 132, Negatives = 22
# Model 28: Positives = 135, Negatives = 19
# Model 29: Positives = 125, Negatives = 29
# Model 30: Positives = 142, Negatives = 12
# Model 31: Positives = 131, Negatives = 23
# Model 32: Positives = 125, Negatives = 29
# Model 33: Positives = 139, Negatives = 15
# Model 34: Positives = 131, Negatives = 23
# Model 35: Positives = 140, Negatives = 14
# Model 36: Positives = 124, Negatives = 30
# Model 37: Positives = 129, Negatives = 25
# Model 38: Positives = 132, Negatives = 22
# Model 39: Positives = 124, Negatives = 30
# Model 40: Positives = 131, Negatives = 23
# Model 41: Positives = 132, Negatives = 22
# Model 42: Positives = 124, Negatives = 30
# Model 43: Positives = 134, Negatives = 20
# Model 44: Positives = 122, Negatives = 32
# Model 45: Positives = 131, Negatives = 23
# Model 46: Positives = 132, Negatives = 22
# Model 47: Positives = 143, Negatives = 11
# Model 48: Positives = 138, Negatives = 16
# Model 49: Positives = 142, Negatives = 12
# Model 50: Positives = 129, Negatives = 25

# %%
def apply_labeling_from_spies(csv, mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    def get_min_max_label(score):
        if score < min_score:
            return "StrongNegative"
        elif min_score <= score < mean_score:
            return "PseudoNegative"
        elif mean_score <= score < max_score:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df["min_max_label"] = df["average_score"].apply(get_min_max_label)

    def get_percentile_label(score):
        if score < percentile_25:
            return "StrongNegative"
        elif percentile_25 <= score < percentile_50:
            return "PseudoNegative"
        elif percentile_50 <= score < percentile_75:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df["percentile_label"] = df["average_score"].apply(get_percentile_label)
    df["threshold_label"] = df["average_score"].apply(lambda x: "Negative" if x < 0.5 else "Positive")

    min_max_results = []
    min_max_results.append((df["average_score"] < min_score).sum()) # min_max_strong_negative_count
    min_max_results.append(((df["average_score"] > min_score) & (df["average_score"] < mean_score)).sum()) # min_max_pseudo_negative_count
    min_max_results.append(((df["average_score"] > mean_score) & (df["average_score"] < max_score)).sum()) # min_max_pseudo_positive_count
    min_max_results.append((df["average_score"] > max_score).sum()) # min_max_strong_positive_count

    percentile_results = []
    percentile_results.append((df["average_score"] < percentile_25).sum()) # percentile_strong_negative_count
    percentile_results.append(((df["average_score"] > percentile_25) & (df["average_score"] < percentile_50)).sum()) # percentile_pseudo_negative_count
    percentile_results.append(((df["average_score"] > percentile_50) & (df["average_score"] < percentile_75)).sum()) # percentile_pseudo_positive_count
    percentile_results.append((df["average_score"] > percentile_75).sum()) # percentile_strong_positive_count

    threshold_results = []
    threshold_results.append((df["average_score"] < 0.5).sum()) # threshold_negative_count
    threshold_results.append((df["average_score"] > 0.5).sum()) # threshold_positive_count

    # Table 1: Min/Max and Percentile
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    minmax_percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Min_Max (Using Mean)": min_max_results,
        "Percentile (75-50-25)": percentile_results
    })

    # Table 2: Threshold 0.5
    labels_2 = ["Negative", "Positive"]
    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold (0.5)": threshold_results
    })

    print(minmax_percentile_df,"\n", threshold_df)

    df.to_csv(csv, index=False)

    return min_max_results, percentile_results, threshold_results

def show_evaluation_results(min_max_all, percentile_all, threshold_all):
    # Compute mean and std for each label
    min_max_mean = np.mean(min_max_all, axis=0)
    min_max_std = np.std(min_max_all, axis=0)

    percentile_mean = np.mean(percentile_all, axis=0)
    percentile_std = np.std(percentile_all, axis=0)

    threshold_mean = np.mean(threshold_all, axis=0)
    threshold_std = np.std(threshold_all, axis=0)

    # Create DataFrames to display
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    labels_2 = ["Negative", "Positive"]

    min_max_df = pd.DataFrame({
        "Label": labels_4,
        "Min-Max Mean": min_max_mean,
        "Min-Max Std": min_max_std
    })

    percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Percentile Mean": percentile_mean,
        "Percentile Std": percentile_std
    })

    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold Mean": threshold_mean,
        "Threshold Std": threshold_std
    })

    # Display
    print("=== Min-Max Results ===")
    print(min_max_df)
    print("\n=== Percentile Results ===")
    print(percentile_df)
    print("\n=== Threshold Results ===")
    print(threshold_df)

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     36
# 1  PseudoNegative                    59                     37
# 2  PseudoPositive                    95                     31
# 3  StrongPositive                     0                     50
#        Label  Threshold (0.5)
# 0  Negative               19
# 1  Positive              135
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     3                     26
# 1  PseudoNegative                    46                     51
# 2  PseudoPositive                   101                     33
# 3  StrongPositive                     4                     44
#        Label  Threshold (0.5)
# 0  Negative               21
# 1  Positive              133
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     3                     48
# 1  PseudoNegative                    58                     36
# 2  PseudoPositive                    92                     27
# 3  StrongPositive                     1                     43
#        Label  Threshold (0.5)
# 0  Negative               23
# 1  Positive              131
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     29
# 1  PseudoNegative                    49                     34
# 2  PseudoPositive                   102                     36
# 3  StrongPositive                     3                     55
#        Label  Threshold (0.5)
# 0  Negative               14
# 1  Positive              140
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     35
# 1  PseudoNegative                    49                     37
# 2  PseudoPositive                   104                     32
# 3  StrongPositive                     1                     50
#        Label  Threshold (0.5)
# 0  Negative               22
# 1  Positive              132
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           1.2     1.469694
# 1  PseudoNegative          52.2     5.268776
# 2  PseudoPositive          98.8     4.534314
# 3  StrongPositive           1.8     1.469694
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative             34.8        7.573638
# 1  PseudoNegative             39.0        6.099180
# 2  PseudoPositive             31.8        2.925748
# 3  StrongPositive             48.4        4.409082
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative            19.8       3.187475
# 1  Positive           134.2       3.187475

# %%
test_unlabeled_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp1/Test/CombinedUnlabeled"  
csv_output_exp1 = "GATModels-5A_exp1v2/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp1, csv_output_exp1, models_exp1)

test_unlabeled_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp2/Test/CombinedUnlabeled"  
csv_output_exp2 = "GATModels-5A_exp2v2/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp2, csv_output_exp2, models_exp2)

test_unlabeled_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp3/Test/CombinedUnlabeled"  
csv_output_exp3 = "GATModels-5A_exp3v2/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp3, csv_output_exp3, models_exp3)

test_unlabeled_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp4/Test/CombinedUnlabeled"  
csv_output_exp4 = "GATModels-5A_exp4v2/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp4, csv_output_exp4, models_exp4)

test_unlabeled_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp5/Test/CombinedUnlabeled"  
csv_output_exp5 = "GATModels-5A_exp5v2/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 218, Negatives = 705
# Model 2: Positives = 276, Negatives = 647
# Model 3: Positives = 259, Negatives = 664
# Model 4: Positives = 292, Negatives = 631
# Model 5: Positives = 245, Negatives = 678
# Model 6: Positives = 261, Negatives = 662
# Model 7: Positives = 276, Negatives = 647
# Model 8: Positives = 275, Negatives = 648
# Model 9: Positives = 314, Negatives = 609
# Model 10: Positives = 252, Negatives = 671
# Model 11: Positives = 248, Negatives = 675
# Model 12: Positives = 330, Negatives = 593
# Model 13: Positives = 304, Negatives = 619
# Model 14: Positives = 258, Negatives = 665
# Model 15: Positives = 260, Negatives = 663
# Model 16: Positives = 269, Negatives = 654
# Model 17: Positives = 311, Negatives = 612
# Model 18: Positives = 286, Negatives = 637
# Model 19: Positives = 239, Negatives = 684
# Model 20: Positives = 271, Negatives = 652
# Model 21: Positives = 261, Negatives = 662
# Model 22: Positives = 229, Negatives = 694
# Model 23: Positives = 199, Negatives = 724
# Model 24: Positives = 271, Negatives = 652
# Model 25: Positives = 309, Negatives = 614
# Model 26: Positives = 269, Negatives = 654
# Model 27: Positives = 281, Negatives = 642
# Model 28: Positives = 268, Negatives = 655
# Model 29: Positives = 222, Negatives = 701
# Model 30: Positives = 215, Negatives = 708
# Model 31: Positives = 241, Negatives = 682
# Model 32: Positives = 312, Negatives = 611
# Model 33: Positives = 294, Negatives = 629
# Model 34: Positives = 236, Negatives = 687
# Model 35: Positives = 274, Negatives = 649
# Model 36: Positives = 274, Negatives = 649
# Model 37: Positives = 308, Negatives = 615
# Model 38: Positives = 266, Negatives = 657
# Model 39: Positives = 285, Negatives = 638
# Model 40: Positives = 272, Negatives = 651
# Model 41: Positives = 243, Negatives = 680
# Model 42: Positives = 283, Negatives = 640
# Model 43: Positives = 288, Negatives = 635
# Model 44: Positives = 331, Negatives = 592
# Model 45: Positives = 287, Negatives = 636
# Model 46: Positives = 286, Negatives = 637
# Model 47: Positives = 236, Negatives = 687
# Model 48: Positives = 277, Negatives = 646
# Model 49: Positives = 258, Negatives = 665
# Model 50: Positives = 250, Negatives = 673
#
# Model Predictions Summary:
# Model 1: Positives = 234, Negatives = 689
# Model 2: Positives = 264, Negatives = 659
# Model 3: Positives = 311, Negatives = 612
# Model 4: Positives = 327, Negatives = 596
# Model 5: Positives = 300, Negatives = 623
# Model 6: Positives = 251, Negatives = 672
# Model 7: Positives = 338, Negatives = 585
# Model 8: Positives = 295, Negatives = 628
# Model 9: Positives = 302, Negatives = 621
# Model 10: Positives = 275, Negatives = 648
# Model 11: Positives = 292, Negatives = 631
# Model 12: Positives = 226, Negatives = 697
# Model 13: Positives = 269, Negatives = 654
# Model 14: Positives = 282, Negatives = 641
# Model 15: Positives = 334, Negatives = 589
# Model 16: Positives = 287, Negatives = 636
# Model 17: Positives = 227, Negatives = 696
# Model 18: Positives = 270, Negatives = 653
# Model 19: Positives = 267, Negatives = 656
# Model 20: Positives = 290, Negatives = 633
# Model 21: Positives = 251, Negatives = 672
# Model 22: Positives = 288, Negatives = 635
# Model 23: Positives = 298, Negatives = 625
# Model 24: Positives = 255, Negatives = 668
# Model 25: Positives = 302, Negatives = 621
# Model 26: Positives = 252, Negatives = 671
# Model 27: Positives = 246, Negatives = 677
# Model 28: Positives = 263, Negatives = 660
# Model 29: Positives = 349, Negatives = 574
# Model 30: Positives = 250, Negatives = 673
# Model 31: Positives = 275, Negatives = 648
# Model 32: Positives = 294, Negatives = 629
# Model 33: Positives = 255, Negatives = 668
# Model 34: Positives = 270, Negatives = 653
# Model 35: Positives = 221, Negatives = 702
# Model 36: Positives = 301, Negatives = 622
# Model 37: Positives = 222, Negatives = 701
# Model 38: Positives = 336, Negatives = 587
# Model 39: Positives = 267, Negatives = 656
# Model 40: Positives = 333, Negatives = 590
# Model 41: Positives = 213, Negatives = 710
# Model 42: Positives = 319, Negatives = 604
# Model 43: Positives = 260, Negatives = 663
# Model 44: Positives = 298, Negatives = 625
# Model 45: Positives = 287, Negatives = 636
# Model 46: Positives = 245, Negatives = 678
# Model 47: Positives = 336, Negatives = 587
# Model 48: Positives = 283, Negatives = 640
# Model 49: Positives = 295, Negatives = 628
# Model 50: Positives = 289, Negatives = 634
#
# Model Predictions Summary:
# Model 1: Positives = 209, Negatives = 714
# Model 2: Positives = 271, Negatives = 652
# Model 3: Positives = 300, Negatives = 623
# Model 4: Positives = 273, Negatives = 650
# Model 5: Positives = 339, Negatives = 584
# Model 6: Positives = 257, Negatives = 666
# Model 7: Positives = 278, Negatives = 645
# Model 8: Positives = 256, Negatives = 667
# Model 9: Positives = 269, Negatives = 654
# Model 10: Positives = 254, Negatives = 669
# Model 11: Positives = 262, Negatives = 661
# Model 12: Positives = 282, Negatives = 641
# Model 13: Positives = 297, Negatives = 626
# Model 14: Positives = 305, Negatives = 618
# Model 15: Positives = 253, Negatives = 670
# Model 16: Positives = 268, Negatives = 655
# Model 17: Positives = 235, Negatives = 688
# Model 18: Positives = 286, Negatives = 637
# Model 19: Positives = 337, Negatives = 586
# Model 20: Positives = 307, Negatives = 616
# Model 21: Positives = 247, Negatives = 676
# Model 22: Positives = 238, Negatives = 685
# Model 23: Positives = 263, Negatives = 660
# Model 24: Positives = 214, Negatives = 709
# Model 25: Positives = 271, Negatives = 652
# Model 26: Positives = 266, Negatives = 657
# Model 27: Positives = 294, Negatives = 629
# Model 28: Positives = 293, Negatives = 630
# Model 29: Positives = 264, Negatives = 659
# Model 30: Positives = 350, Negatives = 573
# Model 31: Positives = 259, Negatives = 664
# Model 32: Positives = 291, Negatives = 632
# Model 33: Positives = 267, Negatives = 656
# Model 34: Positives = 295, Negatives = 628
# Model 35: Positives = 254, Negatives = 669
# Model 36: Positives = 242, Negatives = 681
# Model 37: Positives = 278, Negatives = 645
# Model 38: Positives = 262, Negatives = 661
# Model 39: Positives = 237, Negatives = 686
# Model 40: Positives = 282, Negatives = 641
# Model 41: Positives = 299, Negatives = 624
# Model 42: Positives = 257, Negatives = 666
# Model 43: Positives = 262, Negatives = 661
# Model 44: Positives = 310, Negatives = 613
# Model 45: Positives = 257, Negatives = 666
# Model 46: Positives = 308, Negatives = 615
# Model 47: Positives = 235, Negatives = 688
# Model 48: Positives = 252, Negatives = 671
# Model 49: Positives = 261, Negatives = 662
# Model 50: Positives = 255, Negatives = 668
#
# Model Predictions Summary:
# Model 1: Positives = 225, Negatives = 698
# Model 2: Positives = 217, Negatives = 706
# Model 3: Positives = 221, Negatives = 702
# Model 4: Positives = 313, Negatives = 610
# Model 5: Positives = 247, Negatives = 676
# Model 6: Positives = 253, Negatives = 670
# Model 7: Positives = 302, Negatives = 621
# Model 8: Positives = 254, Negatives = 669
# Model 9: Positives = 306, Negatives = 617
# Model 10: Positives = 303, Negatives = 620
# Model 11: Positives = 229, Negatives = 694
# Model 12: Positives = 265, Negatives = 658
# Model 13: Positives = 328, Negatives = 595
# Model 14: Positives = 267, Negatives = 656
# Model 15: Positives = 247, Negatives = 676
# Model 16: Positives = 228, Negatives = 695
# Model 17: Positives = 267, Negatives = 656
# Model 18: Positives = 239, Negatives = 684
# Model 19: Positives = 257, Negatives = 666
# Model 20: Positives = 270, Negatives = 653
# Model 21: Positives = 291, Negatives = 632
# Model 22: Positives = 245, Negatives = 678
# Model 23: Positives = 187, Negatives = 736
# Model 24: Positives = 264, Negatives = 659
# Model 25: Positives = 247, Negatives = 676
# Model 26: Positives = 253, Negatives = 670
# Model 27: Positives = 262, Negatives = 661
# Model 28: Positives = 248, Negatives = 675
# Model 29: Positives = 266, Negatives = 657
# Model 30: Positives = 245, Negatives = 678
# Model 31: Positives = 284, Negatives = 639
# Model 32: Positives = 265, Negatives = 658
# Model 33: Positives = 250, Negatives = 673
# Model 34: Positives = 286, Negatives = 637
# Model 35: Positives = 261, Negatives = 662
# Model 36: Positives = 297, Negatives = 626
# Model 37: Positives = 229, Negatives = 694
# Model 38: Positives = 234, Negatives = 689
# Model 39: Positives = 316, Negatives = 607
# Model 40: Positives = 300, Negatives = 623
# Model 41: Positives = 243, Negatives = 680
# Model 42: Positives = 237, Negatives = 686
# Model 43: Positives = 293, Negatives = 630
# Model 44: Positives = 291, Negatives = 632
# Model 45: Positives = 311, Negatives = 612
# Model 46: Positives = 240, Negatives = 683
# Model 47: Positives = 233, Negatives = 690
# Model 48: Positives = 220, Negatives = 703
# Model 49: Positives = 264, Negatives = 659
# Model 50: Positives = 262, Negatives = 661
#
# Model Predictions Summary:
# Model 1: Positives = 296, Negatives = 627
# Model 2: Positives = 282, Negatives = 641
# Model 3: Positives = 286, Negatives = 637
# Model 4: Positives = 261, Negatives = 662
# Model 5: Positives = 246, Negatives = 677
# Model 6: Positives = 161, Negatives = 762
# Model 7: Positives = 285, Negatives = 638
# Model 8: Positives = 257, Negatives = 666
# Model 9: Positives = 330, Negatives = 593
# Model 10: Positives = 290, Negatives = 633
# Model 11: Positives = 224, Negatives = 699
# Model 12: Positives = 283, Negatives = 640
# Model 13: Positives = 216, Negatives = 707
# Model 14: Positives = 227, Negatives = 696
# Model 15: Positives = 256, Negatives = 667
# Model 16: Positives = 323, Negatives = 600
# Model 17: Positives = 361, Negatives = 562
# Model 18: Positives = 304, Negatives = 619
# Model 19: Positives = 267, Negatives = 656
# Model 20: Positives = 301, Negatives = 622
# Model 21: Positives = 220, Negatives = 703
# Model 22: Positives = 272, Negatives = 651
# Model 23: Positives = 327, Negatives = 596
# Model 24: Positives = 257, Negatives = 666
# Model 25: Positives = 267, Negatives = 656
# Model 26: Positives = 302, Negatives = 621
# Model 27: Positives = 298, Negatives = 625
# Model 28: Positives = 339, Negatives = 584
# Model 29: Positives = 235, Negatives = 688
# Model 30: Positives = 367, Negatives = 556
# Model 31: Positives = 267, Negatives = 656
# Model 32: Positives = 212, Negatives = 711
# Model 33: Positives = 338, Negatives = 585
# Model 34: Positives = 290, Negatives = 633
# Model 35: Positives = 342, Negatives = 581
# Model 36: Positives = 224, Negatives = 699
# Model 37: Positives = 261, Negatives = 662
# Model 38: Positives = 273, Negatives = 650
# Model 39: Positives = 249, Negatives = 674
# Model 40: Positives = 239, Negatives = 684
# Model 41: Positives = 269, Negatives = 654
# Model 42: Positives = 222, Negatives = 701
# Model 43: Positives = 292, Negatives = 631
# Model 44: Positives = 238, Negatives = 685
# Model 45: Positives = 294, Negatives = 629
# Model 46: Positives = 299, Negatives = 624
# Model 47: Positives = 340, Negatives = 583
# Model 48: Positives = 326, Negatives = 597
# Model 49: Positives = 374, Negatives = 549
# Model 50: Positives = 273, Negatives = 650

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   266                    736
# 1  PseudoNegative                   519                     78
# 2  PseudoPositive                   138                     59
# 3  StrongPositive                     0                     50
#        Label  Threshold (0.5)
# 0  Negative              663
# 1  Positive              260
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   227                    696
# 1  PseudoNegative                   553                    137
# 2  PseudoPositive                   138                     42
# 3  StrongPositive                     5                     48
#        Label  Threshold (0.5)
# 0  Negative              653
# 1  Positive              270
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   291                    761
# 1  PseudoNegative                   515                     83
# 2  PseudoPositive                   115                     28
# 3  StrongPositive                     2                     51
#        Label  Threshold (0.5)
# 0  Negative              651
# 1  Positive              272
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   139                    717
# 1  PseudoNegative                   638                     95
# 2  PseudoPositive                   142                     53
# 3  StrongPositive                     4                     58
#        Label  Threshold (0.5)
# 0  Negative              661
# 1  Positive              262
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                    66                    727
# 1  PseudoNegative                   731                    111
# 2  PseudoPositive                   126                     47
# 3  StrongPositive                     0                     38
#        Label  Threshold (0.5)
# 0  Negative              639
# 1  Positive              284
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative         197.8    83.688470
# 1  PseudoNegative         591.2    82.719768
# 2  PseudoPositive         131.8     9.967949
# 3  StrongPositive           2.2     2.039608
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative            727.4       21.434552
# 1  PseudoNegative            100.8       21.376623
# 2  PseudoPositive             45.8       10.571660
# 3  StrongPositive             49.0        6.449806
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative           653.4        8.52291
# 1  Positive           269.6        8.52291

# %%
test_ivan_exp1 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp1 = "GATModels-5A_exp1v2/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp1, csv_output_exp1, models_exp1)

test_ivan_exp2 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp2 = "GATModels-5A_exp2v2/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp2, csv_output_exp2, models_exp2)

test_ivan_exp3 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp3 = "GATModels-5A_exp3v2/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp3, csv_output_exp3, models_exp3)

test_ivan_exp4 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp4 = "GATModels-5A_exp4v2/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp4, csv_output_exp4, models_exp4)

test_ivan_exp5 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp5 = "GATModels-5A_exp5v2/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 40, Negatives = 17
# Model 2: Positives = 41, Negatives = 16
# Model 3: Positives = 46, Negatives = 11
# Model 4: Positives = 44, Negatives = 13
# Model 5: Positives = 45, Negatives = 12
# Model 6: Positives = 46, Negatives = 11
# Model 7: Positives = 45, Negatives = 12
# Model 8: Positives = 45, Negatives = 12
# Model 9: Positives = 48, Negatives = 9
# Model 10: Positives = 46, Negatives = 11
# Model 11: Positives = 44, Negatives = 13
# Model 12: Positives = 49, Negatives = 8
# Model 13: Positives = 48, Negatives = 9
# Model 14: Positives = 45, Negatives = 12
# Model 15: Positives = 44, Negatives = 13
# Model 16: Positives = 46, Negatives = 11
# Model 17: Positives = 46, Negatives = 11
# Model 18: Positives = 46, Negatives = 11
# Model 19: Positives = 40, Negatives = 17
# Model 20: Positives = 45, Negatives = 12
# Model 21: Positives = 42, Negatives = 15
# Model 22: Positives = 39, Negatives = 18
# Model 23: Positives = 39, Negatives = 18
# Model 24: Positives = 45, Negatives = 12
# Model 25: Positives = 50, Negatives = 7
# Model 26: Positives = 44, Negatives = 13
# Model 27: Positives = 48, Negatives = 9
# Model 28: Positives = 47, Negatives = 10
# Model 29: Positives = 41, Negatives = 16
# Model 30: Positives = 38, Negatives = 19
# Model 31: Positives = 42, Negatives = 15
# Model 32: Positives = 48, Negatives = 9
# Model 33: Positives = 47, Negatives = 10
# Model 34: Positives = 43, Negatives = 14
# Model 35: Positives = 45, Negatives = 12
# Model 36: Positives = 45, Negatives = 12
# Model 37: Positives = 47, Negatives = 10
# Model 38: Positives = 42, Negatives = 15
# Model 39: Positives = 48, Negatives = 9
# Model 40: Positives = 48, Negatives = 9
# Model 41: Positives = 47, Negatives = 10
# Model 42: Positives = 45, Negatives = 12
# Model 43: Positives = 46, Negatives = 11
# Model 44: Positives = 49, Negatives = 8
# Model 45: Positives = 46, Negatives = 11
# Model 46: Positives = 46, Negatives = 11
# Model 47: Positives = 43, Negatives = 14
# Model 48: Positives = 43, Negatives = 14
# Model 49: Positives = 44, Negatives = 13
# Model 50: Positives = 37, Negatives = 20
#
# Model Predictions Summary:
# Model 1: Positives = 45, Negatives = 12
# Model 2: Positives = 46, Negatives = 11
# Model 3: Positives = 49, Negatives = 8
# Model 4: Positives = 49, Negatives = 8
# Model 5: Positives = 48, Negatives = 9
# Model 6: Positives = 47, Negatives = 10
# Model 7: Positives = 50, Negatives = 7
# Model 8: Positives = 44, Negatives = 13
# Model 9: Positives = 48, Negatives = 9
# Model 10: Positives = 45, Negatives = 12
# Model 11: Positives = 48, Negatives = 9
# Model 12: Positives = 46, Negatives = 11
# Model 13: Positives = 45, Negatives = 12
# Model 14: Positives = 48, Negatives = 9
# Model 15: Positives = 49, Negatives = 8
# Model 16: Positives = 47, Negatives = 10
# Model 17: Positives = 45, Negatives = 12
# Model 18: Positives = 46, Negatives = 11
# Model 19: Positives = 39, Negatives = 18
# Model 20: Positives = 48, Negatives = 9
# Model 21: Positives = 45, Negatives = 12
# Model 22: Positives = 46, Negatives = 11
# Model 23: Positives = 48, Negatives = 9
# Model 24: Positives = 46, Negatives = 11
# Model 25: Positives = 48, Negatives = 9
# Model 26: Positives = 41, Negatives = 16
# Model 27: Positives = 46, Negatives = 11
# Model 28: Positives = 49, Negatives = 8
# Model 29: Positives = 48, Negatives = 9
# Model 30: Positives = 43, Negatives = 14
# Model 31: Positives = 48, Negatives = 9
# Model 32: Positives = 47, Negatives = 10
# Model 33: Positives = 46, Negatives = 11
# Model 34: Positives = 46, Negatives = 11
# Model 35: Positives = 45, Negatives = 12
# Model 36: Positives = 49, Negatives = 8
# Model 37: Positives = 45, Negatives = 12
# Model 38: Positives = 49, Negatives = 8
# Model 39: Positives = 48, Negatives = 9
# Model 40: Positives = 49, Negatives = 8
# Model 41: Positives = 43, Negatives = 14
# Model 42: Positives = 47, Negatives = 10
# Model 43: Positives = 45, Negatives = 12
# Model 44: Positives = 47, Negatives = 10
# Model 45: Positives = 44, Negatives = 13
# Model 46: Positives = 41, Negatives = 16
# Model 47: Positives = 48, Negatives = 9
# Model 48: Positives = 48, Negatives = 9
# Model 49: Positives = 48, Negatives = 9
# Model 50: Positives = 47, Negatives = 10
#
# Model Predictions Summary:
# Model 1: Positives = 44, Negatives = 13
# Model 2: Positives = 44, Negatives = 13
# Model 3: Positives = 44, Negatives = 13
# Model 4: Positives = 45, Negatives = 12
# Model 5: Positives = 47, Negatives = 10
# Model 6: Positives = 48, Negatives = 9
# Model 7: Positives = 46, Negatives = 11
# Model 8: Positives = 42, Negatives = 15
# Model 9: Positives = 46, Negatives = 11
# Model 10: Positives = 45, Negatives = 12
# Model 11: Positives = 47, Negatives = 10
# Model 12: Positives = 45, Negatives = 12
# Model 13: Positives = 45, Negatives = 12
# Model 14: Positives = 47, Negatives = 10
# Model 15: Positives = 45, Negatives = 12
# Model 16: Positives = 47, Negatives = 10
# Model 17: Positives = 39, Negatives = 18
# Model 18: Positives = 41, Negatives = 16
# Model 19: Positives = 45, Negatives = 12
# Model 20: Positives = 45, Negatives = 12
# Model 21: Positives = 45, Negatives = 12
# Model 22: Positives = 43, Negatives = 14
# Model 23: Positives = 42, Negatives = 15
# Model 24: Positives = 43, Negatives = 14
# Model 25: Positives = 44, Negatives = 13
# Model 26: Positives = 42, Negatives = 15
# Model 27: Positives = 43, Negatives = 14
# Model 28: Positives = 39, Negatives = 18
# Model 29: Positives = 44, Negatives = 13
# Model 30: Positives = 48, Negatives = 9
# Model 31: Positives = 45, Negatives = 12
# Model 32: Positives = 47, Negatives = 10
# Model 33: Positives = 45, Negatives = 12
# Model 34: Positives = 48, Negatives = 9
# Model 35: Positives = 46, Negatives = 11
# Model 36: Positives = 42, Negatives = 15
# Model 37: Positives = 40, Negatives = 17
# Model 38: Positives = 40, Negatives = 17
# Model 39: Positives = 43, Negatives = 14
# Model 40: Positives = 44, Negatives = 13
# Model 41: Positives = 45, Negatives = 12
# Model 42: Positives = 45, Negatives = 12
# Model 43: Positives = 47, Negatives = 10
# Model 44: Positives = 47, Negatives = 10
# Model 45: Positives = 43, Negatives = 14
# Model 46: Positives = 46, Negatives = 11
# Model 47: Positives = 40, Negatives = 17
# Model 48: Positives = 45, Negatives = 12
# Model 49: Positives = 44, Negatives = 13
# Model 50: Positives = 40, Negatives = 17
#
# Model Predictions Summary:
# Model 1: Positives = 46, Negatives = 11
# Model 2: Positives = 42, Negatives = 15
# Model 3: Positives = 43, Negatives = 14
# Model 4: Positives = 47, Negatives = 10
# Model 5: Positives = 48, Negatives = 9
# Model 6: Positives = 45, Negatives = 12
# Model 7: Positives = 43, Negatives = 14
# Model 8: Positives = 43, Negatives = 14
# Model 9: Positives = 45, Negatives = 12
# Model 10: Positives = 47, Negatives = 10
# Model 11: Positives = 38, Negatives = 19
# Model 12: Positives = 46, Negatives = 11
# Model 13: Positives = 46, Negatives = 11
# Model 14: Positives = 42, Negatives = 15
# Model 15: Positives = 46, Negatives = 11
# Model 16: Positives = 40, Negatives = 17
# Model 17: Positives = 46, Negatives = 11
# Model 18: Positives = 43, Negatives = 14
# Model 19: Positives = 41, Negatives = 16
# Model 20: Positives = 45, Negatives = 12
# Model 21: Positives = 46, Negatives = 11
# Model 22: Positives = 44, Negatives = 13
# Model 23: Positives = 36, Negatives = 21
# Model 24: Positives = 42, Negatives = 15
# Model 25: Positives = 45, Negatives = 12
# Model 26: Positives = 40, Negatives = 17
# Model 27: Positives = 44, Negatives = 13
# Model 28: Positives = 44, Negatives = 13
# Model 29: Positives = 46, Negatives = 11
# Model 30: Positives = 47, Negatives = 10
# Model 31: Positives = 49, Negatives = 8
# Model 32: Positives = 48, Negatives = 9
# Model 33: Positives = 44, Negatives = 13
# Model 34: Positives = 46, Negatives = 11
# Model 35: Positives = 40, Negatives = 17
# Model 36: Positives = 43, Negatives = 14
# Model 37: Positives = 41, Negatives = 16
# Model 38: Positives = 45, Negatives = 12
# Model 39: Positives = 43, Negatives = 14
# Model 40: Positives = 45, Negatives = 12
# Model 41: Positives = 45, Negatives = 12
# Model 42: Positives = 43, Negatives = 14
# Model 43: Positives = 46, Negatives = 11
# Model 44: Positives = 47, Negatives = 10
# Model 45: Positives = 45, Negatives = 12
# Model 46: Positives = 46, Negatives = 11
# Model 47: Positives = 46, Negatives = 11
# Model 48: Positives = 39, Negatives = 18
# Model 49: Positives = 44, Negatives = 13
# Model 50: Positives = 36, Negatives = 21
#
# Model Predictions Summary:
# Model 1: Positives = 45, Negatives = 12
# Model 2: Positives = 47, Negatives = 10
# Model 3: Positives = 46, Negatives = 11
# Model 4: Positives = 44, Negatives = 13
# Model 5: Positives = 45, Negatives = 12
# Model 6: Positives = 36, Negatives = 21
# Model 7: Positives = 47, Negatives = 10
# Model 8: Positives = 45, Negatives = 12
# Model 9: Positives = 46, Negatives = 11
# Model 10: Positives = 48, Negatives = 9
# Model 11: Positives = 41, Negatives = 16
# Model 12: Positives = 43, Negatives = 14
# Model 13: Positives = 42, Negatives = 15
# Model 14: Positives = 45, Negatives = 12
# Model 15: Positives = 46, Negatives = 11
# Model 16: Positives = 48, Negatives = 9
# Model 17: Positives = 48, Negatives = 9
# Model 18: Positives = 47, Negatives = 10
# Model 19: Positives = 44, Negatives = 13
# Model 20: Positives = 47, Negatives = 10
# Model 21: Positives = 43, Negatives = 14
# Model 22: Positives = 46, Negatives = 11
# Model 23: Positives = 49, Negatives = 8
# Model 24: Positives = 42, Negatives = 15
# Model 25: Positives = 44, Negatives = 13
# Model 26: Positives = 47, Negatives = 10
# Model 27: Positives = 47, Negatives = 10
# Model 28: Positives = 46, Negatives = 11
# Model 29: Positives = 43, Negatives = 14
# Model 30: Positives = 50, Negatives = 7
# Model 31: Positives = 44, Negatives = 13
# Model 32: Positives = 43, Negatives = 14
# Model 33: Positives = 45, Negatives = 12
# Model 34: Positives = 51, Negatives = 6
# Model 35: Positives = 45, Negatives = 12
# Model 36: Positives = 45, Negatives = 12
# Model 37: Positives = 43, Negatives = 14
# Model 38: Positives = 46, Negatives = 11
# Model 39: Positives = 41, Negatives = 16
# Model 40: Positives = 43, Negatives = 14
# Model 41: Positives = 43, Negatives = 14
# Model 42: Positives = 40, Negatives = 17
# Model 43: Positives = 47, Negatives = 10
# Model 44: Positives = 41, Negatives = 16
# Model 45: Positives = 44, Negatives = 13
# Model 46: Positives = 46, Negatives = 11
# Model 47: Positives = 48, Negatives = 9
# Model 48: Positives = 49, Negatives = 8
# Model 49: Positives = 51, Negatives = 6
# Model 50: Positives = 42, Negatives = 15

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     19
# 1  PseudoNegative                    24                      8
# 2  PseudoPositive                    32                      8
# 3  StrongPositive                     0                     22
#        Label  Threshold (0.5)
# 0  Negative               12
# 1  Positive               45
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     14
# 1  PseudoNegative                    18                     15
# 2  PseudoPositive                    37                     12
# 3  StrongPositive                     1                     16
#        Label  Threshold (0.5)
# 0  Negative                9
# 1  Positive               48
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     21
# 1  PseudoNegative                    24                      9
# 2  PseudoPositive                    31                      7
# 3  StrongPositive                     1                     20
#        Label  Threshold (0.5)
# 0  Negative               13
# 1  Positive               44
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     17
# 1  PseudoNegative                    23                     14
# 2  PseudoPositive                    32                      8
# 3  StrongPositive                     1                     18
#        Label  Threshold (0.5)
# 0  Negative               13
# 1  Positive               44
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     18
# 1  PseudoNegative                    25                     18
# 2  PseudoPositive                    31                      7
# 3  StrongPositive                     0                     14
#        Label  Threshold (0.5)
# 0  Negative               10
# 1  Positive               47
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           1.0     0.000000
# 1  PseudoNegative          22.8     2.481935
# 2  PseudoPositive          32.6     2.244994
# 3  StrongPositive           0.6     0.489898
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative             17.8        2.315167
# 1  PseudoNegative             12.8        3.762978
# 2  PseudoPositive              8.4        1.854724
# 3  StrongPositive             18.0        2.828427
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative            11.4       1.624808
# 1  Positive            45.6       1.624808
