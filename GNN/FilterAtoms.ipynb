# %%
import MDAnalysis as mda
import pandas as pd
from biopandas.pdb import PandasPdb
import os
import glob
import re
import math
import numpy as np

def pdb_to_dataframe(pdb_file):
    """
    Load a PDB file using MDAnalysis and convert key atom information to a pandas DataFrame.
    """
    u = mda.Universe(pdb_file)
    
    # Extract atom-related data: atom name, residue name, residue ID, and chain ID
    atom_data = {
        'Atom Name': u.atoms.names,
        'Residue Name': u.atoms.resnames,
        'Residue ID': u.atoms.resids,
        'Chain ID': u.atoms.segids,
        'X': u.atoms.positions[:, 0],
        'Y': u.atoms.positions[:, 1],
        'Z': u.atoms.positions[:, 2],
    }
    
    # Create a pandas DataFrame from the atom data
    df = pd.DataFrame(atom_data)
    
    return df

def grid_list(atom_df):
    return list(zip(atom_df['x_coord'], atom_df['y_coord'], atom_df['z_coord']))

def filtering_proteins(atom_df, grid_list, radius=5.0):
    atom_coords = atom_df[['x_coord', 'y_coord', 'z_coord']].values
    filtered_atoms = set()

    for x, y, z in grid_list:
        distances_sq = (atom_coords[:, 0] - x)**2 + (atom_coords[:, 1] - y)**2 + (atom_coords[:, 2] - z)**2
        mask = distances_sq <= radius**2
        filtered_atoms.update(atom_df.index[mask])

    print(f"Total atoms within {radius} Å cutoff: {len(filtered_atoms)}")
    return atom_df.loc[list(filtered_atoms)]

# %%
def get_positive_ligand_atoms(positive_file, protein_name):
    protein_pdb_df = PandasPdb().read_pdb(positive_file)
    protein_pdb_df.df.keys()
    protein = protein_pdb_df.df['ATOM']
    protein = protein[~protein['atom_name'].str.startswith('H')] # don't use hydrogen
    protein_coords = protein[['x_coord', 'y_coord', 'z_coord']].values
    protein_centroid = protein_coords.mean(axis=0)
    print(set(protein['chain_id']))
    print(positive_file)

    ligand_df = PandasPdb().read_pdb(positive_file)
    ligand_df.df.keys()
    ligand = ligand_df.df['HETATM']
    ligand = ligand[ligand['residue_name']=="CLR"]
    x = list(set(zip(ligand['residue_number'], ligand['chain_id'])))

    #get the most inward residue
    min_distance = float('inf')
    closest_clr = None

    all_ligands = []

    for residue_number, chain_id in x:
        clr_atoms = ligand[(ligand['residue_number'] == residue_number) & (ligand['chain_id'] == chain_id)]
        if clr_atoms.empty:
            continue

        clr_coords = clr_atoms[['x_coord', 'y_coord', 'z_coord']].values
        clr_centroid = clr_coords.mean(axis=0)
        
        distance = np.linalg.norm(protein_centroid - clr_centroid)
        
        if distance < min_distance:
            min_distance = distance
            closest_clr = (residue_number, chain_id)

        grid_list_ = grid_list(clr_atoms)

        all_ligands.append(filtering_proteins(protein, grid_list_))

    ligand_ = ligand[(ligand['residue_number'] == closest_clr[0]) & (ligand['chain_id'] == closest_clr[1])]
    grid_list_ = grid_list(ligand_)

    filtered_atoms = filtering_proteins(protein, grid_list_)

    # Save to pdb
    filtered_pdb = PandasPdb()
    filtered_pdb.df['ATOM'] = filtered_atoms
    filtered_pdb_path = f"filtered-pdbs-distinct-5A/positive/{protein_name}-filtered.pdb"
    os.makedirs(os.path.dirname(filtered_pdb_path), exist_ok=True)
    filtered_pdb.to_pdb(path=filtered_pdb_path, records=None, gz=False, append_newline=True)

    return protein, all_ligands

# %%
def check_if_unlabeled_is_positive(positive_df, unlabeled_df):
    # Create a unique key for each atom based on identifying features
    positive_df['atom_key'] = (
        positive_df['atom_name'].str.strip() + '_' +
        positive_df['residue_name'].str.strip() + '_' +
        positive_df['residue_number'].astype(str) + '_' +
        positive_df['chain_id'].fillna('')
    )

    unlabeled_df['atom_key'] = (
        unlabeled_df['atom_name'].str.strip() + '_' +
        unlabeled_df['residue_name'].str.strip() + '_' +
        unlabeled_df['residue_number'].astype(str) + '_' +
        unlabeled_df['chain_id'].fillna('')
    )

    keys1 = set(positive_df['atom_key'])
    keys2 = set(unlabeled_df['atom_key'])

    common_atoms = keys1 & keys2
    total_atoms = max(len(keys1), len(keys2))

    if total_atoms == 0:
        print("Zero total atoms")
        return False

    similarity = len(common_atoms) / total_atoms
    print(similarity)
    return similarity >= 0.2

# %%
def get_protein_name(filename):
    basename = os.path.basename(filename)  # Get file name without path
    match = re.match(r'([a-zA-Z0-9]{4})', basename)  # Match the first 4-character PDB ID
    if match:
        return match.group(1).upper()
    else:
        return None
def get_mode_index(filename):
    basename = os.path.basename(filename)
    match = re.search(r'mode_(\d+)', basename)
    if match:
        return int(match.group(1))
    else:
        return None  # or raise ValueError("No mode index found.")

def natural_sort_key(s):
    """Function to sort strings in a natural alphanumeric order."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', s)]

# %%
positive_files = glob.glob("CLR-PDB/*.pdb")
positive_files = sorted(positive_files, key=natural_sort_key)

unlabeled_files = glob.glob("CLR-Unlabeled-Distinct/*.pdb")
unlabeled_files = sorted(unlabeled_files, key=natural_sort_key)

positive_index = 0
protein, all_lig_filtered = get_positive_ligand_atoms(positive_files[positive_index], get_protein_name(positive_files[positive_index]))

for unlabeled_file in unlabeled_files:
    positive_name = get_protein_name(positive_files[positive_index])
    unlabeled_name = get_protein_name(unlabeled_file)

    fragment_index = get_mode_index(unlabeled_file)

    if positive_name != unlabeled_name:
        positive_index += 1
        positive_name = get_protein_name(positive_files[positive_index])

        if positive_name != unlabeled_name:
            raise Exception("Proteins Not Matching Up!!!")
        
        protein, all_lig_filtered = get_positive_ligand_atoms(positive_files[positive_index], positive_name)

    fragment_df = PandasPdb().read_pdb(unlabeled_file)
    fragment_df.df.keys()
    fragment = fragment_df.df['HETATM']

    grid_list_ = grid_list(fragment)

    filtered_atoms = filtering_proteins(protein, grid_list_)
    
    if not filtered_atoms.empty:
        for lig in all_lig_filtered:
            is_positive = check_if_unlabeled_is_positive(lig, filtered_atoms)

            if is_positive:
                break

        # Save to pdb
        filtered_pdb = PandasPdb()
        filtered_pdb.df['ATOM'] = filtered_atoms

        if is_positive:
            filtered_pdb_path = f"filtered-pdbs-distinct-5A/unlabeled/{unlabeled_name}-f{fragment_index}-positive.pdb"
        else:
            filtered_pdb_path = f"filtered-pdbs-distinct-5A/unlabeled/{unlabeled_name}-f{fragment_index}.pdb"
        os.makedirs(os.path.dirname(filtered_pdb_path), exist_ok=True)
        filtered_pdb.to_pdb(path=filtered_pdb_path, records=None, gz=False, append_newline=True)
    
    fragment_index += 1

# %%
import numpy as np

def compute_inverse_pairwise_distances(df):
    """
    Compute the pairwise Euclidean distances between residues based on their 3D coordinates.

    Parameters:
    df (pd.DataFrame): DataFrame containing 'X', 'Y', 'Z' coordinates and 'NewIndex' as index.

    Returns:
    pd.DataFrame: A DataFrame containing the pairwise distance matrix.
    """
    # Extract the coordinates (X, Y, Z)
    coordinates = df[['X', 'Y', 'Z']].values

    # Calculate pairwise distances using broadcasting
    diff = coordinates[:, np.newaxis, :] - coordinates[np.newaxis, :, :]
    distances = np.sqrt(np.sum(diff ** 2, axis=-1))

    # Compute inverse distance (1/d)
    with np.errstate(divide='ignore'):  # Ignore division by zero warning
        inverse_distances = 1 / distances

    # Set diagonal elements (self-distances) to 1
    np.fill_diagonal(inverse_distances, 1)

    # Cap values at 1
    inverse_distances = np.minimum(inverse_distances, 1)

    return inverse_distances

def pdb_to_dataframe(pdb_file):
    """
    Load a PDB file using MDAnalysis and convert key atom information to a pandas DataFrame.
    """
    u = mda.Universe(pdb_file)
    
    # Extract atom-related data: atom name, residue name, residue ID, and chain ID
    atom_data = {
        'Atom Name': u.atoms.names,
        'Residue Name': u.atoms.resnames,
        'Residue ID': u.atoms.resids,
        'Chain ID': u.atoms.segids,
        'X': u.atoms.positions[:, 0],
        'Y': u.atoms.positions[:, 1],
        'Z': u.atoms.positions[:, 2],
    }
    
    # Create a pandas DataFrame from the atom data
    df = pd.DataFrame(atom_data)
    
    return df

def one_hot_encoding(pdb_df):
    biggest_set = [
        # Carbon (C) subtypes
        'C', 'CA', 'CB', 'CD', 'CD1', 'CD2', 'CE', 'CE1', 'CE2', 'CE3', 'CG', 'CG1', 'CG2', 'CH2', 'CZ', 'CZ2', 'CZ3',

        # Oxygen (O) subtypes
        'O', 'OH', 'OD1', 'OD2', 'OE1', 'OE2', 'OG', 'OG1', 

        # Nitrogen (N) subtypes
        'N', 'NE', 'NE1', 'NE2', 'ND1', 'ND2', 'NZ', 'NH1', 'NH2', 

        # Sulfur (S) subtypes
        'SD', 'SG'
    ]

    biggest_set.append('UNKNOWN')  # Add an additional column for unknown atom types
    
    # Create a zero matrix with shape (num_rows, num_unique_atoms)
    num_rows = len(pdb_df)
    num_cols = len(biggest_set)
    one_hot_matrix = np.zeros((num_rows, num_cols), dtype=int)

    # Create a mapping from atom name to index
    atom_to_index = {atom: idx for idx, atom in enumerate(biggest_set)}

    # Fill the one-hot matrix
    for i, atom in enumerate(pdb_df['Atom Name']):
        if atom in atom_to_index:
            one_hot_matrix[i, atom_to_index[atom]] = 1
        else:
            one_hot_matrix[i, atom_to_index['UNKNOWN']] = 1
            print(atom, "went to unknown column")

    return one_hot_matrix

def min_max_normalization(matrix):
    """
    Perform Min-Max normalization on a given matrix.

    Parameters:
    matrix (np.ndarray): The input matrix to be normalized.

    Returns:
    np.ndarray: The normalized matrix with values scaled to the range [0, 1].
    """
    # Compute the minimum and maximum values for the matrix
    min_val = np.min(matrix)
    max_val = np.max(matrix)

    # Apply Min-Max normalization formula
    normalized_matrix = (matrix - min_val) / (max_val - min_val)

    return normalized_matrix

# %%
max_atoms = 150
output_dir = "cholesterol-graph-5A/positive"
os.makedirs(output_dir, exist_ok=True)

positive_files = glob.glob("filtered-pdbs-distinct-5A/positive/*.pdb")
positive_files = sorted(positive_files, key=natural_sort_key)

for file in positive_files:
    pdb_df = pdb_to_dataframe(file)
    encoded_matrix = one_hot_encoding(pdb_df)
    inverse_distance = compute_inverse_pairwise_distances(pdb_df) # don't need to normalize since gat notebook already does that

    combined_matrix = inverse_distance @ encoded_matrix # for gnn
    combined_matrix = min_max_normalization(combined_matrix)

    num_atoms = inverse_distance.shape[0]

    if num_atoms > max_atoms:
        print(f"{file} has {num_atoms} atoms, exceeding the limit of {max_atoms}")
        raise Exception("Too many atoms!")
    
    combined_matrix = np.pad(combined_matrix, ((0, max_atoms - num_atoms), (0, 0)), mode='constant') # padding for gnn

    # Save to file
    base_name = os.path.splitext(os.path.basename(file))[0]
    output_path = os.path.join(output_dir, f"{base_name}_combined_matrix.npy")

    np.save(output_path, combined_matrix)

    print(f"Saved: {output_path}")
# Out:
# Saved: cholesterol-separate-graphs-5A/positive/1LRI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/1N83-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/1ZHY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/2RH1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/2ZXE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3A3Y-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3AM6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3D4S-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3GKI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3N9Y-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3NY8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3NY9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3NYA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3WGU-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/3WGV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4BOE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4BQU-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4DKL-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4EIY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4HYT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4IB4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4M48-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4NC3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4NTJ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4OR2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4PXZ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4RES-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XNU-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XNV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XNX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XP1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XP4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XP5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XP6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XP9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XPA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XPB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XPF-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XPG-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XPH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XPT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/4XT1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVR-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVS-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVU-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVW-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AVZ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW0-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5AW9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5C1M-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5D5A-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5D6L-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5I6X-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5I71-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5I73-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5I74-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5I75-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5IU4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5IU7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5IU8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5IUA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5IUB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5JQH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5JTB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5K2A-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5K2B-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5K2C-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5K2D-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5L7D-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5LWE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5MZJ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5MZP-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5N2R-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5NLX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5NM2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5NM4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5OLG-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5OLH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5OLO-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5OLV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5OLZ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5OM1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5OM4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5TCX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5TVN-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5UPH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5UVI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5VRA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5WVR-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5X7D-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5X93-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5XR8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5XRA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5ZM5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/5ZM7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6A15-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6A93-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6A94-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6AQF-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6B73-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6BHU-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6CO7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6DRX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6DRY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6DRZ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6DS0-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6GT3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6GYH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6IBB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6IDF-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6IIU-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6IIV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6IYC-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6JMQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6JXH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6JXI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6JXJ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6JZH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6KUW-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6LFO-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6LPJ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6LPK-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6LPL-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6LQG-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6LR4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6LW5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6M0F-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6M0Z-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6M2R-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6M3Z-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6M38-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6M47-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6MSM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6N4B-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6NBF-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6NF4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6O1V-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6O3C-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6OBA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6OMM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6OS1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6OS2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PB0-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PB1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PEQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PRZ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PS0-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PS1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PS2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PS3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PS4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PS5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PS6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PS7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PT0-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6PT2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6RZ6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6RZ7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6RZ9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6S0L-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6S0Q-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6S7P-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6T4G-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6T4I-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6T9N-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6T9O-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6TLQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6TPK-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6UCB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6UD4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6UD8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6UY0-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6V22-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6VI4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6VN7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6W5S-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WBF-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WBG-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WBM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WBN-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WGT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WH4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WIV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WLW-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WM2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6WQA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6XBK-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6ZDR-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/6ZDV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7A69-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7ARO-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7BTS-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7BU6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7BU7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7BVQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7C9I-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7CFM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7CFN-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7CKW-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7CKY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7CKZ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7CU3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7CZ5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7D8X-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7D76-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7D77-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7D91-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DDH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DDL-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DF8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DFW-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DRT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DTY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DUQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DUR-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7DW9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7E2X-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7E2Y-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7E2Z-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7E14-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7E32-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7EJX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7EKI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7EKP-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7EKT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/7ET1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/
-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SR7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SR8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SR9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SRA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SRB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SRC-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SRD-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SRE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SRF-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SRG-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SRI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SS3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SS6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SS7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SS8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SS9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SZA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SZB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8SZH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T2V-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T03-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T3S-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T3V-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T04-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T05-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T6U-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T6V-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T56-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8T57-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8TF5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8TKP-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8TW4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8TW6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8U4N-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8U4O-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8U4P-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8U4Q-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8U4R-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8U4S-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8U4T-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UBR-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UGY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UH3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UUK-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UVC-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UVD-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UVE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UVF-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UVG-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8UVI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8V0G-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8V1G-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8V7Z-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8V60-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8V63-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8V64-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8VAV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8VY7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8VY9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8W2L-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8W4A-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8W6H-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8W6O-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8W8B-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8W88-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WA5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WE6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WE7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WE8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WE9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WJX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WOQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WOR-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WOS-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WOT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WPU-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WR3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8WRB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X5B-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X5F-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X52-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X53-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X54-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X90-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X91-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X93-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8X94-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XBS-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XC1-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XGM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XMM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XOR-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XOS-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XQI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XQJ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XQL-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XQN-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XQO-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XQP-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XQS-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8XQT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8Y6I-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8Y56-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8Y69-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YJP-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YK0-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YKY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YN2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YN3-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YN4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YN5-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YN6-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YN7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YN8-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YN9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YNA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YR2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YU7-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YUT-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YUU-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8YUV-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8Z8Z-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8Z74-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8ZJG-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8ZLE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8ZPL-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8ZPM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8ZPN-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8ZSJ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/8ZYJ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9B8O-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9BBC-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9BR2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9BUK-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9BUR-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9BUX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9BVH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9C12-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CDC-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CDD-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CDE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CIA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CQ4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CUI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CUK-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CZM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9CZQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9D3E-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9D3G-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9D18-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9D19-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DBK-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DBL-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DBM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DBN-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DNW-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DNX-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DNY-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DNZ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DO0-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DVJ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DVK-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DVL-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DVM-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DVN-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DVO-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DVP-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DW9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9DXQ-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9E82-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9EAH-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9EAI-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9EO4-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9EUO-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9EUP-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9F41-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9FUP-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9GE2-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9GYO-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9IJ9-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9IJA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9IMA-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9INE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9INF-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9ITB-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9ITE-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9ITG-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J3X-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J7M-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J7N-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J7O-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J8C-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J8D-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J40-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J97-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9J98-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9K1D-filtered_graphs.npy
# Saved: cholesterol-separate-graphs-5A/positive/9K7B-filtered_graphs.npy

# %%
max_atoms = 150
output_dir = "cholesterol-graph-5A/unlabeled"
os.makedirs(output_dir, exist_ok=True)

unlabeled_files = glob.glob("filtered-pdbs-distinct-5A/unlabeled/*.pdb")
unlabeled_files = sorted(unlabeled_files, key=natural_sort_key)

for file in unlabeled_files:
    pdb_df = pdb_to_dataframe(file)
    encoded_matrix = one_hot_encoding(pdb_df)
    inverse_distance = compute_inverse_pairwise_distances(pdb_df) # don't need to normalize since gat notebook already does that

    combined_matrix = inverse_distance @ encoded_matrix # for gnn
    combined_matrix = min_max_normalization(combined_matrix)

    num_atoms = inverse_distance.shape[0]

    if num_atoms > max_atoms:
        print(f"{file} has {num_atoms} atoms, exceeding the limit of {max_atoms}")
        raise Exception("Too many atoms!")
    
    combined_matrix = np.pad(combined_matrix, ((0, max_atoms - num_atoms), (0, 0)), mode='constant') # padding for gnn

    # Save to file
    base_name = os.path.splitext(os.path.basename(file))[0]
    output_path = os.path.join(output_dir, f"{base_name}_combined_matrix.npy")

    np.save(output_path, combined_matrix)

    print(f"Saved: {output_path}")
# Out:
# Saved: cholesterol-separate-graphs-5A/unlabeled/1LRI-f1_graphs.npy
# Saved: cholesterol-separate-graphs-5A/unlabeled/1LRI-f4_graphs.npy
# Saved: cholesterol-separate-graphs-5A/unlabeled/