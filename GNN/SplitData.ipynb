# %%
import glob
import os
import shutil
import random

# Define the source and destination folders
source_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/PositiveWithoutSpies'  # Replace with the path to your source folder
destination_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive'  # Replace with the path to your destination folder

# Make sure the destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Get the list of all files in the source folder
all_files = os.listdir(source_folder)

# Randomly select 154 positives
selected_positives = random.sample(all_files, k=154)

# Move the selected fragment files to the destination folder
for positive in selected_positives:
    src_path = os.path.join(source_folder, positive)
    dest_path = os.path.join(destination_folder, positive)
    shutil.move(src_path, dest_path)
    print(f'Moved: {positive}')

print(f'Moved {len(selected_positives)} positives to {destination_folder}')

# %%
# Define the source and destination folders
source_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/PositiveWithoutSpies'  # Replace with the path to your source folder
destination_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Spies'  # Replace with the path to your destination folder

# Make sure the destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Get the list of all files in the source folder
all_files = os.listdir(source_folder)

# Randomly select 154 positives
selected_positives = random.sample(all_files, k=154)

# Move the selected fragment files to the destination folder
for positive in selected_positives:
    src_path = os.path.join(source_folder, positive)
    dest_path = os.path.join(destination_folder, positive)
    shutil.move(src_path, dest_path)
    print(f'Moved: {positive}')

print(f'Moved {len(selected_positives)} positives to {destination_folder}')

# %%
# Define the source and destination folders
source_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/PositiveWithoutSpies'  # Replace with the path to your source folder
destination_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Validation_Set'  # Replace with the path to your destination folder

# Make sure the destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Get the list of all files in the source folder
all_files = os.listdir(source_folder)

# Randomly select 77 positives
selected_positives = random.sample(all_files, k=77)

# Move the selected fragment files to the destination folder
for positive in selected_positives:
    src_path = os.path.join(source_folder, positive)
    dest_path = os.path.join(destination_folder, positive)
    shutil.move(src_path, dest_path)
    print(f'Moved: {positive}')

print(f'Moved {len(selected_positives)} positives to {destination_folder}')

# %%
import os
import shutil
import csv

# Set your paths
source_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/UnlabeledWithSpies' 
destination_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/LikelyPositives'

# Ensure destination directory exists
os.makedirs(destination_folder, exist_ok=True)

# Go through each file in the source directory
for filename in os.listdir(source_folder):
    if "positive" in filename:
        source_path = os.path.join(source_folder, filename)
        dest_path = os.path.join(destination_folder, filename)
        if os.path.isfile(source_path):
            shutil.move(source_path, dest_path)
            print(f"Moved: {filename}")

# %%
# Define the source and destination folders
source_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/UnlabeledWithSpies'  # Replace with the path to your source folder
destination_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled'  # Replace with the path to your destination folder

# Make sure the destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Get the list of all files in the source folder
all_files = os.listdir(source_folder)

# Randomly select 554 fragments
selected_fragments = random.sample(all_files, k=554)

# Move the selected fragment files to the destination folder
for fragment in selected_fragments:
    src_path = os.path.join(source_folder, fragment)
    dest_path = os.path.join(destination_folder, fragment)
    shutil.move(src_path, dest_path)
    print(f'Moved: {fragment}')

print(f'Moved {len(selected_fragments)} fragments to {destination_folder}')

# %%
# Define the source and destination folders
source_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/UnlabeledWithSpies'  # Replace with the path to your source folder
destination_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Validation_Set'  # Replace with the path to your destination folder

# Make sure the destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Get the list of all files in the source folder
all_files = os.listdir(source_folder)

# Randomly select 277 fragments
selected_fragments = random.sample(all_files, k=277)

# Move the selected fragment files to the destination folder
for fragment in selected_fragments:
    src_path = os.path.join(source_folder, fragment)
    dest_path = os.path.join(destination_folder, fragment)
    shutil.move(src_path, dest_path)
    print(f'Moved: {fragment}')

print(f'Moved {len(selected_fragments)} fragments to {destination_folder}')

# %%
# Define the source and destination folders
source_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Spies'  
destination_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/UnlabeledWithSpies' 

# Make sure the destination folder exists
os.makedirs(destination_folder, exist_ok=True)

# Get the list of all files in the source folder
all_files = os.listdir(source_folder)

# Move the selected fragment files to the destination folder
for spy in all_files:
    src_path = os.path.join(source_folder, spy)
    dest_path = os.path.join(destination_folder, spy)
    shutil.copy(src_path, dest_path)
    print(f'Copied: {spy}')

print(f'Copied {len(all_files)} spies to {destination_folder}')

# %%
import os
import shutil
import random

source_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/UnlabeledWithSpies' 
k_subsets_folder = '../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/k_subsets' 

# Make sure the k_subsets folder exists
os.makedirs(k_subsets_folder, exist_ok=True)

# Get the list of all files in the source folder
all_files = os.listdir(source_folder)

# Create 50 directories (k_subsets)
k = 50
for i in range(k):
    subset_folder = os.path.join(k_subsets_folder, f'subset_{i+1}')
    os.makedirs(subset_folder, exist_ok=True)

# Distribute 385 files to each subset 
for i in range(k):
    # Randomly select 385 files for this subset 
    selected_files = random.sample(all_files, k=385)
    
    # Create the subset folder
    subset_folder = os.path.join(k_subsets_folder, f'subset_{i+1}')
    
    # Copy the selected files into the corresponding subset folder
    for file in selected_files:
        src_path = os.path.join(source_folder, file)
        dest_path = os.path.join(subset_folder, file)
        
        # Copy the file
        shutil.copy(src_path, dest_path)
        print(f'Copied {file} to {subset_folder}')

print(f'Finished copying 385 files into each of the {k} subsets.')
