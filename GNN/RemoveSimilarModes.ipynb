# %%
import os
import glob
import pandas as pd
import numpy as np
from scipy.spatial import distance_matrix
import re
from collections import defaultdict
from biopandas.pdb import PandasPdb

def grid_list(atom_df):
    return list(zip(atom_df['x_coord'], atom_df['y_coord'], atom_df['z_coord']))

def load_atom_df(pdb_path):
    ligand_df = PandasPdb().read_pdb(pdb_path)
    ligand_df.df.keys()
    ligand = ligand_df.df['HETATM'] 
    return ligand

def compute_overlap(coords1, coords2, threshold=2.0):
    if len(coords1) == 0 or len(coords2) == 0:
        return 0
    dists = distance_matrix(coords1, coords2)
    overlap1 = (np.min(dists, axis=1) < threshold).sum() / len(coords1)
    overlap2 = (np.min(dists, axis=0) < threshold).sum() / len(coords2)
    return min(overlap1, overlap2)

def process_modes_by_coords(mode_files, overlap_cutoff=0.7):
    keep = []
    for file in mode_files:
        df = load_atom_df(file)
        coords = grid_list(df)
        similar = False
        for kept_file in keep:
            kept_df = load_atom_df(kept_file)
            kept_coords = grid_list(kept_df)
            overlap = compute_overlap(coords, kept_coords)
            if overlap >= overlap_cutoff:
                print(f"Deleting {file} — {overlap*100:.1f}% overlap with {kept_file}")
                os.remove(file)
                similar = True
                break
        if not similar:
            keep.append(file)
    return keep

# %%
def get_protein_name(filename):
    basename = os.path.basename(filename)  # Get file name without path
    match = re.match(r'([a-zA-Z0-9]{4})', basename)  # Match the first 4-character PDB ID
    if match:
        return match.group(1).upper()
    else:
        return None

def natural_sort_key(s):
    """Function to sort strings in a natural alphanumeric order."""
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', s)]

unlabeled_files = glob.glob("CLR-Unlabeled_/*.pdb")
unlabeled_files = sorted(unlabeled_files, key=natural_sort_key)

# Group by protein name
grouped = defaultdict(list)
for file in unlabeled_files:
    protein = get_protein_name(file)
    if protein:
        grouped[protein].append(file)

# Convert to list of lists
list_of_lists = list(grouped.values())

for i, group in enumerate(list_of_lists):
    process_modes_by_coords(group)
# Out:
# Deleting CLR-Unlabeled_/1LRI_protein_vina_out1LRI_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/1LRI_protein_vina_out1LRI_mode_1.pdb
# Deleting CLR-Unlabeled_/1LRI_protein_vina_out1LRI_mode_3.pdb — 83.8% overlap with CLR-Unlabeled_/1LRI_protein_vina_out1LRI_mode_1.pdb
# Deleting CLR-Unlabeled_/1LRI_protein_vina_out1LRI_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/1LRI_protein_vina_out1LRI_mode_1.pdb
# Deleting CLR-Unlabeled_/1N83_protein_vina_out1N83_mode_3.pdb — 97.3% overlap with CLR-Unlabeled_/1N83_protein_vina_out1N83_mode_1.pdb
# Deleting CLR-Unlabeled_/1N83_protein_vina_out1N83_mode_5.pdb — 70.3% overlap with CLR-Unlabeled_/1N83_protein_vina_out1N83_mode_1.pdb
# Deleting CLR-Unlabeled_/2ZXE_protein_vina_out2ZXE_mode_2.pdb — 70.3% overlap with CLR-Unlabeled_/2ZXE_protein_vina_out2ZXE_mode_1.pdb
# Deleting CLR-Unlabeled_/2ZXE_protein_vina_out2ZXE_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/2ZXE_protein_vina_out2ZXE_mode_1.pdb
# Deleting CLR-Unlabeled_/2ZXE_protein_vina_out2ZXE_mode_4.pdb — 73.0% overlap with CLR-Unlabeled_/2ZXE_protein_vina_out2ZXE_mode_1.pdb
# Deleting CLR-Unlabeled_/2ZXE_protein_vina_out2ZXE_mode_5.pdb — 81.1% overlap with CLR-Unlabeled_/2ZXE_protein_vina_out2ZXE_mode_1.pdb
# Deleting CLR-Unlabeled_/3A3Y_protein_vina_out3A3Y_mode_2.pdb — 71.6% overlap with CLR-Unlabeled_/3A3Y_protein_vina_out3A3Y_mode_1.pdb
# Deleting CLR-Unlabeled_/3A3Y_protein_vina_out3A3Y_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/3A3Y_protein_vina_out3A3Y_mode_1.pdb
# Deleting CLR-Unlabeled_/3A3Y_protein_vina_out3A3Y_mode_5.pdb — 75.7% overlap with CLR-Unlabeled_/3A3Y_protein_vina_out3A3Y_mode_4.pdb
# Deleting CLR-Unlabeled_/3AM6_protein_vina_out3AM6_mode_5.pdb — 77.0% overlap with CLR-Unlabeled_/3AM6_protein_vina_out3AM6_mode_2.pdb
# Deleting CLR-Unlabeled_/3N9Y_protein_vina_out3N9Y_mode_2.pdb — 100.0% overlap with CLR-Unlabeled_/3N9Y_protein_vina_out3N9Y_mode_1.pdb
# Deleting CLR-Unlabeled_/3NY8_protein_vina_out3NY8_mode_5.pdb — 83.8% overlap with CLR-Unlabeled_/3NY8_protein_vina_out3NY8_mode_3.pdb
# Deleting CLR-Unlabeled_/3NY9_protein_vina_out3NY9_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/3NY9_protein_vina_out3NY9_mode_1.pdb
# Deleting CLR-Unlabeled_/3NY9_protein_vina_out3NY9_mode_5.pdb — 93.2% overlap with CLR-Unlabeled_/3NY9_protein_vina_out3NY9_mode_3.pdb
# Deleting CLR-Unlabeled_/3NYA_protein_vina_out3NYA_mode_2.pdb — 79.7% overlap with CLR-Unlabeled_/3NYA_protein_vina_out3NYA_mode_1.pdb
# Deleting CLR-Unlabeled_/3NYA_protein_vina_out3NYA_mode_4.pdb — 74.3% overlap with CLR-Unlabeled_/3NYA_protein_vina_out3NYA_mode_1.pdb
# Deleting CLR-Unlabeled_/3WGU_protein_vina_out3WGU_mode_4.pdb — 86.5% overlap with CLR-Unlabeled_/3WGU_protein_vina_out3WGU_mode_2.pdb
# Deleting CLR-Unlabeled_/3WGV_protein_vina_out3WGV_mode_2.pdb — 83.8% overlap with CLR-Unlabeled_/3WGV_protein_vina_out3WGV_mode_1.pdb
# Deleting CLR-Unlabeled_/3WGV_protein_vina_out3WGV_mode_5.pdb — 93.2% overlap with CLR-Unlabeled_/3WGV_protein_vina_out3WGV_mode_3.pdb
# Deleting CLR-Unlabeled_/4BOE_protein_vina_out4BOE_mode_2.pdb — 90.5% overlap with CLR-Unlabeled_/4BOE_protein_vina_out4BOE_mode_1.pdb
# Deleting CLR-Unlabeled_/4BOE_protein_vina_out4BOE_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/4BOE_protein_vina_out4BOE_mode_1.pdb
# Deleting CLR-Unlabeled_/4BOE_protein_vina_out4BOE_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/4BOE_protein_vina_out4BOE_mode_1.pdb
# Deleting CLR-Unlabeled_/4DKL_protein_vina_out4DKL_mode_5.pdb — 86.5% overlap with CLR-Unlabeled_/4DKL_protein_vina_out4DKL_mode_3.pdb
# Deleting CLR-Unlabeled_/4EIY_protein_vina_out4EIY_mode_2.pdb — 81.1% overlap with CLR-Unlabeled_/4EIY_protein_vina_out4EIY_mode_1.pdb
# Deleting CLR-Unlabeled_/4EIY_protein_vina_out4EIY_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/4EIY_protein_vina_out4EIY_mode_1.pdb
# Deleting CLR-Unlabeled_/4HYT_protein_vina_out4HYT_mode_4.pdb — 78.4% overlap with CLR-Unlabeled_/4HYT_protein_vina_out4HYT_mode_1.pdb
# Deleting CLR-Unlabeled_/4HYT_protein_vina_out4HYT_mode_5.pdb — 93.2% overlap with CLR-Unlabeled_/4HYT_protein_vina_out4HYT_mode_1.pdb
# Deleting CLR-Unlabeled_/4IB4_protein_vina_out4IB4_mode_4.pdb — 71.6% overlap with CLR-Unlabeled_/4IB4_protein_vina_out4IB4_mode_2.pdb
# Deleting CLR-Unlabeled_/4IB4_protein_vina_out4IB4_mode_5.pdb — 95.9% overlap with CLR-Unlabeled_/4IB4_protein_vina_out4IB4_mode_1.pdb
# Deleting CLR-Unlabeled_/4M48_protein_vina_out4M48_mode_2.pdb — 79.7% overlap with CLR-Unlabeled_/4M48_protein_vina_out4M48_mode_1.pdb
# Deleting CLR-Unlabeled_/4M48_protein_vina_out4M48_mode_5.pdb — 86.5% overlap with CLR-Unlabeled_/4M48_protein_vina_out4M48_mode_4.pdb
# Deleting CLR-Unlabeled_/4NC3_protein_vina_out4NC3_mode_2.pdb — 90.5% overlap with CLR-Unlabeled_/4NC3_protein_vina_out4NC3_mode_1.pdb
# Deleting CLR-Unlabeled_/4NC3_protein_vina_out4NC3_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/4NC3_protein_vina_out4NC3_mode_1.pdb
# Deleting CLR-Unlabeled_/4NC3_protein_vina_out4NC3_mode_5.pdb — 97.3% overlap with CLR-Unlabeled_/4NC3_protein_vina_out4NC3_mode_1.pdb
# Deleting CLR-Unlabeled_/4NTJ_protein_vina_out4NTJ_mode_2.pdb — 90.5% overlap with CLR-Unlabeled_/4NTJ_protein_vina_out4NTJ_mode_1.pdb
# Deleting CLR-Unlabeled_/4OR2_protein_vina_out4OR2_mode_2.pdb — 90.5% overlap with CLR-Unlabeled_/4OR2_protein_vina_out4OR2_mode_1.pdb
# Deleting CLR-Unlabeled_/4OR2_protein_vina_out4OR2_mode_5.pdb — 71.6% overlap with CLR-Unlabeled_/4OR2_protein_vina_out4OR2_mode_3.pdb
# Deleting CLR-Unlabeled_/4PXZ_protein_vina_out4PXZ_mode_3.pdb — 90.5% overlap with CLR-Unlabeled_/4PXZ_protein_vina_out4PXZ_mode_1.pdb
# Deleting CLR-Unlabeled_/4RES_protein_vina_out4RES_mode_3.pdb — 95.9% overlap with CLR-Unlabeled_/4RES_protein_vina_out4RES_mode_1.pdb
# Deleting CLR-Unlabeled_/4RES_protein_vina_out4RES_mode_4.pdb — 79.7% overlap with CLR-Unlabeled_/4RES_protein_vina_out4RES_mode_2.pdb
# Deleting CLR-Unlabeled_/4XNU_protein_vina_out4XNU_mode_3.pdb — 78.4% overlap with CLR-Unlabeled_/4XNU_protein_vina_out4XNU_mode_1.pdb
# Deleting CLR-Unlabeled_/4XNV_protein_vina_out4XNV_mode_4.pdb — 93.2% overlap with CLR-Unlabeled_/4XNV_protein_vina_out4XNV_mode_3.pdb
# Deleting CLR-Unlabeled_/4XNV_protein_vina_out4XNV_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/4XNV_protein_vina_out4XNV_mode_2.pdb
# Deleting CLR-Unlabeled_/4XNX_protein_vina_out4XNX_mode_2.pdb — 97.3% overlap with CLR-Unlabeled_/4XNX_protein_vina_out4XNX_mode_1.pdb
# Deleting CLR-Unlabeled_/4XNX_protein_vina_out4XNX_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/4XNX_protein_vina_out4XNX_mode_1.pdb
# Deleting CLR-Unlabeled_/4XP1_protein_vina_out4XP1_mode_2.pdb — 79.7% overlap with CLR-Unlabeled_/4XP1_protein_vina_out4XP1_mode_1.pdb
# Deleting CLR-Unlabeled_/4XP1_protein_vina_out4XP1_mode_3.pdb — 87.8% overlap with CLR-Unlabeled_/4XP1_protein_vina_out4XP1_mode_1.pdb
# Deleting CLR-Unlabeled_/4XP1_protein_vina_out4XP1_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/4XP1_protein_vina_out4XP1_mode_4.pdb
# Deleting CLR-Unlabeled_/4XP4_protein_vina_out4XP4_mode_2.pdb — 81.1% overlap with CLR-Unlabeled_/4XP4_protein_vina_out4XP4_mode_1.pdb
# Deleting CLR-Unlabeled_/4XP4_protein_vina_out4XP4_mode_4.pdb — 87.8% overlap with CLR-Unlabeled_/4XP4_protein_vina_out4XP4_mode_1.pdb
# Deleting CLR-Unlabeled_/4XP5_protein_vina_out4XP5_mode_5.pdb — 78.4% overlap with CLR-Unlabeled_/4XP5_protein_vina_out4XP5_mode_3.pdb
# Deleting CLR-Unlabeled_/4XP6_protein_vina_out4XP6_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/4XP6_protein_vina_out4XP6_mode_1.pdb
# Deleting CLR-Unlabeled_/4XP6_protein_vina_out4XP6_mode_4.pdb — 74.3% overlap with CLR-Unlabeled_/4XP6_protein_vina_out4XP6_mode_1.pdb
# Deleting CLR-Unlabeled_/4XP6_protein_vina_out4XP6_mode_5.pdb — 95.9% overlap with CLR-Unlabeled_/4XP6_protein_vina_out4XP6_mode_3.pdb
# Deleting CLR-Unlabeled_/4XP9_protein_vina_out4XP9_mode_4.pdb — 77.0% overlap with CLR-Unlabeled_/4XP9_protein_vina_out4XP9_mode_3.pdb
# Deleting CLR-Unlabeled_/4XP9_protein_vina_out4XP9_mode_5.pdb — 73.0% overlap with CLR-Unlabeled_/4XP9_protein_vina_out4XP9_mode_3.pdb
# Deleting CLR-Unlabeled_/4XPA_protein_vina_out4XPA_mode_2.pdb — 83.8% overlap with CLR-Unlabeled_/4XPA_protein_vina_out4XPA_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPA_protein_vina_out4XPA_mode_4.pdb — 79.7% overlap with CLR-Unlabeled_/4XPA_protein_vina_out4XPA_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPB_protein_vina_out4XPB_mode_3.pdb — 83.8% overlap with CLR-Unlabeled_/4XPB_protein_vina_out4XPB_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPB_protein_vina_out4XPB_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/4XPB_protein_vina_out4XPB_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPB_protein_vina_out4XPB_mode_5.pdb — 83.8% overlap with CLR-Unlabeled_/4XPB_protein_vina_out4XPB_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPF_protein_vina_out4XPF_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/4XPF_protein_vina_out4XPF_mode_2.pdb
# Deleting CLR-Unlabeled_/4XPG_protein_vina_out4XPG_mode_4.pdb — 79.7% overlap with CLR-Unlabeled_/4XPG_protein_vina_out4XPG_mode_3.pdb
# Deleting CLR-Unlabeled_/4XPH_protein_vina_out4XPH_mode_2.pdb — 74.3% overlap with CLR-Unlabeled_/4XPH_protein_vina_out4XPH_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPH_protein_vina_out4XPH_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/4XPH_protein_vina_out4XPH_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPH_protein_vina_out4XPH_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/4XPH_protein_vina_out4XPH_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPT_protein_vina_out4XPT_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/4XPT_protein_vina_out4XPT_mode_1.pdb
# Deleting CLR-Unlabeled_/4XPT_protein_vina_out4XPT_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/4XPT_protein_vina_out4XPT_mode_1.pdb
# Deleting CLR-Unlabeled_/4XT1_protein_vina_out4XT1_mode_2.pdb — 91.9% overlap with CLR-Unlabeled_/4XT1_protein_vina_out4XT1_mode_1.pdb
# Deleting CLR-Unlabeled_/4XT1_protein_vina_out4XT1_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/4XT1_protein_vina_out4XT1_mode_3.pdb
# Deleting CLR-Unlabeled_/5AVQ_protein_vina_out5AVQ_mode_2.pdb — 90.5% overlap with CLR-Unlabeled_/5AVQ_protein_vina_out5AVQ_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVQ_protein_vina_out5AVQ_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/5AVQ_protein_vina_out5AVQ_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVQ_protein_vina_out5AVQ_mode_5.pdb — 75.7% overlap with CLR-Unlabeled_/5AVQ_protein_vina_out5AVQ_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVS_protein_vina_out5AVS_mode_3.pdb — 91.9% overlap with CLR-Unlabeled_/5AVS_protein_vina_out5AVS_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVS_protein_vina_out5AVS_mode_4.pdb — 90.5% overlap with CLR-Unlabeled_/5AVS_protein_vina_out5AVS_mode_2.pdb
# Deleting CLR-Unlabeled_/5AVT_protein_vina_out5AVT_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/5AVT_protein_vina_out5AVT_mode_3.pdb
# Deleting CLR-Unlabeled_/5AVU_protein_vina_out5AVU_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/5AVU_protein_vina_out5AVU_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVU_protein_vina_out5AVU_mode_5.pdb — 87.8% overlap with CLR-Unlabeled_/5AVU_protein_vina_out5AVU_mode_3.pdb
# Deleting CLR-Unlabeled_/5AVV_protein_vina_out5AVV_mode_2.pdb — 89.2% overlap with CLR-Unlabeled_/5AVV_protein_vina_out5AVV_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVV_protein_vina_out5AVV_mode_3.pdb — 83.8% overlap with CLR-Unlabeled_/5AVV_protein_vina_out5AVV_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVW_protein_vina_out5AVW_mode_2.pdb — 75.7% overlap with CLR-Unlabeled_/5AVW_protein_vina_out5AVW_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVW_protein_vina_out5AVW_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/5AVW_protein_vina_out5AVW_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVX_protein_vina_out5AVX_mode_2.pdb — 94.6% overlap with CLR-Unlabeled_/5AVX_protein_vina_out5AVX_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVX_protein_vina_out5AVX_mode_3.pdb — 79.7% overlap with CLR-Unlabeled_/5AVX_protein_vina_out5AVX_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVX_protein_vina_out5AVX_mode_5.pdb — 81.1% overlap with CLR-Unlabeled_/5AVX_protein_vina_out5AVX_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVY_protein_vina_out5AVY_mode_3.pdb — 98.6% overlap with CLR-Unlabeled_/5AVY_protein_vina_out5AVY_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVY_protein_vina_out5AVY_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/5AVY_protein_vina_out5AVY_mode_1.pdb
# Deleting CLR-Unlabeled_/5AVZ_protein_vina_out5AVZ_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/5AVZ_protein_vina_out5AVZ_mode_3.pdb
# Deleting CLR-Unlabeled_/5AVZ_protein_vina_out5AVZ_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/5AVZ_protein_vina_out5AVZ_mode_3.pdb
# Deleting CLR-Unlabeled_/5AW0_protein_vina_out5AW0_mode_2.pdb — 79.7% overlap with CLR-Unlabeled_/5AW0_protein_vina_out5AW0_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW0_protein_vina_out5AW0_mode_3.pdb — 90.5% overlap with CLR-Unlabeled_/5AW0_protein_vina_out5AW0_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW1_protein_vina_out5AW1_mode_2.pdb — 97.3% overlap with CLR-Unlabeled_/5AW1_protein_vina_out5AW1_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW1_protein_vina_out5AW1_mode_3.pdb — 73.0% overlap with CLR-Unlabeled_/5AW1_protein_vina_out5AW1_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW1_protein_vina_out5AW1_mode_4.pdb — 74.3% overlap with CLR-Unlabeled_/5AW1_protein_vina_out5AW1_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW2_protein_vina_out5AW2_mode_3.pdb — 91.9% overlap with CLR-Unlabeled_/5AW2_protein_vina_out5AW2_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW2_protein_vina_out5AW2_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/5AW2_protein_vina_out5AW2_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW2_protein_vina_out5AW2_mode_5.pdb — 98.6% overlap with CLR-Unlabeled_/5AW2_protein_vina_out5AW2_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW3_protein_vina_out5AW3_mode_2.pdb — 82.4% overlap with CLR-Unlabeled_/5AW3_protein_vina_out5AW3_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW3_protein_vina_out5AW3_mode_3.pdb — 95.9% overlap with CLR-Unlabeled_/5AW3_protein_vina_out5AW3_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW3_protein_vina_out5AW3_mode_4.pdb — 70.3% overlap with CLR-Unlabeled_/5AW3_protein_vina_out5AW3_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW3_protein_vina_out5AW3_mode_5.pdb — 97.3% overlap with CLR-Unlabeled_/5AW3_protein_vina_out5AW3_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW4_protein_vina_out5AW4_mode_2.pdb — 93.2% overlap with CLR-Unlabeled_/5AW4_protein_vina_out5AW4_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW4_protein_vina_out5AW4_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/5AW4_protein_vina_out5AW4_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW4_protein_vina_out5AW4_mode_4.pdb — 78.4% overlap with CLR-Unlabeled_/5AW4_protein_vina_out5AW4_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW5_protein_vina_out5AW5_mode_2.pdb — 89.2% overlap with CLR-Unlabeled_/5AW5_protein_vina_out5AW5_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW5_protein_vina_out5AW5_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/5AW5_protein_vina_out5AW5_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW5_protein_vina_out5AW5_mode_4.pdb — 74.3% overlap with CLR-Unlabeled_/5AW5_protein_vina_out5AW5_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW5_protein_vina_out5AW5_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/5AW5_protein_vina_out5AW5_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW6_protein_vina_out5AW6_mode_3.pdb — 78.4% overlap with CLR-Unlabeled_/5AW6_protein_vina_out5AW6_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW6_protein_vina_out5AW6_mode_5.pdb — 85.1% overlap with CLR-Unlabeled_/5AW6_protein_vina_out5AW6_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW7_protein_vina_out5AW7_mode_3.pdb — 98.6% overlap with CLR-Unlabeled_/5AW7_protein_vina_out5AW7_mode_2.pdb
# Deleting CLR-Unlabeled_/5AW7_protein_vina_out5AW7_mode_4.pdb — 78.4% overlap with CLR-Unlabeled_/5AW7_protein_vina_out5AW7_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW7_protein_vina_out5AW7_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/5AW7_protein_vina_out5AW7_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW8_protein_vina_out5AW8_mode_2.pdb — 83.8% overlap with CLR-Unlabeled_/5AW8_protein_vina_out5AW8_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW8_protein_vina_out5AW8_mode_3.pdb — 75.7% overlap with CLR-Unlabeled_/5AW8_protein_vina_out5AW8_mode_1.pdb
# Deleting CLR-Unlabeled_/5AW9_protein_vina_out5AW9_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/5AW9_protein_vina_out5AW9_mode_1.pdb
# Deleting CLR-Unlabeled_/5C1M_protein_vina_out5C1M_mode_2.pdb — 86.5% overlap with CLR-Unlabeled_/5C1M_protein_vina_out5C1M_mode_1.pdb
# Deleting CLR-Unlabeled_/5C1M_protein_vina_out5C1M_mode_4.pdb — 100.0% overlap with CLR-Unlabeled_/5C1M_protein_vina_out5C1M_mode_3.pdb
# Deleting CLR-Unlabeled_/5C1M_protein_vina_out5C1M_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/5C1M_protein_vina_out5C1M_mode_3.pdb
# Deleting CLR-Unlabeled_/5D5A_protein_vina_out5D5A_mode_4.pdb — 87.8% overlap with CLR-Unlabeled_/5D5A_protein_vina_out5D5A_mode_1.pdb
# Deleting CLR-Unlabeled_/5D6L_protein_vina_out5D6L_mode_3.pdb — 75.7% overlap with CLR-Unlabeled_/5D6L_protein_vina_out5D6L_mode_2.pdb
# Deleting CLR-Unlabeled_/5I6X_protein_vina_out5I6X_mode_2.pdb — 86.5% overlap with CLR-Unlabeled_/5I6X_protein_vina_out5I6X_mode_1.pdb
# Deleting CLR-Unlabeled_/5I6X_protein_vina_out5I6X_mode_5.pdb — 70.3% overlap with CLR-Unlabeled_/5I6X_protein_vina_out5I6X_mode_4.pdb
# Deleting CLR-Unlabeled_/5I71_protein_vina_out5I71_mode_2.pdb — 86.5% overlap with CLR-Unlabeled_/5I71_protein_vina_out5I71_mode_1.pdb
# Deleting CLR-Unlabeled_/5I71_protein_vina_out5I71_mode_3.pdb — 87.8% overlap with CLR-Unlabeled_/5I71_protein_vina_out5I71_mode_1.pdb
# Deleting CLR-Unlabeled_/5I71_protein_vina_out5I71_mode_4.pdb — 71.6% overlap with CLR-Unlabeled_/5I71_protein_vina_out5I71_mode_1.pdb
# Deleting CLR-Unlabeled_/5I73_protein_vina_out5I73_mode_4.pdb — 97.3% overlap with CLR-Unlabeled_/5I73_protein_vina_out5I73_mode_1.pdb
# Deleting CLR-Unlabeled_/5I74_protein_vina_out5I74_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/5I74_protein_vina_out5I74_mode_2.pdb
# Deleting CLR-Unlabeled_/5IU4_protein_vina_out5IU4_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/5IU4_protein_vina_out5IU4_mode_1.pdb
# Deleting CLR-Unlabeled_/5IU4_protein_vina_out5IU4_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/5IU4_protein_vina_out5IU4_mode_1.pdb
# Deleting CLR-Unlabeled_/5IU4_protein_vina_out5IU4_mode_5.pdb — 77.0% overlap with CLR-Unlabeled_/5IU4_protein_vina_out5IU4_mode_2.pdb
# Deleting CLR-Unlabeled_/5IU7_protein_vina_out5IU7_mode_3.pdb — 87.8% overlap with CLR-Unlabeled_/5IU7_protein_vina_out5IU7_mode_2.pdb
# Deleting CLR-Unlabeled_/5IU7_protein_vina_out5IU7_mode_5.pdb — 86.5% overlap with CLR-Unlabeled_/5IU7_protein_vina_out5IU7_mode_2.pdb
# Deleting CLR-Unlabeled_/5IU8_protein_vina_out5IU8_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/5IU8_protein_vina_out5IU8_mode_1.pdb
# Deleting CLR-Unlabeled_/5IU8_protein_vina_out5IU8_mode_3.pdb — 70.3% overlap with CLR-Unlabeled_/5IU8_protein_vina_out5IU8_mode_1.pdb
# Deleting CLR-Unlabeled_/5IUA_protein_vina_out5IUA_mode_4.pdb — 74.3% overlap with CLR-Unlabeled_/5IUA_protein_vina_out5IUA_mode_1.pdb
# Deleting CLR-Unlabeled_/5IUA_protein_vina_out5IUA_mode_5.pdb — 75.7% overlap with CLR-Unlabeled_/5IUA_protein_vina_out5IUA_mode_1.pdb
# Deleting CLR-Unlabeled_/5IUB_protein_vina_out5IUB_mode_3.pdb — 74.3% overlap with CLR-Unlabeled_/5IUB_protein_vina_out5IUB_mode_1.pdb
# Deleting CLR-Unlabeled_/5IUB_protein_vina_out5IUB_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/5IUB_protein_vina_out5IUB_mode_2.pdb
# Deleting CLR-Unlabeled_/5JQH_protein_vina_out5JQH_mode_3.pdb — 87.8% overlap with CLR-Unlabeled_/5JQH_protein_vina_out5JQH_mode_1.pdb
# Deleting CLR-Unlabeled_/5JQH_protein_vina_out5JQH_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/5JQH_protein_vina_out5JQH_mode_2.pdb
# Deleting CLR-Unlabeled_/5JQH_protein_vina_out5JQH_mode_5.pdb — 77.0% overlap with CLR-Unlabeled_/5JQH_protein_vina_out5JQH_mode_1.pdb
# Deleting CLR-Unlabeled_/5JTB_protein_vina_out5JTB_mode_3.pdb — 89.2% overlap with CLR-Unlabeled_/5JTB_protein_vina_out5JTB_mode_1.pdb
# Deleting CLR-Unlabeled_/5JTB_protein_vina_out5JTB_mode_4.pdb — 95.9% overlap with CLR-Unlabeled_/5JTB_protein_vina_out5JTB_mode_2.pdb
# Deleting CLR-Unlabeled_/5K2A_protein_vina_out5K2A_mode_4.pdb — 89.2% overlap with CLR-Unlabeled_/5K2A_protein_vina_out5K2A_mode_1.pdb
# Deleting CLR-Unlabeled_/5K2A_protein_vina_out5K2A_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/5K2A_protein_vina_out5K2A_mode_1.pdb
# Deleting CLR-Unlabeled_/5K2B_protein_vina_out5K2B_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/5K2B_protein_vina_out5K2B_mode_1.pdb
# Deleting CLR-Unlabeled_/5K2B_protein_vina_out5K2B_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/5K2B_protein_vina_out5K2B_mode_2.pdb
# Deleting CLR-Unlabeled_/5K2D_protein_vina_out5K2D_mode_2.pdb — 86.5% overlap with CLR-Unlabeled_/5K2D_protein_vina_out5K2D_mode_1.pdb
# Deleting CLR-Unlabeled_/5K2D_protein_vina_out5K2D_mode_3.pdb — 81.1% overlap with CLR-Unlabeled_/5K2D_protein_vina_out5K2D_mode_1.pdb
# Deleting CLR-Unlabeled_/5LWE_protein_vina_out5LWE_mode_2.pdb — 93.2% overlap with CLR-Unlabeled_/5LWE_protein_vina_out5LWE_mode_1.pdb
# Deleting CLR-Unlabeled_/5LWE_protein_vina_out5LWE_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/5LWE_protein_vina_out5LWE_mode_1.pdb
# Deleting CLR-Unlabeled_/5MZP_protein_vina_out5MZP_mode_4.pdb — 71.6% overlap with CLR-Unlabeled_/5MZP_protein_vina_out5MZP_mode_1.pdb
# Deleting CLR-Unlabeled_/5MZP_protein_vina_out5MZP_mode_5.pdb — 85.1% overlap with CLR-Unlabeled_/5MZP_protein_vina_out5MZP_mode_1.pdb
# Deleting CLR-Unlabeled_/5NLX_protein_vina_out5NLX_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/5NLX_protein_vina_out5NLX_mode_2.pdb
# Deleting CLR-Unlabeled_/5NM2_protein_vina_out5NM2_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/5NM2_protein_vina_out5NM2_mode_3.pdb
# Deleting CLR-Unlabeled_/5NM4_protein_vina_out5NM4_mode_4.pdb — 70.3% overlap with CLR-Unlabeled_/5NM4_protein_vina_out5NM4_mode_3.pdb
# Deleting CLR-Unlabeled_/5NM4_protein_vina_out5NM4_mode_5.pdb — 78.4% overlap with CLR-Unlabeled_/5NM4_protein_vina_out5NM4_mode_3.pdb
# Deleting CLR-Unlabeled_/5OLG_protein_vina_out5OLG_mode_2.pdb — 95.9% overlap with CLR-Unlabeled_/5OLG_protein_vina_out5OLG_mode_1.pdb
# Deleting CLR-Unlabeled_/5OLG_protein_vina_out5OLG_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/5OLG_protein_vina_out5OLG_mode_1.pdb
# Deleting CLR-Unlabeled_/5OLH_protein_vina_out5OLH_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/5OLH_protein_vina_out5OLH_mode_3.pdb
# Deleting CLR-Unlabeled_/5OLO_protein_vina_out5OLO_mode_3.pdb — 81.1% overlap with CLR-Unlabeled_/5OLO_protein_vina_out5OLO_mode_2.pdb
# Deleting CLR-Unlabeled_/5OLO_protein_vina_out5OLO_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/5OLO_protein_vina_out5OLO_mode_4.pdb
# Deleting CLR-Unlabeled_/5OLV_protein_vina_out5OLV_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/5OLV_protein_vina_out5OLV_mode_1.pdb
# Deleting CLR-Unlabeled_/5OLV_protein_vina_out5OLV_mode_5.pdb — 74.3% overlap with CLR-Unlabeled_/5OLV_protein_vina_out5OLV_mode_1.pdb
# Deleting CLR-Unlabeled_/5OLZ_protein_vina_out5OLZ_mode_4.pdb — 79.7% overlap with CLR-Unlabeled_/5OLZ_protein_vina_out5OLZ_mode_2.pdb
# Deleting CLR-Unlabeled_/5OM1_protein_vina_out5OM1_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/5OM1_protein_vina_out5OM1_mode_1.pdb
# Deleting CLR-Unlabeled_/5OM4_protein_vina_out5OM4_mode_2.pdb — 81.1% overlap with CLR-Unlabeled_/5OM4_protein_vina_out5OM4_mode_1.pdb
# Deleting CLR-Unlabeled_/5OM4_protein_vina_out5OM4_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/5OM4_protein_vina_out5OM4_mode_1.pdb
# Deleting CLR-Unlabeled_/5OM4_protein_vina_out5OM4_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/5OM4_protein_vina_out5OM4_mode_1.pdb
# Deleting CLR-Unlabeled_/5TCX_protein_vina_out5TCX_mode_2.pdb — 93.2% overlap with CLR-Unlabeled_/5TCX_protein_vina_out5TCX_mode_1.pdb
# Deleting CLR-Unlabeled_/5TCX_protein_vina_out5TCX_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/5TCX_protein_vina_out5TCX_mode_3.pdb
# Deleting CLR-Unlabeled_/5TVN_protein_vina_out5TVN_mode_2.pdb — 70.3% overlap with CLR-Unlabeled_/5TVN_protein_vina_out5TVN_mode_1.pdb
# Deleting CLR-Unlabeled_/5TVN_protein_vina_out5TVN_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/5TVN_protein_vina_out5TVN_mode_1.pdb
# Deleting CLR-Unlabeled_/5TVN_protein_vina_out5TVN_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/5TVN_protein_vina_out5TVN_mode_1.pdb
# Deleting CLR-Unlabeled_/5TVN_protein_vina_out5TVN_mode_5.pdb — 93.2% overlap with CLR-Unlabeled_/5TVN_protein_vina_out5TVN_mode_1.pdb
# Deleting CLR-Unlabeled_/5UPH_protein_vina_out5UPH_mode_2.pdb — 78.4% overlap with CLR-Unlabeled_/5UPH_protein_vina_out5UPH_mode_1.pdb
# Deleting CLR-Unlabeled_/5UVI_protein_vina_out5UVI_mode_2.pdb — 75.7% overlap with CLR-Unlabeled_/5UVI_protein_vina_out5UVI_mode_1.pdb
# Deleting CLR-Unlabeled_/5UVI_protein_vina_out5UVI_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/5UVI_protein_vina_out5UVI_mode_1.pdb
# Deleting CLR-Unlabeled_/5VRA_protein_vina_out5VRA_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/5VRA_protein_vina_out5VRA_mode_1.pdb
# Deleting CLR-Unlabeled_/5VRA_protein_vina_out5VRA_mode_3.pdb — 75.7% overlap with CLR-Unlabeled_/5VRA_protein_vina_out5VRA_mode_1.pdb
# Deleting CLR-Unlabeled_/5VRA_protein_vina_out5VRA_mode_5.pdb — 75.7% overlap with CLR-Unlabeled_/5VRA_protein_vina_out5VRA_mode_1.pdb
# Deleting CLR-Unlabeled_/5WVR_protein_vina_out5WVR_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/5WVR_protein_vina_out5WVR_mode_1.pdb
# Deleting CLR-Unlabeled_/5WVR_protein_vina_out5WVR_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/5WVR_protein_vina_out5WVR_mode_1.pdb
# Deleting CLR-Unlabeled_/5WVR_protein_vina_out5WVR_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/5WVR_protein_vina_out5WVR_mode_1.pdb
# Deleting CLR-Unlabeled_/5X7D_protein_vina_out5X7D_mode_2.pdb — 86.5% overlap with CLR-Unlabeled_/5X7D_protein_vina_out5X7D_mode_1.pdb
# Deleting CLR-Unlabeled_/5X7D_protein_vina_out5X7D_mode_3.pdb — 89.2% overlap with CLR-Unlabeled_/5X7D_protein_vina_out5X7D_mode_1.pdb
# Deleting CLR-Unlabeled_/5X7D_protein_vina_out5X7D_mode_5.pdb — 78.4% overlap with CLR-Unlabeled_/5X7D_protein_vina_out5X7D_mode_1.pdb
# Deleting CLR-Unlabeled_/5X93_protein_vina_out5X93_mode_5.pdb — 85.1% overlap with CLR-Unlabeled_/5X93_protein_vina_out5X93_mode_3.pdb
# Deleting CLR-Unlabeled_/5XR8_protein_vina_out5XR8_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/5XR8_protein_vina_out5XR8_mode_1.pdb
# Deleting CLR-Unlabeled_/5XRA_protein_vina_out5XRA_mode_2.pdb — 97.3% overlap with CLR-Unlabeled_/5XRA_protein_vina_out5XRA_mode_1.pdb
# Deleting CLR-Unlabeled_/5XRA_protein_vina_out5XRA_mode_3.pdb — 81.1% overlap with CLR-Unlabeled_/5XRA_protein_vina_out5XRA_mode_1.pdb
# Deleting CLR-Unlabeled_/5XRA_protein_vina_out5XRA_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/5XRA_protein_vina_out5XRA_mode_1.pdb
# Deleting CLR-Unlabeled_/5ZM7_protein_vina_out5ZM7_mode_4.pdb — 94.6% overlap with CLR-Unlabeled_/5ZM7_protein_vina_out5ZM7_mode_2.pdb
# Deleting CLR-Unlabeled_/6A15_protein_vina_out6A15_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/6A15_protein_vina_out6A15_mode_1.pdb
# Deleting CLR-Unlabeled_/6A93_protein_vina_out6A93_mode_2.pdb — 89.2% overlap with CLR-Unlabeled_/6A93_protein_vina_out6A93_mode_1.pdb
# Deleting CLR-Unlabeled_/6A93_protein_vina_out6A93_mode_5.pdb — 78.4% overlap with CLR-Unlabeled_/6A93_protein_vina_out6A93_mode_4.pdb
# Deleting CLR-Unlabeled_/6A94_protein_vina_out6A94_mode_2.pdb — 79.7% overlap with CLR-Unlabeled_/6A94_protein_vina_out6A94_mode_1.pdb
# Deleting CLR-Unlabeled_/6A94_protein_vina_out6A94_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/6A94_protein_vina_out6A94_mode_1.pdb
# Deleting CLR-Unlabeled_/6A94_protein_vina_out6A94_mode_4.pdb — 75.7% overlap with CLR-Unlabeled_/6A94_protein_vina_out6A94_mode_1.pdb
# Deleting CLR-Unlabeled_/6AQF_protein_vina_out6AQF_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/6AQF_protein_vina_out6AQF_mode_2.pdb
# Deleting CLR-Unlabeled_/6AQF_protein_vina_out6AQF_mode_5.pdb — 85.1% overlap with CLR-Unlabeled_/6AQF_protein_vina_out6AQF_mode_1.pdb
# Deleting CLR-Unlabeled_/6BHU_protein_vina_out6BHU_mode_5.pdb — 93.2% overlap with CLR-Unlabeled_/6BHU_protein_vina_out6BHU_mode_1.pdb
# Deleting CLR-Unlabeled_/6CO7_protein_vina_out6CO7_mode_4.pdb — 70.3% overlap with CLR-Unlabeled_/6CO7_protein_vina_out6CO7_mode_1.pdb
# Deleting CLR-Unlabeled_/6CO7_protein_vina_out6CO7_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/6CO7_protein_vina_out6CO7_mode_2.pdb
# Deleting CLR-Unlabeled_/6DRX_protein_vina_out6DRX_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/6DRX_protein_vina_out6DRX_mode_1.pdb
# Deleting CLR-Unlabeled_/6DRX_protein_vina_out6DRX_mode_4.pdb — 93.2% overlap with CLR-Unlabeled_/6DRX_protein_vina_out6DRX_mode_3.pdb
# Deleting CLR-Unlabeled_/6DRY_protein_vina_out6DRY_mode_2.pdb — 74.3% overlap with CLR-Unlabeled_/6DRY_protein_vina_out6DRY_mode_1.pdb
# Deleting CLR-Unlabeled_/6DRY_protein_vina_out6DRY_mode_4.pdb — 97.3% overlap with CLR-Unlabeled_/6DRY_protein_vina_out6DRY_mode_1.pdb
# Deleting CLR-Unlabeled_/6DRY_protein_vina_out6DRY_mode_5.pdb — 85.1% overlap with CLR-Unlabeled_/6DRY_protein_vina_out6DRY_mode_1.pdb
# Deleting CLR-Unlabeled_/6DRZ_protein_vina_out6DRZ_mode_3.pdb — 90.5% overlap with CLR-Unlabeled_/6DRZ_protein_vina_out6DRZ_mode_1.pdb
# Deleting CLR-Unlabeled_/6DRZ_protein_vina_out6DRZ_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/6DRZ_protein_vina_out6DRZ_mode_2.pdb
# Deleting CLR-Unlabeled_/6DS0_protein_vina_out6DS0_mode_2.pdb — 89.2% overlap with CLR-Unlabeled_/6DS0_protein_vina_out6DS0_mode_1.pdb
# Deleting CLR-Unlabeled_/6DS0_protein_vina_out6DS0_mode_4.pdb — 75.7% overlap with CLR-Unlabeled_/6DS0_protein_vina_out6DS0_mode_1.pdb
# Deleting CLR-Unlabeled_/6DS0_protein_vina_out6DS0_mode_5.pdb — 86.5% overlap with CLR-Unlabeled_/6DS0_protein_vina_out6DS0_mode_3.pdb
# Deleting CLR-Unlabeled_/6GT3_protein_vina_out6GT3_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/6GT3_protein_vina_out6GT3_mode_1.pdb
# Deleting CLR-Unlabeled_/6GT3_protein_vina_out6GT3_mode_5.pdb — 78.4% overlap with CLR-Unlabeled_/6GT3_protein_vina_out6GT3_mode_2.pdb
# Deleting CLR-Unlabeled_/6GYH_protein_vina_out6GYH_mode_5.pdb — 79.7% overlap with CLR-Unlabeled_/6GYH_protein_vina_out6GYH_mode_4.pdb
# Deleting CLR-Unlabeled_/6IBB_protein_vina_out6IBB_mode_2.pdb — 90.5% overlap with CLR-Unlabeled_/6IBB_protein_vina_out6IBB_mode_1.pdb
# Deleting CLR-Unlabeled_/6IBB_protein_vina_out6IBB_mode_4.pdb — 75.7% overlap with CLR-Unlabeled_/6IBB_protein_vina_out6IBB_mode_1.pdb
# Deleting CLR-Unlabeled_/6IIU_protein_vina_out6IIU_mode_2.pdb — 91.9% overlap with CLR-Unlabeled_/6IIU_protein_vina_out6IIU_mode_1.pdb
# Deleting CLR-Unlabeled_/6IIU_protein_vina_out6IIU_mode_3.pdb — 93.2% overlap with CLR-Unlabeled_/6IIU_protein_vina_out6IIU_mode_1.pdb
# Deleting CLR-Unlabeled_/6IIU_protein_vina_out6IIU_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/6IIU_protein_vina_out6IIU_mode_1.pdb
# Deleting CLR-Unlabeled_/6IIU_protein_vina_out6IIU_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/6IIU_protein_vina_out6IIU_mode_1.pdb
# Deleting CLR-Unlabeled_/6IIV_protein_vina_out6IIV_mode_2.pdb — 78.4% overlap with CLR-Unlabeled_/6IIV_protein_vina_out6IIV_mode_1.pdb
# Deleting CLR-Unlabeled_/6IIV_protein_vina_out6IIV_mode_3.pdb — 91.9% overlap with CLR-Unlabeled_/6IIV_protein_vina_out6IIV_mode_1.pdb
# Deleting CLR-Unlabeled_/6IIV_protein_vina_out6IIV_mode_4.pdb — 73.0% overlap with CLR-Unlabeled_/6IIV_protein_vina_out6IIV_mode_1.pdb
# Deleting CLR-Unlabeled_/6JMQ_protein_vina_out6JMQ_mode_2.pdb — 95.9% overlap with CLR-Unlabeled_/6JMQ_protein_vina_out6JMQ_mode_1.pdb
# Deleting CLR-Unlabeled_/6JMQ_protein_vina_out6JMQ_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/6JMQ_protein_vina_out6JMQ_mode_1.pdb
# Deleting CLR-Unlabeled_/6JMQ_protein_vina_out6JMQ_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/6JMQ_protein_vina_out6JMQ_mode_4.pdb
# Deleting CLR-Unlabeled_/6JXH_protein_vina_out6JXH_mode_2.pdb — 82.4% overlap with CLR-Unlabeled_/6JXH_protein_vina_out6JXH_mode_1.pdb
# Deleting CLR-Unlabeled_/6JXH_protein_vina_out6JXH_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/6JXH_protein_vina_out6JXH_mode_1.pdb
# Deleting CLR-Unlabeled_/6JXI_protein_vina_out6JXI_mode_5.pdb — 70.3% overlap with CLR-Unlabeled_/6JXI_protein_vina_out6JXI_mode_2.pdb
# Deleting CLR-Unlabeled_/6JZH_protein_vina_out6JZH_mode_5.pdb — 94.6% overlap with CLR-Unlabeled_/6JZH_protein_vina_out6JZH_mode_1.pdb
# Deleting CLR-Unlabeled_/6KUW_protein_vina_out6KUW_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/6KUW_protein_vina_out6KUW_mode_1.pdb
# Deleting CLR-Unlabeled_/6KUW_protein_vina_out6KUW_mode_4.pdb — 70.3% overlap with CLR-Unlabeled_/6KUW_protein_vina_out6KUW_mode_1.pdb
# Deleting CLR-Unlabeled_/6LPJ_protein_vina_out6LPJ_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/6LPJ_protein_vina_out6LPJ_mode_1.pdb
# Deleting CLR-Unlabeled_/6LPJ_protein_vina_out6LPJ_mode_3.pdb — 90.5% overlap with CLR-Unlabeled_/6LPJ_protein_vina_out6LPJ_mode_1.pdb
# Deleting CLR-Unlabeled_/6LPK_protein_vina_out6LPK_mode_2.pdb — 79.7% overlap with CLR-Unlabeled_/6LPK_protein_vina_out6LPK_mode_1.pdb
# Deleting CLR-Unlabeled_/6LPK_protein_vina_out6LPK_mode_4.pdb — 74.3% overlap with CLR-Unlabeled_/6LPK_protein_vina_out6LPK_mode_1.pdb
# Deleting CLR-Unlabeled_/6LPK_protein_vina_out6LPK_mode_5.pdb — 93.2% overlap with CLR-Unlabeled_/6LPK_protein_vina_out6LPK_mode_1.pdb
# Deleting CLR-Unlabeled_/6LPL_protein_vina_out6LPL_mode_4.pdb — 78.4% overlap with CLR-Unlabeled_/6LPL_protein_vina_out6LPL_mode_1.pdb
# Deleting CLR-Unlabeled_/6LQG_protein_vina_out6LQG_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/6LQG_protein_vina_out6LQG_mode_1.pdb
# Deleting CLR-Unlabeled_/6LQG_protein_vina_out6LQG_mode_5.pdb — 71.6% overlap with CLR-Unlabeled_/6LQG_protein_vina_out6LQG_mode_2.pdb
# Deleting CLR-Unlabeled_/6LR4_protein_vina_out6LR4_mode_2.pdb — 78.4% overlap with CLR-Unlabeled_/6LR4_protein_vina_out6LR4_mode_1.pdb
# Deleting CLR-Unlabeled_/6LW5_protein_vina_out6LW5_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/6LW5_protein_vina_out6LW5_mode_1.pdb
# Deleting CLR-Unlabeled_/6LW5_protein_vina_out6LW5_mode_3.pdb — 95.9% overlap with CLR-Unlabeled_/6LW5_protein_vina_out6LW5_mode_1.pdb
# Deleting CLR-Unlabeled_/6LW5_protein_vina_out6LW5_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/6LW5_protein_vina_out6LW5_mode_1.pdb
# Deleting CLR-Unlabeled_/6LW5_protein_vina_out6LW5_mode_5.pdb — 94.6% overlap with CLR-Unlabeled_/6LW5_protein_vina_out6LW5_mode_1.pdb
# Deleting CLR-Unlabeled_/6M0F_protein_vina_out6M0F_mode_2.pdb — 83.8% overlap with CLR-Unlabeled_/6M0F_protein_vina_out6M0F_mode_1.pdb
# Deleting CLR-Unlabeled_/6M0F_protein_vina_out6M0F_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/6M0F_protein_vina_out6M0F_mode_3.pdb
# Deleting CLR-Unlabeled_/6M0Z_protein_vina_out6M0Z_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/6M0Z_protein_vina_out6M0Z_mode_1.pdb
# Deleting CLR-Unlabeled_/6M2R_protein_vina_out6M2R_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/6M2R_protein_vina_out6M2R_mode_1.pdb
# Deleting CLR-Unlabeled_/6M3Z_protein_vina_out6M3Z_mode_4.pdb — 77.0% overlap with CLR-Unlabeled_/6M3Z_protein_vina_out6M3Z_mode_2.pdb
# Deleting CLR-Unlabeled_/6M38_protein_vina_out6M38_mode_2.pdb — 81.1% overlap with CLR-Unlabeled_/6M38_protein_vina_out6M38_mode_1.pdb
# Deleting CLR-Unlabeled_/6M38_protein_vina_out6M38_mode_4.pdb — 89.2% overlap with CLR-Unlabeled_/6M38_protein_vina_out6M38_mode_1.pdb
# Deleting CLR-Unlabeled_/6M47_protein_vina_out6M47_mode_3.pdb — 81.1% overlap with CLR-Unlabeled_/6M47_protein_vina_out6M47_mode_1.pdb
# Deleting CLR-Unlabeled_/6MSM_protein_vina_out6MSM_mode_5.pdb — 98.6% overlap with CLR-Unlabeled_/6MSM_protein_vina_out6MSM_mode_2.pdb
# Deleting CLR-Unlabeled_/6N4B_protein_vina_out6N4B_mode_2.pdb — 74.3% overlap with CLR-Unlabeled_/6N4B_protein_vina_out6N4B_mode_1.pdb
# Deleting CLR-Unlabeled_/6N4B_protein_vina_out6N4B_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/6N4B_protein_vina_out6N4B_mode_1.pdb
# Deleting CLR-Unlabeled_/6N4B_protein_vina_out6N4B_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/6N4B_protein_vina_out6N4B_mode_1.pdb
# Deleting CLR-Unlabeled_/6NBF_protein_vina_out6NBF_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/6NBF_protein_vina_out6NBF_mode_1.pdb
# Deleting CLR-Unlabeled_/6NBF_protein_vina_out6NBF_mode_4.pdb — 94.6% overlap with CLR-Unlabeled_/6NBF_protein_vina_out6NBF_mode_2.pdb
# Deleting CLR-Unlabeled_/6NBF_protein_vina_out6NBF_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/6NBF_protein_vina_out6NBF_mode_2.pdb
# Deleting CLR-Unlabeled_/6NF4_protein_vina_out6NF4_mode_2.pdb — 74.3% overlap with CLR-Unlabeled_/6NF4_protein_vina_out6NF4_mode_1.pdb
# Deleting CLR-Unlabeled_/6NF4_protein_vina_out6NF4_mode_3.pdb — 87.8% overlap with CLR-Unlabeled_/6NF4_protein_vina_out6NF4_mode_1.pdb
# Deleting CLR-Unlabeled_/6NF4_protein_vina_out6NF4_mode_4.pdb — 89.2% overlap with CLR-Unlabeled_/6NF4_protein_vina_out6NF4_mode_1.pdb
# Deleting CLR-Unlabeled_/6NF4_protein_vina_out6NF4_mode_5.pdb — 86.5% overlap with CLR-Unlabeled_/6NF4_protein_vina_out6NF4_mode_1.pdb
# Deleting CLR-Unlabeled_/6O1V_protein_vina_out6O1V_mode_2.pdb — 83.8% overlap with CLR-Unlabeled_/6O1V_protein_vina_out6O1V_mode_1.pdb
# Deleting CLR-Unlabeled_/6O3C_protein_vina_out6O3C_mode_2.pdb — 82.4% overlap with CLR-Unlabeled_/6O3C_protein_vina_out6O3C_mode_1.pdb
# Deleting CLR-Unlabeled_/6OBA_protein_vina_out6OBA_mode_5.pdb — 73.0% overlap with CLR-Unlabeled_/6OBA_protein_vina_out6OBA_mode_3.pdb
# Deleting CLR-Unlabeled_/6OMM_protein_vina_out6OMM_mode_2.pdb — 74.3% overlap with CLR-Unlabeled_/6OMM_protein_vina_out6OMM_mode_1.pdb
# Deleting CLR-Unlabeled_/6OMM_protein_vina_out6OMM_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/6OMM_protein_vina_out6OMM_mode_1.pdb
# Deleting CLR-Unlabeled_/6OS1_protein_vina_out6OS1_mode_3.pdb — 90.5% overlap with CLR-Unlabeled_/6OS1_protein_vina_out6OS1_mode_1.pdb
# Deleting CLR-Unlabeled_/6OS2_protein_vina_out6OS2_mode_5.pdb — 79.7% overlap with CLR-Unlabeled_/6OS2_protein_vina_out6OS2_mode_1.pdb
# Deleting CLR-Unlabeled_/6PB0_protein_vina_out6PB0_mode_2.pdb — 78.4% overlap with CLR-Unlabeled_/6PB0_protein_vina_out6PB0_mode_1.pdb
# Deleting CLR-Unlabeled_/6PB0_protein_vina_out6PB0_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/6PB0_protein_vina_out6PB0_mode_1.pdb
# Deleting CLR-Unlabeled_/6PB0_protein_vina_out6PB0_mode_4.pdb — 86.5% overlap with CLR-Unlabeled_/6PB0_protein_vina_out6PB0_mode_1.pdb
# Deleting CLR-Unlabeled_/6PB1_protein_vina_out6PB1_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/6PB1_protein_vina_out6PB1_mode_3.pdb
# Deleting CLR-Unlabeled_/6PEQ_protein_vina_out6PEQ_mode_4.pdb — 70.3% overlap with CLR-Unlabeled_/6PEQ_protein_vina_out6PEQ_mode_2.pdb
# Deleting CLR-Unlabeled_/6PS0_protein_vina_out6PS0_mode_3.pdb — 93.2% overlap with CLR-Unlabeled_/6PS0_protein_vina_out6PS0_mode_1.pdb
# Deleting CLR-Unlabeled_/6PS1_protein_vina_out6PS1_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/6PS1_protein_vina_out6PS1_mode_2.pdb
# Deleting CLR-Unlabeled_/6PS2_protein_vina_out6PS2_mode_4.pdb — 87.8% overlap with CLR-Unlabeled_/6PS2_protein_vina_out6PS2_mode_2.pdb
# Deleting CLR-Unlabeled_/6PS3_protein_vina_out6PS3_mode_4.pdb — 95.9% overlap with CLR-Unlabeled_/6PS3_protein_vina_out6PS3_mode_2.pdb
# Deleting CLR-Unlabeled_/6PS4_protein_vina_out6PS4_mode_4.pdb — 79.7% overlap with CLR-Unlabeled_/6PS4_protein_vina_out6PS4_mode_2.pdb
# Deleting CLR-Unlabeled_/6PS4_protein_vina_out6PS4_mode_5.pdb — 83.8% overlap with CLR-Unlabeled_/6PS4_protein_vina_out6PS4_mode_3.pdb
# Deleting CLR-Unlabeled_/6PS5_protein_vina_out6PS5_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/6PS5_protein_vina_out6PS5_mode_2.pdb
# Deleting CLR-Unlabeled_/6PS5_protein_vina_out6PS5_mode_4.pdb — 70.3% overlap with CLR-Unlabeled_/6PS5_protein_vina_out6PS5_mode_2.pdb
# Deleting CLR-Unlabeled_/6PS5_protein_vina_out6PS5_mode_5.pdb — 79.7% overlap with CLR-Unlabeled_/6PS5_protein_vina_out6PS5_mode_1.pdb
# Deleting CLR-Unlabeled_/6PS6_protein_vina_out6PS6_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/6PS6_protein_vina_out6PS6_mode_1.pdb
# Deleting CLR-Unlabeled_/6PS7_protein_vina_out6PS7_mode_2.pdb — 74.3% overlap with CLR-Unlabeled_/6PS7_protein_vina_out6PS7_mode_1.pdb
# Deleting CLR-Unlabeled_/6PS7_protein_vina_out6PS7_mode_3.pdb — 94.6% overlap with CLR-Unlabeled_/6PS7_protein_vina_out6PS7_mode_1.pdb
# Deleting CLR-Unlabeled_/6PT0_protein_vina_out6PT0_mode_2.pdb — 86.5% overlap with CLR-Unlabeled_/6PT0_protein_vina_out6PT0_mode_1.pdb
# Deleting CLR-Unlabeled_/6PT0_protein_vina_out6PT0_mode_4.pdb — 94.6% overlap with CLR-Unlabeled_/6PT0_protein_vina_out6PT0_mode_1.pdb
# Deleting CLR-Unlabeled_/6RZ6_protein_vina_out6RZ6_mode_5.pdb — 98.6% overlap with CLR-Unlabeled_/6RZ6_protein_vina_out6RZ6_mode_3.pdb
# Deleting CLR-Unlabeled_/6RZ7_protein_vina_out6RZ7_mode_3.pdb — 91.9% overlap with CLR-Unlabeled_/6RZ7_protein_vina_out6RZ7_mode_2.pdb
# Deleting CLR-Unlabeled_/6S0L_protein_vina_out6S0L_mode_3.pdb — 79.7% overlap with CLR-Unlabeled_/6S0L_protein_vina_out6S0L_mode_1.pdb
# Deleting CLR-Unlabeled_/6S0Q_protein_vina_out6S0Q_mode_2.pdb — 74.3% overlap with CLR-Unlabeled_/6S0Q_protein_vina_out6S0Q_mode_1.pdb
# Deleting CLR-Unlabeled_/6S7P_protein_vina_out6S7P_mode_2.pdb — 81.1% overlap with CLR-Unlabeled_/6S7P_protein_vina_out6S7P_mode_1.pdb
# Deleting CLR-Unlabeled_/6S7P_protein_vina_out6S7P_mode_4.pdb — 86.5% overlap with CLR-Unlabeled_/6S7P_protein_vina_out6S7P_mode_3.pdb
# Deleting CLR-Unlabeled_/6S7P_protein_vina_out6S7P_mode_5.pdb — 81.1% overlap with CLR-Unlabeled_/6S7P_protein_vina_out6S7P_mode_3.pdb
# Deleting CLR-Unlabeled_/6T4G_protein_vina_out6T4G_mode_2.pdb — 86.5% overlap with CLR-Unlabeled_/6T4G_protein_vina_out6T4G_mode_1.pdb
# Deleting CLR-Unlabeled_/6T4G_protein_vina_out6T4G_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/6T4G_protein_vina_out6T4G_mode_3.pdb
# Deleting CLR-Unlabeled_/6T4G_protein_vina_out6T4G_mode_5.pdb — 74.3% overlap with CLR-Unlabeled_/6T4G_protein_vina_out6T4G_mode_3.pdb
# Deleting CLR-Unlabeled_/6T4I_protein_vina_out6T4I_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/6T4I_protein_vina_out6T4I_mode_2.pdb
# Deleting CLR-Unlabeled_/6T9N_protein_vina_out6T9N_mode_3.pdb — 75.7% overlap with CLR-Unlabeled_/6T9N_protein_vina_out6T9N_mode_1.pdb
# Deleting CLR-Unlabeled_/6T9N_protein_vina_out6T9N_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/6T9N_protein_vina_out6T9N_mode_1.pdb
# Deleting CLR-Unlabeled_/6T9O_protein_vina_out6T9O_mode_2.pdb — 70.3% overlap with CLR-Unlabeled_/6T9O_protein_vina_out6T9O_mode_1.pdb
# Deleting CLR-Unlabeled_/6TLQ_protein_vina_out6TLQ_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/6TLQ_protein_vina_out6TLQ_mode_1.pdb
# Deleting CLR-Unlabeled_/6TLQ_protein_vina_out6TLQ_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/6TLQ_protein_vina_out6TLQ_mode_1.pdb
# Deleting CLR-Unlabeled_/6TLQ_protein_vina_out6TLQ_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/6TLQ_protein_vina_out6TLQ_mode_1.pdb
# Deleting CLR-Unlabeled_/6TLQ_protein_vina_out6TLQ_mode_5.pdb — 77.0% overlap with CLR-Unlabeled_/6TLQ_protein_vina_out6TLQ_mode_1.pdb
# Deleting CLR-Unlabeled_/6TPK_protein_vina_out6TPK_mode_3.pdb — 75.7% overlap with CLR-Unlabeled_/6TPK_protein_vina_out6TPK_mode_2.pdb
# Deleting CLR-Unlabeled_/6UD4_protein_vina_out6UD4_mode_4.pdb — 100.0% overlap with CLR-Unlabeled_/6UD4_protein_vina_out6UD4_mode_2.pdb
# Deleting CLR-Unlabeled_/6V22_protein_vina_out6V22_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/6V22_protein_vina_out6V22_mode_2.pdb
# Deleting CLR-Unlabeled_/6VI4_protein_vina_out6VI4_mode_3.pdb — 83.8% overlap with CLR-Unlabeled_/6VI4_protein_vina_out6VI4_mode_1.pdb
# Deleting CLR-Unlabeled_/6VN7_protein_vina_out6VN7_mode_3.pdb — 94.6% overlap with CLR-Unlabeled_/6VN7_protein_vina_out6VN7_mode_1.pdb
# Deleting CLR-Unlabeled_/6VN7_protein_vina_out6VN7_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/6VN7_protein_vina_out6VN7_mode_2.pdb
# Deleting CLR-Unlabeled_/6WBF_protein_vina_out6WBF_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/6WBF_protein_vina_out6WBF_mode_2.pdb
# Deleting CLR-Unlabeled_/6WBG_protein_vina_out6WBG_mode_4.pdb — 94.6% overlap with CLR-Unlabeled_/6WBG_protein_vina_out6WBG_mode_1.pdb
# Deleting CLR-Unlabeled_/6WBN_protein_vina_out6WBN_mode_5.pdb — 86.5% overlap with CLR-Unlabeled_/6WBN_protein_vina_out6WBN_mode_3.pdb
# Deleting CLR-Unlabeled_/6WIV_protein_vina_out6WIV_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/6WIV_protein_vina_out6WIV_mode_2.pdb
# Deleting CLR-Unlabeled_/6WLW_protein_vina_out6WLW_mode_2.pdb — 90.5% overlap with CLR-Unlabeled_/6WLW_protein_vina_out6WLW_mode_1.pdb
# Deleting CLR-Unlabeled_/6WLW_protein_vina_out6WLW_mode_5.pdb — 87.8% overlap with CLR-Unlabeled_/6WLW_protein_vina_out6WLW_mode_1.pdb
# Deleting CLR-Unlabeled_/6WM2_protein_vina_out6WM2_mode_4.pdb — 86.5% overlap with CLR-Unlabeled_/6WM2_protein_vina_out6WM2_mode_3.pdb
# Deleting CLR-Unlabeled_/6WM2_protein_vina_out6WM2_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/6WM2_protein_vina_out6WM2_mode_3.pdb
# Deleting CLR-Unlabeled_/6WQA_protein_vina_out6WQA_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/6WQA_protein_vina_out6WQA_mode_3.pdb
# Deleting CLR-Unlabeled_/6ZDR_protein_vina_out6ZDR_mode_2.pdb — 98.6% overlap with CLR-Unlabeled_/6ZDR_protein_vina_out6ZDR_mode_1.pdb
# Deleting CLR-Unlabeled_/6ZDR_protein_vina_out6ZDR_mode_3.pdb — 89.2% overlap with CLR-Unlabeled_/6ZDR_protein_vina_out6ZDR_mode_1.pdb
# Deleting CLR-Unlabeled_/6ZDR_protein_vina_out6ZDR_mode_4.pdb — 77.0% overlap with CLR-Unlabeled_/6ZDR_protein_vina_out6ZDR_mode_1.pdb
# Deleting CLR-Unlabeled_/6ZDR_protein_vina_out6ZDR_mode_5.pdb — 87.8% overlap with CLR-Unlabeled_/6ZDR_protein_vina_out6ZDR_mode_1.pdb
# Deleting CLR-Unlabeled_/6ZDV_protein_vina_out6ZDV_mode_2.pdb — 81.1% overlap with CLR-Unlabeled_/6ZDV_protein_vina_out6ZDV_mode_1.pdb
# Deleting CLR-Unlabeled_/6ZDV_protein_vina_out6ZDV_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/6ZDV_protein_vina_out6ZDV_mode_1.pdb
# Deleting CLR-Unlabeled_/6ZDV_protein_vina_out6ZDV_mode_5.pdb — 94.6% overlap with CLR-Unlabeled_/6ZDV_protein_vina_out6ZDV_mode_4.pdb
# Deleting CLR-Unlabeled_/7A69_protein_vina_out7A69_mode_2.pdb — 81.1% overlap with CLR-Unlabeled_/7A69_protein_vina_out7A69_mode_1.pdb
# Deleting CLR-Unlabeled_/7ARO_protein_vina_out7ARO_mode_5.pdb — 78.4% overlap with CLR-Unlabeled_/7ARO_protein_vina_out7ARO_mode_2.pdb
# Deleting CLR-Unlabeled_/7BTS_protein_vina_out7BTS_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/7BTS_protein_vina_out7BTS_mode_2.pdb
# Deleting CLR-Unlabeled_/7BU7_protein_vina_out7BU7_mode_2.pdb — 75.7% overlap with CLR-Unlabeled_/7BU7_protein_vina_out7BU7_mode_1.pdb
# Deleting CLR-Unlabeled_/7BVQ_protein_vina_out7BVQ_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/7BVQ_protein_vina_out7BVQ_mode_1.pdb
# Deleting CLR-Unlabeled_/7BVQ_protein_vina_out7BVQ_mode_5.pdb — 73.0% overlap with CLR-Unlabeled_/7BVQ_protein_vina_out7BVQ_mode_1.pdb
# Deleting CLR-Unlabeled_/7C9I_protein_vina_out7C9I_mode_3.pdb — 74.3% overlap with CLR-Unlabeled_/7C9I_protein_vina_out7C9I_mode_2.pdb
# Deleting CLR-Unlabeled_/7C9I_protein_vina_out7C9I_mode_4.pdb — 90.5% overlap with CLR-Unlabeled_/7C9I_protein_vina_out7C9I_mode_1.pdb
# Deleting CLR-Unlabeled_/7CFM_protein_vina_out7CFM_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/7CFM_protein_vina_out7CFM_mode_2.pdb
# Deleting CLR-Unlabeled_/7CFN_protein_vina_out7CFN_mode_3.pdb — 98.6% overlap with CLR-Unlabeled_/7CFN_protein_vina_out7CFN_mode_1.pdb
# Deleting CLR-Unlabeled_/7CFN_protein_vina_out7CFN_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/7CFN_protein_vina_out7CFN_mode_2.pdb
# Deleting CLR-Unlabeled_/7CFN_protein_vina_out7CFN_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/7CFN_protein_vina_out7CFN_mode_2.pdb
# Deleting CLR-Unlabeled_/7CKW_protein_vina_out7CKW_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/7CKW_protein_vina_out7CKW_mode_3.pdb
# Deleting CLR-Unlabeled_/7CKY_protein_vina_out7CKY_mode_4.pdb — 75.7% overlap with CLR-Unlabeled_/7CKY_protein_vina_out7CKY_mode_3.pdb
# Deleting CLR-Unlabeled_/7CKZ_protein_vina_out7CKZ_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/7CKZ_protein_vina_out7CKZ_mode_1.pdb
# Deleting CLR-Unlabeled_/7CKZ_protein_vina_out7CKZ_mode_4.pdb — 87.8% overlap with CLR-Unlabeled_/7CKZ_protein_vina_out7CKZ_mode_3.pdb
# Deleting CLR-Unlabeled_/7CU3_protein_vina_out7CU3_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/7CU3_protein_vina_out7CU3_mode_1.pdb
# Deleting CLR-Unlabeled_/7CZ5_protein_vina_out7CZ5_mode_2.pdb — 70.3% overlap with CLR-Unlabeled_/7CZ5_protein_vina_out7CZ5_mode_1.pdb
# Deleting CLR-Unlabeled_/7D8X_protein_vina_out7D8X_mode_3.pdb — 95.9% overlap with CLR-Unlabeled_/7D8X_protein_vina_out7D8X_mode_1.pdb
# Deleting CLR-Unlabeled_/7D8X_protein_vina_out7D8X_mode_5.pdb — 90.5% overlap with CLR-Unlabeled_/7D8X_protein_vina_out7D8X_mode_1.pdb
# Deleting CLR-Unlabeled_/7D77_protein_vina_out7D77_mode_3.pdb — 95.9% overlap with CLR-Unlabeled_/7D77_protein_vina_out7D77_mode_2.pdb
# ...
# Deleting CLR-Unlabeled_/8YN3_protein_vina_out8YN3_mode_5.pdb — 71.6% overlap with CLR-Unlabeled_/8YN3_protein_vina_out8YN3_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN4_protein_vina_out8YN4_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/8YN4_protein_vina_out8YN4_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN4_protein_vina_out8YN4_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/8YN4_protein_vina_out8YN4_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN4_protein_vina_out8YN4_mode_4.pdb — 95.9% overlap with CLR-Unlabeled_/8YN4_protein_vina_out8YN4_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN4_protein_vina_out8YN4_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/8YN4_protein_vina_out8YN4_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN5_protein_vina_out8YN5_mode_2.pdb — 90.5% overlap with CLR-Unlabeled_/8YN5_protein_vina_out8YN5_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN5_protein_vina_out8YN5_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/8YN5_protein_vina_out8YN5_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN6_protein_vina_out8YN6_mode_3.pdb — 87.8% overlap with CLR-Unlabeled_/8YN6_protein_vina_out8YN6_mode_2.pdb
# Deleting CLR-Unlabeled_/8YN7_protein_vina_out8YN7_mode_2.pdb — 78.4% overlap with CLR-Unlabeled_/8YN7_protein_vina_out8YN7_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN7_protein_vina_out8YN7_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/8YN7_protein_vina_out8YN7_mode_1.pdb
# Deleting CLR-Unlabeled_/8YN8_protein_vina_out8YN8_mode_4.pdb — 70.3% overlap with CLR-Unlabeled_/8YN8_protein_vina_out8YN8_mode_2.pdb
# Deleting CLR-Unlabeled_/8YN9_protein_vina_out8YN9_mode_4.pdb — 90.5% overlap with CLR-Unlabeled_/8YN9_protein_vina_out8YN9_mode_1.pdb
# Deleting CLR-Unlabeled_/8YNA_protein_vina_out8YNA_mode_3.pdb — 95.9% overlap with CLR-Unlabeled_/8YNA_protein_vina_out8YNA_mode_1.pdb
# Deleting CLR-Unlabeled_/8YNA_protein_vina_out8YNA_mode_5.pdb — 75.7% overlap with CLR-Unlabeled_/8YNA_protein_vina_out8YNA_mode_1.pdb
# Deleting CLR-Unlabeled_/8YR2_protein_vina_out8YR2_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/8YR2_protein_vina_out8YR2_mode_1.pdb
# Deleting CLR-Unlabeled_/8YUT_protein_vina_out8YUT_mode_4.pdb — 71.6% overlap with CLR-Unlabeled_/8YUT_protein_vina_out8YUT_mode_2.pdb
# Deleting CLR-Unlabeled_/8YUU_protein_vina_out8YUU_mode_3.pdb — 89.2% overlap with CLR-Unlabeled_/8YUU_protein_vina_out8YUU_mode_2.pdb
# Deleting CLR-Unlabeled_/8YUU_protein_vina_out8YUU_mode_4.pdb — 73.0% overlap with CLR-Unlabeled_/8YUU_protein_vina_out8YUU_mode_1.pdb
# Deleting CLR-Unlabeled_/8YUU_protein_vina_out8YUU_mode_5.pdb — 75.7% overlap with CLR-Unlabeled_/8YUU_protein_vina_out8YUU_mode_1.pdb
# Deleting CLR-Unlabeled_/8Z74_protein_vina_out8Z74_mode_2.pdb — 97.3% overlap with CLR-Unlabeled_/8Z74_protein_vina_out8Z74_mode_1.pdb
# Deleting CLR-Unlabeled_/8Z74_protein_vina_out8Z74_mode_3.pdb — 75.7% overlap with CLR-Unlabeled_/8Z74_protein_vina_out8Z74_mode_1.pdb
# Deleting CLR-Unlabeled_/8Z74_protein_vina_out8Z74_mode_4.pdb — 75.7% overlap with CLR-Unlabeled_/8Z74_protein_vina_out8Z74_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZJG_protein_vina_out8ZJG_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/8ZJG_protein_vina_out8ZJG_mode_2.pdb
# Deleting CLR-Unlabeled_/8ZJG_protein_vina_out8ZJG_mode_4.pdb — 87.8% overlap with CLR-Unlabeled_/8ZJG_protein_vina_out8ZJG_mode_2.pdb
# Deleting CLR-Unlabeled_/8ZJG_protein_vina_out8ZJG_mode_5.pdb — 83.8% overlap with CLR-Unlabeled_/8ZJG_protein_vina_out8ZJG_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZLE_protein_vina_out8ZLE_mode_2.pdb — 89.2% overlap with CLR-Unlabeled_/8ZLE_protein_vina_out8ZLE_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZLE_protein_vina_out8ZLE_mode_3.pdb — 81.1% overlap with CLR-Unlabeled_/8ZLE_protein_vina_out8ZLE_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZLE_protein_vina_out8ZLE_mode_4.pdb — 79.7% overlap with CLR-Unlabeled_/8ZLE_protein_vina_out8ZLE_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZLE_protein_vina_out8ZLE_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/8ZLE_protein_vina_out8ZLE_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZPL_protein_vina_out8ZPL_mode_3.pdb — 83.8% overlap with CLR-Unlabeled_/8ZPL_protein_vina_out8ZPL_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZPL_protein_vina_out8ZPL_mode_5.pdb — 97.3% overlap with CLR-Unlabeled_/8ZPL_protein_vina_out8ZPL_mode_4.pdb
# Deleting CLR-Unlabeled_/8ZPM_protein_vina_out8ZPM_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/8ZPM_protein_vina_out8ZPM_mode_2.pdb
# Deleting CLR-Unlabeled_/8ZPM_protein_vina_out8ZPM_mode_4.pdb — 97.3% overlap with CLR-Unlabeled_/8ZPM_protein_vina_out8ZPM_mode_2.pdb
# Deleting CLR-Unlabeled_/8ZPM_protein_vina_out8ZPM_mode_5.pdb — 86.5% overlap with CLR-Unlabeled_/8ZPM_protein_vina_out8ZPM_mode_2.pdb
# Deleting CLR-Unlabeled_/8ZPN_protein_vina_out8ZPN_mode_4.pdb — 86.5% overlap with CLR-Unlabeled_/8ZPN_protein_vina_out8ZPN_mode_3.pdb
# Deleting CLR-Unlabeled_/8ZSJ_protein_vina_out8ZSJ_mode_2.pdb — 98.6% overlap with CLR-Unlabeled_/8ZSJ_protein_vina_out8ZSJ_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZSJ_protein_vina_out8ZSJ_mode_3.pdb — 71.6% overlap with CLR-Unlabeled_/8ZSJ_protein_vina_out8ZSJ_mode_1.pdb
# Deleting CLR-Unlabeled_/8ZYJ_protein_vina_out8ZYJ_mode_2.pdb — 86.5% overlap with CLR-Unlabeled_/8ZYJ_protein_vina_out8ZYJ_mode_1.pdb
# Deleting CLR-Unlabeled_/9B8O_protein_vina_out9B8O_mode_3.pdb — 83.8% overlap with CLR-Unlabeled_/9B8O_protein_vina_out9B8O_mode_1.pdb
# Deleting CLR-Unlabeled_/9BBC_protein_vina_out9BBC_mode_4.pdb — 86.5% overlap with CLR-Unlabeled_/9BBC_protein_vina_out9BBC_mode_3.pdb
# Deleting CLR-Unlabeled_/9BR2_protein_vina_out9BR2_mode_2.pdb — 89.2% overlap with CLR-Unlabeled_/9BR2_protein_vina_out9BR2_mode_1.pdb
# Deleting CLR-Unlabeled_/9BUK_protein_vina_out9BUK_mode_4.pdb — 75.7% overlap with CLR-Unlabeled_/9BUK_protein_vina_out9BUK_mode_2.pdb
# Deleting CLR-Unlabeled_/9BUR_protein_vina_out9BUR_mode_4.pdb — 79.7% overlap with CLR-Unlabeled_/9BUR_protein_vina_out9BUR_mode_1.pdb
# Deleting CLR-Unlabeled_/9BUX_protein_vina_out9BUX_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/9BUX_protein_vina_out9BUX_mode_3.pdb
# Deleting CLR-Unlabeled_/9BVH_protein_vina_out9BVH_mode_2.pdb — 82.4% overlap with CLR-Unlabeled_/9BVH_protein_vina_out9BVH_mode_1.pdb
# Deleting CLR-Unlabeled_/9C12_protein_vina_out9C12_mode_4.pdb — 87.8% overlap with CLR-Unlabeled_/9C12_protein_vina_out9C12_mode_2.pdb
# Deleting CLR-Unlabeled_/9CDC_protein_vina_out9CDC_mode_5.pdb — 77.0% overlap with CLR-Unlabeled_/9CDC_protein_vina_out9CDC_mode_1.pdb
# Deleting CLR-Unlabeled_/9CDD_protein_vina_out9CDD_mode_5.pdb — 85.1% overlap with CLR-Unlabeled_/9CDD_protein_vina_out9CDD_mode_2.pdb
# Deleting CLR-Unlabeled_/9CDE_protein_vina_out9CDE_mode_4.pdb — 94.6% overlap with CLR-Unlabeled_/9CDE_protein_vina_out9CDE_mode_1.pdb
# Deleting CLR-Unlabeled_/9CDE_protein_vina_out9CDE_mode_5.pdb — 95.9% overlap with CLR-Unlabeled_/9CDE_protein_vina_out9CDE_mode_3.pdb
# Deleting CLR-Unlabeled_/9CIA_protein_vina_out9CIA_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/9CIA_protein_vina_out9CIA_mode_1.pdb
# Deleting CLR-Unlabeled_/9CQ4_protein_vina_out9CQ4_mode_4.pdb — 85.1% overlap with CLR-Unlabeled_/9CQ4_protein_vina_out9CQ4_mode_1.pdb
# Deleting CLR-Unlabeled_/9CUK_protein_vina_out9CUK_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/9CUK_protein_vina_out9CUK_mode_1.pdb
# Deleting CLR-Unlabeled_/9CUK_protein_vina_out9CUK_mode_5.pdb — 94.6% overlap with CLR-Unlabeled_/9CUK_protein_vina_out9CUK_mode_2.pdb
# Deleting CLR-Unlabeled_/9CZM_protein_vina_out9CZM_mode_2.pdb — 93.2% overlap with CLR-Unlabeled_/9CZM_protein_vina_out9CZM_mode_1.pdb
# Deleting CLR-Unlabeled_/9CZQ_protein_vina_out9CZQ_mode_3.pdb — 74.3% overlap with CLR-Unlabeled_/9CZQ_protein_vina_out9CZQ_mode_1.pdb
# Deleting CLR-Unlabeled_/9D3E_protein_vina_out9D3E_mode_3.pdb — 93.2% overlap with CLR-Unlabeled_/9D3E_protein_vina_out9D3E_mode_1.pdb
# Deleting CLR-Unlabeled_/9D3E_protein_vina_out9D3E_mode_4.pdb — 93.2% overlap with CLR-Unlabeled_/9D3E_protein_vina_out9D3E_mode_2.pdb
# Deleting CLR-Unlabeled_/9D3G_protein_vina_out9D3G_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/9D3G_protein_vina_out9D3G_mode_1.pdb
# Deleting CLR-Unlabeled_/9D18_protein_vina_out9D18_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/9D18_protein_vina_out9D18_mode_2.pdb
# Deleting CLR-Unlabeled_/9D18_protein_vina_out9D18_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/9D18_protein_vina_out9D18_mode_2.pdb
# Deleting CLR-Unlabeled_/9DBK_protein_vina_out9DBK_mode_3.pdb — 91.9% overlap with CLR-Unlabeled_/9DBK_protein_vina_out9DBK_mode_2.pdb
# Deleting CLR-Unlabeled_/9DBK_protein_vina_out9DBK_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/9DBK_protein_vina_out9DBK_mode_1.pdb
# Deleting CLR-Unlabeled_/9DBM_protein_vina_out9DBM_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/9DBM_protein_vina_out9DBM_mode_1.pdb
# Deleting CLR-Unlabeled_/9DBN_protein_vina_out9DBN_mode_5.pdb — 85.1% overlap with CLR-Unlabeled_/9DBN_protein_vina_out9DBN_mode_2.pdb
# Deleting CLR-Unlabeled_/9DNX_protein_vina_out9DNX_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/9DNX_protein_vina_out9DNX_mode_1.pdb
# Deleting CLR-Unlabeled_/9DNX_protein_vina_out9DNX_mode_5.pdb — 82.4% overlap with CLR-Unlabeled_/9DNX_protein_vina_out9DNX_mode_3.pdb
# Deleting CLR-Unlabeled_/9DNZ_protein_vina_out9DNZ_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/9DNZ_protein_vina_out9DNZ_mode_4.pdb
# Deleting CLR-Unlabeled_/9DVJ_protein_vina_out9DVJ_mode_5.pdb — 83.8% overlap with CLR-Unlabeled_/9DVJ_protein_vina_out9DVJ_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVK_protein_vina_out9DVK_mode_2.pdb — 70.3% overlap with CLR-Unlabeled_/9DVK_protein_vina_out9DVK_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVK_protein_vina_out9DVK_mode_5.pdb — 75.7% overlap with CLR-Unlabeled_/9DVK_protein_vina_out9DVK_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVL_protein_vina_out9DVL_mode_3.pdb — 81.1% overlap with CLR-Unlabeled_/9DVL_protein_vina_out9DVL_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVM_protein_vina_out9DVM_mode_5.pdb — 79.7% overlap with CLR-Unlabeled_/9DVM_protein_vina_out9DVM_mode_2.pdb
# Deleting CLR-Unlabeled_/9DVO_protein_vina_out9DVO_mode_2.pdb — 94.6% overlap with CLR-Unlabeled_/9DVO_protein_vina_out9DVO_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVO_protein_vina_out9DVO_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/9DVO_protein_vina_out9DVO_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVP_protein_vina_out9DVP_mode_2.pdb — 91.9% overlap with CLR-Unlabeled_/9DVP_protein_vina_out9DVP_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVP_protein_vina_out9DVP_mode_3.pdb — 98.6% overlap with CLR-Unlabeled_/9DVP_protein_vina_out9DVP_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVP_protein_vina_out9DVP_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/9DVP_protein_vina_out9DVP_mode_1.pdb
# Deleting CLR-Unlabeled_/9DVP_protein_vina_out9DVP_mode_5.pdb — 85.1% overlap with CLR-Unlabeled_/9DVP_protein_vina_out9DVP_mode_1.pdb
# Deleting CLR-Unlabeled_/9EAI_protein_vina_out9EAI_mode_3.pdb — 90.5% overlap with CLR-Unlabeled_/9EAI_protein_vina_out9EAI_mode_1.pdb
# Deleting CLR-Unlabeled_/9EAI_protein_vina_out9EAI_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/9EAI_protein_vina_out9EAI_mode_1.pdb
# Deleting CLR-Unlabeled_/9EO4_protein_vina_out9EO4_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/9EO4_protein_vina_out9EO4_mode_1.pdb
# Deleting CLR-Unlabeled_/9EO4_protein_vina_out9EO4_mode_5.pdb — 97.3% overlap with CLR-Unlabeled_/9EO4_protein_vina_out9EO4_mode_4.pdb
# Deleting CLR-Unlabeled_/9EUO_protein_vina_out9EUO_mode_2.pdb — 94.6% overlap with CLR-Unlabeled_/9EUO_protein_vina_out9EUO_mode_1.pdb
# Deleting CLR-Unlabeled_/9EUO_protein_vina_out9EUO_mode_3.pdb — 87.8% overlap with CLR-Unlabeled_/9EUO_protein_vina_out9EUO_mode_1.pdb
# Deleting CLR-Unlabeled_/9EUO_protein_vina_out9EUO_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/9EUO_protein_vina_out9EUO_mode_1.pdb
# Deleting CLR-Unlabeled_/9EUO_protein_vina_out9EUO_mode_5.pdb — 89.2% overlap with CLR-Unlabeled_/9EUO_protein_vina_out9EUO_mode_1.pdb
# Deleting CLR-Unlabeled_/9EUP_protein_vina_out9EUP_mode_4.pdb — 82.4% overlap with CLR-Unlabeled_/9EUP_protein_vina_out9EUP_mode_1.pdb
# Deleting CLR-Unlabeled_/9F41_protein_vina_out9F41_mode_3.pdb — 85.1% overlap with CLR-Unlabeled_/9F41_protein_vina_out9F41_mode_1.pdb
# Deleting CLR-Unlabeled_/9FUP_protein_vina_out9FUP_mode_2.pdb — 78.4% overlap with CLR-Unlabeled_/9FUP_protein_vina_out9FUP_mode_1.pdb
# Deleting CLR-Unlabeled_/9FUP_protein_vina_out9FUP_mode_3.pdb — 79.7% overlap with CLR-Unlabeled_/9FUP_protein_vina_out9FUP_mode_1.pdb
# Deleting CLR-Unlabeled_/9FUP_protein_vina_out9FUP_mode_4.pdb — 94.6% overlap with CLR-Unlabeled_/9FUP_protein_vina_out9FUP_mode_1.pdb
# Deleting CLR-Unlabeled_/9GE2_protein_vina_out9GE2_mode_3.pdb — 77.0% overlap with CLR-Unlabeled_/9GE2_protein_vina_out9GE2_mode_2.pdb
# Deleting CLR-Unlabeled_/9GYO_protein_vina_out9GYO_mode_2.pdb — 87.8% overlap with CLR-Unlabeled_/9GYO_protein_vina_out9GYO_mode_1.pdb
# Deleting CLR-Unlabeled_/9IJ9_protein_vina_out9IJ9_mode_3.pdb — 82.4% overlap with CLR-Unlabeled_/9IJ9_protein_vina_out9IJ9_mode_2.pdb
# Deleting CLR-Unlabeled_/9IMA_protein_vina_out9IMA_mode_2.pdb — 78.4% overlap with CLR-Unlabeled_/9IMA_protein_vina_out9IMA_mode_1.pdb
# Deleting CLR-Unlabeled_/9INE_protein_vina_out9INE_mode_3.pdb — 97.3% overlap with CLR-Unlabeled_/9INE_protein_vina_out9INE_mode_1.pdb
# Deleting CLR-Unlabeled_/9INE_protein_vina_out9INE_mode_4.pdb — 83.8% overlap with CLR-Unlabeled_/9INE_protein_vina_out9INE_mode_1.pdb
# Deleting CLR-Unlabeled_/9INF_protein_vina_out9INF_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/9INF_protein_vina_out9INF_mode_2.pdb
# Deleting CLR-Unlabeled_/9ITB_protein_vina_out9ITB_mode_2.pdb — 81.1% overlap with CLR-Unlabeled_/9ITB_protein_vina_out9ITB_mode_1.pdb
# Deleting CLR-Unlabeled_/9ITB_protein_vina_out9ITB_mode_3.pdb — 87.8% overlap with CLR-Unlabeled_/9ITB_protein_vina_out9ITB_mode_1.pdb
# Deleting CLR-Unlabeled_/9ITE_protein_vina_out9ITE_mode_3.pdb — 79.7% overlap with CLR-Unlabeled_/9ITE_protein_vina_out9ITE_mode_1.pdb
# Deleting CLR-Unlabeled_/9ITE_protein_vina_out9ITE_mode_5.pdb — 70.3% overlap with CLR-Unlabeled_/9ITE_protein_vina_out9ITE_mode_2.pdb
# Deleting CLR-Unlabeled_/9ITG_protein_vina_out9ITG_mode_3.pdb — 83.8% overlap with CLR-Unlabeled_/9ITG_protein_vina_out9ITG_mode_1.pdb
# Deleting CLR-Unlabeled_/9J3X_protein_vina_out9J3X_mode_2.pdb — 85.1% overlap with CLR-Unlabeled_/9J3X_protein_vina_out9J3X_mode_1.pdb
# Deleting CLR-Unlabeled_/9J3X_protein_vina_out9J3X_mode_3.pdb — 89.2% overlap with CLR-Unlabeled_/9J3X_protein_vina_out9J3X_mode_1.pdb
# Deleting CLR-Unlabeled_/9J3X_protein_vina_out9J3X_mode_5.pdb — 91.9% overlap with CLR-Unlabeled_/9J3X_protein_vina_out9J3X_mode_1.pdb
# Deleting CLR-Unlabeled_/9J7M_protein_vina_out9J7M_mode_3.pdb — 79.7% overlap with CLR-Unlabeled_/9J7M_protein_vina_out9J7M_mode_2.pdb
# Deleting CLR-Unlabeled_/9J7N_protein_vina_out9J7N_mode_5.pdb — 94.6% overlap with CLR-Unlabeled_/9J7N_protein_vina_out9J7N_mode_3.pdb
# Deleting CLR-Unlabeled_/9J8C_protein_vina_out9J8C_mode_2.pdb — 83.8% overlap with CLR-Unlabeled_/9J8C_protein_vina_out9J8C_mode_1.pdb
# Deleting CLR-Unlabeled_/9J8C_protein_vina_out9J8C_mode_4.pdb — 86.5% overlap with CLR-Unlabeled_/9J8C_protein_vina_out9J8C_mode_3.pdb
# Deleting CLR-Unlabeled_/9J8D_protein_vina_out9J8D_mode_3.pdb — 73.0% overlap with CLR-Unlabeled_/9J8D_protein_vina_out9J8D_mode_1.pdb
# Deleting CLR-Unlabeled_/9J8D_protein_vina_out9J8D_mode_4.pdb — 95.9% overlap with CLR-Unlabeled_/9J8D_protein_vina_out9J8D_mode_1.pdb
# Deleting CLR-Unlabeled_/9J40_protein_vina_out9J40_mode_3.pdb — 86.5% overlap with CLR-Unlabeled_/9J40_protein_vina_out9J40_mode_1.pdb
# Deleting CLR-Unlabeled_/9J40_protein_vina_out9J40_mode_4.pdb — 81.1% overlap with CLR-Unlabeled_/9J40_protein_vina_out9J40_mode_1.pdb
# Deleting CLR-Unlabeled_/9J97_protein_vina_out9J97_mode_4.pdb — 91.9% overlap with CLR-Unlabeled_/9J97_protein_vina_out9J97_mode_3.pdb
# Deleting CLR-Unlabeled_/9J98_protein_vina_out9J98_mode_4.pdb — 86.5% overlap with CLR-Unlabeled_/9J98_protein_vina_out9J98_mode_1.pdb
# Deleting CLR-Unlabeled_/9J98_protein_vina_out9J98_mode_5.pdb — 83.8% overlap with CLR-Unlabeled_/9J98_protein_vina_out9J98_mode_3.pdb
# Deleting CLR-Unlabeled_/9K1D_protein_vina_out9K1D_mode_4.pdb — 78.4% overlap with CLR-Unlabeled_/9K1D_protein_vina_out9K1D_mode_1.pdb
