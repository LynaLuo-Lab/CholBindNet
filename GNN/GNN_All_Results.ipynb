# %%
import torch
import torch.nn as nn
import glob
import numpy as np
import csv
import os

# Define the 2D CNN model in PyTorch
class CNN2D(nn.Module):
    def __init__(self, input_channels):
        super(CNN2D, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(input_channels, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU()
        )
        self.pool1 = nn.MaxPool2d(2, 2)
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )
        self.pool2 = nn.MaxPool2d(2, 2)
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU()
        )
        self.pool3 = nn.MaxPool2d(2, 2)
        
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(128 * 4 * 18, 128)  # Adjust based on input size
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, 1)
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.pool2(x)
        
        x = self.conv3(x)
        x = self.pool3(x)
        
        x = self.flatten(x)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

models_exp1 = []
models_exp2 = []
models_exp3 = []
models_exp4 = []
models_exp5 = []

k = 50

for i in range (1, (k + 1)):
    model_exp1 = CNN2D(input_channels=1).to(device)
    model_exp1 = nn.DataParallel(model_exp1)

    model_exp2 = CNN2D(input_channels=1).to(device)
    model_exp2 = nn.DataParallel(model_exp2)

    model_exp3 = CNN2D(input_channels=1).to(device)
    model_exp3 = nn.DataParallel(model_exp3)

    model_exp4 = CNN2D(input_channels=1).to(device)
    model_exp4 = nn.DataParallel(model_exp4)

    model_exp5 = CNN2D(input_channels=1).to(device)
    model_exp5 = nn.DataParallel(model_exp5)

    model_path = f"../../../Models/Cholesterol/GNN/GNN-5A_Exp1/Models/model_bin_{i}.pth" 
    model_exp1.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/GNN/GNN-5A_Exp2/Models/model_bin_{i}.pth" 
    model_exp2.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/GNN/GNN-5A_Exp3/Models/model_bin_{i}.pth" 
    model_exp3.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/GNN/GNN-5A_Exp4/Models/model_bin_{i}.pth" 
    model_exp4.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"../../../Models/Cholesterol/GNN/GNN-5A_Exp5/Models/model_bin_{i}.pth" 
    model_exp5.load_state_dict(torch.load(model_path, map_location=device))

    model_exp1.eval()
    model_exp2.eval()
    model_exp3.eval()
    model_exp4.eval()
    model_exp5.eval()

    models_exp1.append(model_exp1)
    models_exp2.append(model_exp2)
    models_exp3.append(model_exp3)
    models_exp4.append(model_exp4)
    models_exp5.append(model_exp5)
# Out:
# /tmp/ipykernel_1373676/3951675209.py:82: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp1.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_1373676/3951675209.py:85: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp2.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_1373676/3951675209.py:88: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp3.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_1373676/3951675209.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp4.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_1373676/3951675209.py:94: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp5.load_state_dict(torch.load(model_path, map_location=device))

# %%
def evaluate_file(model, file_path, threshold=0.5):
    grid = np.load(file_path)

    if grid.ndim == 2:
        non_padded_rows = np.sum(np.any(grid != 0, axis=(1)))
    else:
        raise ValueError(f"Unexpected grid shape: {grid.shape}")
    
    grid_tensor = torch.tensor(grid, dtype=torch.float32).unsqueeze(0).unsqueeze(0)  # Add batch and channel dims
    grid_tensor = grid_tensor.to(device)
    
    model.eval()
    with torch.no_grad():
        output = model(grid_tensor).squeeze(1)  

    prob = torch.sigmoid(output).item()

    predicted_class = int(prob >= threshold)

    return predicted_class, prob, non_padded_rows

# %%
def evaluate_directory(dir, csv_output, models):
    predictions = []
    capture_rate = 0
    overlapping_capture_rate = 0
    overlapping_index = 0

    files = glob.glob(f"{dir}/*.npy")

    model_positive_counts = [0] * len(models)
    model_negative_counts = [0] * len(models)

    #print(f"{'Filename':<120} {'IndividualCaptureRate':<25} NumberOfAtoms")

    os.makedirs(os.path.dirname(csv_output), exist_ok=True)

    with open(csv_output, "w", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["filename", "average_score", "score_std", "number_atoms"]) 

        for file in sorted(files):    
            model_probs = []
            for model_index, model in enumerate(models):
                predicted_class, prob, non_padded_rows = evaluate_file(model, file)
                model_probs.append(prob)

                if predicted_class == 1:
                    model_positive_counts[model_index] += 1
                else:
                    model_negative_counts[model_index] += 1

            prediction_mean = np.mean(model_probs)
            prediction_std = np.std(model_probs)

            predictions.append((model_index, predicted_class))
            capture_rate += prediction_mean
            #if non_padded_rows <= 65 and non_padded_rows >= 55:
            #print(f"{file:<120} {prediction:<25} {non_padded_rows}")
            overlapping_capture_rate += prediction_mean
            overlapping_index += 1
            writer.writerow([file, prediction_mean, prediction_std, non_padded_rows])

    capture_rate /= len(files)
    overlapping_capture_rate /= overlapping_index

    print("\nModel Predictions Summary:")
    for i, (pos, neg) in enumerate(zip(model_positive_counts, model_negative_counts), start=1):
        print(f"Model {i}: Positives = {pos}, Negatives = {neg}")

    print("Overlapping Capture Rate is", overlapping_capture_rate)

    return capture_rate

# %%
spies_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A/Spies"  
csv_output_exp1 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp1/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp1, csv_output_exp1, models_exp1)

spies_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp2/Spies"  
csv_output_exp2 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp2/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp2, csv_output_exp2, models_exp2)

spies_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp3/Spies"  
csv_output_exp3 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp3/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp3, csv_output_exp3, models_exp3)

spies_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp4/Spies"  
csv_output_exp4 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp4/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp4, csv_output_exp4, models_exp4)

spies_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Spies"  
csv_output_exp5 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp5/NewResults/SpyCaptureRates.csv"

spy_capture_rate = evaluate_directory(spies_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 121, Negatives = 33
# Model 2: Positives = 110, Negatives = 44
# Model 3: Positives = 115, Negatives = 39
# Model 4: Positives = 111, Negatives = 43
# Model 5: Positives = 115, Negatives = 39
# Model 6: Positives = 108, Negatives = 46
# Model 7: Positives = 109, Negatives = 45
# Model 8: Positives = 108, Negatives = 46
# Model 9: Positives = 122, Negatives = 32
# Model 10: Positives = 106, Negatives = 48
# Model 11: Positives = 116, Negatives = 38
# Model 12: Positives = 124, Negatives = 30
# Model 13: Positives = 121, Negatives = 33
# Model 14: Positives = 121, Negatives = 33
# Model 15: Positives = 117, Negatives = 37
# Model 16: Positives = 103, Negatives = 51
# Model 17: Positives = 121, Negatives = 33
# Model 18: Positives = 99, Negatives = 55
# Model 19: Positives = 104, Negatives = 50
# Model 20: Positives = 111, Negatives = 43
# Model 21: Positives = 118, Negatives = 36
# Model 22: Positives = 105, Negatives = 49
# Model 23: Positives = 115, Negatives = 39
# Model 24: Positives = 107, Negatives = 47
# Model 25: Positives = 113, Negatives = 41
# Model 26: Positives = 119, Negatives = 35
# Model 27: Positives = 110, Negatives = 44
# Model 28: Positives = 112, Negatives = 42
# Model 29: Positives = 109, Negatives = 45
# Model 30: Positives = 106, Negatives = 48
# Model 31: Positives = 108, Negatives = 46
# Model 32: Positives = 108, Negatives = 46
# Model 33: Positives = 106, Negatives = 48
# Model 34: Positives = 119, Negatives = 35
# Model 35: Positives = 117, Negatives = 37
# Model 36: Positives = 114, Negatives = 40
# Model 37: Positives = 113, Negatives = 41
# Model 38: Positives = 109, Negatives = 45
# Model 39: Positives = 117, Negatives = 37
# Model 40: Positives = 117, Negatives = 37
# Model 41: Positives = 113, Negatives = 41
# Model 42: Positives = 109, Negatives = 45
# Model 43: Positives = 109, Negatives = 45
# Model 44: Positives = 114, Negatives = 40
# Model 45: Positives = 112, Negatives = 42
# Model 46: Positives = 117, Negatives = 37
# Model 47: Positives = 117, Negatives = 37
# Model 48: Positives = 116, Negatives = 38
# Model 49: Positives = 106, Negatives = 48
# Model 50: Positives = 110, Negatives = 44
# Overlapping Capture Rate is 0.7153583526085794
#
# Model Predictions Summary:
# Model 1: Positives = 112, Negatives = 42
# Model 2: Positives = 119, Negatives = 35
# Model 3: Positives = 122, Negatives = 32
# Model 4: Positives = 114, Negatives = 40
# Model 5: Positives = 121, Negatives = 33
# Model 6: Positives = 125, Negatives = 29
# Model 7: Positives = 122, Negatives = 32
# Model 8: Positives = 123, Negatives = 31
# Model 9: Positives = 131, Negatives = 23
# Model 10: Positives = 114, Negatives = 40
# Model 11: Positives = 118, Negatives = 36
# Model 12: Positives = 124, Negatives = 30
# Model 13: Positives = 123, Negatives = 31
# Model 14: Positives = 111, Negatives = 43
# Model 15: Positives = 115, Negatives = 39
# Model 16: Positives = 118, Negatives = 36
# Model 17: Positives = 123, Negatives = 31
# Model 18: Positives = 123, Negatives = 31
# Model 19: Positives = 117, Negatives = 37
# Model 20: Positives = 133, Negatives = 21
# Model 21: Positives = 120, Negatives = 34
# Model 22: Positives = 124, Negatives = 30
# Model 23: Positives = 115, Negatives = 39
# Model 24: Positives = 110, Negatives = 44
# Model 25: Positives = 122, Negatives = 32
# Model 26: Positives = 118, Negatives = 36
# Model 27: Positives = 127, Negatives = 27
# Model 28: Positives = 117, Negatives = 37
# Model 29: Positives = 113, Negatives = 41
# Model 30: Positives = 121, Negatives = 33
# Model 31: Positives = 121, Negatives = 33
# Model 32: Positives = 118, Negatives = 36
# Model 33: Positives = 122, Negatives = 32
# Model 34: Positives = 125, Negatives = 29
# Model 35: Positives = 111, Negatives = 43
# Model 36: Positives = 123, Negatives = 31
# Model 37: Positives = 108, Negatives = 46
# Model 38: Positives = 123, Negatives = 31
# Model 39: Positives = 120, Negatives = 34
# Model 40: Positives = 118, Negatives = 36
# Model 41: Positives = 112, Negatives = 42
# Model 42: Positives = 124, Negatives = 30
# Model 43: Positives = 121, Negatives = 33
# Model 44: Positives = 122, Negatives = 32
# Model 45: Positives = 116, Negatives = 38
# Model 46: Positives = 115, Negatives = 39
# Model 47: Positives = 130, Negatives = 24
# Model 48: Positives = 121, Negatives = 33
# Model 49: Positives = 121, Negatives = 33
# Model 50: Positives = 116, Negatives = 38
# Overlapping Capture Rate is 0.749904223618932
#
# Model Predictions Summary:
# Model 1: Positives = 119, Negatives = 35
# Model 2: Positives = 121, Negatives = 33
# Model 3: Positives = 115, Negatives = 39
# Model 4: Positives = 116, Negatives = 38
# Model 5: Positives = 124, Negatives = 30
# Model 6: Positives = 125, Negatives = 29
# Model 7: Positives = 114, Negatives = 40
# Model 8: Positives = 119, Negatives = 35
# Model 9: Positives = 122, Negatives = 32
# Model 10: Positives = 116, Negatives = 38
# Model 11: Positives = 119, Negatives = 35
# Model 12: Positives = 116, Negatives = 38
# Model 13: Positives = 115, Negatives = 39
# Model 14: Positives = 121, Negatives = 33
# Model 15: Positives = 122, Negatives = 32
# Model 16: Positives = 118, Negatives = 36
# Model 17: Positives = 127, Negatives = 27
# Model 18: Positives = 110, Negatives = 44
# Model 19: Positives = 113, Negatives = 41
# Model 20: Positives = 118, Negatives = 36
# Model 21: Positives = 120, Negatives = 34
# Model 22: Positives = 120, Negatives = 34
# Model 23: Positives = 119, Negatives = 35
# Model 24: Positives = 128, Negatives = 26
# Model 25: Positives = 120, Negatives = 34
# Model 26: Positives = 113, Negatives = 41
# Model 27: Positives = 123, Negatives = 31
# Model 28: Positives = 124, Negatives = 30
# Model 29: Positives = 119, Negatives = 35
# Model 30: Positives = 113, Negatives = 41
# Model 31: Positives = 114, Negatives = 40
# Model 32: Positives = 110, Negatives = 44
# Model 33: Positives = 118, Negatives = 36
# Model 34: Positives = 119, Negatives = 35
# Model 35: Positives = 111, Negatives = 43
# Model 36: Positives = 125, Negatives = 29
# Model 37: Positives = 116, Negatives = 38
# Model 38: Positives = 117, Negatives = 37
# Model 39: Positives = 110, Negatives = 44
# Model 40: Positives = 127, Negatives = 27
# Model 41: Positives = 115, Negatives = 39
# Model 42: Positives = 116, Negatives = 38
# Model 43: Positives = 116, Negatives = 38
# Model 44: Positives = 129, Negatives = 25
# Model 45: Positives = 118, Negatives = 36
# Model 46: Positives = 117, Negatives = 37
# Model 47: Positives = 122, Negatives = 32
# Model 48: Positives = 123, Negatives = 31
# Model 49: Positives = 121, Negatives = 33
# Model 50: Positives = 122, Negatives = 32
# Overlapping Capture Rate is 0.744754434801251
#
# Model Predictions Summary:
# Model 1: Positives = 116, Negatives = 38
# Model 2: Positives = 123, Negatives = 31
# Model 3: Positives = 120, Negatives = 34
# Model 4: Positives = 107, Negatives = 47
# Model 5: Positives = 114, Negatives = 40
# Model 6: Positives = 103, Negatives = 51
# Model 7: Positives = 114, Negatives = 40
# Model 8: Positives = 117, Negatives = 37
# Model 9: Positives = 119, Negatives = 35
# Model 10: Positives = 107, Negatives = 47
# Model 11: Positives = 117, Negatives = 37
# Model 12: Positives = 119, Negatives = 35
# Model 13: Positives = 107, Negatives = 47
# Model 14: Positives = 107, Negatives = 47
# Model 15: Positives = 109, Negatives = 45
# Model 16: Positives = 112, Negatives = 42
# Model 17: Positives = 111, Negatives = 43
# Model 18: Positives = 117, Negatives = 37
# Model 19: Positives = 110, Negatives = 44
# Model 20: Positives = 104, Negatives = 50
# Model 21: Positives = 112, Negatives = 42
# Model 22: Positives = 110, Negatives = 44
# Model 23: Positives = 122, Negatives = 32
# Model 24: Positives = 117, Negatives = 37
# Model 25: Positives = 105, Negatives = 49
# Model 26: Positives = 99, Negatives = 55
# Model 27: Positives = 113, Negatives = 41
# Model 28: Positives = 116, Negatives = 38
# Model 29: Positives = 104, Negatives = 50
# Model 30: Positives = 110, Negatives = 44
# Model 31: Positives = 108, Negatives = 46
# Model 32: Positives = 112, Negatives = 42
# Model 33: Positives = 117, Negatives = 37
# Model 34: Positives = 118, Negatives = 36
# Model 35: Positives = 116, Negatives = 38
# Model 36: Positives = 113, Negatives = 41
# Model 37: Positives = 109, Negatives = 45
# Model 38: Positives = 115, Negatives = 39
# Model 39: Positives = 119, Negatives = 35
# Model 40: Positives = 117, Negatives = 37
# Model 41: Positives = 109, Negatives = 45
# Model 42: Positives = 124, Negatives = 30
# Model 43: Positives = 102, Negatives = 52
# Model 44: Positives = 113, Negatives = 41
# Model 45: Positives = 113, Negatives = 41
# Model 46: Positives = 118, Negatives = 36
# Model 47: Positives = 119, Negatives = 35
# Model 48: Positives = 115, Negatives = 39
# Model 49: Positives = 112, Negatives = 42
# Model 50: Positives = 111, Negatives = 43
# Overlapping Capture Rate is 0.7099726800994974
#
# Model Predictions Summary:
# Model 1: Positives = 106, Negatives = 48
# Model 2: Positives = 114, Negatives = 40
# Model 3: Positives = 111, Negatives = 43
# Model 4: Positives = 116, Negatives = 38
# Model 5: Positives = 117, Negatives = 37
# Model 6: Positives = 115, Negatives = 39
# Model 7: Positives = 113, Negatives = 41
# Model 8: Positives = 115, Negatives = 39
# Model 9: Positives = 112, Negatives = 42
# Model 10: Positives = 113, Negatives = 41
# Model 11: Positives = 121, Negatives = 33
# Model 12: Positives = 108, Negatives = 46
# Model 13: Positives = 117, Negatives = 37
# Model 14: Positives = 100, Negatives = 54
# Model 15: Positives = 121, Negatives = 33
# Model 16: Positives = 109, Negatives = 45
# Model 17: Positives = 106, Negatives = 48
# Model 18: Positives = 113, Negatives = 41
# Model 19: Positives = 115, Negatives = 39
# Model 20: Positives = 105, Negatives = 49
# Model 21: Positives = 114, Negatives = 40
# Model 22: Positives = 102, Negatives = 52
# Model 23: Positives = 125, Negatives = 29
# Model 24: Positives = 119, Negatives = 35
# Model 25: Positives = 110, Negatives = 44
# Model 26: Positives = 121, Negatives = 33
# Model 27: Positives = 109, Negatives = 45
# Model 28: Positives = 114, Negatives = 40
# Model 29: Positives = 121, Negatives = 33
# Model 30: Positives = 118, Negatives = 36
# Model 31: Positives = 110, Negatives = 44
# Model 32: Positives = 103, Negatives = 51
# Model 33: Positives = 107, Negatives = 47
# Model 34: Positives = 108, Negatives = 46
# Model 35: Positives = 117, Negatives = 37
# Model 36: Positives = 109, Negatives = 45
# Model 37: Positives = 122, Negatives = 32
# Model 38: Positives = 112, Negatives = 42
# Model 39: Positives = 107, Negatives = 47
# Model 40: Positives = 108, Negatives = 46
# Model 41: Positives = 123, Negatives = 31
# Model 42: Positives = 122, Negatives = 32
# Model 43: Positives = 120, Negatives = 34
# Model 44: Positives = 114, Negatives = 40
# Model 45: Positives = 114, Negatives = 40
# Model 46: Positives = 108, Negatives = 46
# Model 47: Positives = 116, Negatives = 38
# Model 48: Positives = 107, Negatives = 47
# Model 49: Positives = 107, Negatives = 47
# Model 50: Positives = 117, Negatives = 37
# Overlapping Capture Rate is 0.7120675674568148

# %%
import pandas as pd

def get_spy_info(csv):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    # Extract the 'average_score' column
    scores = df["average_score"]

    # Compute statistics
    mean_score = scores.mean()
    percentile_50 = scores.quantile(0.5)
    percentile_25 = scores.quantile(0.25)
    percentile_75 = scores.quantile(0.75)
    min_score = scores.min()
    max_score = scores.max()

    # Print results
    print(f"Mean: {mean_score:.6f}")
    print(f"50th Percentile (Median): {percentile_50:.6f}")
    print(f"Bottom 25 Percentile: {percentile_25:.6f}")
    print(f"Top 25 Percentile: {percentile_75:.6f}")
    print(f"Min: {min_score:.6f}")
    print(f"Max: {max_score:.6f}\n")

    return mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score

print("Experiment 1 Spy Results:")
mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1 = get_spy_info(csv_output_exp1)

print("Experiment 2 Spy Results:")
mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2 = get_spy_info(csv_output_exp2)

print("Experiment 3 Spy Results:")
mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3 = get_spy_info(csv_output_exp3)

print("Experiment 4 Spy Results:")
mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4 = get_spy_info(csv_output_exp4)

print("Experiment 5 Spy Results:")
mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5 = get_spy_info(csv_output_exp5)
# Out:
# Experiment 1 Spy Results:
# Mean: 0.715358
# 50th Percentile (Median): 0.766796
# Bottom 25 Percentile: 0.672870
# Top 25 Percentile: 0.827340
# Min: 0.012814
# Max: 0.952532
#
# Experiment 2 Spy Results:
# Mean: 0.749904
# 50th Percentile (Median): 0.794622
# Bottom 25 Percentile: 0.732618
# Top 25 Percentile: 0.850029
# Min: 0.091547
# Max: 0.964338
#
# Experiment 3 Spy Results:
# Mean: 0.744754
# 50th Percentile (Median): 0.794971
# Bottom 25 Percentile: 0.705047
# Top 25 Percentile: 0.844019
# Min: 0.018880
# Max: 0.944226
#
# Experiment 4 Spy Results:
# Mean: 0.709973
# 50th Percentile (Median): 0.762311
# Bottom 25 Percentile: 0.658557
# Top 25 Percentile: 0.825139
# Min: 0.000157
# Max: 0.949129
#
# Experiment 5 Spy Results:
# Mean: 0.712068
# 50th Percentile (Median): 0.770435
# Bottom 25 Percentile: 0.669200
# Top 25 Percentile: 0.828231
# Min: 0.000156
# Max: 0.946053

# %%
test_positives_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A/Test/Positive"  
csv_output_exp1 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp1/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp1, csv_output_exp1, models_exp1)

test_positives_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp2/Test/Positive"  
csv_output_exp2 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp2/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp2, csv_output_exp2, models_exp2)

test_positives_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp3/Test/Positive"  
csv_output_exp3 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp3/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp3, csv_output_exp3, models_exp3)

test_positives_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp4/Test/Positive"  
csv_output_exp4 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp4/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp4, csv_output_exp4, models_exp4)

test_positives_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive"  
csv_output_exp5 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp5/NewResults/TestPositiveCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_positives_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 146, Negatives = 8
# Model 2: Positives = 144, Negatives = 10
# Model 3: Positives = 144, Negatives = 10
# Model 4: Positives = 146, Negatives = 8
# Model 5: Positives = 144, Negatives = 10
# Model 6: Positives = 146, Negatives = 8
# Model 7: Positives = 144, Negatives = 10
# Model 8: Positives = 144, Negatives = 10
# Model 9: Positives = 146, Negatives = 8
# Model 10: Positives = 144, Negatives = 10
# Model 11: Positives = 147, Negatives = 7
# Model 12: Positives = 147, Negatives = 7
# Model 13: Positives = 147, Negatives = 7
# Model 14: Positives = 146, Negatives = 8
# Model 15: Positives = 145, Negatives = 9
# Model 16: Positives = 144, Negatives = 10
# Model 17: Positives = 147, Negatives = 7
# Model 18: Positives = 146, Negatives = 8
# Model 19: Positives = 146, Negatives = 8
# Model 20: Positives = 147, Negatives = 7
# Model 21: Positives = 145, Negatives = 9
# Model 22: Positives = 144, Negatives = 10
# Model 23: Positives = 143, Negatives = 11
# Model 24: Positives = 144, Negatives = 10
# Model 25: Positives = 147, Negatives = 7
# Model 26: Positives = 146, Negatives = 8
# Model 27: Positives = 148, Negatives = 6
# Model 28: Positives = 143, Negatives = 11
# Model 29: Positives = 147, Negatives = 7
# Model 30: Positives = 146, Negatives = 8
# Model 31: Positives = 144, Negatives = 10
# Model 32: Positives = 142, Negatives = 12
# Model 33: Positives = 141, Negatives = 13
# Model 34: Positives = 148, Negatives = 6
# Model 35: Positives = 145, Negatives = 9
# Model 36: Positives = 144, Negatives = 10
# Model 37: Positives = 142, Negatives = 12
# Model 38: Positives = 146, Negatives = 8
# Model 39: Positives = 146, Negatives = 8
# Model 40: Positives = 146, Negatives = 8
# Model 41: Positives = 147, Negatives = 7
# Model 42: Positives = 144, Negatives = 10
# Model 43: Positives = 143, Negatives = 11
# Model 44: Positives = 142, Negatives = 12
# Model 45: Positives = 148, Negatives = 6
# Model 46: Positives = 145, Negatives = 9
# Model 47: Positives = 146, Negatives = 8
# Model 48: Positives = 146, Negatives = 8
# Model 49: Positives = 143, Negatives = 11
# Model 50: Positives = 146, Negatives = 8
# Overlapping Capture Rate is 0.8748568219277858
#
# Model Predictions Summary:
# Model 1: Positives = 144, Negatives = 10
# Model 2: Positives = 148, Negatives = 6
# Model 3: Positives = 146, Negatives = 8
# Model 4: Positives = 145, Negatives = 9
# Model 5: Positives = 146, Negatives = 8
# Model 6: Positives = 145, Negatives = 9
# Model 7: Positives = 147, Negatives = 7
# Model 8: Positives = 146, Negatives = 8
# Model 9: Positives = 147, Negatives = 7
# Model 10: Positives = 143, Negatives = 11
# Model 11: Positives = 146, Negatives = 8
# Model 12: Positives = 146, Negatives = 8
# Model 13: Positives = 147, Negatives = 7
# Model 14: Positives = 146, Negatives = 8
# Model 15: Positives = 144, Negatives = 10
# Model 16: Positives = 145, Negatives = 9
# Model 17: Positives = 145, Negatives = 9
# Model 18: Positives = 143, Negatives = 11
# Model 19: Positives = 148, Negatives = 6
# Model 20: Positives = 146, Negatives = 8
# Model 21: Positives = 146, Negatives = 8
# Model 22: Positives = 146, Negatives = 8
# Model 23: Positives = 147, Negatives = 7
# Model 24: Positives = 145, Negatives = 9
# Model 25: Positives = 147, Negatives = 7
# Model 26: Positives = 146, Negatives = 8
# Model 27: Positives = 146, Negatives = 8
# Model 28: Positives = 145, Negatives = 9
# Model 29: Positives = 146, Negatives = 8
# Model 30: Positives = 145, Negatives = 9
# Model 31: Positives = 145, Negatives = 9
# Model 32: Positives = 142, Negatives = 12
# Model 33: Positives = 146, Negatives = 8
# Model 34: Positives = 145, Negatives = 9
# Model 35: Positives = 147, Negatives = 7
# Model 36: Positives = 146, Negatives = 8
# Model 37: Positives = 145, Negatives = 9
# Model 38: Positives = 145, Negatives = 9
# Model 39: Positives = 145, Negatives = 9
# Model 40: Positives = 143, Negatives = 11
# Model 41: Positives = 145, Negatives = 9
# Model 42: Positives = 146, Negatives = 8
# Model 43: Positives = 146, Negatives = 8
# Model 44: Positives = 145, Negatives = 9
# Model 45: Positives = 145, Negatives = 9
# Model 46: Positives = 148, Negatives = 6
# Model 47: Positives = 146, Negatives = 8
# Model 48: Positives = 146, Negatives = 8
# Model 49: Positives = 146, Negatives = 8
# Model 50: Positives = 145, Negatives = 9
# Overlapping Capture Rate is 0.8704416118488757
#
# Model Predictions Summary:
# Model 1: Positives = 134, Negatives = 20
# Model 2: Positives = 138, Negatives = 16
# Model 3: Positives = 134, Negatives = 20
# Model 4: Positives = 135, Negatives = 19
# Model 5: Positives = 136, Negatives = 18
# Model 6: Positives = 139, Negatives = 15
# Model 7: Positives = 137, Negatives = 17
# Model 8: Positives = 134, Negatives = 20
# Model 9: Positives = 137, Negatives = 17
# Model 10: Positives = 136, Negatives = 18
# Model 11: Positives = 134, Negatives = 20
# Model 12: Positives = 137, Negatives = 17
# Model 13: Positives = 134, Negatives = 20
# Model 14: Positives = 136, Negatives = 18
# Model 15: Positives = 135, Negatives = 19
# Model 16: Positives = 131, Negatives = 23
# Model 17: Positives = 136, Negatives = 18
# Model 18: Positives = 133, Negatives = 21
# Model 19: Positives = 139, Negatives = 15
# Model 20: Positives = 132, Negatives = 22
# Model 21: Positives = 136, Negatives = 18
# Model 22: Positives = 135, Negatives = 19
# Model 23: Positives = 139, Negatives = 15
# Model 24: Positives = 136, Negatives = 18
# Model 25: Positives = 137, Negatives = 17
# Model 26: Positives = 135, Negatives = 19
# Model 27: Positives = 136, Negatives = 18
# Model 28: Positives = 135, Negatives = 19
# Model 29: Positives = 134, Negatives = 20
# Model 30: Positives = 133, Negatives = 21
# Model 31: Positives = 135, Negatives = 19
# Model 32: Positives = 138, Negatives = 16
# Model 33: Positives = 131, Negatives = 23
# Model 34: Positives = 134, Negatives = 20
# Model 35: Positives = 137, Negatives = 17
# Model 36: Positives = 141, Negatives = 13
# Model 37: Positives = 130, Negatives = 24
# Model 38: Positives = 135, Negatives = 19
# Model 39: Positives = 138, Negatives = 16
# Model 40: Positives = 133, Negatives = 21
# Model 41: Positives = 134, Negatives = 20
# Model 42: Positives = 138, Negatives = 16
# Model 43: Positives = 135, Negatives = 19
# Model 44: Positives = 138, Negatives = 16
# Model 45: Positives = 136, Negatives = 18
# Model 46: Positives = 135, Negatives = 19
# Model 47: Positives = 137, Negatives = 17
# Model 48: Positives = 134, Negatives = 20
# Model 49: Positives = 135, Negatives = 19
# Model 50: Positives = 133, Negatives = 21
# Overlapping Capture Rate is 0.8178567583337892
#
# Model Predictions Summary:
# Model 1: Positives = 143, Negatives = 11
# Model 2: Positives = 142, Negatives = 12
# Model 3: Positives = 147, Negatives = 7
# Model 4: Positives = 136, Negatives = 18
# Model 5: Positives = 145, Negatives = 9
# Model 6: Positives = 142, Negatives = 12
# Model 7: Positives = 137, Negatives = 17
# Model 8: Positives = 146, Negatives = 8
# Model 9: Positives = 142, Negatives = 12
# Model 10: Positives = 144, Negatives = 10
# Model 11: Positives = 142, Negatives = 12
# Model 12: Positives = 141, Negatives = 13
# Model 13: Positives = 142, Negatives = 12
# Model 14: Positives = 144, Negatives = 10
# Model 15: Positives = 141, Negatives = 13
# Model 16: Positives = 145, Negatives = 9
# Model 17: Positives = 140, Negatives = 14
# Model 18: Positives = 144, Negatives = 10
# Model 19: Positives = 143, Negatives = 11
# Model 20: Positives = 138, Negatives = 16
# Model 21: Positives = 144, Negatives = 10
# Model 22: Positives = 136, Negatives = 18
# Model 23: Positives = 145, Negatives = 9
# Model 24: Positives = 142, Negatives = 12
# Model 25: Positives = 142, Negatives = 12
# Model 26: Positives = 142, Negatives = 12
# Model 27: Positives = 145, Negatives = 9
# Model 28: Positives = 141, Negatives = 13
# Model 29: Positives = 139, Negatives = 15
# Model 30: Positives = 145, Negatives = 9
# Model 31: Positives = 142, Negatives = 12
# Model 32: Positives = 140, Negatives = 14
# Model 33: Positives = 142, Negatives = 12
# Model 34: Positives = 145, Negatives = 9
# Model 35: Positives = 141, Negatives = 13
# Model 36: Positives = 140, Negatives = 14
# Model 37: Positives = 141, Negatives = 13
# Model 38: Positives = 143, Negatives = 11
# Model 39: Positives = 145, Negatives = 9
# Model 40: Positives = 140, Negatives = 14
# Model 41: Positives = 142, Negatives = 12
# Model 42: Positives = 146, Negatives = 8
# Model 43: Positives = 142, Negatives = 12
# Model 44: Positives = 140, Negatives = 14
# Model 45: Positives = 143, Negatives = 11
# Model 46: Positives = 143, Negatives = 11
# Model 47: Positives = 143, Negatives = 11
# Model 48: Positives = 139, Negatives = 15
# Model 49: Positives = 142, Negatives = 12
# Model 50: Positives = 141, Negatives = 13
# Overlapping Capture Rate is 0.859936587231207
#
# Model Predictions Summary:
# Model 1: Positives = 139, Negatives = 15
# Model 2: Positives = 143, Negatives = 11
# Model 3: Positives = 141, Negatives = 13
# Model 4: Positives = 146, Negatives = 8
# Model 5: Positives = 146, Negatives = 8
# Model 6: Positives = 144, Negatives = 10
# Model 7: Positives = 148, Negatives = 6
# Model 8: Positives = 142, Negatives = 12
# Model 9: Positives = 146, Negatives = 8
# Model 10: Positives = 144, Negatives = 10
# Model 11: Positives = 141, Negatives = 13
# Model 12: Positives = 144, Negatives = 10
# Model 13: Positives = 144, Negatives = 10
# Model 14: Positives = 138, Negatives = 16
# Model 15: Positives = 138, Negatives = 16
# Model 16: Positives = 145, Negatives = 9
# Model 17: Positives = 140, Negatives = 14
# Model 18: Positives = 144, Negatives = 10
# Model 19: Positives = 141, Negatives = 13
# Model 20: Positives = 140, Negatives = 14
# Model 21: Positives = 145, Negatives = 9
# Model 22: Positives = 140, Negatives = 14
# Model 23: Positives = 149, Negatives = 5
# Model 24: Positives = 145, Negatives = 9
# Model 25: Positives = 139, Negatives = 15
# Model 26: Positives = 144, Negatives = 10
# Model 27: Positives = 141, Negatives = 13
# Model 28: Positives = 146, Negatives = 8
# Model 29: Positives = 140, Negatives = 14
# Model 30: Positives = 143, Negatives = 11
# Model 31: Positives = 146, Negatives = 8
# Model 32: Positives = 145, Negatives = 9
# Model 33: Positives = 143, Negatives = 11
# Model 34: Positives = 140, Negatives = 14
# Model 35: Positives = 142, Negatives = 12
# Model 36: Positives = 144, Negatives = 10
# Model 37: Positives = 147, Negatives = 7
# Model 38: Positives = 142, Negatives = 12
# Model 39: Positives = 142, Negatives = 12
# Model 40: Positives = 142, Negatives = 12
# Model 41: Positives = 143, Negatives = 11
# Model 42: Positives = 142, Negatives = 12
# Model 43: Positives = 140, Negatives = 14
# Model 44: Positives = 145, Negatives = 9
# Model 45: Positives = 142, Negatives = 12
# Model 46: Positives = 136, Negatives = 18
# Model 47: Positives = 140, Negatives = 14
# Model 48: Positives = 140, Negatives = 14
# Model 49: Positives = 141, Negatives = 13
# Model 50: Positives = 141, Negatives = 13
# Overlapping Capture Rate is 0.8598165087329299

# %%
def apply_labeling_from_spies(csv, mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    def get_min_max_label(score):
        if score < min_score:
            return "StrongNegative"
        elif min_score <= score < mean_score:
            return "PseudoNegative"
        elif mean_score <= score < max_score:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df["min_max_label"] = df["average_score"].apply(get_min_max_label)

    def get_percentile_label(score):
        if score < percentile_25:
            return "StrongNegative"
        elif percentile_25 <= score < percentile_50:
            return "PseudoNegative"
        elif percentile_50 <= score < percentile_75:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df["percentile_label"] = df["average_score"].apply(get_percentile_label)
    df["threshold_label"] = df["average_score"].apply(lambda x: "Negative" if x < 0.5 else "Positive")

    min_max_results = []
    min_max_results.append((df["average_score"] < min_score).sum()) # min_max_strong_negative_count
    min_max_results.append(((df["average_score"] > min_score) & (df["average_score"] < mean_score)).sum()) # min_max_pseudo_negative_count
    min_max_results.append(((df["average_score"] > mean_score) & (df["average_score"] < max_score)).sum()) # min_max_pseudo_positive_count
    min_max_results.append((df["average_score"] > max_score).sum()) # min_max_strong_positive_count

    percentile_results = []
    percentile_results.append((df["average_score"] < percentile_25).sum()) # percentile_strong_negative_count
    percentile_results.append(((df["average_score"] > percentile_25) & (df["average_score"] < percentile_50)).sum()) # percentile_pseudo_negative_count
    percentile_results.append(((df["average_score"] > percentile_50) & (df["average_score"] < percentile_75)).sum()) # percentile_pseudo_positive_count
    percentile_results.append((df["average_score"] > percentile_75).sum()) # percentile_strong_positive_count

    threshold_results = []
    threshold_results.append((df["average_score"] < 0.5).sum()) # threshold_negative_count
    threshold_results.append((df["average_score"] > 0.5).sum()) # threshold_positive_count

    # Table 1: Min/Max and Percentile
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    minmax_percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Min_Max (Using Mean)": min_max_results,
        "Percentile (75-50-25)": percentile_results
    })

    # Table 2: Threshold 0.5
    labels_2 = ["Negative", "Positive"]
    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold (0.5)": threshold_results
    })

    print(minmax_percentile_df,"\n", threshold_df)

    df.to_csv(csv, index=False)

    return min_max_results, percentile_results, threshold_results

def show_evaluation_results(min_max_all, percentile_all, threshold_all):
    # Compute mean and std for each label
    min_max_mean = np.mean(min_max_all, axis=0)
    min_max_std = np.std(min_max_all, axis=0)

    percentile_mean = np.mean(percentile_all, axis=0)
    percentile_std = np.std(percentile_all, axis=0)

    threshold_mean = np.mean(threshold_all, axis=0)
    threshold_std = np.std(threshold_all, axis=0)

    # Create DataFrames to display
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    labels_2 = ["Negative", "Positive"]

    min_max_df = pd.DataFrame({
        "Label": labels_4,
        "Min-Max Mean": min_max_mean,
        "Min-Max Std": min_max_std
    })

    percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Percentile Mean": percentile_mean,
        "Percentile Std": percentile_std
    })

    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold Mean": threshold_mean,
        "Threshold Std": threshold_std
    })

    # Display
    print("=== Min-Max Results ===")
    print(min_max_df)
    print("\n=== Percentile Results ===")
    print(percentile_df)
    print("\n=== Threshold Results ===")
    print(threshold_df)

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     13
# 1  PseudoNegative                    16                      5
# 2  PseudoPositive                    94                      7
# 3  StrongPositive                    44                    129
#        Label  Threshold (0.5)
# 0  Negative                8
# 1  Positive              146
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     3                     14
# 1  PseudoNegative                    13                      8
# 2  PseudoPositive                   113                     11
# 3  StrongPositive                    25                    121
#        Label  Threshold (0.5)
# 0  Negative                7
# 1  Positive              147
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     26
# 1  PseudoNegative                    29                      7
# 2  PseudoPositive                    74                     12
# 3  StrongPositive                    50                    109
#        Label  Threshold (0.5)
# 0  Negative               16
# 1  Positive              138
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     17
# 1  PseudoNegative                    19                      4
# 2  PseudoPositive                    81                     10
# 3  StrongPositive                    54                    123
#        Label  Threshold (0.5)
# 0  Negative                8
# 1  Positive              146
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     20
# 1  PseudoNegative                    20                      5
# 2  PseudoPositive                    85                     10
# 3  StrongPositive                    49                    119
#        Label  Threshold (0.5)
# 0  Negative               10
# 1  Positive              144
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           0.8     1.166190
# 1  PseudoNegative          19.4     5.388877
# 2  PseudoPositive          89.4    13.455111
# 3  StrongPositive          44.4    10.209799
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative             18.0        4.690416
# 1  PseudoNegative              5.8        1.469694
# 2  PseudoPositive             10.0        1.673320
# 3  StrongPositive            120.2        6.523803
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative             9.8       3.249615
# 1  Positive           144.2       3.249615

# %%
test_unlabeled_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A/Test/CombinedUnlabeled"  
csv_output_exp1 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp1/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp1, csv_output_exp1, models_exp1)

test_unlabeled_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp2/Test/CombinedUnlabeled"  
csv_output_exp2 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp2/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp2, csv_output_exp2, models_exp2)

test_unlabeled_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp3/Test/CombinedUnlabeled"  
csv_output_exp3 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp3/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp3, csv_output_exp3, models_exp3)

test_unlabeled_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp4/Test/CombinedUnlabeled"  
csv_output_exp4 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp4/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp4, csv_output_exp4, models_exp4)

test_unlabeled_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/CombinedUnlabeled"  
csv_output_exp5 = "../../../Models/Cholesterol/GNN/GNN-5A_Exp5/NewResults/TestUnlabeledCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_unlabeled_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 291, Negatives = 632
# Model 2: Positives = 279, Negatives = 644
# Model 3: Positives = 306, Negatives = 617
# Model 4: Positives = 275, Negatives = 648
# Model 5: Positives = 303, Negatives = 620
# Model 6: Positives = 312, Negatives = 611
# Model 7: Positives = 291, Negatives = 632
# Model 8: Positives = 278, Negatives = 645
# Model 9: Positives = 296, Negatives = 627
# Model 10: Positives = 327, Negatives = 596
# Model 11: Positives = 316, Negatives = 607
# Model 12: Positives = 326, Negatives = 597
# Model 13: Positives = 297, Negatives = 626
# Model 14: Positives = 275, Negatives = 648
# Model 15: Positives = 285, Negatives = 638
# Model 16: Positives = 319, Negatives = 604
# Model 17: Positives = 292, Negatives = 631
# Model 18: Positives = 299, Negatives = 624
# Model 19: Positives = 306, Negatives = 617
# Model 20: Positives = 299, Negatives = 624
# Model 21: Positives = 310, Negatives = 613
# Model 22: Positives = 274, Negatives = 649
# Model 23: Positives = 310, Negatives = 613
# Model 24: Positives = 280, Negatives = 643
# Model 25: Positives = 274, Negatives = 649
# Model 26: Positives = 297, Negatives = 626
# Model 27: Positives = 307, Negatives = 616
# Model 28: Positives = 308, Negatives = 615
# Model 29: Positives = 312, Negatives = 611
# Model 30: Positives = 303, Negatives = 620
# Model 31: Positives = 278, Negatives = 645
# Model 32: Positives = 277, Negatives = 646
# Model 33: Positives = 300, Negatives = 623
# Model 34: Positives = 266, Negatives = 657
# Model 35: Positives = 285, Negatives = 638
# Model 36: Positives = 292, Negatives = 631
# Model 37: Positives = 302, Negatives = 621
# Model 38: Positives = 296, Negatives = 627
# Model 39: Positives = 293, Negatives = 630
# Model 40: Positives = 288, Negatives = 635
# Model 41: Positives = 316, Negatives = 607
# Model 42: Positives = 277, Negatives = 646
# Model 43: Positives = 269, Negatives = 654
# Model 44: Positives = 257, Negatives = 666
# Model 45: Positives = 308, Negatives = 615
# Model 46: Positives = 283, Negatives = 640
# Model 47: Positives = 288, Negatives = 635
# Model 48: Positives = 307, Negatives = 616
# Model 49: Positives = 274, Negatives = 649
# Model 50: Positives = 279, Negatives = 644
# Overlapping Capture Rate is 0.31409405665643053
#
# Model Predictions Summary:
# Model 1: Positives = 303, Negatives = 620
# Model 2: Positives = 294, Negatives = 629
# Model 3: Positives = 290, Negatives = 633
# Model 4: Positives = 318, Negatives = 605
# Model 5: Positives = 283, Negatives = 640
# Model 6: Positives = 298, Negatives = 625
# Model 7: Positives = 320, Negatives = 603
# Model 8: Positives = 297, Negatives = 626
# Model 9: Positives = 335, Negatives = 588
# Model 10: Positives = 303, Negatives = 620
# Model 11: Positives = 311, Negatives = 612
# Model 12: Positives = 336, Negatives = 587
# Model 13: Positives = 314, Negatives = 609
# Model 14: Positives = 288, Negatives = 635
# Model 15: Positives = 275, Negatives = 648
# Model 16: Positives = 314, Negatives = 609
# Model 17: Positives = 336, Negatives = 587
# Model 18: Positives = 285, Negatives = 638
# Model 19: Positives = 296, Negatives = 627
# Model 20: Positives = 311, Negatives = 612
# Model 21: Positives = 279, Negatives = 644
# Model 22: Positives = 303, Negatives = 620
# Model 23: Positives = 312, Negatives = 611
# Model 24: Positives = 288, Negatives = 635
# Model 25: Positives = 316, Negatives = 607
# Model 26: Positives = 309, Negatives = 614
# Model 27: Positives = 306, Negatives = 617
# Model 28: Positives = 296, Negatives = 627
# Model 29: Positives = 286, Negatives = 637
# Model 30: Positives = 282, Negatives = 641
# Model 31: Positives = 297, Negatives = 626
# Model 32: Positives = 336, Negatives = 587
# Model 33: Positives = 305, Negatives = 618
# Model 34: Positives = 307, Negatives = 616
# Model 35: Positives = 286, Negatives = 637
# Model 36: Positives = 277, Negatives = 646
# Model 37: Positives = 305, Negatives = 618
# Model 38: Positives = 300, Negatives = 623
# Model 39: Positives = 288, Negatives = 635
# Model 40: Positives = 318, Negatives = 605
# Model 41: Positives = 286, Negatives = 637
# Model 42: Positives = 301, Negatives = 622
# Model 43: Positives = 301, Negatives = 622
# Model 44: Positives = 301, Negatives = 622
# Model 45: Positives = 279, Negatives = 644
# Model 46: Positives = 297, Negatives = 626
# Model 47: Positives = 293, Negatives = 630
# Model 48: Positives = 324, Negatives = 599
# Model 49: Positives = 305, Negatives = 618
# Model 50: Positives = 283, Negatives = 640
# Overlapping Capture Rate is 0.32377704576154404
#
# Model Predictions Summary:
# Model 1: Positives = 291, Negatives = 632
# Model 2: Positives = 284, Negatives = 639
# Model 3: Positives = 303, Negatives = 620
# Model 4: Positives = 297, Negatives = 626
# Model 5: Positives = 302, Negatives = 621
# Model 6: Positives = 294, Negatives = 629
# Model 7: Positives = 280, Negatives = 643
# Model 8: Positives = 312, Negatives = 611
# Model 9: Positives = 294, Negatives = 629
# Model 10: Positives = 279, Negatives = 644
# Model 11: Positives = 277, Negatives = 646
# Model 12: Positives = 267, Negatives = 656
# Model 13: Positives = 282, Negatives = 641
# Model 14: Positives = 275, Negatives = 648
# Model 15: Positives = 300, Negatives = 623
# Model 16: Positives = 292, Negatives = 631
# Model 17: Positives = 262, Negatives = 661
# Model 18: Positives = 282, Negatives = 641
# Model 19: Positives = 282, Negatives = 641
# Model 20: Positives = 289, Negatives = 634
# Model 21: Positives = 258, Negatives = 665
# Model 22: Positives = 293, Negatives = 630
# Model 23: Positives = 286, Negatives = 637
# Model 24: Positives = 289, Negatives = 634
# Model 25: Positives = 269, Negatives = 654
# Model 26: Positives = 288, Negatives = 635
# Model 27: Positives = 305, Negatives = 618
# Model 28: Positives = 277, Negatives = 646
# Model 29: Positives = 263, Negatives = 660
# Model 30: Positives = 298, Negatives = 625
# Model 31: Positives = 286, Negatives = 637
# Model 32: Positives = 282, Negatives = 641
# Model 33: Positives = 296, Negatives = 627
# Model 34: Positives = 278, Negatives = 645
# Model 35: Positives = 288, Negatives = 635
# Model 36: Positives = 304, Negatives = 619
# Model 37: Positives = 257, Negatives = 666
# Model 38: Positives = 276, Negatives = 647
# Model 39: Positives = 283, Negatives = 640
# Model 40: Positives = 283, Negatives = 640
# Model 41: Positives = 284, Negatives = 639
# Model 42: Positives = 272, Negatives = 651
# Model 43: Positives = 288, Negatives = 635
# Model 44: Positives = 293, Negatives = 630
# Model 45: Positives = 277, Negatives = 646
# Model 46: Positives = 285, Negatives = 638
# Model 47: Positives = 292, Negatives = 631
# Model 48: Positives = 307, Negatives = 616
# Model 49: Positives = 302, Negatives = 621
# Model 50: Positives = 284, Negatives = 639
# Overlapping Capture Rate is 0.3059497974635499
#
# Model Predictions Summary:
# Model 1: Positives = 276, Negatives = 647
# Model 2: Positives = 271, Negatives = 652
# Model 3: Positives = 279, Negatives = 644
# Model 4: Positives = 292, Negatives = 631
# Model 5: Positives = 254, Negatives = 669
# Model 6: Positives = 282, Negatives = 641
# Model 7: Positives = 268, Negatives = 655
# Model 8: Positives = 281, Negatives = 642
# Model 9: Positives = 287, Negatives = 636
# Model 10: Positives = 272, Negatives = 651
# Model 11: Positives = 282, Negatives = 641
# Model 12: Positives = 294, Negatives = 629
# Model 13: Positives = 256, Negatives = 667
# Model 14: Positives = 253, Negatives = 670
# Model 15: Positives = 254, Negatives = 669
# Model 16: Positives = 262, Negatives = 661
# Model 17: Positives = 296, Negatives = 627
# Model 18: Positives = 289, Negatives = 634
# Model 19: Positives = 291, Negatives = 632
# Model 20: Positives = 291, Negatives = 632
# Model 21: Positives = 282, Negatives = 641
# Model 22: Positives = 261, Negatives = 662
# Model 23: Positives = 300, Negatives = 623
# Model 24: Positives = 294, Negatives = 629
# Model 25: Positives = 247, Negatives = 676
# Model 26: Positives = 256, Negatives = 667
# Model 27: Positives = 280, Negatives = 643
# Model 28: Positives = 259, Negatives = 664
# Model 29: Positives = 271, Negatives = 652
# Model 30: Positives = 253, Negatives = 670
# Model 31: Positives = 276, Negatives = 647
# Model 32: Positives = 285, Negatives = 638
# Model 33: Positives = 306, Negatives = 617
# Model 34: Positives = 291, Negatives = 632
# Model 35: Positives = 289, Negatives = 634
# Model 36: Positives = 267, Negatives = 656
# Model 37: Positives = 289, Negatives = 634
# Model 38: Positives = 281, Negatives = 642
# Model 39: Positives = 284, Negatives = 639
# Model 40: Positives = 272, Negatives = 651
# Model 41: Positives = 298, Negatives = 625
# Model 42: Positives = 283, Negatives = 640
# Model 43: Positives = 268, Negatives = 655
# Model 44: Positives = 277, Negatives = 646
# Model 45: Positives = 300, Negatives = 623
# Model 46: Positives = 261, Negatives = 662
# Model 47: Positives = 282, Negatives = 641
# Model 48: Positives = 262, Negatives = 661
# Model 49: Positives = 281, Negatives = 642
# Model 50: Positives = 252, Negatives = 671
# Overlapping Capture Rate is 0.2990905335428217
#
# Model Predictions Summary:
# Model 1: Positives = 283, Negatives = 640
# Model 2: Positives = 263, Negatives = 660
# Model 3: Positives = 274, Negatives = 649
# Model 4: Positives = 281, Negatives = 642
# Model 5: Positives = 271, Negatives = 652
# Model 6: Positives = 284, Negatives = 639
# Model 7: Positives = 273, Negatives = 650
# Model 8: Positives = 294, Negatives = 629
# Model 9: Positives = 289, Negatives = 634
# Model 10: Positives = 264, Negatives = 659
# Model 11: Positives = 272, Negatives = 651
# Model 12: Positives = 277, Negatives = 646
# Model 13: Positives = 288, Negatives = 635
# Model 14: Positives = 251, Negatives = 672
# Model 15: Positives = 259, Negatives = 664
# Model 16: Positives = 251, Negatives = 672
# Model 17: Positives = 262, Negatives = 661
# Model 18: Positives = 285, Negatives = 638
# Model 19: Positives = 258, Negatives = 665
# Model 20: Positives = 267, Negatives = 656
# Model 21: Positives = 273, Negatives = 650
# Model 22: Positives = 276, Negatives = 647
# Model 23: Positives = 278, Negatives = 645
# Model 24: Positives = 299, Negatives = 624
# Model 25: Positives = 261, Negatives = 662
# Model 26: Positives = 268, Negatives = 655
# Model 27: Positives = 268, Negatives = 655
# Model 28: Positives = 270, Negatives = 653
# Model 29: Positives = 286, Negatives = 637
# Model 30: Positives = 273, Negatives = 650
# Model 31: Positives = 272, Negatives = 651
# Model 32: Positives = 289, Negatives = 634
# Model 33: Positives = 319, Negatives = 604
# Model 34: Positives = 257, Negatives = 666
# Model 35: Positives = 270, Negatives = 653
# Model 36: Positives = 272, Negatives = 651
# Model 37: Positives = 281, Negatives = 642
# Model 38: Positives = 264, Negatives = 659
# Model 39: Positives = 280, Negatives = 643
# Model 40: Positives = 287, Negatives = 636
# Model 41: Positives = 258, Negatives = 665
# Model 42: Positives = 267, Negatives = 656
# Model 43: Positives = 286, Negatives = 637
# Model 44: Positives = 265, Negatives = 658
# Model 45: Positives = 288, Negatives = 635
# Model 46: Positives = 274, Negatives = 649
# Model 47: Positives = 278, Negatives = 645
# Model 48: Positives = 286, Negatives = 637
# Model 49: Positives = 271, Negatives = 652
# Model 50: Positives = 263, Negatives = 660
# Overlapping Capture Rate is 0.29715565583898373

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   314                    691
# 1  PseudoNegative                   398                     44
# 2  PseudoPositive                   188                     46
# 3  StrongPositive                    23                    142
#        Label  Threshold (0.5)
# 0  Negative              626
# 1  Positive              297
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   417                    720
# 1  PseudoNegative                   314                     37
# 2  PseudoPositive                   182                     43
# 3  StrongPositive                    10                    123
#        Label  Threshold (0.5)
# 0  Negative              621
# 1  Positive              302
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   341                    705
# 1  PseudoNegative                   389                     59
# 2  PseudoPositive                   162                     43
# 3  StrongPositive                    31                    116
#        Label  Threshold (0.5)
# 0  Negative              635
# 1  Positive              288
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                    60                    703
# 1  PseudoNegative                   659                     35
# 2  PseudoPositive                   158                     27
# 3  StrongPositive                    46                    158
#        Label  Threshold (0.5)
# 0  Negative              648
# 1  Positive              275
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                    71                    700
# 1  PseudoNegative                   653                     48
# 2  PseudoPositive                   165                     35
# 3  StrongPositive                    34                    140
#        Label  Threshold (0.5)
# 0  Negative              652
# 1  Positive              271
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative         240.6   146.945704
# 1  PseudoNegative         482.6   144.566386
# 2  PseudoPositive         171.0    11.798305
# 3  StrongPositive          28.8    11.956588
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative            703.8        9.410632
# 1  PseudoNegative             44.6        8.593020
# 2  PseudoPositive             38.8        6.939741
# 3  StrongPositive            135.8       14.864723
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative           636.4      12.043255
# 1  Positive           286.6      12.043255

# %%
test_ivan_exp1 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive"  
csv_output_exp1 = "GNN-5A_Exp1/Results/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp1, csv_output_exp1, models_exp1)

test_ivan_exp2 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive"  
csv_output_exp2 = "GNN-5A_Exp2/Results/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp2, csv_output_exp2, models_exp2)

test_ivan_exp3 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive"  
csv_output_exp3 = "GNN-5A_Exp3/Results/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp3, csv_output_exp3, models_exp3)

test_ivan_exp4 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive"  
csv_output_exp4 = "GNN-5A_Exp4/Results/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp4, csv_output_exp4, models_exp4)

test_ivan_exp5 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive"  
csv_output_exp5 = "GNN-5A_Exp5/Results/TestIvanCaptureRates.csv"

spy_capture_rate = evaluate_directory(test_ivan_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 53, Negatives = 4
# Model 2: Positives = 53, Negatives = 4
# Model 3: Positives = 51, Negatives = 6
# Model 4: Positives = 53, Negatives = 4
# Model 5: Positives = 53, Negatives = 4
# Model 6: Positives = 55, Negatives = 2
# Model 7: Positives = 55, Negatives = 2
# Model 8: Positives = 54, Negatives = 3
# Model 9: Positives = 54, Negatives = 3
# Model 10: Positives = 55, Negatives = 2
# Model 11: Positives = 52, Negatives = 5
# Model 12: Positives = 53, Negatives = 4
# Model 13: Positives = 53, Negatives = 4
# Model 14: Positives = 53, Negatives = 4
# Model 15: Positives = 53, Negatives = 4
# Model 16: Positives = 53, Negatives = 4
# Model 17: Positives = 54, Negatives = 3
# Model 18: Positives = 51, Negatives = 6
# Model 19: Positives = 55, Negatives = 2
# Model 20: Positives = 53, Negatives = 4
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 52, Negatives = 5
# Model 23: Positives = 51, Negatives = 6
# Model 24: Positives = 55, Negatives = 2
# Model 25: Positives = 53, Negatives = 4
# Model 26: Positives = 52, Negatives = 5
# Model 27: Positives = 54, Negatives = 3
# Model 28: Positives = 54, Negatives = 3
# Model 29: Positives = 55, Negatives = 2
# Model 30: Positives = 54, Negatives = 3
# Model 31: Positives = 54, Negatives = 3
# Model 32: Positives = 52, Negatives = 5
# Model 33: Positives = 55, Negatives = 2
# Model 34: Positives = 52, Negatives = 5
# Model 35: Positives = 53, Negatives = 4
# Model 36: Positives = 52, Negatives = 5
# Model 37: Positives = 55, Negatives = 2
# Model 38: Positives = 52, Negatives = 5
# Model 39: Positives = 54, Negatives = 3
# Model 40: Positives = 52, Negatives = 5
# Model 41: Positives = 54, Negatives = 3
# Model 42: Positives = 51, Negatives = 6
# Model 43: Positives = 55, Negatives = 2
# Model 44: Positives = 55, Negatives = 2
# Model 45: Positives = 54, Negatives = 3
# Model 46: Positives = 53, Negatives = 4
# Model 47: Positives = 54, Negatives = 3
# Model 48: Positives = 54, Negatives = 3
# Model 49: Positives = 51, Negatives = 6
# Model 50: Positives = 53, Negatives = 4
# Overlapping Capture Rate is 0.8362539086046447
#
# Model Predictions Summary:
# Model 1: Positives = 51, Negatives = 6
# Model 2: Positives = 54, Negatives = 3
# Model 3: Positives = 52, Negatives = 5
# Model 4: Positives = 54, Negatives = 3
# Model 5: Positives = 53, Negatives = 4
# Model 6: Positives = 54, Negatives = 3
# Model 7: Positives = 53, Negatives = 4
# Model 8: Positives = 54, Negatives = 3
# Model 9: Positives = 54, Negatives = 3
# Model 10: Positives = 50, Negatives = 7
# Model 11: Positives = 52, Negatives = 5
# Model 12: Positives = 54, Negatives = 3
# Model 13: Positives = 54, Negatives = 3
# Model 14: Positives = 54, Negatives = 3
# Model 15: Positives = 52, Negatives = 5
# Model 16: Positives = 53, Negatives = 4
# Model 17: Positives = 53, Negatives = 4
# Model 18: Positives = 53, Negatives = 4
# Model 19: Positives = 54, Negatives = 3
# Model 20: Positives = 55, Negatives = 2
# Model 21: Positives = 54, Negatives = 3
# Model 22: Positives = 54, Negatives = 3
# Model 23: Positives = 55, Negatives = 2
# Model 24: Positives = 51, Negatives = 6
# Model 25: Positives = 52, Negatives = 5
# Model 26: Positives = 54, Negatives = 3
# Model 27: Positives = 55, Negatives = 2
# Model 28: Positives = 50, Negatives = 7
# Model 29: Positives = 54, Negatives = 3
# Model 30: Positives = 54, Negatives = 3
# Model 31: Positives = 55, Negatives = 2
# Model 32: Positives = 54, Negatives = 3
# Model 33: Positives = 53, Negatives = 4
# Model 34: Positives = 53, Negatives = 4
# Model 35: Positives = 53, Negatives = 4
# Model 36: Positives = 54, Negatives = 3
# Model 37: Positives = 54, Negatives = 3
# Model 38: Positives = 55, Negatives = 2
# Model 39: Positives = 53, Negatives = 4
# Model 40: Positives = 55, Negatives = 2
# Model 41: Positives = 53, Negatives = 4
# Model 42: Positives = 54, Negatives = 3
# Model 43: Positives = 54, Negatives = 3
# Model 44: Positives = 53, Negatives = 4
# Model 45: Positives = 54, Negatives = 3
# Model 46: Positives = 54, Negatives = 3
# Model 47: Positives = 52, Negatives = 5
# Model 48: Positives = 55, Negatives = 2
# Model 49: Positives = 52, Negatives = 5
# Model 50: Positives = 52, Negatives = 5
# Overlapping Capture Rate is 0.8467835715729664
#
# Model Predictions Summary:
# Model 1: Positives = 54, Negatives = 3
# Model 2: Positives = 54, Negatives = 3
# Model 3: Positives = 52, Negatives = 5
# Model 4: Positives = 52, Negatives = 5
# Model 5: Positives = 54, Negatives = 3
# Model 6: Positives = 53, Negatives = 4
# Model 7: Positives = 52, Negatives = 5
# Model 8: Positives = 52, Negatives = 5
# Model 9: Positives = 54, Negatives = 3
# Model 10: Positives = 54, Negatives = 3
# Model 11: Positives = 53, Negatives = 4
# Model 12: Positives = 54, Negatives = 3
# Model 13: Positives = 52, Negatives = 5
# Model 14: Positives = 51, Negatives = 6
# Model 15: Positives = 55, Negatives = 2
# Model 16: Positives = 54, Negatives = 3
# Model 17: Positives = 52, Negatives = 5
# Model 18: Positives = 53, Negatives = 4
# Model 19: Positives = 53, Negatives = 4
# Model 20: Positives = 55, Negatives = 2
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 52, Negatives = 5
# Model 23: Positives = 54, Negatives = 3
# Model 24: Positives = 53, Negatives = 4
# Model 25: Positives = 53, Negatives = 4
# Model 26: Positives = 55, Negatives = 2
# Model 27: Positives = 54, Negatives = 3
# Model 28: Positives = 53, Negatives = 4
# Model 29: Positives = 52, Negatives = 5
# Model 30: Positives = 54, Negatives = 3
# Model 31: Positives = 51, Negatives = 6
# Model 32: Positives = 52, Negatives = 5
# Model 33: Positives = 54, Negatives = 3
# Model 34: Positives = 51, Negatives = 6
# Model 35: Positives = 53, Negatives = 4
# Model 36: Positives = 54, Negatives = 3
# Model 37: Positives = 54, Negatives = 3
# Model 38: Positives = 54, Negatives = 3
# Model 39: Positives = 54, Negatives = 3
# Model 40: Positives = 55, Negatives = 2
# Model 41: Positives = 52, Negatives = 5
# Model 42: Positives = 54, Negatives = 3
# Model 43: Positives = 53, Negatives = 4
# Model 44: Positives = 54, Negatives = 3
# Model 45: Positives = 50, Negatives = 7
# Model 46: Positives = 54, Negatives = 3
# Model 47: Positives = 54, Negatives = 3
# Model 48: Positives = 54, Negatives = 3
# Model 49: Positives = 55, Negatives = 2
# Model 50: Positives = 55, Negatives = 2
# Overlapping Capture Rate is 0.8426697974317914
#
# Model Predictions Summary:
# Model 1: Positives = 53, Negatives = 4
# Model 2: Positives = 52, Negatives = 5
# Model 3: Positives = 54, Negatives = 3
# Model 4: Positives = 53, Negatives = 4
# Model 5: Positives = 51, Negatives = 6
# Model 6: Positives = 54, Negatives = 3
# Model 7: Positives = 52, Negatives = 5
# Model 8: Positives = 54, Negatives = 3
# Model 9: Positives = 55, Negatives = 2
# Model 10: Positives = 52, Negatives = 5
# Model 11: Positives = 54, Negatives = 3
# Model 12: Positives = 54, Negatives = 3
# Model 13: Positives = 53, Negatives = 4
# Model 14: Positives = 51, Negatives = 6
# Model 15: Positives = 51, Negatives = 6
# Model 16: Positives = 52, Negatives = 5
# Model 17: Positives = 53, Negatives = 4
# Model 18: Positives = 55, Negatives = 2
# Model 19: Positives = 54, Negatives = 3
# Model 20: Positives = 52, Negatives = 5
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 52, Negatives = 5
# Model 23: Positives = 53, Negatives = 4
# Model 24: Positives = 53, Negatives = 4
# Model 25: Positives = 52, Negatives = 5
# Model 26: Positives = 53, Negatives = 4
# Model 27: Positives = 54, Negatives = 3
# Model 28: Positives = 54, Negatives = 3
# Model 29: Positives = 52, Negatives = 5
# Model 30: Positives = 53, Negatives = 4
# Model 31: Positives = 54, Negatives = 3
# Model 32: Positives = 54, Negatives = 3
# Model 33: Positives = 53, Negatives = 4
# Model 34: Positives = 53, Negatives = 4
# Model 35: Positives = 53, Negatives = 4
# Model 36: Positives = 53, Negatives = 4
# Model 37: Positives = 53, Negatives = 4
# Model 38: Positives = 52, Negatives = 5
# Model 39: Positives = 52, Negatives = 5
# Model 40: Positives = 53, Negatives = 4
# Model 41: Positives = 52, Negatives = 5
# Model 42: Positives = 53, Negatives = 4
# Model 43: Positives = 54, Negatives = 3
# Model 44: Positives = 52, Negatives = 5
# Model 45: Positives = 53, Negatives = 4
# Model 46: Positives = 53, Negatives = 4
# Model 47: Positives = 53, Negatives = 4
# Model 48: Positives = 50, Negatives = 7
# Model 49: Positives = 52, Negatives = 5
# Model 50: Positives = 52, Negatives = 5
# Overlapping Capture Rate is 0.8471244790198551
#
# Model Predictions Summary:
# Model 1: Positives = 53, Negatives = 4
# Model 2: Positives = 52, Negatives = 5
# Model 3: Positives = 52, Negatives = 5
# Model 4: Positives = 55, Negatives = 2
# Model 5: Positives = 53, Negatives = 4
# Model 6: Positives = 54, Negatives = 3
# Model 7: Positives = 52, Negatives = 5
# Model 8: Positives = 52, Negatives = 5
# Model 9: Positives = 52, Negatives = 5
# Model 10: Positives = 49, Negatives = 8
# Model 11: Positives = 53, Negatives = 4
# Model 12: Positives = 54, Negatives = 3
# Model 13: Positives = 55, Negatives = 2
# Model 14: Positives = 54, Negatives = 3
# Model 15: Positives = 54, Negatives = 3
# Model 16: Positives = 54, Negatives = 3
# Model 17: Positives = 54, Negatives = 3
# Model 18: Positives = 54, Negatives = 3
# Model 19: Positives = 53, Negatives = 4
# Model 20: Positives = 53, Negatives = 4
# Model 21: Positives = 51, Negatives = 6
# Model 22: Positives = 55, Negatives = 2
# Model 23: Positives = 53, Negatives = 4
# Model 24: Positives = 55, Negatives = 2
# Model 25: Positives = 52, Negatives = 5
# Model 26: Positives = 54, Negatives = 3
# Model 27: Positives = 50, Negatives = 7
# Model 28: Positives = 52, Negatives = 5
# Model 29: Positives = 51, Negatives = 6
# Model 30: Positives = 55, Negatives = 2
# Model 31: Positives = 53, Negatives = 4
# Model 32: Positives = 53, Negatives = 4
# Model 33: Positives = 55, Negatives = 2
# Model 34: Positives = 53, Negatives = 4
# Model 35: Positives = 51, Negatives = 6
# Model 36: Positives = 54, Negatives = 3
# Model 37: Positives = 55, Negatives = 2
# Model 38: Positives = 53, Negatives = 4
# Model 39: Positives = 52, Negatives = 5
# Model 40: Positives = 54, Negatives = 3
# Model 41: Positives = 50, Negatives = 7
# Model 42: Positives = 53, Negatives = 4
# Model 43: Positives = 54, Negatives = 3
# Model 44: Positives = 53, Negatives = 4
# Model 45: Positives = 50, Negatives = 7
# Model 46: Positives = 54, Negatives = 3
# Model 47: Positives = 52, Negatives = 5
# Model 48: Positives = 52, Negatives = 5
# Model 49: Positives = 52, Negatives = 5
# Model 50: Positives = 51, Negatives = 6
# Overlapping Capture Rate is 0.8478727973274901

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                      4
# 1  PseudoNegative                     7                      7
# 2  PseudoPositive                    44                      6
# 3  StrongPositive                     6                     40
#        Label  Threshold (0.5)
# 0  Negative                3
# 1  Positive               54
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     2                      7
# 1  PseudoNegative                     7                      7
# 2  PseudoPositive                    38                      5
# 3  StrongPositive                    10                     38
#        Label  Threshold (0.5)
# 0  Negative                2
# 1  Positive               55
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     2                      7
# 1  PseudoNegative                     5                      5
# 2  PseudoPositive                    32                      4
# 3  StrongPositive                    18                     41
#        Label  Threshold (0.5)
# 0  Negative                3
# 1  Positive               54
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                      6
# 1  PseudoNegative                     7                      3
# 2  PseudoPositive                    31                      5
# 3  StrongPositive                    19                     43
#        Label  Threshold (0.5)
# 0  Negative                3
# 1  Positive               54
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                      5
# 1  PseudoNegative                     7                      5
# 2  PseudoPositive                    29                      6
# 3  StrongPositive                    21                     41
#        Label  Threshold (0.5)
# 0  Negative                3
# 1  Positive               54
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           0.8     0.979796
# 1  PseudoNegative           6.6     0.800000
# 2  PseudoPositive          34.8     5.491812
# 3  StrongPositive          14.8     5.775812
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative              5.8        1.166190
# 1  PseudoNegative              5.4        1.496663
# 2  PseudoPositive              5.2        0.748331
# 3  StrongPositive             40.6        1.624808
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative             2.8            0.4
# 1  Positive            54.2            0.4
