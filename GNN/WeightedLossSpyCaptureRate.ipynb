# %%
import torch
import torch.nn as nn
import glob
import csv
import numpy as np

class CNN2D(nn.Module):
    def __init__(self, input_channels):
        super(CNN2D, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(input_channels, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU()
        )
        self.pool1 = nn.MaxPool2d(2, 2)
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU()
        )
        self.pool2 = nn.MaxPool2d(2, 2)
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU()
        )
        self.pool3 = nn.MaxPool2d(2, 2)

        
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(128 * 4 * 18, 128)  # Adjust based on input size
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, 1)
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.pool2(x)
        
        x = self.conv3(x)
        x = self.pool3(x)
        
        x = self.flatten(x)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

models = []

k = 50

for i in range (1, (k + 1)):
    model = CNN2D(input_channels=1).to(device)
    model = nn.DataParallel(model)

    model_path = f"../../../Models/Cholesterol/GNN/WeightedGNNModels-5A_exp5/model_bin_{i}.pth" 
    model.load_state_dict(torch.load(model_path, map_location=device))

    model.eval()

    models.append(model)
# Out:
# /tmp/ipykernel_648973/1598989798.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=device))

# %%
def evaluate_file(model, file_path, threshold=0.5):
    grid = np.load(file_path)

    if grid.ndim == 2:
        non_padded_rows = np.sum(np.any(grid != 0, axis=(1)))
    else:
        raise ValueError(f"Unexpected grid shape: {grid.shape}")
    
    grid_tensor = torch.tensor(grid, dtype=torch.float32).unsqueeze(0).unsqueeze(0)  # Add batch and channel dims
    grid_tensor = grid_tensor.to(device)
    
    model.eval()
    with torch.no_grad():
        output = model(grid_tensor).squeeze(1)  

    prob = torch.sigmoid(output).item()

    predicted_class = int(prob >= threshold)

    return predicted_class, prob, non_padded_rows

# %%
def evaluate_directory(dir, csv_output):
    predictions = []
    capture_rate = 0
    overlapping_capture_rate = 0
    overlapping_index = 0

    files = glob.glob(f"{dir}/*.npy")

    model_positive_counts = [0] * len(models)
    model_negative_counts = [0] * len(models)

    print(f"{'Filename':<120} {'IndividualCaptureRate':<25} NumberOfAtoms")

    with open(csv_output, "w", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["filename", "average_score", "number_atoms"]) 

        for file in sorted(files):    
            prediction = 0
            for model_index, model in enumerate(models):
                predicted_class, prob, non_padded_rows = evaluate_file(model, file)
                prediction += prob

                if predicted_class == 1:
                    model_positive_counts[model_index] += 1
                else:
                    model_negative_counts[model_index] += 1

            prediction /= len(models)
            predictions.append((model_index, predicted_class))
            capture_rate += prediction
            #if non_padded_rows <= 65 and non_padded_rows >= 55:
            print(f"{file:<120} {prediction:<25} {non_padded_rows}")
            overlapping_capture_rate += prediction
            overlapping_index += 1
            writer.writerow([file, prediction, non_padded_rows])

    capture_rate /= len(files)
    overlapping_capture_rate /= overlapping_index

    print("\nModel Predictions Summary:")
    for i, (pos, neg) in enumerate(zip(model_positive_counts, model_negative_counts), start=1):
        print(f"Model {i}: Positives = {pos}, Negatives = {neg}")

    print("Overlapping Capture Rate is", overlapping_capture_rate)

    return capture_rate

# %%
spies = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive"  
csv_output = "ivan_capture_rates.csv"

spy_capture_rate = evaluate_directory(spies, csv_output)

print("Spy Capture Rate is", spy_capture_rate)
# Out:
# Filename                                                                                                                 IndividualCaptureRate     NumberOfAtoms
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/8SRK-filtered_combined_matrix.npy                 0.8998823642730713        60
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/8SZG-filtered_combined_matrix.npy                 0.9125057816505432        24
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/8SZI-filtered_combined_matrix.npy                 0.9164428985118866        24
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/8V81-filtered_combined_matrix.npy                 0.5179643788933754        25
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/9AXF-filtered_combined_matrix.npy                 0.7753488111495972        22
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/9B36-filtered_combined_matrix.npy                 0.906761245727539         33
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/9B37-filtered_combined_matrix.npy                 0.9364497709274292        35
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/9C3E-filtered_combined_matrix.npy                 0.9727159237861633        55
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/9DMG-filtered_combined_matrix.npy                 0.7588651478290558        52
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/9DMT-filtered_combined_matrix.npy                 0.8039027285575867        54
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/9DXS-filtered_combined_matrix.npy                 0.9362064850330353        36
# ../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-graph-5A/positive/9II3-filtered_combined_matrix.npy                 0.9720907723903656        26
#
# Model Predictions Summary:
# Model 1: Positives = 53, Negatives = 4
# Model 2: Positives = 52, Negatives = 5
# Model 3: Positives = 53, Negatives = 4
# Model 4: Positives = 55, Negatives = 2
# Model 5: Positives = 53, Negatives = 4
# Model 6: Positives = 55, Negatives = 2
# Model 7: Positives = 54, Negatives = 3
# Model 8: Positives = 52, Negatives = 5
# Model 9: Positives = 53, Negatives = 4
# Model 10: Positives = 50, Negatives = 7
# Model 11: Positives = 53, Negatives = 4
# Model 12: Positives = 54, Negatives = 3
# Model 13: Positives = 55, Negatives = 2
# Model 14: Positives = 55, Negatives = 2
# Model 15: Positives = 54, Negatives = 3
# Model 16: Positives = 50, Negatives = 7
# Model 17: Positives = 52, Negatives = 5
# Model 18: Positives = 54, Negatives = 3
# Model 19: Positives = 53, Negatives = 4
# Model 20: Positives = 53, Negatives = 4
# Model 21: Positives = 51, Negatives = 6
# Model 22: Positives = 53, Negatives = 4
# Model 23: Positives = 54, Negatives = 3
# Model 24: Positives = 54, Negatives = 3
# Model 25: Positives = 49, Negatives = 8
# Model 26: Positives = 55, Negatives = 2
# Model 27: Positives = 49, Negatives = 8
# Model 28: Positives = 52, Negatives = 5
# Model 29: Positives = 53, Negatives = 4
# Model 30: Positives = 54, Negatives = 3
# Model 31: Positives = 54, Negatives = 3
# Model 32: Positives = 51, Negatives = 6
# Model 33: Positives = 54, Negatives = 3
# Model 34: Positives = 52, Negatives = 5
# Model 35: Positives = 53, Negatives = 4
# Model 36: Positives = 52, Negatives = 5
# Model 37: Positives = 55, Negatives = 2
# Model 38: Positives = 51, Negatives = 6
# Model 39: Positives = 53, Negatives = 4
# Model 40: Positives = 52, Negatives = 5
# Model 41: Positives = 52, Negatives = 5
# Model 42: Positives = 54, Negatives = 3
# Model 43: Positives = 54, Negatives = 3
# Model 44: Positives = 53, Negatives = 4
# Model 45: Positives = 50, Negatives = 7
# Model 46: Positives = 53, Negatives = 4
# Model 47: Positives = 52, Negatives = 5
# Model 48: Positives = 50, Negatives = 7
# Model 49: Positives = 54, Negatives = 3
# Model 50: Positives = 52, Negatives = 5
# Overlapping Capture Rate is 0.8478355351366661
# Spy Capture Rate is 0.8478355351366661

# %%
test_positives = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive"
csv_output = "test_positive_capture_rates.csv"

test_positives_capture_rate = evaluate_directory(test_positives, csv_output)

print("Test Positives Capture Rate is", test_positives_capture_rate)
# Out:
# Filename                                                                                                                 IndividualCaptureRate     NumberOfAtoms
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/6CO7-filtered_combined_matrix.npy            0.9590863716602326        55
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/7DDH-filtered_combined_matrix.npy            0.9758950531482696        56
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/7F61-filtered_combined_matrix.npy            0.9235081505775452        59
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/7FJD-filtered_combined_matrix.npy            0.9255039882659912        57
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/7FJE-filtered_combined_matrix.npy            0.8120794075727463        58
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/7P02-filtered_combined_matrix.npy            0.9321866536140442        56
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/7SK7-filtered_combined_matrix.npy            0.6623569414019584        64
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/8C9W-filtered_combined_matrix.npy            0.5429003366827965        55
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/8CRR-filtered_combined_matrix.npy            0.8605288910865784        59
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/8DPH-filtered_combined_matrix.npy            0.9812967884540558        55
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/8Q7B-filtered_combined_matrix.npy            0.6898489964008331        61
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/8SI7-filtered_combined_matrix.npy            0.9353053033351898        65
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/8SIA-filtered_combined_matrix.npy            0.9606540334224701        59
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/8WR3-filtered_combined_matrix.npy            0.5669555719196796        56
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/9BBC-filtered_combined_matrix.npy            0.5116908407211304        59
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/9CUK-filtered_combined_matrix.npy            0.9392107152938842        59
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/9D19-filtered_combined_matrix.npy            0.32586052298545837       58
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/9DBK-filtered_combined_matrix.npy            0.8526331788301468        60
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/9DBN-filtered_combined_matrix.npy            0.9617324638366699        61
#
# Model Predictions Summary:
# Model 1: Positives = 137, Negatives = 17
# Model 2: Positives = 145, Negatives = 9
# Model 3: Positives = 140, Negatives = 14
# Model 4: Positives = 147, Negatives = 7
# Model 5: Positives = 142, Negatives = 12
# Model 6: Positives = 147, Negatives = 7
# Model 7: Positives = 148, Negatives = 6
# Model 8: Positives = 140, Negatives = 14
# Model 9: Positives = 147, Negatives = 7
# Model 10: Positives = 143, Negatives = 11
# Model 11: Positives = 144, Negatives = 10
# Model 12: Positives = 141, Negatives = 13
# Model 13: Positives = 143, Negatives = 11
# Model 14: Positives = 143, Negatives = 11
# Model 15: Positives = 140, Negatives = 14
# Model 16: Positives = 144, Negatives = 10
# Model 17: Positives = 139, Negatives = 15
# Model 18: Positives = 141, Negatives = 13
# Model 19: Positives = 142, Negatives = 12
# Model 20: Positives = 145, Negatives = 9
# Model 21: Positives = 143, Negatives = 11
# Model 22: Positives = 144, Negatives = 10
# Model 23: Positives = 147, Negatives = 7
# Model 24: Positives = 144, Negatives = 10
# Model 25: Positives = 144, Negatives = 10
# Model 26: Positives = 147, Negatives = 7
# Model 27: Positives = 139, Negatives = 15
# Model 28: Positives = 145, Negatives = 9
# Model 29: Positives = 141, Negatives = 13
# Model 30: Positives = 143, Negatives = 11
# Model 31: Positives = 143, Negatives = 11
# Model 32: Positives = 145, Negatives = 9
# Model 33: Positives = 142, Negatives = 12
# Model 34: Positives = 141, Negatives = 13
# Model 35: Positives = 140, Negatives = 14
# Model 36: Positives = 145, Negatives = 9
# Model 37: Positives = 147, Negatives = 7
# Model 38: Positives = 146, Negatives = 8
# Model 39: Positives = 141, Negatives = 13
# Model 40: Positives = 143, Negatives = 11
# Model 41: Positives = 141, Negatives = 13
# Model 42: Positives = 143, Negatives = 11
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/8K9R-f5_combined_matrix.npy                 0.2530911548435688        61
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/8SGW-f2_combined_matrix.npy                 0.28180636450648305       64
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/8SR7-f3_combined_matrix.npy                 0.6241176187992096        65
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/8SZH-f5_combined_matrix.npy                 0.0024870772007852793     64
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/8V63-f5_combined_matrix.npy                 0.1284134287945926        55
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/8WPU-f4_combined_matrix.npy                 0.04603752510156482       55
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/8YUV-f3_combined_matrix.npy                 0.11213237335905432       58
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/9DBK-f1_combined_matrix.npy                 0.03129124126862735       62
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/9DVM-f4_combined_matrix.npy                 0.02000573684461415       58
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/9IJA-f3_combined_matrix.npy                 0.25404239594936373       64
# ../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/9J7M-f1_combined_matrix.npy                 0.00594546395004727       59
#
# Model Predictions Summary:
# Model 1: Positives = 49, Negatives = 505
# Model 2: Positives = 35, Negatives = 519
# Model 3: Positives = 43, Negatives = 511
# Model 4: Positives = 45, Negatives = 509
# Model 5: Positives = 47, Negatives = 507
# Model 6: Positives = 64, Negatives = 490
# Model 7: Positives = 51, Negatives = 503
# Model 8: Positives = 42, Negatives = 512
# Model 9: Positives = 55, Negatives = 499
# Model 10: Positives = 40, Negatives = 514
# Model 11: Positives = 47, Negatives = 507
# Model 12: Positives = 56, Negatives = 498
# Model 13: Positives = 54, Negatives = 500
# Model 14: Positives = 49, Negatives = 505
# Model 15: Positives = 46, Negatives = 508
# Model 16: Positives = 42, Negatives = 512
# Model 17: Positives = 43, Negatives = 511
# Model 18: Positives = 49, Negatives = 505
# Model 19: Positives = 40, Negatives = 514
# Model 20: Positives = 51, Negatives = 503
# Model 21: Positives = 50, Negatives = 504
# Model 22: Positives = 52, Negatives = 502
# Model 23: Positives = 52, Negatives = 502
# Model 24: Positives = 48, Negatives = 506
# Model 25: Positives = 42, Negatives = 512
# Model 26: Positives = 42, Negatives = 512
# Model 27: Positives = 45, Negatives = 509
# Model 28: Positives = 44, Negatives = 510
# Model 29: Positives = 51, Negatives = 503
# Model 30: Positives = 45, Negatives = 509
# Model 31: Positives = 44, Negatives = 510
# Model 32: Positives = 48, Negatives = 506
# Model 33: Positives = 56, Negatives = 498
# Model 34: Positives = 43, Negatives = 511
# Model 35: Positives = 50, Negatives = 504
# Model 36: Positives = 46, Negatives = 508
# Model 37: Positives = 48, Negatives = 506
# Model 38: Positives = 51, Negatives = 503
# Model 39: Positives = 47, Negatives = 507
# Model 40: Positives = 50, Negatives = 504
# Model 41: Positives = 35, Negatives = 519
# Model 42: Positives = 48, Negatives = 506
# Model 43: Positives = 50, Negatives = 504
# Model 44: Positives = 45, Negatives = 509
# Model 45: Positives = 54, Negatives = 500
# Model 46: Positives = 50, Negatives = 504
# Model 47: Positives = 44, Negatives = 510
# Model 48: Positives = 48, Negatives = 506
# Model 49: Positives = 46, Negatives = 508
# Model 50: Positives = 49, Negatives = 505
# Overlapping Capture Rate is 0.20753562124979816
# Test Unlabeled Capture Rate is 0.1046486677956766

# %%
test_likely_positives = f"../../../Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/LikelyPosit