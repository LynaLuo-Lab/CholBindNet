# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool
import glob
import numpy as np
import csv
from torch_geometric.data import Data
import os

class GCN(nn.Module):
    def __init__(self, input_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, 32)
        self.bn1 = nn.BatchNorm1d(32)
        
        self.conv2 = GCNConv(32, 64)
        self.bn2 = nn.BatchNorm1d(64)
        
        self.conv3 = GCNConv(64, 128)
        self.bn3 = nn.BatchNorm1d(128)

        self.dropout_gcn = nn.Dropout(0.2)
        self.dropout = nn.Dropout(0.6)
        
        self.fc1 = nn.Linear(128, 64)
        self.out = nn.Linear(64, 1)

    def forward(self, data):
        x, edge_index, edge_weight, batch = data.x, data.edge_index, data.edge_attr, data.batch

        x = self.conv1(x, edge_index, edge_weight)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.dropout_gcn(x)

        x = self.conv2(x, edge_index, edge_weight)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.dropout_gcn(x)

        x = self.conv3(x, edge_index, edge_weight)
        x = self.bn3(x)
        x = F.relu(x)
        x = self.dropout_gcn(x)

        # Global pooling to get graph-level representation
        x = global_mean_pool(x, batch)

        x = self.fc1(x)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.out(x)

        return x
    
def organize_graph_and_add_weight(file_path, label):
    data = np.load(file_path, allow_pickle=True).item()
    inverse_distance = data['inverse_distance']
    encoded_matrix = data['encoded_matrix']

    x = torch.tensor(encoded_matrix, dtype=torch.float32)
    adj = torch.tensor(inverse_distance, dtype=torch.float32)

    # Normalize adjacency (row-normalize)
    #adj = adj / (adj.sum(dim=1, keepdim=True) + 1e-8)

    # Create edge_index and edge weights
    edge_index = (adj > 0).nonzero(as_tuple=False).t()
    edge_weight = adj[adj > 0]

    y = torch.tensor([label], dtype=torch.float32)
    
    return Data(x=x, edge_index=edge_index, edge_attr=edge_weight, y=y)
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

models_exp1 = []
models_exp2 = []
models_exp3 = []
models_exp4 = []
models_exp5 = []

k = 50

for i in range (1, (k + 1)):
    model_exp1 = GCN(input_dim=37).to(device)

    model_exp2 = GCN(input_dim=37).to(device)

    model_exp3 = GCN(input_dim=37).to(device)

    model_exp4 = GCN(input_dim=37).to(device)

    model_exp5 = GCN(input_dim=37).to(device)

    model_path = f"GCN-5A_Exp1/Models/model_bin_{i}.pth" 
    model_exp1.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"GCN-5A_Exp2/Models/model_bin_{i}.pth" 
    model_exp2.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"GCN-5A_Exp3/Models/model_bin_{i}.pth" 
    model_exp3.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"GCN-5A_Exp4/Models/model_bin_{i}.pth" 
    model_exp4.load_state_dict(torch.load(model_path, map_location=device))

    model_path = f"GCN-5A_Exp5/Models/model_bin_{i}.pth" 
    model_exp5.load_state_dict(torch.load(model_path, map_location=device))

    model_exp1.eval()
    model_exp2.eval()
    model_exp3.eval()
    model_exp4.eval()
    model_exp5.eval()

    models_exp1.append(model_exp1)
    models_exp2.append(model_exp2)
    models_exp3.append(model_exp3)
    models_exp4.append(model_exp4)
    models_exp5.append(model_exp5)
# Out:
# /tmp/ipykernel_928312/3551714475.py:98: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp1.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_928312/3551714475.py:101: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp2.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_928312/3551714475.py:104: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp3.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_928312/3551714475.py:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp4.load_state_dict(torch.load(model_path, map_location=device))
# /tmp/ipykernel_928312/3551714475.py:110: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_exp5.load_state_dict(torch.load(model_path, map_location=device))

# %%
def get_capture_rate(dir, csv_output, models):
    predictions = []
    capture_rate = 0
    overlapping_capture_rate = 0
    overlapping_index = 0

    files = glob.glob(f"{dir}/*.npy")

    model_positive_counts = [0] * len(models)
    model_negative_counts = [0] * len(models)

    os.makedirs(os.path.dirname(csv_output), exist_ok=True)

    with open(csv_output, "w", newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["filename", "average_score", "score_std", "number_atoms"]) 

        for file in sorted(files):    
            model_probs = []
            for model_index, model in enumerate(models):
                graph = organize_graph_and_add_weight(file, label=0).to(device)
                graph.batch = torch.zeros(graph.num_nodes, dtype=torch.long).to(device)
                non_padded_rows = graph.x.size(0)
                with torch.no_grad():
                    out = model(graph)
                    prob = torch.sigmoid(out).item()
                    model_probs.append(prob)

                    if prob >= 0.5:
                        model_positive_counts[model_index] += 1
                    else:
                        model_negative_counts[model_index] += 1

            prediction_mean = np.mean(model_probs)
            prediction_std = np.std(model_probs)

            predictions.append((file, prediction_mean))
            capture_rate += prediction_mean
            #print(f"{file:<120} {prediction:<25} {non_padded_rows}")
            overlapping_capture_rate += prediction_mean
            overlapping_index += 1
            writer.writerow([file, prediction_mean, prediction_std, non_padded_rows])

    capture_rate /= len(files)
    overlapping_capture_rate /= overlapping_index

    print("\nModel Predictions Summary:")
    for i, (pos, neg) in enumerate(zip(model_positive_counts, model_negative_counts), start=1):
        print(f"Model {i}: Positives = {pos}, Negatives = {neg}")

    #print("Overlapping Capture Rate is", overlapping_capture_rate)

    return capture_rate

# %%
spies_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp1/Spies"  
csv_output_exp1 = "GCN-5A_Exp1/Results/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp1, csv_output_exp1, models_exp1)

spies_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp2/Spies"  
csv_output_exp2 = "GCN-5A_Exp2/Results/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp2, csv_output_exp2, models_exp2)

spies_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp3/Spies"  
csv_output_exp3 = "GCN-5A_Exp3/Results/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp3, csv_output_exp3, models_exp3)

spies_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp4/Spies"  
csv_output_exp4 = "GCN-5A_Exp4/Results/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp4, csv_output_exp4, models_exp4)

spies_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp5/Spies"  
csv_output_exp5 = "GCN-5A_Exp5/Results/SpyCaptureRates.csv"

spy_capture_rate = get_capture_rate(spies_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 118, Negatives = 36
# Model 2: Positives = 131, Negatives = 23
# Model 3: Positives = 120, Negatives = 34
# Model 4: Positives = 131, Negatives = 23
# Model 5: Positives = 122, Negatives = 32
# Model 6: Positives = 124, Negatives = 30
# Model 7: Positives = 131, Negatives = 23
# Model 8: Positives = 130, Negatives = 24
# Model 9: Positives = 117, Negatives = 37
# Model 10: Positives = 123, Negatives = 31
# Model 11: Positives = 137, Negatives = 17
# Model 12: Positives = 115, Negatives = 39
# Model 13: Positives = 117, Negatives = 37
# Model 14: Positives = 128, Negatives = 26
# Model 15: Positives = 118, Negatives = 36
# Model 16: Positives = 121, Negatives = 33
# Model 17: Positives = 107, Negatives = 47
# Model 18: Positives = 117, Negatives = 37
# Model 19: Positives = 122, Negatives = 32
# Model 20: Positives = 115, Negatives = 39
# Model 21: Positives = 135, Negatives = 19
# Model 22: Positives = 118, Negatives = 36
# Model 23: Positives = 127, Negatives = 27
# Model 24: Positives = 129, Negatives = 25
# Model 25: Positives = 113, Negatives = 41
# Model 26: Positives = 120, Negatives = 34
# Model 27: Positives = 120, Negatives = 34
# Model 28: Positives = 120, Negatives = 34
# Model 29: Positives = 102, Negatives = 52
# Model 30: Positives = 116, Negatives = 38
# Model 31: Positives = 130, Negatives = 24
# Model 32: Positives = 116, Negatives = 38
# Model 33: Positives = 128, Negatives = 26
# Model 34: Positives = 119, Negatives = 35
# Model 35: Positives = 117, Negatives = 37
# Model 36: Positives = 118, Negatives = 36
# Model 37: Positives = 124, Negatives = 30
# Model 38: Positives = 123, Negatives = 31
# Model 39: Positives = 129, Negatives = 25
# Model 40: Positives = 124, Negatives = 30
# Model 41: Positives = 128, Negatives = 26
# Model 42: Positives = 131, Negatives = 23
# Model 43: Positives = 126, Negatives = 28
# Model 44: Positives = 124, Negatives = 30
# Model 45: Positives = 110, Negatives = 44
# Model 46: Positives = 121, Negatives = 33
# Model 47: Positives = 127, Negatives = 27
# Model 48: Positives = 123, Negatives = 31
# Model 49: Positives = 124, Negatives = 30
# Model 50: Positives = 115, Negatives = 39
#
# Model Predictions Summary:
# Model 1: Positives = 123, Negatives = 31
# Model 2: Positives = 129, Negatives = 25
# Model 3: Positives = 134, Negatives = 20
# Model 4: Positives = 125, Negatives = 29
# Model 5: Positives = 127, Negatives = 27
# Model 6: Positives = 119, Negatives = 35
# Model 7: Positives = 131, Negatives = 23
# Model 8: Positives = 130, Negatives = 24
# Model 9: Positives = 132, Negatives = 22
# Model 10: Positives = 137, Negatives = 17
# Model 11: Positives = 113, Negatives = 41
# Model 12: Positives = 125, Negatives = 29
# Model 13: Positives = 135, Negatives = 19
# Model 14: Positives = 117, Negatives = 37
# Model 15: Positives = 113, Negatives = 41
# Model 16: Positives = 127, Negatives = 27
# Model 17: Positives = 122, Negatives = 32
# Model 18: Positives = 129, Negatives = 25
# Model 19: Positives = 121, Negatives = 33
# Model 20: Positives = 123, Negatives = 31
# Model 21: Positives = 124, Negatives = 30
# Model 22: Positives = 140, Negatives = 14
# Model 23: Positives = 118, Negatives = 36
# Model 24: Positives = 129, Negatives = 25
# Model 25: Positives = 124, Negatives = 30
# Model 26: Positives = 117, Negatives = 37
# Model 27: Positives = 113, Negatives = 41
# Model 28: Positives = 119, Negatives = 35
# Model 29: Positives = 128, Negatives = 26
# Model 30: Positives = 128, Negatives = 26
# Model 31: Positives = 131, Negatives = 23
# Model 32: Positives = 125, Negatives = 29
# Model 33: Positives = 134, Negatives = 20
# Model 34: Positives = 132, Negatives = 22
# Model 35: Positives = 120, Negatives = 34
# Model 36: Positives = 132, Negatives = 22
# Model 37: Positives = 130, Negatives = 24
# Model 38: Positives = 122, Negatives = 32
# Model 39: Positives = 119, Negatives = 35
# Model 40: Positives = 126, Negatives = 28
# Model 41: Positives = 131, Negatives = 23
# Model 42: Positives = 133, Negatives = 21
# Model 43: Positives = 125, Negatives = 29
# Model 44: Positives = 134, Negatives = 20
# Model 45: Positives = 128, Negatives = 26
# Model 46: Positives = 113, Negatives = 41
# Model 47: Positives = 125, Negatives = 29
# Model 48: Positives = 126, Negatives = 28
# Model 49: Positives = 131, Negatives = 23
# Model 50: Positives = 126, Negatives = 28
#
# Model Predictions Summary:
# Model 1: Positives = 129, Negatives = 25
# Model 2: Positives = 133, Negatives = 21
# Model 3: Positives = 139, Negatives = 15
# Model 4: Positives = 122, Negatives = 32
# Model 5: Positives = 125, Negatives = 29
# Model 6: Positives = 118, Negatives = 36
# Model 7: Positives = 132, Negatives = 22
# Model 8: Positives = 126, Negatives = 28
# Model 9: Positives = 126, Negatives = 28
# Model 10: Positives = 122, Negatives = 32
# Model 11: Positives = 135, Negatives = 19
# Model 12: Positives = 123, Negatives = 31
# Model 13: Positives = 127, Negatives = 27
# Model 14: Positives = 136, Negatives = 18
# Model 15: Positives = 122, Negatives = 32
# Model 16: Positives = 122, Negatives = 32
# Model 17: Positives = 126, Negatives = 28
# Model 18: Positives = 124, Negatives = 30
# Model 19: Positives = 131, Negatives = 23
# Model 20: Positives = 123, Negatives = 31
# Model 21: Positives = 112, Negatives = 42
# Model 22: Positives = 136, Negatives = 18
# Model 23: Positives = 126, Negatives = 28
# Model 24: Positives = 131, Negatives = 23
# Model 25: Positives = 128, Negatives = 26
# Model 26: Positives = 122, Negatives = 32
# Model 27: Positives = 129, Negatives = 25
# Model 28: Positives = 125, Negatives = 29
# Model 29: Positives = 127, Negatives = 27
# Model 30: Positives = 137, Negatives = 17
# Model 31: Positives = 128, Negatives = 26
# Model 32: Positives = 131, Negatives = 23
# Model 33: Positives = 117, Negatives = 37
# Model 34: Positives = 132, Negatives = 22
# Model 35: Positives = 124, Negatives = 30
# Model 36: Positives = 130, Negatives = 24
# Model 37: Positives = 119, Negatives = 35
# Model 38: Positives = 126, Negatives = 28
# Model 39: Positives = 139, Negatives = 15
# Model 40: Positives = 135, Negatives = 19
# Model 41: Positives = 123, Negatives = 31
# Model 42: Positives = 131, Negatives = 23
# Model 43: Positives = 137, Negatives = 17
# Model 44: Positives = 135, Negatives = 19
# Model 45: Positives = 124, Negatives = 30
# Model 46: Positives = 126, Negatives = 28
# Model 47: Positives = 130, Negatives = 24
# Model 48: Positives = 129, Negatives = 25
# Model 49: Positives = 128, Negatives = 26
# Model 50: Positives = 113, Negatives = 41
#
# Model Predictions Summary:
# Model 1: Positives = 126, Negatives = 28
# Model 2: Positives = 121, Negatives = 33
# Model 3: Positives = 112, Negatives = 42
# Model 4: Positives = 123, Negatives = 31
# Model 5: Positives = 125, Negatives = 29
# Model 6: Positives = 113, Negatives = 41
# Model 7: Positives = 126, Negatives = 28
# Model 8: Positives = 114, Negatives = 40
# Model 9: Positives = 120, Negatives = 34
# Model 10: Positives = 120, Negatives = 34
# Model 11: Positives = 120, Negatives = 34
# Model 12: Positives = 124, Negatives = 30
# Model 13: Positives = 117, Negatives = 37
# Model 14: Positives = 122, Negatives = 32
# Model 15: Positives = 131, Negatives = 23
# Model 16: Positives = 109, Negatives = 45
# Model 17: Positives = 106, Negatives = 48
# Model 18: Positives = 103, Negatives = 51
# Model 19: Positives = 123, Negatives = 31
# Model 20: Positives = 132, Negatives = 22
# Model 21: Positives = 129, Negatives = 25
# Model 22: Positives = 137, Negatives = 17
# Model 23: Positives = 128, Negatives = 26
# Model 24: Positives = 120, Negatives = 34
# Model 25: Positives = 123, Negatives = 31
# Model 26: Positives = 127, Negatives = 27
# Model 27: Positives = 115, Negatives = 39
# Model 28: Positives = 114, Negatives = 40
# Model 29: Positives = 129, Negatives = 25
# Model 30: Positives = 111, Negatives = 43
# Model 31: Positives = 126, Negatives = 28
# Model 32: Positives = 105, Negatives = 49
# Model 33: Positives = 123, Negatives = 31
# Model 34: Positives = 113, Negatives = 41
# Model 35: Positives = 123, Negatives = 31
# Model 36: Positives = 115, Negatives = 39
# Model 37: Positives = 120, Negatives = 34
# Model 38: Positives = 124, Negatives = 30
# Model 39: Positives = 117, Negatives = 37
# Model 40: Positives = 126, Negatives = 28
# Model 41: Positives = 126, Negatives = 28
# Model 42: Positives = 113, Negatives = 41
# Model 43: Positives = 128, Negatives = 26
# Model 44: Positives = 117, Negatives = 37
# Model 45: Positives = 114, Negatives = 40
# Model 46: Positives = 125, Negatives = 29
# Model 47: Positives = 128, Negatives = 26
# Model 48: Positives = 127, Negatives = 27
# Model 49: Positives = 108, Negatives = 46
# Model 50: Positives = 111, Negatives = 43
#
# Model Predictions Summary:
# Model 1: Positives = 121, Negatives = 33
# Model 2: Positives = 130, Negatives = 24
# Model 3: Positives = 120, Negatives = 34
# Model 4: Positives = 124, Negatives = 30
# Model 5: Positives = 114, Negatives = 40
# Model 6: Positives = 116, Negatives = 38
# Model 7: Positives = 119, Negatives = 35
# Model 8: Positives = 119, Negatives = 35
# Model 9: Positives = 128, Negatives = 26
# Model 10: Positives = 125, Negatives = 29
# Model 11: Positives = 123, Negatives = 31
# Model 12: Positives = 120, Negatives = 34
# Model 13: Positives = 128, Negatives = 26
# Model 14: Positives = 118, Negatives = 36
# Model 15: Positives = 118, Negatives = 36
# Model 16: Positives = 123, Negatives = 31
# Model 17: Positives = 115, Negatives = 39
# Model 18: Positives = 120, Negatives = 34
# Model 19: Positives = 112, Negatives = 42
# Model 20: Positives = 119, Negatives = 35
# Model 21: Positives = 113, Negatives = 41
# Model 22: Positives = 118, Negatives = 36
# Model 23: Positives = 132, Negatives = 22
# Model 24: Positives = 113, Negatives = 41
# Model 25: Positives = 114, Negatives = 40
# Model 26: Positives = 121, Negatives = 33
# Model 27: Positives = 106, Negatives = 48
# Model 28: Positives = 130, Negatives = 24
# Model 29: Positives = 112, Negatives = 42
# Model 30: Positives = 123, Negatives = 31
# Model 31: Positives = 112, Negatives = 42
# Model 32: Positives = 132, Negatives = 22
# Model 33: Positives = 124, Negatives = 30
# Model 34: Positives = 112, Negatives = 42
# Model 35: Positives = 119, Negatives = 35
# Model 36: Positives = 117, Negatives = 37
# Model 37: Positives = 120, Negatives = 34
# Model 38: Positives = 118, Negatives = 36
# Model 39: Positives = 129, Negatives = 25
# Model 40: Positives = 119, Negatives = 35
# Model 41: Positives = 122, Negatives = 32
# Model 42: Positives = 111, Negatives = 43
# Model 43: Positives = 119, Negatives = 35
# Model 44: Positives = 123, Negatives = 31
# Model 45: Positives = 128, Negatives = 26
# Model 46: Positives = 119, Negatives = 35
# Model 47: Positives = 121, Negatives = 33
# Model 48: Positives = 120, Negatives = 34
# Model 49: Positives = 132, Negatives = 22
# Model 50: Positives = 122, Negatives = 32

# %%
import pandas as pd

def get_spy_info(csv):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    # Extract the 'average_score' column
    scores = df["average_score"]

    # Compute statistics
    mean_score = scores.mean()
    percentile_50 = scores.quantile(0.5)
    percentile_25 = scores.quantile(0.25)
    percentile_75 = scores.quantile(0.75)
    min_score = scores.min()
    max_score = scores.max()

    # Print results
    print(f"Mean: {mean_score:.6f}")
    print(f"50th Percentile (Median): {percentile_50:.6f}")
    print(f"Bottom 25 Percentile: {percentile_25:.6f}")
    print(f"Top 25 Percentile: {percentile_75:.6f}")
    print(f"Min: {min_score:.6f}")
    print(f"Max: {max_score:.6f}\n")

    return mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score

print("Experiment 1 Spy Results:")
mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1 = get_spy_info(csv_output_exp1)

print("Experiment 2 Spy Results:")
mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2 = get_spy_info(csv_output_exp2)

print("Experiment 3 Spy Results:")
mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3 = get_spy_info(csv_output_exp3)

print("Experiment 4 Spy Results:")
mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4 = get_spy_info(csv_output_exp4)

print("Experiment 5 Spy Results:")
mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5 = get_spy_info(csv_output_exp5)
# Out:
# Experiment 1 Spy Results:
# Mean: 0.747436
# 50th Percentile (Median): 0.794645
# Bottom 25 Percentile: 0.671681
# Top 25 Percentile: 0.876279
# Min: 0.092567
# Max: 0.978279
#
# Experiment 2 Spy Results:
# Mean: 0.770596
# 50th Percentile (Median): 0.823733
# Bottom 25 Percentile: 0.683083
# Top 25 Percentile: 0.910043
# Min: 0.172504
# Max: 0.971192
#
# Experiment 3 Spy Results:
# Mean: 0.780548
# 50th Percentile (Median): 0.819758
# Bottom 25 Percentile: 0.708112
# Top 25 Percentile: 0.901665
# Min: 0.034102
# Max: 0.964920
#
# Experiment 4 Spy Results:
# Mean: 0.734243
# 50th Percentile (Median): 0.799679
# Bottom 25 Percentile: 0.649582
# Top 25 Percentile: 0.869579
# Min: 0.008715
# Max: 0.972053
#
# Experiment 5 Spy Results:
# Mean: 0.743760
# 50th Percentile (Median): 0.813436
# Bottom 25 Percentile: 0.649597
# Top 25 Percentile: 0.889125
# Min: 0.005725
# Max: 0.976941

# %%
test_positives_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp1/Test/Positive"  
csv_output_exp1 = "GCN-5A_Exp1/Results/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp1, csv_output_exp1, models_exp1)

test_positives_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp2/Test/Positive"  
csv_output_exp2 = "GCN-5A_Exp2/Results/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp2, csv_output_exp2, models_exp2)

test_positives_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp3/Test/Positive"  
csv_output_exp3 = "GCN-5A_Exp3/Results/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp3, csv_output_exp3, models_exp3)

test_positives_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp4/Test/Positive"  
csv_output_exp4 = "GCN-5A_Exp4/Results/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp4, csv_output_exp4, models_exp4)

test_positives_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp5/Test/Positive"  
csv_output_exp5 = "GCN-5A_Exp5/Results/TestPositiveCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_positives_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 142, Negatives = 12
# Model 2: Positives = 144, Negatives = 10
# Model 3: Positives = 143, Negatives = 11
# Model 4: Positives = 147, Negatives = 7
# Model 5: Positives = 142, Negatives = 12
# Model 6: Positives = 143, Negatives = 11
# Model 7: Positives = 148, Negatives = 6
# Model 8: Positives = 144, Negatives = 10
# Model 9: Positives = 137, Negatives = 17
# Model 10: Positives = 147, Negatives = 7
# Model 11: Positives = 148, Negatives = 6
# Model 12: Positives = 142, Negatives = 12
# Model 13: Positives = 143, Negatives = 11
# Model 14: Positives = 137, Negatives = 17
# Model 15: Positives = 142, Negatives = 12
# Model 16: Positives = 142, Negatives = 12
# Model 17: Positives = 135, Negatives = 19
# Model 18: Positives = 148, Negatives = 6
# Model 19: Positives = 141, Negatives = 13
# Model 20: Positives = 139, Negatives = 15
# Model 21: Positives = 145, Negatives = 9
# Model 22: Positives = 138, Negatives = 16
# Model 23: Positives = 135, Negatives = 19
# Model 24: Positives = 141, Negatives = 13
# Model 25: Positives = 133, Negatives = 21
# Model 26: Positives = 139, Negatives = 15
# Model 27: Positives = 145, Negatives = 9
# Model 28: Positives = 135, Negatives = 19
# Model 29: Positives = 129, Negatives = 25
# Model 30: Positives = 141, Negatives = 13
# Model 31: Positives = 145, Negatives = 9
# Model 32: Positives = 137, Negatives = 17
# Model 33: Positives = 145, Negatives = 9
# Model 34: Positives = 134, Negatives = 20
# Model 35: Positives = 140, Negatives = 14
# Model 36: Positives = 139, Negatives = 15
# Model 37: Positives = 142, Negatives = 12
# Model 38: Positives = 144, Negatives = 10
# Model 39: Positives = 145, Negatives = 9
# Model 40: Positives = 139, Negatives = 15
# Model 41: Positives = 148, Negatives = 6
# Model 42: Positives = 149, Negatives = 5
# Model 43: Positives = 142, Negatives = 12
# Model 44: Positives = 137, Negatives = 17
# Model 45: Positives = 136, Negatives = 18
# Model 46: Positives = 136, Negatives = 18
# Model 47: Positives = 149, Negatives = 5
# Model 48: Positives = 144, Negatives = 10
# Model 49: Positives = 142, Negatives = 12
# Model 50: Positives = 135, Negatives = 19
#
# Model Predictions Summary:
# Model 1: Positives = 140, Negatives = 14
# Model 2: Positives = 141, Negatives = 13
# Model 3: Positives = 145, Negatives = 9
# Model 4: Positives = 137, Negatives = 17
# Model 5: Positives = 136, Negatives = 18
# Model 6: Positives = 137, Negatives = 17
# Model 7: Positives = 144, Negatives = 10
# Model 8: Positives = 140, Negatives = 14
# Model 9: Positives = 140, Negatives = 14
# Model 10: Positives = 143, Negatives = 11
# Model 11: Positives = 132, Negatives = 22
# Model 12: Positives = 140, Negatives = 14
# Model 13: Positives = 142, Negatives = 12
# Model 14: Positives = 129, Negatives = 25
# Model 15: Positives = 139, Negatives = 15
# Model 16: Positives = 136, Negatives = 18
# Model 17: Positives = 131, Negatives = 23
# Model 18: Positives = 140, Negatives = 14
# Model 19: Positives = 137, Negatives = 17
# Model 20: Positives = 132, Negatives = 22
# Model 21: Positives = 136, Negatives = 18
# Model 22: Positives = 146, Negatives = 8
# Model 23: Positives = 139, Negatives = 15
# Model 24: Positives = 135, Negatives = 19
# Model 25: Positives = 136, Negatives = 18
# Model 26: Positives = 136, Negatives = 18
# Model 27: Positives = 141, Negatives = 13
# Model 28: Positives = 137, Negatives = 17
# Model 29: Positives = 138, Negatives = 16
# Model 30: Positives = 144, Negatives = 10
# Model 31: Positives = 142, Negatives = 12
# Model 32: Positives = 139, Negatives = 15
# Model 33: Positives = 145, Negatives = 9
# Model 34: Positives = 145, Negatives = 9
# Model 35: Positives = 127, Negatives = 27
# Model 36: Positives = 131, Negatives = 23
# Model 37: Positives = 136, Negatives = 18
# Model 38: Positives = 137, Negatives = 17
# Model 39: Positives = 134, Negatives = 20
# Model 40: Positives = 137, Negatives = 17
# Model 41: Positives = 139, Negatives = 15
# Model 42: Positives = 142, Negatives = 12
# Model 43: Positives = 140, Negatives = 14
# Model 44: Positives = 140, Negatives = 14
# Model 45: Positives = 139, Negatives = 15
# Model 46: Positives = 131, Negatives = 23
# Model 47: Positives = 125, Negatives = 29
# Model 48: Positives = 135, Negatives = 19
# Model 49: Positives = 137, Negatives = 17
# Model 50: Positives = 135, Negatives = 19
#
# Model Predictions Summary:
# Model 1: Positives = 130, Negatives = 24
# Model 2: Positives = 137, Negatives = 17
# Model 3: Positives = 138, Negatives = 16
# Model 4: Positives = 127, Negatives = 27
# Model 5: Positives = 139, Negatives = 15
# Model 6: Positives = 125, Negatives = 29
# Model 7: Positives = 131, Negatives = 23
# Model 8: Positives = 130, Negatives = 24
# Model 9: Positives = 132, Negatives = 22
# Model 10: Positives = 132, Negatives = 22
# Model 11: Positives = 142, Negatives = 12
# Model 12: Positives = 132, Negatives = 22
# Model 13: Positives = 132, Negatives = 22
# Model 14: Positives = 137, Negatives = 17
# Model 15: Positives = 128, Negatives = 26
# Model 16: Positives = 133, Negatives = 21
# Model 17: Positives = 135, Negatives = 19
# Model 18: Positives = 125, Negatives = 29
# Model 19: Positives = 138, Negatives = 16
# Model 20: Positives = 128, Negatives = 26
# Model 21: Positives = 126, Negatives = 28
# Model 22: Positives = 140, Negatives = 14
# Model 23: Positives = 135, Negatives = 19
# Model 24: Positives = 128, Negatives = 26
# Model 25: Positives = 132, Negatives = 22
# Model 26: Positives = 132, Negatives = 22
# Model 27: Positives = 136, Negatives = 18
# Model 28: Positives = 132, Negatives = 22
# Model 29: Positives = 133, Negatives = 21
# Model 30: Positives = 134, Negatives = 20
# Model 31: Positives = 132, Negatives = 22
# Model 32: Positives = 139, Negatives = 15
# Model 33: Positives = 136, Negatives = 18
# Model 34: Positives = 131, Negatives = 23
# Model 35: Positives = 122, Negatives = 32
# Model 36: Positives = 140, Negatives = 14
# Model 37: Positives = 133, Negatives = 21
# Model 38: Positives = 137, Negatives = 17
# Model 39: Positives = 138, Negatives = 16
# Model 40: Positives = 142, Negatives = 12
# Model 41: Positives = 131, Negatives = 23
# Model 42: Positives = 130, Negatives = 24
# Model 43: Positives = 138, Negatives = 16
# Model 44: Positives = 136, Negatives = 18
# Model 45: Positives = 138, Negatives = 16
# Model 46: Positives = 136, Negatives = 18
# Model 47: Positives = 134, Negatives = 20
# Model 48: Positives = 140, Negatives = 14
# Model 49: Positives = 142, Negatives = 12
# Model 50: Positives = 127, Negatives = 27
#
# Model Predictions Summary:
# Model 1: Positives = 139, Negatives = 15
# Model 2: Positives = 131, Negatives = 23
# Model 3: Positives = 137, Negatives = 17
# Model 4: Positives = 138, Negatives = 16
# Model 5: Positives = 141, Negatives = 13
# Model 6: Positives = 130, Negatives = 24
# Model 7: Positives = 141, Negatives = 13
# Model 8: Positives = 136, Negatives = 18
# Model 9: Positives = 139, Negatives = 15
# Model 10: Positives = 134, Negatives = 20
# Model 11: Positives = 137, Negatives = 17
# Model 12: Positives = 142, Negatives = 12
# Model 13: Positives = 135, Negatives = 19
# Model 14: Positives = 143, Negatives = 11
# Model 15: Positives = 145, Negatives = 9
# Model 16: Positives = 128, Negatives = 26
# Model 17: Positives = 136, Negatives = 18
# Model 18: Positives = 126, Negatives = 28
# Model 19: Positives = 136, Negatives = 18
# Model 20: Positives = 144, Negatives = 10
# Model 21: Positives = 139, Negatives = 15
# Model 22: Positives = 146, Negatives = 8
# Model 23: Positives = 139, Negatives = 15
# Model 24: Positives = 140, Negatives = 14
# Model 25: Positives = 134, Negatives = 20
# Model 26: Positives = 137, Negatives = 17
# Model 27: Positives = 139, Negatives = 15
# Model 28: Positives = 127, Negatives = 27
# Model 29: Positives = 139, Negatives = 15
# Model 30: Positives = 127, Negatives = 27
# Model 31: Positives = 142, Negatives = 12
# Model 32: Positives = 132, Negatives = 22
# Model 33: Positives = 139, Negatives = 15
# Model 34: Positives = 136, Negatives = 18
# Model 35: Positives = 145, Negatives = 9
# Model 36: Positives = 134, Negatives = 20
# Model 37: Positives = 141, Negatives = 13
# Model 38: Positives = 133, Negatives = 21
# Model 39: Positives = 127, Negatives = 27
# Model 40: Positives = 143, Negatives = 11
# Model 41: Positives = 141, Negatives = 13
# Model 42: Positives = 130, Negatives = 24
# Model 43: Positives = 144, Negatives = 10
# Model 44: Positives = 141, Negatives = 13
# Model 45: Positives = 132, Negatives = 22
# Model 46: Positives = 143, Negatives = 11
# Model 47: Positives = 143, Negatives = 11
# Model 48: Positives = 138, Negatives = 16
# Model 49: Positives = 125, Negatives = 29
# Model 50: Positives = 136, Negatives = 18
#
# Model Predictions Summary:
# Model 1: Positives = 139, Negatives = 15
# Model 2: Positives = 141, Negatives = 13
# Model 3: Positives = 135, Negatives = 19
# Model 4: Positives = 139, Negatives = 15
# Model 5: Positives = 135, Negatives = 19
# Model 6: Positives = 137, Negatives = 17
# Model 7: Positives = 139, Negatives = 15
# Model 8: Positives = 132, Negatives = 22
# Model 9: Positives = 139, Negatives = 15
# Model 10: Positives = 141, Negatives = 13
# Model 11: Positives = 141, Negatives = 13
# Model 12: Positives = 136, Negatives = 18
# Model 13: Positives = 138, Negatives = 16
# Model 14: Positives = 138, Negatives = 16
# Model 15: Positives = 128, Negatives = 26
# Model 16: Positives = 137, Negatives = 17
# Model 17: Positives = 134, Negatives = 20
# Model 18: Positives = 141, Negatives = 13
# Model 19: Positives = 136, Negatives = 18
# Model 20: Positives = 135, Negatives = 19
# Model 21: Positives = 137, Negatives = 17
# Model 22: Positives = 133, Negatives = 21
# Model 23: Positives = 145, Negatives = 9
# Model 24: Positives = 136, Negatives = 18
# Model 25: Positives = 135, Negatives = 19
# Model 26: Positives = 136, Negatives = 18
# Model 27: Positives = 127, Negatives = 27
# Model 28: Positives = 144, Negatives = 10
# Model 29: Positives = 130, Negatives = 24
# Model 30: Positives = 132, Negatives = 22
# Model 31: Positives = 132, Negatives = 22
# Model 32: Positives = 143, Negatives = 11
# Model 33: Positives = 138, Negatives = 16
# Model 34: Positives = 147, Negatives = 7
# Model 35: Positives = 140, Negatives = 14
# Model 36: Positives = 131, Negatives = 23
# Model 37: Positives = 136, Negatives = 18
# Model 38: Positives = 137, Negatives = 17
# Model 39: Positives = 143, Negatives = 11
# Model 40: Positives = 140, Negatives = 14
# Model 41: Positives = 144, Negatives = 10
# Model 42: Positives = 139, Negatives = 15
# Model 43: Positives = 138, Negatives = 16
# Model 44: Positives = 136, Negatives = 18
# Model 45: Positives = 132, Negatives = 22
# Model 46: Positives = 140, Negatives = 14
# Model 47: Positives = 138, Negatives = 16
# Model 48: Positives = 146, Negatives = 8
# Model 49: Positives = 142, Negatives = 12
# Model 50: Positives = 140, Negatives = 14

# %%
def apply_labeling_from_spies(csv, mean_score, percentile_50, percentile_25, percentile_75, min_score, max_score):
    df = pd.read_csv(csv)  # Replace with your actual filename if needed

    def get_min_max_label(score):
        if score < min_score:
            return "StrongNegative"
        elif min_score <= score < mean_score:
            return "PseudoNegative"
        elif mean_score <= score < max_score:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df["min_max_label"] = df["average_score"].apply(get_min_max_label)

    def get_percentile_label(score):
        if score < percentile_25:
            return "StrongNegative"
        elif percentile_25 <= score < percentile_50:
            return "PseudoNegative"
        elif percentile_50 <= score < percentile_75:
            return "PseudoPositive"
        else:
            return "StrongPositive"

    df["percentile_label"] = df["average_score"].apply(get_percentile_label)
    df["threshold_label"] = df["average_score"].apply(lambda x: "Negative" if x < 0.5 else "Positive")

    min_max_results = []
    min_max_results.append((df["average_score"] < min_score).sum()) # min_max_strong_negative_count
    min_max_results.append(((df["average_score"] > min_score) & (df["average_score"] < mean_score)).sum()) # min_max_pseudo_negative_count
    min_max_results.append(((df["average_score"] > mean_score) & (df["average_score"] < max_score)).sum()) # min_max_pseudo_positive_count
    min_max_results.append((df["average_score"] > max_score).sum()) # min_max_strong_positive_count

    percentile_results = []
    percentile_results.append((df["average_score"] < percentile_25).sum()) # percentile_strong_negative_count
    percentile_results.append(((df["average_score"] > percentile_25) & (df["average_score"] < percentile_50)).sum()) # percentile_pseudo_negative_count
    percentile_results.append(((df["average_score"] > percentile_50) & (df["average_score"] < percentile_75)).sum()) # percentile_pseudo_positive_count
    percentile_results.append((df["average_score"] > percentile_75).sum()) # percentile_strong_positive_count

    threshold_results = []
    threshold_results.append((df["average_score"] < 0.5).sum()) # threshold_negative_count
    threshold_results.append((df["average_score"] > 0.5).sum()) # threshold_positive_count

    # Table 1: Min/Max and Percentile
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    minmax_percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Min_Max (Using Mean)": min_max_results,
        "Percentile (75-50-25)": percentile_results
    })

    # Table 2: Threshold 0.5
    labels_2 = ["Negative", "Positive"]
    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold (0.5)": threshold_results
    })

    print(minmax_percentile_df,"\n", threshold_df)

    df.to_csv(csv, index=False)

    return min_max_results, percentile_results, threshold_results

def show_evaluation_results(min_max_all, percentile_all, threshold_all):
    # Compute mean and std for each label
    min_max_mean = np.mean(min_max_all, axis=0)
    min_max_std = np.std(min_max_all, axis=0)

    percentile_mean = np.mean(percentile_all, axis=0)
    percentile_std = np.std(percentile_all, axis=0)

    threshold_mean = np.mean(threshold_all, axis=0)
    threshold_std = np.std(threshold_all, axis=0)

    # Create DataFrames to display
    labels_4 = ["StrongNegative", "PseudoNegative", "PseudoPositive", "StrongPositive"]
    labels_2 = ["Negative", "Positive"]

    min_max_df = pd.DataFrame({
        "Label": labels_4,
        "Min-Max Mean": min_max_mean,
        "Min-Max Std": min_max_std
    })

    percentile_df = pd.DataFrame({
        "Label": labels_4,
        "Percentile Mean": percentile_mean,
        "Percentile Std": percentile_std
    })

    threshold_df = pd.DataFrame({
        "Label": labels_2,
        "Threshold Mean": threshold_mean,
        "Threshold Std": threshold_std
    })

    # Display
    print("=== Min-Max Results ===")
    print(min_max_df)
    print("\n=== Percentile Results ===")
    print(percentile_df)
    print("\n=== Threshold Results ===")
    print(threshold_df)

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     17
# 1  PseudoNegative                    26                     20
# 2  PseudoPositive                   115                     23
# 3  StrongPositive                    13                     94
#        Label  Threshold (0.5)
# 0  Negative                3
# 1  Positive              151
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     3                     20
# 1  PseudoNegative                    22                     20
# 2  PseudoPositive                   116                     32
# 3  StrongPositive                    13                     82
#        Label  Threshold (0.5)
# 0  Negative               10
# 1  Positive              144
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     31
# 1  PseudoNegative                    42                     16
# 2  PseudoPositive                   101                     36
# 3  StrongPositive                    11                     71
#        Label  Threshold (0.5)
# 0  Negative               17
# 1  Positive              137
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     23
# 1  PseudoNegative                    30                     20
# 2  PseudoPositive                   109                     23
# 3  StrongPositive                    15                     88
#        Label  Threshold (0.5)
# 0  Negative                8
# 1  Positive              146
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                     19
# 1  PseudoNegative                    30                     24
# 2  PseudoPositive                   108                     20
# 3  StrongPositive                    16                     91
#        Label  Threshold (0.5)
# 0  Negative                9
# 1  Positive              145
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           0.6     1.200000
# 1  PseudoNegative          30.0     6.693280
# 2  PseudoPositive         109.8     5.418487
# 3  StrongPositive          13.6     1.743560
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative             22.0        4.898979
# 1  PseudoNegative             20.0        2.529822
# 2  PseudoPositive             26.8        6.112283
# 3  StrongPositive             85.2        8.133880
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative             9.4       4.498889
# 1  Positive           144.6       4.498889

# %%
test_unlabeled_exp1 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp1/Test/CombinedUnlabeled"  
csv_output_exp1 = "GCN-5A_Exp1/Results/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp1, csv_output_exp1, models_exp1)

test_unlabeled_exp2 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp2/Test/CombinedUnlabeled"  
csv_output_exp2 = "GCN-5A_Exp2/Results/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp2, csv_output_exp2, models_exp2)

test_unlabeled_exp3 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp3/Test/CombinedUnlabeled"  
csv_output_exp3 = "GCN-5A_Exp3/Results/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp3, csv_output_exp3, models_exp3)

test_unlabeled_exp4 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp4/Test/CombinedUnlabeled"  
csv_output_exp4 = "GCN-5A_Exp4/Results/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp4, csv_output_exp4, models_exp4)

test_unlabeled_exp5 = f"../../../Data/SplitData/Cholesterol/cholesterol-separate-graphs-5A_exp5/Test/CombinedUnlabeled"  
csv_output_exp5 = "GCN-5A_Exp5/Results/TestUnlabeledCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_unlabeled_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 267, Negatives = 656
# Model 2: Positives = 291, Negatives = 632
# Model 3: Positives = 278, Negatives = 645
# Model 4: Positives = 253, Negatives = 670
# Model 5: Positives = 258, Negatives = 665
# Model 6: Positives = 260, Negatives = 663
# Model 7: Positives = 255, Negatives = 668
# Model 8: Positives = 249, Negatives = 674
# Model 9: Positives = 218, Negatives = 705
# Model 10: Positives = 274, Negatives = 649
# Model 11: Positives = 289, Negatives = 634
# Model 12: Positives = 259, Negatives = 664
# Model 13: Positives = 262, Negatives = 661
# Model 14: Positives = 244, Negatives = 679
# Model 15: Positives = 243, Negatives = 680
# Model 16: Positives = 279, Negatives = 644
# Model 17: Positives = 171, Negatives = 752
# Model 18: Positives = 270, Negatives = 653
# Model 19: Positives = 254, Negatives = 669
# Model 20: Positives = 214, Negatives = 709
# Model 21: Positives = 274, Negatives = 649
# Model 22: Positives = 218, Negatives = 705
# Model 23: Positives = 205, Negatives = 718
# Model 24: Positives = 250, Negatives = 673
# Model 25: Positives = 204, Negatives = 719
# Model 26: Positives = 266, Negatives = 657
# Model 27: Positives = 251, Negatives = 672
# Model 28: Positives = 205, Negatives = 718
# Model 29: Positives = 195, Negatives = 728
# Model 30: Positives = 259, Negatives = 664
# Model 31: Positives = 256, Negatives = 667
# Model 32: Positives = 217, Negatives = 706
# Model 33: Positives = 275, Negatives = 648
# Model 34: Positives = 245, Negatives = 678
# Model 35: Positives = 242, Negatives = 681
# Model 36: Positives = 229, Negatives = 694
# Model 37: Positives = 251, Negatives = 672
# Model 38: Positives = 260, Negatives = 663
# Model 39: Positives = 262, Negatives = 661
# Model 40: Positives = 216, Negatives = 707
# Model 41: Positives = 263, Negatives = 660
# Model 42: Positives = 295, Negatives = 628
# Model 43: Positives = 270, Negatives = 653
# Model 44: Positives = 254, Negatives = 669
# Model 45: Positives = 225, Negatives = 698
# Model 46: Positives = 249, Negatives = 674
# Model 47: Positives = 273, Negatives = 650
# Model 48: Positives = 234, Negatives = 689
# Model 49: Positives = 229, Negatives = 694
# Model 50: Positives = 192, Negatives = 731
#
# Model Predictions Summary:
# Model 1: Positives = 270, Negatives = 653
# Model 2: Positives = 309, Negatives = 614
# Model 3: Positives = 279, Negatives = 644
# Model 4: Positives = 204, Negatives = 719
# Model 5: Positives = 234, Negatives = 689
# Model 6: Positives = 239, Negatives = 684
# Model 7: Positives = 278, Negatives = 645
# Model 8: Positives = 278, Negatives = 645
# Model 9: Positives = 261, Negatives = 662
# Model 10: Positives = 290, Negatives = 633
# Model 11: Positives = 171, Negatives = 752
# Model 12: Positives = 256, Negatives = 667
# Model 13: Positives = 299, Negatives = 624
# Model 14: Positives = 222, Negatives = 701
# Model 15: Positives = 203, Negatives = 720
# Model 16: Positives = 249, Negatives = 674
# Model 17: Positives = 231, Negatives = 692
# Model 18: Positives = 244, Negatives = 679
# Model 19: Positives = 264, Negatives = 659
# Model 20: Positives = 231, Negatives = 692
# Model 21: Positives = 254, Negatives = 669
# Model 22: Positives = 272, Negatives = 651
# Model 23: Positives = 232, Negatives = 691
# Model 24: Positives = 275, Negatives = 648
# Model 25: Positives = 215, Negatives = 708
# Model 26: Positives = 181, Negatives = 742
# Model 27: Positives = 232, Negatives = 691
# Model 28: Positives = 197, Negatives = 726
# Model 29: Positives = 275, Negatives = 648
# Model 30: Positives = 244, Negatives = 679
# Model 31: Positives = 292, Negatives = 631
# Model 32: Positives = 248, Negatives = 675
# Model 33: Positives = 314, Negatives = 609
# Model 34: Positives = 296, Negatives = 627
# Model 35: Positives = 238, Negatives = 685
# Model 36: Positives = 264, Negatives = 659
# Model 37: Positives = 245, Negatives = 678
# Model 38: Positives = 209, Negatives = 714
# Model 39: Positives = 243, Negatives = 680
# Model 40: Positives = 224, Negatives = 699
# Model 41: Positives = 255, Negatives = 668
# Model 42: Positives = 266, Negatives = 657
# Model 43: Positives = 261, Negatives = 662
# Model 44: Positives = 245, Negatives = 678
# Model 45: Positives = 274, Negatives = 649
# Model 46: Positives = 202, Negatives = 721
# Model 47: Positives = 223, Negatives = 700
# Model 48: Positives = 238, Negatives = 685
# Model 49: Positives = 242, Negatives = 681
# Model 50: Positives = 238, Negatives = 685
#
# Model Predictions Summary:
# Model 1: Positives = 209, Negatives = 714
# Model 2: Positives = 248, Negatives = 675
# Model 3: Positives = 276, Negatives = 647
# Model 4: Positives = 209, Negatives = 714
# Model 5: Positives = 272, Negatives = 651
# Model 6: Positives = 197, Negatives = 726
# Model 7: Positives = 240, Negatives = 683
# Model 8: Positives = 221, Negatives = 702
# Model 9: Positives = 230, Negatives = 693
# Model 10: Positives = 239, Negatives = 684
# Model 11: Positives = 252, Negatives = 671
# Model 12: Positives = 271, Negatives = 652
# Model 13: Positives = 259, Negatives = 664
# Model 14: Positives = 268, Negatives = 655
# Model 15: Positives = 232, Negatives = 691
# Model 16: Positives = 213, Negatives = 710
# Model 17: Positives = 256, Negatives = 667
# Model 18: Positives = 216, Negatives = 707
# Model 19: Positives = 283, Negatives = 640
# Model 20: Positives = 220, Negatives = 703
# Model 21: Positives = 195, Negatives = 728
# Model 22: Positives = 281, Negatives = 642
# Model 23: Positives = 239, Negatives = 684
# Model 24: Positives = 213, Negatives = 710
# Model 25: Positives = 230, Negatives = 693
# Model 26: Positives = 247, Negatives = 676
# Model 27: Positives = 257, Negatives = 666
# Model 28: Positives = 211, Negatives = 712
# Model 29: Positives = 214, Negatives = 709
# Model 30: Positives = 295, Negatives = 628
# Model 31: Positives = 224, Negatives = 699
# Model 32: Positives = 225, Negatives = 698
# Model 33: Positives = 267, Negatives = 656
# Model 34: Positives = 236, Negatives = 687
# Model 35: Positives = 184, Negatives = 739
# Model 36: Positives = 274, Negatives = 649
# Model 37: Positives = 225, Negatives = 698
# Model 38: Positives = 251, Negatives = 672
# Model 39: Positives = 266, Negatives = 657
# Model 40: Positives = 268, Negatives = 655
# Model 41: Positives = 223, Negatives = 700
# Model 42: Positives = 260, Negatives = 663
# Model 43: Positives = 260, Negatives = 663
# Model 44: Positives = 253, Negatives = 670
# Model 45: Positives = 250, Negatives = 673
# Model 46: Positives = 268, Negatives = 655
# Model 47: Positives = 259, Negatives = 664
# Model 48: Positives = 260, Negatives = 663
# Model 49: Positives = 253, Negatives = 670
# Model 50: Positives = 222, Negatives = 701
#
# Model Predictions Summary:
# Model 1: Positives = 250, Negatives = 673
# Model 2: Positives = 219, Negatives = 704
# Model 3: Positives = 233, Negatives = 690
# Model 4: Positives = 238, Negatives = 685
# Model 5: Positives = 278, Negatives = 645
# Model 6: Positives = 187, Negatives = 736
# Model 7: Positives = 247, Negatives = 676
# Model 8: Positives = 226, Negatives = 697
# Model 9: Positives = 231, Negatives = 692
# Model 10: Positives = 256, Negatives = 667
# Model 11: Positives = 265, Negatives = 658
# Model 12: Positives = 280, Negatives = 643
# Model 13: Positives = 228, Negatives = 695
# Model 14: Positives = 289, Negatives = 634
# Model 15: Positives = 260, Negatives = 663
# Model 16: Positives = 201, Negatives = 722
# Model 17: Positives = 242, Negatives = 681
# Model 18: Positives = 197, Negatives = 726
# Model 19: Positives = 223, Negatives = 700
# Model 20: Positives = 271, Negatives = 652
# Model 21: Positives = 274, Negatives = 649
# Model 22: Positives = 293, Negatives = 630
# Model 23: Positives = 292, Negatives = 631
# Model 24: Positives = 250, Negatives = 673
# Model 25: Positives = 249, Negatives = 674
# Model 26: Positives = 249, Negatives = 674
# Model 27: Positives = 267, Negatives = 656
# Model 28: Positives = 199, Negatives = 724
# Model 29: Positives = 272, Negatives = 651
# Model 30: Positives = 251, Negatives = 672
# Model 31: Positives = 294, Negatives = 629
# Model 32: Positives = 208, Negatives = 715
# Model 33: Positives = 231, Negatives = 692
# Model 34: Positives = 244, Negatives = 679
# Model 35: Positives = 269, Negatives = 654
# Model 36: Positives = 214, Negatives = 709
# Model 37: Positives = 265, Negatives = 658
# Model 38: Positives = 218, Negatives = 705
# Model 39: Positives = 195, Negatives = 728
# Model 40: Positives = 274, Negatives = 649
# Model 41: Positives = 241, Negatives = 682
# Model 42: Positives = 192, Negatives = 731
# Model 43: Positives = 293, Negatives = 630
# Model 44: Positives = 247, Negatives = 676
# Model 45: Positives = 214, Negatives = 709
# Model 46: Positives = 288, Negatives = 635
# Model 47: Positives = 290, Negatives = 633
# Model 48: Positives = 269, Negatives = 654
# Model 49: Positives = 206, Negatives = 717
# Model 50: Positives = 259, Negatives = 664
#
# Model Predictions Summary:
# Model 1: Positives = 239, Negatives = 684
# Model 2: Positives = 246, Negatives = 677
# Model 3: Positives = 221, Negatives = 702
# Model 4: Positives = 284, Negatives = 639
# Model 5: Positives = 225, Negatives = 698
# Model 6: Positives = 218, Negatives = 705
# Model 7: Positives = 255, Negatives = 668
# Model 8: Positives = 216, Negatives = 707
# Model 9: Positives = 255, Negatives = 668
# Model 10: Positives = 224, Negatives = 699
# Model 11: Positives = 246, Negatives = 677
# Model 12: Positives = 228, Negatives = 695
# Model 13: Positives = 297, Negatives = 626
# Model 14: Positives = 255, Negatives = 668
# Model 15: Positives = 192, Negatives = 731
# Model 16: Positives = 249, Negatives = 674
# Model 17: Positives = 205, Negatives = 718
# Model 18: Positives = 258, Negatives = 665
# Model 19: Positives = 205, Negatives = 718
# Model 20: Positives = 266, Negatives = 657
# Model 21: Positives = 251, Negatives = 672
# Model 22: Positives = 218, Negatives = 705
# Model 23: Positives = 273, Negatives = 650
# Model 24: Positives = 223, Negatives = 700
# Model 25: Positives = 236, Negatives = 687
# Model 26: Positives = 248, Negatives = 675
# Model 27: Positives = 173, Negatives = 750
# Model 28: Positives = 275, Negatives = 648
# Model 29: Positives = 203, Negatives = 720
# Model 30: Positives = 237, Negatives = 686
# Model 31: Positives = 235, Negatives = 688
# Model 32: Positives = 272, Negatives = 651
# Model 33: Positives = 227, Negatives = 696
# Model 34: Positives = 229, Negatives = 694
# Model 35: Positives = 233, Negatives = 690
# Model 36: Positives = 200, Negatives = 723
# Model 37: Positives = 215, Negatives = 708
# Model 38: Positives = 204, Negatives = 719
# Model 39: Positives = 212, Negatives = 711
# Model 40: Positives = 246, Negatives = 677
# Model 41: Positives = 270, Negatives = 653
# Model 42: Positives = 248, Negatives = 675
# Model 43: Positives = 242, Negatives = 681
# Model 44: Positives = 228, Negatives = 695
# Model 45: Positives = 265, Negatives = 658
# Model 46: Positives = 264, Negatives = 659
# Model 47: Positives = 258, Negatives = 665
# Model 48: Positives = 261, Negatives = 662
# Model 49: Positives = 255, Negatives = 668
# Model 50: Positives = 264, Negatives = 659

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   417                    758
# 1  PseudoNegative                   372                     58
# 2  PseudoPositive                   131                     49
# 3  StrongPositive                     3                     58
#        Label  Threshold (0.5)
# 0  Negative              684
# 1  Positive              239
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   517                    757
# 1  PseudoNegative                   288                     66
# 2  PseudoPositive                   109                     56
# 3  StrongPositive                     9                     44
#        Label  Threshold (0.5)
# 0  Negative              685
# 1  Positive              238
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   298                    773
# 1  PseudoNegative                   505                     54
# 2  PseudoPositive                   116                     55
# 3  StrongPositive                     4                     41
#        Label  Threshold (0.5)
# 0  Negative              694
# 1  Positive              229
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   179                    748
# 1  PseudoNegative                   602                     64
# 2  PseudoPositive                   136                     35
# 3  StrongPositive                     6                     76
#        Label  Threshold (0.5)
# 0  Negative              689
# 1  Positive              234
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                   143                    761
# 1  PseudoNegative                   650                     54
# 2  PseudoPositive                   125                     46
# 3  StrongPositive                     5                     62
#        Label  Threshold (0.5)
# 0  Negative              691
# 1  Positive              232
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative         310.8   141.059420
# 1  PseudoNegative         483.4   136.293213
# 2  PseudoPositive         123.4     9.810199
# 3  StrongPositive           5.4     2.059126
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative            759.4        8.064738
# 1  PseudoNegative             59.2        4.995998
# 2  PseudoPositive             48.2        7.573638
# 3  StrongPositive             56.2       12.718490
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative           688.6       3.720215
# 1  Positive           234.4       3.720215

# %%
test_ivan_exp1 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp1 = "GCN-5A_Exp1/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp1, csv_output_exp1, models_exp1)

test_ivan_exp2 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp2 = "GCN-5A_Exp2/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp2, csv_output_exp2, models_exp2)

test_ivan_exp3 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp3 = "GCN-5A_Exp3/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp3, csv_output_exp3, models_exp3)

test_ivan_exp4 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp4 = "GCN-5A_Exp4/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp4, csv_output_exp4, models_exp4)

test_ivan_exp5 = f"../../../Data/SplitData/Cholesterol/IvanTestSet/ivan-separate-graphs-5A/positive"  
csv_output_exp5 = "GCN-5A_Exp5/Results/TestIvanCaptureRates.csv"

spy_capture_rate = get_capture_rate(test_ivan_exp5, csv_output_exp5, models_exp5)
# Out:
# Model Predictions Summary:
# Model 1: Positives = 51, Negatives = 6
# Model 2: Positives = 50, Negatives = 7
# Model 3: Positives = 49, Negatives = 8
# Model 4: Positives = 50, Negatives = 7
# Model 5: Positives = 53, Negatives = 4
# Model 6: Positives = 48, Negatives = 9
# Model 7: Positives = 49, Negatives = 8
# Model 8: Positives = 47, Negatives = 10
# Model 9: Positives = 46, Negatives = 11
# Model 10: Positives = 48, Negatives = 9
# Model 11: Positives = 51, Negatives = 6
# Model 12: Positives = 47, Negatives = 10
# Model 13: Positives = 52, Negatives = 5
# Model 14: Positives = 50, Negatives = 7
# Model 15: Positives = 48, Negatives = 9
# Model 16: Positives = 49, Negatives = 8
# Model 17: Positives = 43, Negatives = 14
# Model 18: Positives = 48, Negatives = 9
# Model 19: Positives = 49, Negatives = 8
# Model 20: Positives = 48, Negatives = 9
# Model 21: Positives = 51, Negatives = 6
# Model 22: Positives = 49, Negatives = 8
# Model 23: Positives = 49, Negatives = 8
# Model 24: Positives = 49, Negatives = 8
# Model 25: Positives = 48, Negatives = 9
# Model 26: Positives = 51, Negatives = 6
# Model 27: Positives = 50, Negatives = 7
# Model 28: Positives = 46, Negatives = 11
# Model 29: Positives = 46, Negatives = 11
# Model 30: Positives = 48, Negatives = 9
# Model 31: Positives = 51, Negatives = 6
# Model 32: Positives = 47, Negatives = 10
# Model 33: Positives = 50, Negatives = 7
# Model 34: Positives = 51, Negatives = 6
# Model 35: Positives = 49, Negatives = 8
# Model 36: Positives = 49, Negatives = 8
# Model 37: Positives = 45, Negatives = 12
# Model 38: Positives = 53, Negatives = 4
# Model 39: Positives = 50, Negatives = 7
# Model 40: Positives = 51, Negatives = 6
# Model 41: Positives = 52, Negatives = 5
# Model 42: Positives = 52, Negatives = 5
# Model 43: Positives = 50, Negatives = 7
# Model 44: Positives = 48, Negatives = 9
# Model 45: Positives = 48, Negatives = 9
# Model 46: Positives = 50, Negatives = 7
# Model 47: Positives = 50, Negatives = 7
# Model 48: Positives = 50, Negatives = 7
# Model 49: Positives = 50, Negatives = 7
# Model 50: Positives = 45, Negatives = 12
#
# Model Predictions Summary:
# Model 1: Positives = 50, Negatives = 7
# Model 2: Positives = 48, Negatives = 9
# Model 3: Positives = 47, Negatives = 10
# Model 4: Positives = 48, Negatives = 9
# Model 5: Positives = 49, Negatives = 8
# Model 6: Positives = 49, Negatives = 8
# Model 7: Positives = 48, Negatives = 9
# Model 8: Positives = 50, Negatives = 7
# Model 9: Positives = 51, Negatives = 6
# Model 10: Positives = 50, Negatives = 7
# Model 11: Positives = 47, Negatives = 10
# Model 12: Positives = 50, Negatives = 7
# Model 13: Positives = 50, Negatives = 7
# Model 14: Positives = 48, Negatives = 9
# Model 15: Positives = 50, Negatives = 7
# Model 16: Positives = 49, Negatives = 8
# Model 17: Positives = 49, Negatives = 8
# Model 18: Positives = 50, Negatives = 7
# Model 19: Positives = 48, Negatives = 9
# Model 20: Positives = 52, Negatives = 5
# Model 21: Positives = 50, Negatives = 7
# Model 22: Positives = 53, Negatives = 4
# Model 23: Positives = 48, Negatives = 9
# Model 24: Positives = 44, Negatives = 13
# Model 25: Positives = 46, Negatives = 11
# Model 26: Positives = 48, Negatives = 9
# Model 27: Positives = 48, Negatives = 9
# Model 28: Positives = 48, Negatives = 9
# Model 29: Positives = 50, Negatives = 7
# Model 30: Positives = 48, Negatives = 9
# Model 31: Positives = 50, Negatives = 7
# Model 32: Positives = 49, Negatives = 8
# Model 33: Positives = 51, Negatives = 6
# Model 34: Positives = 51, Negatives = 6
# Model 35: Positives = 50, Negatives = 7
# Model 36: Positives = 48, Negatives = 9
# Model 37: Positives = 50, Negatives = 7
# Model 38: Positives = 50, Negatives = 7
# Model 39: Positives = 48, Negatives = 9
# Model 40: Positives = 45, Negatives = 12
# Model 41: Positives = 49, Negatives = 8
# Model 42: Positives = 53, Negatives = 4
# Model 43: Positives = 48, Negatives = 9
# Model 44: Positives = 51, Negatives = 6
# Model 45: Positives = 51, Negatives = 6
# Model 46: Positives = 47, Negatives = 10
# Model 47: Positives = 49, Negatives = 8
# Model 48: Positives = 48, Negatives = 9
# Model 49: Positives = 49, Negatives = 8
# Model 50: Positives = 49, Negatives = 8
#
# Model Predictions Summary:
# Model 1: Positives = 49, Negatives = 8
# Model 2: Positives = 51, Negatives = 6
# Model 3: Positives = 52, Negatives = 5
# Model 4: Positives = 47, Negatives = 10
# Model 5: Positives = 50, Negatives = 7
# Model 6: Positives = 43, Negatives = 14
# Model 7: Positives = 48, Negatives = 9
# Model 8: Positives = 51, Negatives = 6
# Model 9: Positives = 50, Negatives = 7
# Model 10: Positives = 50, Negatives = 7
# Model 11: Positives = 51, Negatives = 6
# Model 12: Positives = 46, Negatives = 11
# Model 13: Positives = 53, Negatives = 4
# Model 14: Positives = 52, Negatives = 5
# Model 15: Positives = 50, Negatives = 7
# Model 16: Positives = 47, Negatives = 10
# Model 17: Positives = 49, Negatives = 8
# Model 18: Positives = 46, Negatives = 11
# Model 19: Positives = 46, Negatives = 11
# Model 20: Positives = 46, Negatives = 11
# Model 21: Positives = 47, Negatives = 10
# Model 22: Positives = 51, Negatives = 6
# Model 23: Positives = 48, Negatives = 9
# Model 24: Positives = 48, Negatives = 9
# Model 25: Positives = 47, Negatives = 10
# Model 26: Positives = 53, Negatives = 4
# Model 27: Positives = 49, Negatives = 8
# Model 28: Positives = 50, Negatives = 7
# Model 29: Positives = 50, Negatives = 7
# Model 30: Positives = 48, Negatives = 9
# Model 31: Positives = 44, Negatives = 13
# Model 32: Positives = 44, Negatives = 13
# Model 33: Positives = 49, Negatives = 8
# Model 34: Positives = 52, Negatives = 5
# Model 35: Positives = 43, Negatives = 14
# Model 36: Positives = 50, Negatives = 7
# Model 37: Positives = 48, Negatives = 9
# Model 38: Positives = 52, Negatives = 5
# Model 39: Positives = 50, Negatives = 7
# Model 40: Positives = 47, Negatives = 10
# Model 41: Positives = 49, Negatives = 8
# Model 42: Positives = 52, Negatives = 5
# Model 43: Positives = 49, Negatives = 8
# Model 44: Positives = 48, Negatives = 9
# Model 45: Positives = 51, Negatives = 6
# Model 46: Positives = 50, Negatives = 7
# Model 47: Positives = 48, Negatives = 9
# Model 48: Positives = 51, Negatives = 6
# Model 49: Positives = 52, Negatives = 5
# Model 50: Positives = 44, Negatives = 13
#
# Model Predictions Summary:
# Model 1: Positives = 51, Negatives = 6
# Model 2: Positives = 51, Negatives = 6
# Model 3: Positives = 48, Negatives = 9
# Model 4: Positives = 50, Negatives = 7
# Model 5: Positives = 49, Negatives = 8
# Model 6: Positives = 45, Negatives = 12
# Model 7: Positives = 46, Negatives = 11
# Model 8: Positives = 43, Negatives = 14
# Model 9: Positives = 44, Negatives = 13
# Model 10: Positives = 47, Negatives = 10
# Model 11: Positives = 47, Negatives = 10
# Model 12: Positives = 48, Negatives = 9
# Model 13: Positives = 44, Negatives = 13
# Model 14: Positives = 50, Negatives = 7
# Model 15: Positives = 49, Negatives = 8
# Model 16: Positives = 42, Negatives = 15
# Model 17: Positives = 48, Negatives = 9
# Model 18: Positives = 44, Negatives = 13
# Model 19: Positives = 49, Negatives = 8
# Model 20: Positives = 45, Negatives = 12
# Model 21: Positives = 52, Negatives = 5
# Model 22: Positives = 49, Negatives = 8
# Model 23: Positives = 46, Negatives = 11
# Model 24: Positives = 46, Negatives = 11
# Model 25: Positives = 51, Negatives = 6
# Model 26: Positives = 48, Negatives = 9
# Model 27: Positives = 48, Negatives = 9
# Model 28: Positives = 47, Negatives = 10
# Model 29: Positives = 50, Negatives = 7
# Model 30: Positives = 45, Negatives = 12
# Model 31: Positives = 51, Negatives = 6
# Model 32: Positives = 44, Negatives = 13
# Model 33: Positives = 50, Negatives = 7
# Model 34: Positives = 49, Negatives = 8
# Model 35: Positives = 44, Negatives = 13
# Model 36: Positives = 46, Negatives = 11
# Model 37: Positives = 51, Negatives = 6
# Model 38: Positives = 49, Negatives = 8
# Model 39: Positives = 47, Negatives = 10
# Model 40: Positives = 44, Negatives = 13
# Model 41: Positives = 49, Negatives = 8
# Model 42: Positives = 39, Negatives = 18
# Model 43: Positives = 51, Negatives = 6
# Model 44: Positives = 48, Negatives = 9
# Model 45: Positives = 47, Negatives = 10
# Model 46: Positives = 49, Negatives = 8
# Model 47: Positives = 50, Negatives = 7
# Model 48: Positives = 49, Negatives = 8
# Model 49: Positives = 45, Negatives = 12
# Model 50: Positives = 47, Negatives = 10
#
# Model Predictions Summary:
# Model 1: Positives = 49, Negatives = 8
# Model 2: Positives = 48, Negatives = 9
# Model 3: Positives = 49, Negatives = 8
# Model 4: Positives = 48, Negatives = 9
# Model 5: Positives = 47, Negatives = 10
# Model 6: Positives = 50, Negatives = 7
# Model 7: Positives = 50, Negatives = 7
# Model 8: Positives = 50, Negatives = 7
# Model 9: Positives = 50, Negatives = 7
# Model 10: Positives = 48, Negatives = 9
# Model 11: Positives = 49, Negatives = 8
# Model 12: Positives = 46, Negatives = 11
# Model 13: Positives = 48, Negatives = 9
# Model 14: Positives = 49, Negatives = 8
# Model 15: Positives = 43, Negatives = 14
# Model 16: Positives = 50, Negatives = 7
# Model 17: Positives = 48, Negatives = 9
# Model 18: Positives = 48, Negatives = 9
# Model 19: Positives = 45, Negatives = 12
# Model 20: Positives = 46, Negatives = 11
# Model 21: Positives = 44, Negatives = 13
# Model 22: Positives = 48, Negatives = 9
# Model 23: Positives = 50, Negatives = 7
# Model 24: Positives = 50, Negatives = 7
# Model 25: Positives = 47, Negatives = 10
# Model 26: Positives = 48, Negatives = 9
# Model 27: Positives = 46, Negatives = 11
# Model 28: Positives = 52, Negatives = 5
# Model 29: Positives = 47, Negatives = 10
# Model 30: Positives = 48, Negatives = 9
# Model 31: Positives = 51, Negatives = 6
# Model 32: Positives = 51, Negatives = 6
# Model 33: Positives = 44, Negatives = 13
# Model 34: Positives = 49, Negatives = 8
# Model 35: Positives = 49, Negatives = 8
# Model 36: Positives = 46, Negatives = 11
# Model 37: Positives = 49, Negatives = 8
# Model 38: Positives = 47, Negatives = 10
# Model 39: Positives = 49, Negatives = 8
# Model 40: Positives = 50, Negatives = 7
# Model 41: Positives = 50, Negatives = 7
# Model 42: Positives = 47, Negatives = 10
# Model 43: Positives = 44, Negatives = 13
# Model 44: Positives = 50, Negatives = 7
# Model 45: Positives = 47, Negatives = 10
# Model 46: Positives = 49, Negatives = 8
# Model 47: Positives = 49, Negatives = 8
# Model 48: Positives = 48, Negatives = 9
# Model 49: Positives = 50, Negatives = 7
# Model 50: Positives = 44, Negatives = 13

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', None)

min_max_results_exp1, percentile_results_exp1, threshold_results_exp1 = apply_labeling_from_spies(csv_output_exp1, mean_score_exp1, percentile_50_exp1, percentile_25_exp1, percentile_75_exp1, min_score_exp1, max_score_exp1)
min_max_results_exp2, percentile_results_exp2, threshold_results_exp2 = apply_labeling_from_spies(csv_output_exp2, mean_score_exp2, percentile_50_exp2, percentile_25_exp2, percentile_75_exp2, min_score_exp2, max_score_exp2)
min_max_results_exp3, percentile_results_exp3, threshold_results_exp3 = apply_labeling_from_spies(csv_output_exp3, mean_score_exp3, percentile_50_exp3, percentile_25_exp3, percentile_75_exp3, min_score_exp3, max_score_exp3)
min_max_results_exp4, percentile_results_exp4, threshold_results_exp4 = apply_labeling_from_spies(csv_output_exp4, mean_score_exp4, percentile_50_exp4, percentile_25_exp4, percentile_75_exp4, min_score_exp4, max_score_exp4)
min_max_results_exp5, percentile_results_exp5, threshold_results_exp5 = apply_labeling_from_spies(csv_output_exp5, mean_score_exp5, percentile_50_exp5, percentile_25_exp5, percentile_75_exp5, min_score_exp5, max_score_exp5)

min_max_all = np.array([
    min_max_results_exp1,
    min_max_results_exp2,
    min_max_results_exp3,
    min_max_results_exp4,
    min_max_results_exp5
])

percentile_all = np.array([
    percentile_results_exp1,
    percentile_results_exp2,
    percentile_results_exp3,
    percentile_results_exp4,
    percentile_results_exp5
])

threshold_all = np.array([
    threshold_results_exp1,
    threshold_results_exp2,
    threshold_results_exp3,
    threshold_results_exp4,
    threshold_results_exp5
])

show_evaluation_results(min_max_all, percentile_all, threshold_all)
# Out:
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                     10
# 1  PseudoNegative                    11                      4
# 2  PseudoPositive                    41                      9
# 3  StrongPositive                     4                     34
#        Label  Threshold (0.5)
# 0  Negative                6
# 1  Positive               51
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     4                      8
# 1  PseudoNegative                     4                      7
# 2  PseudoPositive                    48                     19
# 3  StrongPositive                     1                     23
#        Label  Threshold (0.5)
# 0  Negative                6
# 1  Positive               51
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                      8
# 1  PseudoNegative                    12                      9
# 2  PseudoPositive                    39                     21
# 3  StrongPositive                     5                     19
#        Label  Threshold (0.5)
# 0  Negative                6
# 1  Positive               51
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     1                      9
# 1  PseudoNegative                    12                      7
# 2  PseudoPositive                    43                     12
# 3  StrongPositive                     1                     29
#        Label  Threshold (0.5)
# 0  Negative                7
# 1  Positive               50
#             Label  Min_Max (Using Mean)  Percentile (75-50-25)
# 0  StrongNegative                     0                      7
# 1  PseudoNegative                    11                     10
# 2  PseudoPositive                    45                     13
# 3  StrongPositive                     1                     27
#        Label  Threshold (0.5)
# 0  Negative                6
# 1  Positive               51
# === Min-Max Results ===
#             Label  Min-Max Mean  Min-Max Std
# 0  StrongNegative           1.4     1.356466
# 1  PseudoNegative          10.0     3.033150
# 2  PseudoPositive          43.2     3.124100
# 3  StrongPositive           2.4     1.743560
#
# === Percentile Results ===
#             Label  Percentile Mean  Percentile Std
# 0  StrongNegative              8.4        1.019804
# 1  PseudoNegative              7.4        2.059126
# 2  PseudoPositive             14.8        4.489989
# 3  StrongPositive             26.4        5.122499
#
# === Threshold Results ===
#       Label  Threshold Mean  Threshold Std
# 0  Negative             6.2            0.4
# 1  Positive            50.8            0.4
