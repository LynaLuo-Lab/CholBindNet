# %%
import glob
import os
import shutil

source_dir = "/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5"
dest_dir = "CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5"

# %%
spies = glob.glob(f"{source_dir}/Spies/*.npy")
positive_export_folder = glob.glob(f"{dest_dir}/PositiveWithoutSpies/*.npy")

for spy in spies:
    filename = os.path.basename(spy)
    spy_name = filename[:4]

    for positive in positive_export_folder:
        if spy_name in positive:
            destination_path = f"{dest_dir}/Spies/{os.path.basename(positive)}"
            os.makedirs(os.path.dirname(destination_path), exist_ok=True)
            shutil.move(positive, destination_path)

# %%
validation_set = glob.glob(f"{source_dir}/Validation_Set/*.npy")
positive_export_folder = glob.glob(f"{dest_dir}/PositiveWithoutSpies/*.npy")
unlabeled_export_folder = glob.glob(f"{dest_dir}/UnlabeledWithSpies/*.npy")
combined_export_folder = positive_export_folder + unlabeled_export_folder

print(validation_set[:2])

for val in validation_set:
    filename = os.path.basename(val)
    val = filename[:8]

    for sample in combined_export_folder:
        if val in sample:
            destination_path = f"{dest_dir}/Validation_Set/{os.path.basename(sample)}"
            os.makedirs(os.path.dirname(destination_path), exist_ok=True)
            #print(destination_path)
            shutil.move(sample, destination_path)
# Out:
# ['/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Validation_Set/8CT3-filtered_combined_matrix.npy', '/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Validation_Set/5N2R-f1_combined_matrix.npy']

# %%
test_positive = glob.glob(f"{source_dir}/Test/Positive/*.npy")
positive_export_folder = glob.glob(f"{dest_dir}/PositiveWithoutSpies/*.npy")

print(test_positive[:2])

for positive in test_positive:
    filename = os.path.basename(positive)
    positive = filename[:8]

    for sample in positive_export_folder:
        if positive in sample:
            destination_path = f"{dest_dir}/Test/Positive/{os.path.basename(sample)}"
            os.makedirs(os.path.dirname(destination_path), exist_ok=True)
            #print(destination_path)
            shutil.move(sample, destination_path)
# Out:
# ['/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/7VR7-filtered_combined_matrix.npy', '/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Positive/8SRE-filtered_combined_matrix.npy']

# %%
test_unlabeled = glob.glob(f"{source_dir}/Test/Unlabeled/*.npy")
unlabeled_export_folder = glob.glob(f"{dest_dir}/UnlabeledWithSpies/*.npy")

print(test_unlabeled[:2])

for unlabeled in test_unlabeled:
    filename = os.path.basename(unlabeled)
    unlabeled = filename[:8]

    for sample in unlabeled_export_folder:
        if unlabeled in sample:
            destination_path = f"{dest_dir}/Test/Unlabeled/{os.path.basename(sample)}"
            os.makedirs(os.path.dirname(destination_path), exist_ok=True)
            #print(destination_path)
            shutil.move(sample, destination_path)
# Out:
# ['/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/6M0Z-f4_combined_matrix.npy', '/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/Unlabeled/8V64-f4_combined_matrix.npy']

# %%
test_likely_positive = glob.glob(f"{source_dir}/Test/LikelyPositives/*.npy")
unlabeled_export_folder = glob.glob(f"{dest_dir}/UnlabeledWithSpies/*.npy")

print(test_likely_positive[:2])

for likely_positive in test_likely_positive:
    filename = os.path.basename(likely_positive)
    likely_positive = filename[:8]

    for sample in unlabeled_export_folder:
        if likely_positive in sample:
            destination_path = f"{dest_dir}/Test/LikelyPositives/{os.path.basename(sample)}"
            os.makedirs(os.path.dirname(destination_path), exist_ok=True)
            #print(destination_path)
            shutil.move(sample, destination_path)
# Out:
# ['/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/LikelyPositives/8RVW-f3-positive_combined_matrix.npy', '/home/alexhernandez/transmembranebindingAI/Data/SplitData/Cholesterol/cholesterol-graph-5A_exp5/Test/LikelyPositives/8SR8-f4-positive_combined_matrix.npy']

# %%
spies = glob.glob(f"{dest_dir}/Spies/*.npy")
unlabeled_folder = f"{dest_dir}/UnlabeledWithSpies"

print(spies[0])
print(unlabeled_folder)
for spy in spies:
    destination_path = f"{unlabeled_folder}/{os.path.basename(spy)}"
    shutil.copy(spy, destination_path)
# Out:
# CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/Spies/8SS6-filtered_bipartite_graphs.npy
# CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/UnlabeledWithSpies

# %%
import random

source_folder = f"{dest_dir}/UnlabeledWithSpies"
k_subsets_folder = f"{dest_dir}/k_subsets"

# Make sure the k_subsets folder exists
os.makedirs(k_subsets_folder, exist_ok=True)

# Get the list of all files in the source folder
all_files = os.listdir(source_folder)

# Create 50 directories (k_subsets)
k = 50
for i in range(k):
    subset_folder = os.path.join(k_subsets_folder, f'subset_{i+1}')
    os.makedirs(subset_folder, exist_ok=True)

# Distribute 385 files to each subset 
for i in range(k):
    # Randomly select 385 files for this subset 
    selected_files = random.sample(all_files, k=(385*1))
    
    # Create the subset folder
    subset_folder = os.path.join(k_subsets_folder, f'subset_{i+1}')
    
    # Copy the selected files into the corresponding subset folder
    for file in selected_files:
        src_path = os.path.join(source_folder, file)
        dest_path = os.path.join(subset_folder, file)
        
        # Copy the file
        shutil.copy(src_path, dest_path)
        print(f'Copied {file} to {subset_folder}')

print(f'Finished copying 385 files into each of the {k} subsets.')
# Out:
# Copied 7D77-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7WC7-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7WYX-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7TYA-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6IIV-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7XVF-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7LKP-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7E32-filtered_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6IDF-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9INF-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 5AVU-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7OJ8-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 3N9Y-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8SMV-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7BTS-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7YKD-filtered_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 5IU8-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9E82-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8FHD-filtered_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7VV6-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7E2X-filtered_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7EKP-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8SR8-filtered_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 1N83-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7X22-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8SZA-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7XEM-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8QJF-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8SRG-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8VY7-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9DNW-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7D91-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9J40-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7E32-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7T92-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8IZ4-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 4XPH-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6ZDV-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7P00-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8TW4-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7JV5-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8KCT-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9DXQ-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6LQG-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8JC0-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6M2R-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7DUQ-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 5AW8-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8SS7-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9D19-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6GT3-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8UVC-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8JEZ-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7VL9-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9BR2-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6TLQ-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8Z74-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8GNK-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7EKI-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8C9W-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7PP1-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9J7O-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 5AW4-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6DRZ-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7XT8-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8JQR-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8F1D-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8BJF-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8YN2-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7PXE-f3_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8SRE-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7XVE-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9EAH-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 5IUA-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7WFR-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8IZB-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8EIQ-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7EKI-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8UVI-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 5IU7-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7WC7-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8GN7-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 4BQU-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8WE7-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7R8A-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7WQ3-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8F1D-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7M95-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6OMM-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6PS2-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8V63-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 6WIV-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 9DVL-f2_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8UVE-f1_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8YUV-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8YU7-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 7V0S-f5_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 8CS9-f4_bipartite_graphs.npy to CLR_Ligand_Data/cholesterol-clr_prot_adj-graph-clr_exp5/k_subsets/subset_1
# Copied 